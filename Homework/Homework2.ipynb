# %% [markdown]
# ### Homework 2

# %%
# Import Needed Packages

import pandas as pd
import tweepy
import configparser
import json
import os

# %%
# Save actual key values to a separate '.ini' file for privacy reasons (don't want to directly share my keys with the world)

config = configparser.ConfigParser()
config.read('hw2-config.ini')

API_KEY = config['twitter']['API_KEY']
API_KEY_SECRET = config['twitter']['API_KEY_SECRET']
ACCESS_TOKEN = config['twitter']['ACCESS_TOKEN']
ACCESS_TOKEN_SECRET = config['twitter']['ACCESS_TOKEN_SECRET']

# %%
# Define function to print metadata information for tweets

def printtweetdata(n, ith_tweet, scrapped_data):
    
    d = {"Tweet Scraped":n, "Username": ith_tweet[0], "Description" :ith_tweet[1], "Location": ith_tweet[2], 
         "Following Count":ith_tweet[3], "Follower Count":ith_tweet[4],"Total Tweets":ith_tweet[5], "Retweet Count": ith_tweet[6],
         "Tweet Text": ith_tweet[7],"Hashtags Used":ith_tweet[8]}
         
         
    
    print(f"Tweet Scraped{n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f" Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text: {ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")
    
    scraped_data.append(d)
    
    try:
        if not os.path.isdir('/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Homework'):
            os.mkdir('/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Homework')
        with open(f'/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Homework/hw2-scraped_data-{words}.json', 'w') as outfile:
            json.dump(scraped_data, outfile, indent = 4)
    except:
        print ("An exception occurred")

# %%
# Authentication the account and credentials

auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth)

# %%
# Define function to scrape twitter for data based on 3 different prameters

def scrape(words, numtweet, scrapped_data):
    tweets = tweepy.Cursor(api.search_tweets, q = words, len = 'en',
                          tweet_mode = 'extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    
    i = 1
    
    # Extract various infomration through an iterative process
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
    
        
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
            
            
        ith_tweet = [username, description, location, following,
                   followers, totaltweets, retweetcount, text, hashtext]
        
        printtweetdata(i, ith_tweet, scraped_data)
        i = i+1

# %%
# The user will be able to set the parameters through the 'input()' function

print('Enter hasthag to search for')
words = input()

print('Enter number of tweets to search for')
numtweet = int(input())

scraped_data = []
print('Fetching tweets...')

scrape(words, numtweet, scraped_data)
print('scraping has completed! :)')
# Out:
# Enter hasthag to search for
#  #BTC
# Enter number of tweets to search for
#  500
# Unexpected parameter: len
# Fetching tweets...
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Tweet Scraped1:
# Username:ereyestercrypto
# Description:仮想通貨の価格を10分置きに通知するBOTです。BTC/JPY ETH/JPY XRP/JPY LTC/JPY
# @ereyester
# Location:
#  Following Count:1
# Follower Count:997
# Total Tweets:170617
# Retweet Count:0
# Tweet Text: BTC/JPY = 2930617円
# ETH/JPY = 233895円
# XRP/JPY = 46.451円
# LTC/JPY = 7534.6円
# #ビットコイン #仮想通貨 #BTC #ETH #XRP #LTC
# Hashtags Used:['ビットコイン', '仮想通貨', 'BTC', 'ETH', 'XRP', 'LTC']
# Tweet Scraped2:
# Username:CorbettArnita5
# Description:Never perceive anything as being inevitable or predestined. The only absolute is uncertainty.
# Location:Mexico
#  Following Count:94
# Follower Count:1
# Total Tweets:91
# Retweet Count:485
# Tweet Text: The sun rises once again on the #SeedNation☀️
#
# The whole market is red... but not the $SPR Token🔥
#
# With our liquidity manager, the price maintains a range between $0.95 and $1.10🤯
#
# Do you prefer volatile or stable projects?
#
# 💰100$ Giveaway💰
# RT + tag 3 friends
#
# #p2e #BSC #BTC https://t.co/NdywAxUVx8
# Hashtags Used:['SeedNation']
# Tweet Scraped3:
# Username:Yormeyboss
# Description:
# Location:
#  Following Count:30
# Follower Count:3
# Total Tweets:18
# Retweet Count:2
# Tweet Text: NEW GEM! 💎 @Saudishibtoken
# #SaudiShibaInu #SaudiShiba #Bitcoin #cryptocurrency #Binance #BinanceSmartChain #BSC #BSCGems #crypto #LUNA #BNB #PancakeSwap #btc #ETH #Ethereum #dogecoin #doge #SHIB #SAFEMOON #BabyDoge #ElonMusk #NFTs #CoinMarketCap #SaudiNFT #NFT #altseason #LFG 🚀 https://t.co/rQGvVXarML
# Hashtags Used:['SaudiShibaInu', 'SaudiShiba', 'Bitcoin', 'cryptocurrency', 'Binance', 'BinanceSmartChain', 'BSC', 'BSCGems']
# Tweet Scraped4:
# Username:TattooKingdom2
# Description:
# Location:
#  Following Count:321
# Follower Count:60
# Total Tweets:3750
# Retweet Count:2
# Tweet Text: #BTC or #MATIC ?
# Hashtags Used:['BTC', 'MATIC']
# Tweet Scraped5:
# Username:damounp11358
# Description:Photographer& photojournalist&nftartist&nftcreator
# #nft #nftart #art #nfts #crypto #nftartist #digitalart #nftcommunity #nftcollector #cryptoart #ethereum #cryp
# Location:I don't no
#  Following Count:693
# Follower Count:138
# Total Tweets:1686
# Retweet Count:0
# Tweet Text: To help refugee children in , Turkey
# I am selling eight NFTs for $1,500
# https://t.co/hznP1t5z0z #contemporaryart #nftnews #nftgiveaway #raredigitalart #rarible #btc #cryptonews #nftsstories #digitalartist #digitalcollectibles #defi #modernart #nftmarketplace #design #NFT https://t.co/tm15TbNf19
# Hashtags Used:['contemporaryart', 'nftnews', 'nftgiveaway', 'raredigitalart', 'rarible', 'btc', 'cryptonews', 'nftsstories', 'digitalartist', 'digitalcollectibles', 'defi', 'modernart', 'nftmarketplace', 'design', 'NFT']
# Tweet Scraped6:
# Username:msyclvr_
# Description:；manifesting wins 🍀 pls turn off rts ! free tag ♡
# Location:＊ she / her ｜16.
#  Following Count:187
# Follower Count:8
# Total Tweets:263
# Retweet Count:2907
# Tweet Text: First announce🥳🥳🥳🥳
# Your parrots,coming soon...❤🧡💛
# Stay tunned...
# #MyFrendParrot #MFP #NFTs #Metaverse #liveChat #livecam #P2EGame #NFTGiveaways
# #BSCGEMS #BSC  #Mining #btc #Ethereum #BNB #DeFi #Binance #Crypto #mining  #GEM https://t.co/uxbvgAwqa1
# Hashtags Used:['MyFrendParrot', 'MFP', 'NFTs', 'Metaverse', 'liveChat']
# Tweet Scraped7:
# Username:susyweidner
# Description:living in my dream world 🌍 | golf 🏌️‍♀️ | Cryptos 🪙
# Location:Germany
#  Following Count:1731
# Follower Count:79
# Total Tweets:3413
# Retweet Count:0
# Tweet Text: @Poly_Protocol @sCrypto0x I'm excited🎀
#
# @CelesteEuphemi2 @burtfrances85 @JustinB46587491
#
# #Round #BNB #BUSD #Giveaway #BTC #NFT #ETH #USDT #APE
# Hashtags Used:['Round', 'BNB', 'BUSD', 'Giveaway', 'BTC', 'NFT', 'ETH', 'USDT', 'APE']
# Tweet Scraped8:
# Username:yuugiriawano
# Description:仮想通貨やNFT値上がり率ランキング等をつぶやくBotです。
# ホームページもどうぞご覧ください。
# 様々な金融商品の売買シグナルが無料で見られます。
#
# Please visit my website.
# The real-time NFT ranking is here.
# Location:
#  Following Count:0
# Follower Count:922
# Total Tweets:44663
# Retweet Count:0
# Tweet Text: 2022-08-20 04:00:00
#
# BTCUSD
#
#  60min SHORTLINE Sell 47.5%
#
#  １時間足　短いローソク足 売り 47.5%
#
# 詳しくは https://t.co/cLe1T9gJFk で
#
# BTCJPY5分足もあります
#
# #Bitcoin #ビットコイン #BTC #BTCUSD #BTCUSDT #BTCJPY #仮想通貨 #投資 #Crypto #FX https://t.co/4fPLdjHrFm
# Hashtags Used:['Bitcoin', 'ビットコイン', 'BTC', 'BTCUSD', 'BTCUSDT', 'BTCJPY', '仮想通貨', '投資', 'Crypto', 'FX']
# Tweet Scraped9:
# Username:ReginaldGreenc1
# Description:Collector-Trader-Promoter
# Location:
#  Following Count:274
# Follower Count:28
# Total Tweets:369
# Retweet Count:4592
# Tweet Text: 🔥 Sending 2 x $250 in #BNB to 2 random people who:
#
# ✅ Like &amp; RT
# ✅ Follow @AltCryptoGems &amp; @Rovercrc
#
# Choosing the winners in 3 days with Twitterpicker!
#
# #BTC #Giveaway #ETH #Crypto
# Hashtags Used:['BNB']
# Tweet Scraped10:
# Username:DixonChen1
# Description:Dixon Chen | Investor Relations Manager | 30 years in management and business relations
# Location:New York, NY
#  Following Count:1879
# Follower Count:61
# Total Tweets:3174
# Retweet Count:4592
# Tweet Text: 🔥 Sending 2 x $250 in #BNB to 2 random people who:
#
# ✅ Like &amp; RT
# ✅ Follow @AltCryptoGems &amp; @Rovercrc
#
# Choosing the winners in 3 days with Twitterpicker!
#
# #BTC #Giveaway #ETH #Crypto
# Hashtags Used:['BNB']
# Tweet Scraped11:
# Username:prantokumar
# Description:nothing special
# Location:Mymensingh, Bangladesh
#  Following Count:1343
# Follower Count:76
# Total Tweets:4899
# Retweet Count:217
# Tweet Text: #ADAM computing power  2⃣9⃣6⃣0⃣6⃣5⃣TIB
#
# 🎁5 ppl share $20 ADAM
#
# ✅Like➕RT &amp; Tag 3 friends
# ✅Drop your #BSC address
#
# #Airdrop #Giveaway #BTC #Web3 #ETC #Crypto https://t.co/e9x467vi4Q
# Hashtags Used:['ADAM', 'BSC', 'Airdrop']
# Tweet Scraped12:
# Username:wealthof21M
# Description:Dark Satire/Political Economy Analysis, Austrian Economics, #Bitcoin, comedy of monetary policy, bit of healthcare biz & a dash of culture. Having all the fun.
# Location:Colorado, USA
#  Following Count:1447
# Follower Count:447
# Total Tweets:14751
# Retweet Count:8
# Tweet Text: Just my opinion but the #fed will have to change inflation target to 4%, declare victory, institute QE infinity and YCC (financial repression) to solve the USA debt spiral. psst own #btc
#
# STICKY INFLATION - thks @BearTrapsReport https://t.co/re3kJX3ya3
# Hashtags Used:['fed']
# Tweet Scraped13:
# Username:yuugiriawano
# Description:仮想通貨やNFT値上がり率ランキング等をつぶやくBotです。
# ホームページもどうぞご覧ください。
# 様々な金融商品の売買シグナルが無料で見られます。
#
# Please visit my website.
# The real-time NFT ranking is here.
# Location:
#  Following Count:0
# Follower Count:922
# Total Tweets:44663
# Retweet Count:0
# Tweet Text: 2022-08-20 04:00:00
#
# BTCJPY
#
#  60min SHORTLINE Sell 49.6%
#
#  １時間足　短いローソク足 売り 49.6%
#
# 詳しくは https://t.co/cLe1T9gJFk でBTCJPY5分足もあります
#
# #Bitcoin #ビットコイン #BTC #BTCJPY #仮想通貨 #投資 #Crypto #FX https://t.co/P4vdXis0xj
# Hashtags Used:['Bitcoin', 'ビットコイン', 'BTC', 'BTCJPY', '仮想通貨', '投資', 'Crypto', 'FX']
# Tweet Scraped14:
# Username:annaazimi2
# Description:ای کهنه سرباز زمین    جان جهان ایرانزمین ❤️
# Location:
#  Following Count:531
# Follower Count:813
# Total Tweets:14870
# Retweet Count:17
# Tweet Text: بیتکوین داره می‌ریزه
#
# #btc https://t.co/QRITGBV1np
# Hashtags Used:['btc']
# Tweet Scraped15:
# Username:dimas_adzani20
# Description:You are a special part of my life.
# Location:India
#  Following Count:1777
# Follower Count:67
# Total Tweets:3011
# Retweet Count:4592
# Tweet Text: 🔥 Sending 2 x $250 in #BNB to 2 random people who:
#
# ✅ Like &amp; RT
# ✅ Follow @AltCryptoGems &amp; @Rovercrc
#
# Choosing the winners in 3 days with Twitterpicker!
#
# #BTC #Giveaway #ETH #Crypto
# Hashtags Used:['BNB']
# Tweet Scraped16:
# Username:AstrabitTrading
# Description:A portfolio management system that gives you total freedom & control to trade automatically or manually on multiple exchanges simultaneously, anywhere, anytime.
# Location:USA
#  Following Count:122
# Follower Count:2769
# Total Tweets:981
# Retweet Count:3
# Tweet Text: #ETH #BTC
# #botlife
# The best part about this
# Is that i put in absolutley no work
#
# All automated
#
# gotta love it!
#
# WE have a 250$ giveaway with a BOT so go retweet my pinned post
# must follow
#
# @ElevateTrading
# @AstrabitTrading https://t.co/eX3g6vuyYM
# Hashtags Used:['ETH', 'BTC', 'botlife']
# Tweet Scraped17:
# Username:Angelinn_00
# Description:yeni hesap GT yapılır ✨
# Location:Türkiye
#  Following Count:211
# Follower Count:150
# Total Tweets:5597
# Retweet Count:21
# Tweet Text: 💥💫 #waves
# ♦️$waves simetrik üçgeni kirip re-test de tutunup hedefe giderken #btc çelme taktı. Fake out meydana geldi. Buradan ekleme yaptım..
# 📌yeniden üçgen içine giriyor.
# 💸 Hedef 1; 6.25
# 💸Hedef 2; 7.31
# ♦️Anlık 5.04
# 📌Destek;4.33
# 🛑yatırımım var
# Ytd https://t.co/VebEot5cGE https://t.co/87zlRpUmHB
# Hashtags Used:['waves', 'btc']
# Tweet Scraped18:
# Username:draxzler00
# Description:You must be the change you wish to see in the world.
# Location:Rome, Lazio
#  Following Count:1895
# Follower Count:64
# Total Tweets:5015
# Retweet Count:405
# Tweet Text: Are you Degen enough to be a Punter??🎰
# .
# .
# .
# .
# .
# @Stake @LeylaTwitch @RawDogg209 @Drake @opensea
#  #stake #EPL #MLB #The100 #UFC #premierleague #Drake #crypto #NFT #BTC #ETH #BNB #degenscryptoscanner #degen #Degenmint #DegenMints #degens #twitch #Crypto https://t.co/uEOvSFTTPB
# Hashtags Used:['stake', 'EPL', 'MLB']
# Tweet Scraped19:
# Username:Brandon681018
# Description:dont care sadly
# Location:
#  Following Count:568
# Follower Count:356
# Total Tweets:32914
# Retweet Count:4
# Tweet Text: 🎉Giving away 10m OSRS balance💵
# To qualify you must: like, retweet and comment your rune 365 username in the comment section.
# Not on rune365? Sign up today and receive a free 1M OSRS and 1M RS3
# https://t.co/LRR6m31Ic4👈
# #Runescape #osrs #casino #rune365 #ETH #BTC #LTC
# Hashtags Used:[]
# Tweet Scraped20:
# Username:cryptobotprices
# Description:Bot that tweets every hour the prices of #Bitcoin #Ethereum #Solana #DogeCoin #Cardano #LiteCoin #Monero and #BNB
#
# #HODL
# Location:◻️🔗◻️🔗◻️🔗◻️🔗◻️🔗◻️🔗◻️🔗◻️
#  Following Count:0
# Follower Count:14
# Total Tweets:9290
# Retweet Count:0
# Tweet Text: #BTC Stats 📊📈📉 (last 1h)
#
#  Price : 21383.57 #USDT💵
#  Variation : -0.289% (-61.98USDT💵) 🔴⬇️
#
# #cryptonews #cryptomarket #crypto
# Hashtags Used:['BTC', 'USDT', 'cryptonews', 'cryptomarket', 'crypto']
# Tweet Scraped21:
# Username:Pikach00o
# Description:Everything is good 🤠
# Location:Ahmedabad, India
#  Following Count:3162
# Follower Count:55
# Total Tweets:6036
# Retweet Count:959
# Tweet Text: 🔥Decentralized VC Airdrop is live!🔥
#
# 📢Participate in our Airdrop and earn $10 worth of tokens for doing tasks.
#
# https://t.co/Z848A52wc9
#
# Airdrop rewards will be distributed on September 1 and 10,000 lucky random participants will be rewarded.
# #Airdrops #BTC #Ethereum #Giveaway https://t.co/8YkIrc5K2t
# Hashtags Used:[]
# Tweet Scraped22:
# Username:61Ligo61
# Description:Ne kemik uğruna köpek olduk ne de menfaat uğruna çakal. Biz hayatımız boyunca hep dik durduk.
# KURT KAPANI GRUPLARINA Katılmak istermisin ?? RT & FAV ve FAV
# Location:
#  Following Count:4850
# Follower Count:4562
# Total Tweets:82143
# Retweet Count:21
# Tweet Text: 💥💫 #waves
# ♦️$waves simetrik üçgeni kirip re-test de tutunup hedefe giderken #btc çelme taktı. Fake out meydana geldi. Buradan ekleme yaptım..
# 📌yeniden üçgen içine giriyor.
# 💸 Hedef 1; 6.25
# 💸Hedef 2; 7.31
# ♦️Anlık 5.04
# 📌Destek;4.33
# 🛑yatırımım var
# Ytd https://t.co/VebEot5cGE https://t.co/87zlRpUmHB
# Hashtags Used:['waves', 'btc']
# Tweet Scraped23:
# Username:iluvbitcoins
# Description:Hourly updates of #bitcoin #BTC #BCH #ETH #LTC #XRP #cryptocurrency prices from Australian exchanges. Based on Australian dollars and Sydney time.
# Location:Australia
#  Following Count:7
# Follower Count:247
# Total Tweets:62248
# Retweet Count:0
# Tweet Text: Part 2/2:
#
# Coinjar
# #BTC: $31080
# #ETH: $2474
# #LTC: $80
# #XRP: $0.49
#
# DigitalSurge
# #BTC: $31100
# #ETH: $2722
#
# IndependentReserve
# #BTC: $31235
# #BCH: $174
# #ETH: $2475
# #LTC: $80
# #XRP: $0.49
#
# Swyftx
# #BTC: $31139
# #BCH: $172
# #ETH: $2477
# #LTC: $80
# #XRP: $0.49
# Hashtags Used:['BTC', 'ETH', 'LTC', 'XRP', 'BTC', 'ETH', 'BTC', 'BCH', 'ETH', 'LTC', 'XRP', 'BTC', 'BCH', 'ETH', 'LTC', 'XRP']
# Tweet Scraped24:
# Username:BitomicWhales
# Description:I tweet all #Bitcoin transactions over $25M #USD.
#
# https://t.co/JaklYlO2xd for more crypto alerts.
# Location:
#  Following Count:0
# Follower Count:148
# Total Tweets:27743
# Retweet Count:0
# Tweet Text: Someone just transfered 4582.58 #BTC ($98M USD)!
#
#             https://t.co/nAEzi861Wp
# Hashtags Used:['BTC']
# Tweet Scraped25:
# Username:SimonDixonTwitt
# Description:Left Investment Bank 2006. Launched @BankToTheFuture 2010. Spoke at 1st Bitcoin conference & published 1st #Bitcoin book 2011. Angel Investor 💯+ #BTC Companies
# Location:Global
#  Following Count:186
# Follower Count:80197
# Total Tweets:21370
# Retweet Count:1
# Tweet Text: El CEO de @BankToTheFuture, @SimonDixonTwitt 👨‍💼, sostuvo una reunión con el presidente de El Salvador 🇸🇻, @nayibbukele, donde hablaron de los planes de inversión en #Bitcoin en el país
#
# #ElSalvador  #BTC
#
# https://t.co/lZ7uUYrF8I
# Hashtags Used:[]
# Tweet Scraped26:
# Username:CyberStrategy1
# Description:Solving #Crypto Projects Toughest Challenges w/Strategic Truths on #L1/L2s #DeFi, #NFTs, #GameFi, IR, Big Data, Creating Yield / Liquidity, Culture & #IP!
# Location:Cyber-Domain
#  Following Count:567
# Follower Count:609
# Total Tweets:11847
# Retweet Count:230
# Tweet Text: Ah, the old cheeky pre-merge crypto shakeout I see... I don't expect new lows but most likely a gut-check quick drop, but let's see.
#
# New lows = keep adding (for me) as 2-year risk/reward gets really, really attractive
#
# 50% downside vs possible 10x upside = 20:1 R/R
# #ETH #BTC
# Hashtags Used:[]
# Tweet Scraped27:
# Username:JackSintinon
# Description:
# Location:
#  Following Count:8
# Follower Count:24
# Total Tweets:31
# Retweet Count:4
# Tweet Text: Started on #KNC (before it hit the hot list) with $66.66 just because I thought it was funny that that was the max margin @ 75X
#
# 4hrs later, from my gains I sent $100 #USDTether to 4 random members and did a $400 #AirdropAlert
#
# #btc #eth #doge #shibainu #free #Giveaways #Airdrop https://t.co/Yp0VjkwxW0
# Hashtags Used:['KNC']
# Tweet Scraped28:
# Username:XRP_Promoter
# Description:XRP lover from a long time.
# #XRP #XRPprice
#
# DM for business inquiries/promo.
#
# #sponsored Join the People's Blockchain: https://t.co/xcF6DVNr1L
# Location:Blockchain
#  Following Count:14
# Follower Count:54
# Total Tweets:20951
# Retweet Count:0
# Tweet Text: Currency price update:
#
# $21391 #BTC
# $1701.49 #ETH
#
# #BinanceCoin $286.23 #BNB
# #Mina $0.72119 #Mina
# #PaxGold $1742.3 #PAXG
# #Chain $0.087299 #XCN
# #BitcoinSV $52.39 #BSV
#
# $0.340567 USD #XRP
# €0.339324 EURO
# ¥46.61 JPY
#
# Join the People's Blockchain, link in bio.
# Hashtags Used:['BTC', 'ETH', 'BinanceCoin', 'BNB', 'Mina', 'Mina', 'PaxGold', 'PAXG', 'Chain', 'XCN', 'BitcoinSV', 'BSV', 'XRP']
# Tweet Scraped29:
# Username:TI829
# Description:Dj, YouTuber, Gamer, and Bitcoiner. 
# Location:Unknown
#  Following Count:1992
# Follower Count:531
# Total Tweets:55594
# Retweet Count:0
# Tweet Text: Buenas tardes Bitcoiners! Así está el precio del #Bitcoin, sigue bajando y sigue siendo un excelente momento para invertir, recuerden que entre más bajo este el precio del #BTC mejor, suerte a todos 🍀.
# #BitcoinNews #CryptoNews #BitcoinCrash #cryptos https://t.co/JP5JIXGg4B
# Hashtags Used:['Bitcoin', 'BTC', 'BitcoinNews', 'CryptoNews', 'BitcoinCrash', 'cryptos']
# Tweet Scraped30:
# Username:YalovaGuncelTV
# Description:Yalova'nın İlk ve Tek Tarafsız Güncel Haber Sitesi  info@yalovaguncel.com - WhatsApp İhbar Hattı : https://t.co/SwLKXNt3ew
# Location:Yalova / Merkez / Türkiye
#  Following Count:16
# Follower Count:1226
# Total Tweets:6771
# Retweet Count:0
# Tweet Text: Yatırımcısının Güveni Limanı #Altın'da Son Durum https://t.co/pjOLlrESuC  #Kavga #ÜMRvGS #IBAN #Everton #hekts #AdaletBakanlığı #Türkler #Esenler #Nelson #Okan #Bodrum #Oliveira #vakifbank #Tether #NFT #NFTs #NFTart #NFTarts #ETH #BTC #dolar #Bitcoin
# Hashtags Used:['Altın', 'Kavga', 'ÜMRvGS', 'IBAN', 'Everton', 'hekts', 'AdaletBakanlığı', 'Türkler', 'Esenler', 'Nelson', 'Okan', 'Bodrum', 'Oliveira', 'vakifbank', 'Tether', 'NFT', 'NFTs', 'NFTart', 'NFTarts', 'ETH', 'BTC', 'dolar', 'Bitcoin']
# Tweet Scraped31:
# Username:JackSintinon
# Description:
# Location:
#  Following Count:8
# Follower Count:24
# Total Tweets:31
# Retweet Count:4
# Tweet Text: Started on #KNC (before it hit the hot list) with $66.66 just because I thought it was funny that that was the max margin @ 75X
#
# 4hrs later, from my gains I sent $100 #USDTether to 4 random members and did a $400 #AirdropAlert
#
# #btc #eth #doge #shibainu #free #Giveaways #Airdrop https://t.co/GSGFdrA6fR
# Hashtags Used:['KNC']
# Tweet Scraped32:
# Username:iluvbitcoins
# Description:Hourly updates of #bitcoin #BTC #BCH #ETH #LTC #XRP #cryptocurrency prices from Australian exchanges. Based on Australian dollars and Sydney time.
# Location:Australia
#  Following Count:7
# Follower Count:247
# Total Tweets:62248
# Retweet Count:0
# Tweet Text: Part 1/2:
#
# BTCMarkets
# #BTC: $31189
# #BCH: $170
# #ETH: $2471
# #LTC: $80
# #XRP: $0.49
#
# Coinspot
# #BTC: $31388
# #ETH: $2490
# #LTC: $93
# #XRP: $0.49
#
# Cointree
# #BTC: $30748
# #BCH: $167
# #ETH: $2403
# #LTC: $78
# #XRP: $0.48
# Hashtags Used:['BTC', 'BCH', 'ETH', 'LTC', 'XRP', 'BTC', 'ETH', 'LTC', 'XRP', 'BTC', 'BCH', 'ETH', 'LTC', 'XRP']
# Tweet Scraped33:
# Username:ODBA1556S
# Description:Life is defi //// defi is life
# Location:
#  Following Count:115
# Follower Count:96
# Total Tweets:2327
# Retweet Count:87
# Tweet Text: Looks like it was a busy night for @lifeisdefi!
#
# $FEG keeps building!
#
# @FEGtoken #FEG #FEGtoken
# #DeFi #Crypto #Cryptocurrency #Bitcoin #BTC #Ethereum #ETH #Binance #BSC #BSCGem #100xgem #Shiba #DogeChain #DOGE #DogeCoin #XRP #Altcoins #NFTs #NFT #SmartDeFi #FTW https://t.co/zlIpRbLOTo
# Hashtags Used:['FEG', 'FEGtoken', 'DeFi', 'Crypto']
# Tweet Scraped34:
# Username:dip_wetter
# Description:#Hex | #PulseChain | #PulseX | #Hedron                                                              https://t.co/milszXS7kV
# Location:
#  Following Count:743
# Follower Count:573
# Total Tweets:3200
# Retweet Count:11
# Tweet Text: Met a single mom who forgot that she bought 5k of #BTC and 5k of #ETH in Jan of 2016.
#
# I reminded her of her keys, in which she said they’re in her journal in her attic back home.
#
# Her life will change when she flys back home, calls me, sees her balance, and swaps for $HEX
#
# Wild.
# Hashtags Used:['BTC', 'ETH']
# Tweet Scraped35:
# Username:LivePriceCrypto
# Description:I Tweet the latest #Bitcoin & #Ethereum price and Daily/Weekly Technical Indicators Data every minute.
#
# Developed the 20/03/2022
# Location:
#  Following Count:4
# Follower Count:3222
# Total Tweets:210586
# Retweet Count:0
# Tweet Text: #Bitcoin Last Price $21374 #BTC 🚀
# Weekly Indicators:
# •Pivot Fibonacci:
#  -Support 1: 32076
#  -S2: 22276
#  -S3: 6412
#  -Middle: 47940
#  -Resistance 1: 63804
#
# #Ethereum Last Price $1700 #ETH
# •Pivot:
#  -S1: 1550
#  -S2: 570
#  -M: 3137
#  -R1: 4724
#  -R2: 5704
#
# #Crypto #DeFi
# (6/6)
# 210413
# Hashtags Used:['Bitcoin', 'BTC', 'Ethereum', 'ETH', 'Crypto', 'DeFi']
# Tweet Scraped36:
# Username:Ertan_caspr_34
# Description:Hayatta iki şeyi iyi bileceksin haddini ve değerini...😉
# Location:
#  Following Count:318
# Follower Count:48
# Total Tweets:1052
# Retweet Count:86
# Tweet Text: Çekiliş bir kişiye 50$ (900 TL)
#
# -Beni takip et
# -RT yap, beğen
#
# #Giveaway #btc   #eth #shib #knc #hub #glmr #aca #sand #ldo #op #snx #mana #xrp #doge #floki #dks #bnb   #ht #Binance   #erg #nwc #hot #crv #kmd  #chz #city #lazio #wing #stg #trb #spell #hot #ftt #akita #hamster
# Hashtags Used:['Giveaway', 'btc', 'eth', 'shib', 'knc', 'hub', 'glmr', 'aca', 'sand']
# Tweet Scraped37:
# Username:axion_network
# Description:The world's best staking ecosystem! Up to 47% APR. #Crypto launchpad. #NFT Galaxy stakes. Unique Token Accelerator. This is $AXN
# Location:
#  Following Count:70
# Follower Count:16539
# Total Tweets:3090
# Retweet Count:0
# Tweet Text: All qualifying stakes during this period get an opportunity to win a
# • Laptop
# • iPad
# • Smart Monitor
# as well as Summer Stake benefits!!
#
# Learn more:
# https://t.co/FXOYQ2vdlk
#
# #Bitcoin #NFT #BTC #cryptocurrency #NFTs #ETH #DeFi #NFTCommunity #Ethereum #BSC #Polygon #Axion https://t.co/RToFRfbvzR
# Hashtags Used:['Bitcoin', 'NFT', 'BTC', 'cryptocurrency', 'NFTs', 'ETH', 'DeFi', 'NFTCommunity', 'Ethereum', 'BSC', 'Polygon', 'Axion']
# Tweet Scraped38:
# Username:SIFIT_FOON
# Description:SIFIT FOON
#
# #NFT #BTC #BNB #Airdrop
# Location:
#  Following Count:650
# Follower Count:28
# Total Tweets:1500
# Retweet Count:0
# Tweet Text: @Forfeitio It's a very wonderful project !!!! I feel avant-garde and sharpened sensibility!!!! I'm so happy if you give me this one i'm very very thankyou
#
# #NFT #BTC
#
# @mozoseda11
# @SOLTANSALIMI
# @eaeOwxAS5MGqMKc
# Hashtags Used:['NFT', 'BTC']
# Tweet Scraped39:
# Username:beincrypto_es
# Description:🤯 Últimas noticias #cripto | Contenido de aprendizaje 📚 #DeFi 🚀 Fintech | #Bitcoin | BlockChain 🔗 🤓 Todo lo que necesitas saber sobre el ecosistema #crypto
# Location:Spain & Latam
#  Following Count:1044
# Follower Count:27069
# Total Tweets:23799
# Retweet Count:1
# Tweet Text: El CEO de @BankToTheFuture, @SimonDixonTwitt 👨‍💼, sostuvo una reunión con el presidente de El Salvador 🇸🇻, @nayibbukele, donde hablaron de los planes de inversión en #Bitcoin en el país
#
# #ElSalvador  #BTC
#
# https://t.co/lZ7uUYrF8I
# Hashtags Used:['Bitcoin', 'ElSalvador', 'BTC']
# Tweet Scraped40:
# Username:ssharonguerrer1
# Description:CRYPTO INVESTOR AND NFT enthusiast!
# WAX: .mpla.c.wam
# OpenSea:
# 0x0F2738E20F0b39A748BF24c7fB398dbb1c9454C3
# SOLANA:
# 9c9GridbqJQTyjpq2SjBnHNHvcndZvnwnPjA9X8TxATL
# Location:
#  Following Count:1460
# Follower Count:100
# Total Tweets:2405
# Retweet Count:334
# Tweet Text: 🎁 BIG GIVEAWAY🎁
#
# 1️⃣ ❤️+ RT &amp; Tag 3 FRIENDS
#
# 2️⃣ ⬇️‼️GIVEAWAY LINK‼️⬇️
# https://t.co/uQq2Ye9HwA
# 📌+1500$ Reward Pool
#
# ⏲️End 31 August
#
# #WAXP #WAX #BNB  #SolGiveaway #NFT #Solana #TRON  #Crypto #Giveaways #TRX  #NFTGiveaway #AVAX  #ADA #Cardano #BTC  #P2E #SOL #P2E https://t.co/TsfXA6RuS0
# Hashtags Used:[]
# Tweet Scraped41:
# Username:PUMPnDUMPclub
# Description:All about crypto Merchs
# Location:
#  Following Count:0
# Follower Count:0
# Total Tweets:103
# Retweet Count:0
# Tweet Text: https://t.co/OjmA6AxiA5 #btc #bitcoin #eth #ethereum #ada #cardano #xrp #ripple #doge #dogecoin #litecoin #ltc #trx #tron #cryptocurrency #forex #blockchain #money #crypto #eos #exercise #dogstagram #capeverde #gym #binaryoptions #puppy #philadelphia #motivation #success #shibai https://t.co/ToYOmXYzhj
# Hashtags Used:['btc', 'bitcoin', 'eth', 'ethereum', 'ada', 'cardano', 'xrp', 'ripple', 'doge', 'dogecoin', 'litecoin', 'ltc', 'trx', 'tron', 'cryptocurrency', 'forex', 'blockchain', 'money', 'crypto', 'eos', 'exercise', 'dogstagram', 'capeverde', 'gym', 'binaryoptions', 'puppy', 'philadelphia', 'motivation', 'success', 'shibai']
# Tweet Scraped42:
# Username:EipsteinCarl
# Description:I only created this account for elon Mask (i stole this idea from another account)
# Location:
#  Following Count:151
# Follower Count:24
# Total Tweets:11
# Retweet Count:1
# Tweet Text: In Progress
# [Pos] Current Profit($T)
# #BTC[LONG ] -6.9
# #ETH   [-----] +0.0
# #ADA  [LONG ]-32.3
# #SOL   [LONG ] -7.5
# #XRP   [LONG ]-26.4
# #BNB[LONG ] -1.1
# #DOGE [LONG ] +9.5
# #AVAX [LONG ] -2.7
# #TRX [LONG ] -9.7
# #MATIC [LONG ]+33.5
#
# #Binance
# https://t.co/gC32Ueifoo https://t.co/LFPgBs2COC
# Hashtags Used:['BTC', 'ETH', 'ADA', 'SOL', 'XRP']
# Tweet Scraped43:
# Username:NyaCheche
# Description:Türk'üm, ehl-i İslâm'ım..                                                   Muhsin bakışlı Çatlı yürekli
# Location:
#  Following Count:678
# Follower Count:32
# Total Tweets:364
# Retweet Count:0
# Tweet Text: #btc #bitcoin bu gece 21.900 de kapaticak
# Hashtags Used:['btc', 'bitcoin']
# Tweet Scraped44:
# Username:pikpakpokcom
# Description:𝗖𝗨𝗦𝗧𝗢𝗠 𝗦𝗧𝗜𝗖𝗞𝗘𝗥𝗦/𝗗𝗘𝗖𝗔𝗟𝗦
# Location:
#  Following Count:16
# Follower Count:16
# Total Tweets:716
# Retweet Count:0
# Tweet Text: https://t.co/emc3sZYZ7o #btc #bitcoin #eth #ethereum #ada #cardano #xrp #ripple #doge #dogecoin #litecoin #ltc #trx #tron #cryptocurrency #forex #blockchain #money #crypto #eos #exercise #dogstagram #capeverde #gym #binaryoptions #puppy #philadelphia #motivation #success #shibai https://t.co/B5p23l5nGc
# Hashtags Used:['btc', 'bitcoin', 'eth', 'ethereum', 'ada', 'cardano', 'xrp', 'ripple', 'doge', 'dogecoin', 'litecoin', 'ltc', 'trx', 'tron', 'cryptocurrency', 'forex', 'blockchain', 'money', 'crypto', 'eos', 'exercise', 'dogstagram', 'capeverde', 'gym', 'binaryoptions', 'puppy', 'philadelphia', 'motivation', 'success', 'shibai']
# Tweet Scraped45:
# Username:chimangonegro
# Description:#bitcoin no es dinero ,dinero es el peso la libra las fichas de estancia que hacen los ricos para ser más ricos y los pobres más pobres.
# Location:Mar del Plata, Argentina
#  Following Count:873
# Follower Count:84
# Total Tweets:3446
# Retweet Count:11
# Tweet Text: ⚡️#BTC Giveaway!!!⚡️
# Win 1,000 #Sats, just complete the steps:
#
# 1⃣ Like the original tweet.
# 2⃣ Leave your #Bitcoin  #Lightning address in the comments of the original tweet within the next 48 hours.
#
# 📣Get an extra 500 Sats for retweeting the original tweet as well 🤑
# #giveaway https://t.co/LbaWtysxve
# Hashtags Used:['BTC', 'Sats', 'Bitcoin']
# Tweet Scraped46:
# Username:mehabecapital
# Description:Investors Edge
# https://t.co/GR5dapThro
# Channel: https://t.co/cb15kv333D
# Telegram: https://t.co/rQRrBQmNjU…
# Run Ads https://t.co/WhB0lVYh4t
# Location:Global
#  Following Count:2
# Follower Count:2868
# Total Tweets:286567
# Retweet Count:0
# Tweet Text: FDIC issues cease-and-desist letters to FTX US, other crypto firms over deposit insurance #bitcoin #BTC #crypto via @mehabecapital https://t.co/qE87w81lCj
# Hashtags Used:['bitcoin', 'BTC', 'crypto']
# Tweet Scraped47:
# Username:wildinblue1
# Description:
# Location:On a pale blue dot
#  Following Count:456
# Follower Count:112
# Total Tweets:57
# Retweet Count:0
# Tweet Text: This zesty faucet from @_bitcoiner is making me tweet this to claim my free Lightning sats. ⚡
#
# @boltcoiner unlock me 92c76152-e6fc-4287-9834-081874a0849c
#
# #Bitcoin #BTC #LN #LightningNetwork #boltcoiner
# https://t.co/pqVfe9VqrA
# Hashtags Used:['Bitcoin', 'BTC', 'LN', 'LightningNetwork', 'boltcoiner']
# Tweet Scraped48:
# Username:LakeviewMeta
# Description:Welcome to LakeView Meta, Everyone's MetaVerse
# Location:
#  Following Count:192
# Follower Count:2416
# Total Tweets:1111
# Retweet Count:6
# Tweet Text: 🔥🔥🔥 @TheThinker27 is hosting a Twitter Space with @AlphGenesis and @LakeviewMeta ! 🔥🔥🔥
#
# What an opportunity to learn more about all these projects and have a great discussion. Mark your calendars.✔️
#
# Not something to miss!
#
# #Crypto #CryptoNews #BTC #DeFi #TheThinker $TKR https://t.co/2eXog21Skt
# Hashtags Used:[]
# Tweet Scraped49:
# Username:aahhmmaad54321
# Description:
# Location:
#  Following Count:139
# Follower Count:24
# Total Tweets:396
# Retweet Count:1
# Tweet Text: الانزلاق السعري الذي حصل في #البتكوين هو دليل على ان هناك بيع منظم داخل السوق و ان صناع السوق ليس مهتمين في هذه المناطق ادارة رأس المال و تفعيل الستوب بالوقت الحالي شيئ مهم جدا الرقمي المفصلي بالنسبه لي 20700 #BTC #BITCOIN https://t.co/eixDBS221e
# Hashtags Used:['البتكوين']
# Tweet Scraped50:
# Username:Armagan3Talay1
# Description:Econ- FX trader.
# #xauusd #sp500 #nasdaq #brent #dxy
# Sometimes crypto trend.
# Doğuştan vegan beyanatı vermiş bir birey ve ceset yemenize katlanamiyorum.
# Location:Muratpaşa, Antalya
#  Following Count:142
# Follower Count:217
# Total Tweets:7580
# Retweet Count:0
# Tweet Text: #btc piyasa dominasyonu can çekişiyor, buradan kafa kaldırır ama 10 günde olabilir 2 ayda. Şu an #eth #sol #ltc dominasyon olarak hepsi rahat konumda. Acelesi olmayan,mal toplayan için büyük fırsat. https://t.co/QmBNGjEMit
# Hashtags Used:['btc', 'eth', 'sol', 'ltc']
# Tweet Scraped51:
# Username:ajibola_olatayo
# Description:
# Location:
#  Following Count:113
# Follower Count:16
# Total Tweets:118
# Retweet Count:90
# Tweet Text: KYC is an identity verification process in crypto app, targeted at ensuring and enforcing compliance of “one person, one account,” and kicking off scam accounts, bots/multiple accounts, on the project, so that every asset is held by genuine customers.#BTC #CORE #Ethereum #Crypto https://t.co/KUbzt7BtRJ
# Hashtags Used:[]
# Tweet Scraped52:
# Username:Mehmetk48531839
# Description:Adalet herkesin hakkidir
# Location:
#  Following Count:347
# Follower Count:474
# Total Tweets:49441
# Retweet Count:9
# Tweet Text: Sondk Bitcoin Satmışlar ? Kriptopara'lar Neden Düşüyor Altcoin'lerde Düşüş Teknik Analiz
# #CEEK Binance   META Metaverse
# ALTIN #BTC    #ETH BNB   XRP AVAX     ADA SOL XRP GALA MANA SAND APE AXS GMT SHIB
#  https://t.co/IA1EKfL0jZ @YouTube aracılığıyla
# Hashtags Used:['CEEK']
# Tweet Scraped53:
# Username:dlacityx
# Description:♡˖꒰ᵕ༚ᵕ⑅꒱
# Location:
#  Following Count:4972
# Follower Count:370
# Total Tweets:38723
# Retweet Count:6002
# Tweet Text: 🎁 $100 CASH &amp; 5 WL GIVEAWAY 🎁
#
# 🏆 $100 CASH
# 🏆 5x WL
#
# 🎫
# 1⃣ RT + Like
# 2⃣ Follow me &amp; @ENZA_ETH
# 3⃣ Tag 3 friends
#
# 48Hrs📢
# #ETH #NFT #NFTs #Giveaway #SOL
# #Solana #BTC #Crypto #Ethereum https://t.co/NX9WnB9yD3
# Hashtags Used:['ETH']
# Tweet Scraped54:
# Username:cworldalerts
# Description:Crypto World Alerts | Portal de noticias de Criptomonedas #Bitcoin # Ethereum #Altcoins | Noticias de NFT @nftreviewmarket  | Partners @allmedgroup @beoruscorp
# Location:España
#  Following Count:62
# Follower Count:6411
# Total Tweets:8862
# Retweet Count:0
# Tweet Text: #noticiacrypto #criptomoneda #crypto #newscrypto #btc #eth #ethereum (Noticias de Ethereum Samson Mow critica que la Fusión de ETH facilitará la regulación por parte de gobiernos) - https://t.co/LFgoblVqVH ht ... https://t.co/SiyEp2oL3r
# Hashtags Used:['noticiacrypto', 'criptomoneda', 'crypto', 'newscrypto', 'btc', 'eth', 'ethereum']
# Tweet Scraped55:
# Username:mstafadgnn
# Description:$OCEAN $OOKI
# Location:Konya, Türkiye
#  Following Count:133
# Follower Count:127
# Total Tweets:2755
# Retweet Count:10
# Tweet Text: #btc kısa vadeli hareket beklentilerimi grafik üzerinde belirttim.18.700$ üzerinde kaldığımız sürece bu bearish flaş (ayı bayrağı) oluşumunu görebiliriz.Yaz boyunca tamamlanması sürebilir. https://t.co/XazaKrPxSX
# Hashtags Used:['btc']
# Tweet Scraped56:
# Username:Muratt101
# Description:Kapadokya
# Location:Türkiye
#  Following Count:1897
# Follower Count:1294
# Total Tweets:27660
# Retweet Count:86
# Tweet Text: Çekiliş bir kişiye 50$ (900 TL)
#
# -Beni takip et
# -RT yap, beğen
#
# #Giveaway #btc   #eth #shib #knc #hub #glmr #aca #sand #ldo #op #snx #mana #xrp #doge #floki #dks #bnb   #ht #Binance   #erg #nwc #hot #crv #kmd  #chz #city #lazio #wing #stg #trb #spell #hot #ftt #akita #hamster
# Hashtags Used:['Giveaway', 'btc', 'eth', 'shib', 'knc', 'hub', 'glmr', 'aca', 'sand']
# Tweet Scraped57:
# Username:eddieoz
# Description:Privacidade. Liberdade. Criptografia.
#
# CEO/CTO/Content Creator/Antifluencer
# Não faço recomendação de investimento
#
# https://t.co/DuD16m3OsM
# ⚡eddieoz@sats4.life
# Location:C2056B0C12D579A5B172AB853480FB
#  Following Count:1100
# Follower Count:6387
# Total Tweets:35092
# Retweet Count:0
# Tweet Text: @UnderCrypto_ @OliverMychaell @paiva_zeca É possível comprar comida e até combustível com #btc, e é muito fácil através do Bitrefill.
#
# Tb já fiz viagens internacionais desde 2016 usando apenas bitcoin para tudo. Sempre foi possível e está cada vez mais simples.
#
# A adoção mais ampla é só questão de tempo.
# Hashtags Used:['btc']
# Tweet Scraped58:
# Username:crypt0status
# Description:You can follow the instant status of cryptocurrencies.
# Location:
#  Following Count:3
# Follower Count:34
# Total Tweets:2126
# Retweet Count:0
# Tweet Text: 1️⃣ #Bitcoin live: 21388.8600$ - Change: %-8.61 🔴
#
# 1️⃣ #Ethereum live: 1700.9066$ - Change: %-9.31 🔴
#
# Bonus as much as your investment (Coinbase) https://t.co/SbpSs4s0wh 🟢
#
# 🕑 22:00
#
# #btc #eth #coin #crypto #Etherium
# id: 43727362a9
# Hashtags Used:['Bitcoin', 'Ethereum', 'btc', 'eth', 'coin', 'crypto', 'Etherium']
# Tweet Scraped59:
# Username:MoneyBotBR
# Description:Cotação das principais moedas do mercado
# Location:Atualizado a cada 1 hora
#  Following Count:0
# Follower Count:96
# Total Tweets:8031
# Retweet Count:0
# Tweet Text: 🕐 16:00
#
# Dólar Comercial (#USD):
# R$5,19 | 0,41%
#
# Euro (#EUR):
# R$5,20 | -0,13%
#
# Libra Esterlina (#GBP):
# R$6,13 | -0,58%
#
# Bitcoin (#BTC):
# R$111.513,00 | -7,86%
#
# Peso Argentino (#ARS):
# R$0,04 | 0,26%
#
# Yuan Chinês (#CNY):
# R$0,76 | -0,42%
# Hashtags Used:['USD', 'EUR', 'GBP', 'BTC', 'ARS', 'CNY']
# Tweet Scraped60:
# Username:Mehmetk48531839
# Description:Adalet herkesin hakkidir
# Location:
#  Following Count:347
# Follower Count:474
# Total Tweets:49441
# Retweet Count:17
# Tweet Text: #CEEK Neden Sessiz ?
# Gece gece %10 luk Düşüşün Nedeni Ne?
#
# @CEEK @MarySpio get your head out of the sand ??
#
# #btc #avax #altın #dolar #DolarTL #borsa #kripto #Crypto #altcoin #SHIB #shiba #BONE #Coinbase #usdtry #kriptopara #Ethereum https://t.co/DgfbIlJ0rj
# Hashtags Used:['CEEK', 'btc', 'avax']
# Tweet Scraped61:
# Username:pinar_t_
# Description:🧸Bear or Bull🐂 Which Side are you on ? 🔥 Trend analizi & İchimoku (Çaylak)
# Location:
#  Following Count:256
# Follower Count:1261
# Total Tweets:3123
# Retweet Count:0
# Tweet Text: #btc İPTAL
# Fiyat öyle saçmalıyor ki, destekten long girişim de var  ama ekrana yapıştım çok sinir bozucu :)
#
# Bugünü kapattık artık niye dertsiz başa dert arıyoruz ki 😂 👋🏻 https://t.co/soLIaxIZCa https://t.co/vMnXZCdxV5
# Hashtags Used:['btc']
# Tweet Scraped62:
# Username:Serhat11984635
# Description:Serhat
# Location:
#  Following Count:272
# Follower Count:49
# Total Tweets:5612
# Retweet Count:12
# Tweet Text: 25.000 seviyesine kadar yükseliş, ama 25.250 kırılmadan  yeni yükseliş yok diyen kişi 600/700 bin takipçili bir fenomen olsaydı, yer yerinden oynamıştı.
#
# Yaklaşık 4000 dolar kârda takipçilerim. 🎯🎯🎯
#
# Ama her zamanki gibi 50-60 beğeni. ☺️
#
# #Btc #Bitcoin #Crypto https://t.co/egvChoX6Jw
# Hashtags Used:[]
# Tweet Scraped63:
# Username:yuugiriawano
# Description:仮想通貨やNFT値上がり率ランキング等をつぶやくBotです。
# ホームページもどうぞご覧ください。
# 様々な金融商品の売買シグナルが無料で見られます。
#
# Please visit my website.
# The real-time NFT ranking is here.
# Location:
#  Following Count:0
# Follower Count:922
# Total Tweets:44663
# Retweet Count:0
# Tweet Text: 仮想通貨値下がり率ランキング
#
# 2022-08-20 04:00:00
#
# 1位 $BTRST  -96.0
# 2位 $GHST  -92.0
# 3位 $TOKE  -87.0
# 4位 $EXE  -75.0
# 5位 $SHIT  -74.0
# 6位 $ORCA  -70.0
# 7位 $FCT2  -67.0
# 8位 $PRINTS  -66.0
# 9位 $PYR  -65.0
# 10位 $LOOKS  -64.0
# (%)
#
# #Bitcoin #BTC #BTCUSD #BTCJPY #Crypto #FX https://t.co/1EyPTpvdIs
# Hashtags Used:['Bitcoin', 'BTC', 'BTCUSD', 'BTCJPY', 'Crypto', 'FX']
# Tweet Scraped64:
# Username:ppucotahio
# Description:WE PLAY TO WIN | LETS GET IT! | WE ARE ONE
# Location:FR
#  Following Count:1811
# Follower Count:52
# Total Tweets:3088
# Retweet Count:4592
# Tweet Text: 🔥 Sending 2 x $250 in #BNB to 2 random people who:
#
# ✅ Like &amp; RT
# ✅ Follow @AltCryptoGems &amp; @Rovercrc
#
# Choosing the winners in 3 days with Twitterpicker!
#
# #BTC #Giveaway #ETH #Crypto
# Hashtags Used:['BNB']
# Tweet Scraped65:
# Username:AkselAnl
# Description:Tam zamanlı kripto yatırımcısı, yarı zamanlı teknik analist. #GAMBO’ya üye olmak için DM 💌🇹🇷❤️🇹🇷
# Location:İstanbul, Ankara, Eskişehir
#  Following Count:150
# Follower Count:224
# Total Tweets:2198
# Retweet Count:0
# Tweet Text: #RUTHITO #SFP #LONG 20x
# https://t.co/uY5qaxfwbI %13,20 5mn ✔️
# https://t.co/EhslrHjlRS ❌
# https://t.co/Vk0KC4eqYT ❌
#
# https://t.co/tW1QZZ6pE1
# #BTC #BNB #ETH #KAVA #DASH #NEAR #LINK #1inch #YFI #YFII #ANKR #dydx #DOGE #SHIB #IOTX #IOTA
# @SamElaIna https://t.co/j4H0BR98xL
# Hashtags Used:['RUTHITO', 'SFP', 'LONG', 'BTC', 'BNB', 'ETH', 'KAVA', 'DASH', 'NEAR', 'LINK', '1inch', 'YFI', 'YFII', 'ANKR', 'dydx', 'DOGE', 'SHIB', 'IOTX', 'IOTA']
# Tweet Scraped66:
# Username:MandatariosA
# Description:
# Location:
#  Following Count:22
# Follower Count:0
# Total Tweets:18
# Retweet Count:92
# Tweet Text: A trusted and secure bitcoin and crypto exchange
# https://t.co/mVU53euHjY
#
# #Bitcoin #BTC #bitcoins
# #BitcoinCash #Crypto #cryptocurrencies #Cryptocurency #cryptomarket #BTCUSDT #BTCs #USDT #Ethereum #metahoms #blockchain #NFTs #NFTCommuntiy #deleteinstagram  #USTC
# #DeleteFacebook
# Hashtags Used:['Bitcoin', 'BTC', 'bitcoins', 'BitcoinCash', 'Crypto']
# Tweet Scraped67:
# Username:Ap0llor0x
# Description:
# Location:
#  Following Count:47
# Follower Count:39
# Total Tweets:989
# Retweet Count:0
# Tweet Text: #Google  #blackrock #samsung #microsoft #paypal #tencent invest in #crypto #nft &amp; #blockchain
#
# Do you think blockchain &amp; crypto is not the future?
#
# Et vous croyez encore que la blockchain et les cryptos ne sont pas le futur ? #bitcoin #btc #Binance https://t.co/T9DihBJGzU
# Hashtags Used:['Google', 'blackrock', 'samsung', 'microsoft', 'paypal', 'tencent', 'crypto', 'nft', 'blockchain', 'bitcoin', 'btc', 'Binance']
# Tweet Scraped68:
# Username:HEXstreamers
# Description:The HEX TV Guide - https://t.co/D9SD7SPEt6 - Earn 38% APY - https://t.co/7gb49wVdXn
# Location:
#  Following Count:2088
# Follower Count:4057
# Total Tweets:11844
# Retweet Count:0
# Tweet Text: Hexologist is live! @Hexologist31
#
# "Will ETHEREUM be FORCED to AIRDROP?" #HEX #Pulsechain #Crypto #BTC #ETH #DeFi #PassiveIncome
#
# YOUTUBE: https://t.co/SSyxjBAnOS
# Hashtags Used:['HEX', 'Pulsechain', 'Crypto', 'BTC', 'ETH', 'DeFi', 'PassiveIncome']
# Tweet Scraped69:
# Username:Crypto_Abo
# Description:م.ميكاترونكس | ماجستير.ادارة اعمال
# محلل |أساسي | فني | كلاسيكي | #العملات_الرقمية
# #Bitcoin
# #Crypto
# #Blockchain
# #NFT
# #NFTs
# العُقاب🦅
# Location:Köln
#  Following Count:530
# Follower Count:60802
# Total Tweets:17308
# Retweet Count:0
# Tweet Text: الاستحواذ
# يستمر بنزيفه
# #btc.d
# #bitcoin #btc #Ethereum https://t.co/sXidosOSHy https://t.co/DTmGdb2cFs
# Hashtags Used:['btc', 'bitcoin', 'btc', 'Ethereum']
# Tweet Scraped70:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:0
# Follower Count:93
# Total Tweets:28357
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1702.17 USD
# #Bitcoin 0.07957184 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped71:
# Username:Mehmetk48531839
# Description:Adalet herkesin hakkidir
# Location:
#  Following Count:347
# Follower Count:474
# Total Tweets:49441
# Retweet Count:11
# Tweet Text: Sondk Bitcoin altcoin'ler Sert Çekilme Geldi? Düşüş Devam edecekmi?Kriptopara Ceek Btc Eth Shıb Luna
# #CEEK Binance   META Metaverse
# ALTIN #BTC    #ETH BNB   XRP AVAX     ADA SOL XRP GALA MANA SAND APE AXS GMT SHIB
#  https://t.co/RidmBnTyWy @YouTube aracılığıyla
# Hashtags Used:['CEEK']
# Tweet Scraped72:
# Username:SoMuchTrains
# Description:Tired of this shit
# Location:
#  Following Count:751
# Follower Count:864
# Total Tweets:1830
# Retweet Count:52
# Tweet Text: GIVEAWAY🎉🚀
#
# 0.4 #ETHEREUM (2 winners will be announced, 0.2 eth each)
#
# -Rt
# -Follow @thecoinswatch
#
# Ends in 24h
# 💰💰💰💰
#
# #ETH #ETHgiveaways #Crypto #CryptoGiveaway #Giveaway #GiveawayAlert  #BTC
# Hashtags Used:['ETHEREUM']
# Tweet Scraped73:
# Username:Lord_Defi22
# Description:#Defi lover, crypto hodler.
# Location:
#  Following Count:5
# Follower Count:58
# Total Tweets:17071
# Retweet Count:0
# Tweet Text: updated price for $QTUM, $XLM, $SOL:
#
# #QTUM $3.409 USD
# #XLM 5.12e-06 #BTC
# #SOL 0.02188 #ETH
#
# I tweet updated prices, follow me to get recent updates.
#
# #cryptocurrency #crypto
# Hashtags Used:['QTUM', 'XLM', 'BTC', 'SOL', 'ETH', 'cryptocurrency', 'crypto']
# Tweet Scraped74:
# Username:coinok
# Description:Fast Crypto Exchange #BTC #Bitcoin #HODL
# Location:
#  Following Count:3283
# Follower Count:10458
# Total Tweets:486894
# Retweet Count:0
# Tweet Text: 1 BTC Price: Bitstamp 21374.00 USD #BTC #Bitcoin 2022-08-19 15:00 https://t.co/A0rCebsHh2
# Hashtags Used:['BTC', 'Bitcoin']
# Tweet Scraped75:
# Username:by_nukorea
# Description:AIを用いて仮想通貨の相場の予想をするbotです。(BTC：1時間ごと)
#
# 中の人　https://t.co/M3Mpf7lZlw
# リンク提供元：@amazonJP様　、@RakutenJP様
#
# このツイートは個人の趣味であり、ツイート内容による運用結果について一切責任を負いません。
# Location:
#  Following Count:1
# Follower Count:2565
# Total Tweets:56801
# Retweet Count:0
# Tweet Text: 現在のビットコインの価格は2926745.0円です。AIにより1時間後の価格は上がると予想されました。なお、前回の予想ははずれ、現在の予測の正答率は52%です。 #ビットコイン #BTC #AI
# Hashtags Used:['ビットコイン', 'BTC', 'AI']
# Tweet Scraped76:
# Username:jencie16
# Description:
# Location:Navotas City
#  Following Count:346
# Follower Count:65
# Total Tweets:24062
# Retweet Count:6002
# Tweet Text: 🎁 $100 CASH &amp; 5 WL GIVEAWAY 🎁
#
# 🏆 $100 CASH
# 🏆 5x WL
#
# 🎫
# 1⃣ RT + Like
# 2⃣ Follow me &amp; @ENZA_ETH
# 3⃣ Tag 3 friends
#
# 48Hrs📢
# #ETH #NFT #NFTs #Giveaway #SOL
# #Solana #BTC #Crypto #Ethereum https://t.co/NX9WnB9yD3
# Hashtags Used:['ETH']
# Tweet Scraped77:
# Username:cRe5520
# Description:The channel breakout trading strategy bot for BitMEX, FTX, Bybit and Binance Futures.
# This account continuously tweets about how the system is working.
# Location:AWS eu-west-1a Ireland Region
#  Following Count:16
# Follower Count:251
# Total Tweets:41100
# Retweet Count:0
# Tweet Text: strategy: 5010HL1h atr20d: 1050.84
#
# 19 Aug 2022 19:00:17 UTC
# 🍓🇸 'Short' 04:00:17 JST
# --- 23617.5  long_entry_trigger
# --- 21813.5  exit_trigger (ent: 23168.5)
#  &gt;  21364.5  last_price $BTC/USD
#
# #BTC/USD perpetual contract on #BitMEX
# Hashtags Used:['BTC', 'BitMEX']
# Tweet Scraped78:
# Username:Saintdolo
# Description:They say its dangerous to be alone because once you get used to how peaceful it is you realize how annoying it is to be around others.
# Location:Neptune LLA〽️ RIPAI💥
#  Following Count:225
# Follower Count:7
# Total Tweets:651
# Retweet Count:405
# Tweet Text: Are you Degen enough to be a Punter??🎰
# .
# .
# .
# .
# .
# @Stake @LeylaTwitch @RawDogg209 @Drake @opensea
#  #stake #EPL #MLB #The100 #UFC #premierleague #Drake #crypto #NFT #BTC #ETH #BNB #degenscryptoscanner #degen #Degenmint #DegenMints #degens #twitch #Crypto https://t.co/uEOvSFTTPB
# Hashtags Used:['stake', 'EPL', 'MLB']
# Tweet Scraped79:
# Username:BitomicWhales
# Description:I tweet all #Bitcoin transactions over $25M #USD.
#
# https://t.co/JaklYlO2xd for more crypto alerts.
# Location:
#  Following Count:0
# Follower Count:148
# Total Tweets:27743
# Retweet Count:0
# Tweet Text: Someone just transfered 3984.05 #BTC ($85M USD)!
#
#             https://t.co/x08E2uiPeH
# Hashtags Used:['BTC']
# Tweet Scraped80:
# Username:BTCPriceUpdate
# Description:Get frequent updates on Bitcoin Price.
# Location:
#  Following Count:5
# Follower Count:674
# Total Tweets:3361
# Retweet Count:0
# Tweet Text: $BTC Price: $21,356
# #Bitcoin #BTC #BitcoinPrice #Crypto https://t.co/Vcrv0oFogn
# Hashtags Used:['Bitcoin', 'BTC', 'BitcoinPrice', 'Crypto']
# Tweet Scraped81:
# Username:PaulDChrisman1
# Description:COO CDII, LLC
#
# Father, pilot, crypto enthusiast
# Location:Nashville
#  Following Count:268
# Follower Count:894
# Total Tweets:1280
# Retweet Count:6
# Tweet Text: 🔥🔥🔥 @TheThinker27 is hosting a Twitter Space with @AlphGenesis and @LakeviewMeta ! 🔥🔥🔥
#
# What an opportunity to learn more about all these projects and have a great discussion. Mark your calendars.✔️
#
# Not something to miss!
#
# #Crypto #CryptoNews #BTC #DeFi #TheThinker $TKR https://t.co/2eXog21Skt
# Hashtags Used:[]
# Tweet Scraped82:
# Username:memo0265
# Description:Hadi bana bin vur bir say...
# Location: Türkiye
#  Following Count:103
# Follower Count:81
# Total Tweets:3071
# Retweet Count:15
# Tweet Text: Aynı #BTC dominans gibi, hisselerden realize edilen kazançlar ufak ufak kriptoya akar. Sadece ABD piyasalarının kısa vade doyum noktasına ulaşmasını beklemek gerek.
# Hashtags Used:['BTC']
# Tweet Scraped83:
# Username:KriptoHavadis_
# Description:Paylaşımlar Yatırım Tavsiyesi Değildir!
# Youtube Kanalımız: https://t.co/VPNTWrDuuS
# Telegram: https://t.co/4vFyjYVkY0
# Haberler için: https://t.co/A5EayYDbK3
# Location:
#  Following Count:16
# Follower Count:11
# Total Tweets:964
# Retweet Count:0
# Tweet Text: Bitcoin Düşerken Balinalar Bu 15 Altcoin’e Koştu! Kripto para piyasası, haberlerden ve teknik analizlerden büyük bir darbe aldı. #kriptopara #bitcoin #btc
#
# https://t.co/Y9WFNWTLJo https://t.co/ovpfZ5lR1s
# Hashtags Used:['kriptopara', 'bitcoin', 'btc']
# Tweet Scraped84:
# Username:CryptoGunner5
# Description:Only hear for Bitcoin
# Location:
#  Following Count:6
# Follower Count:5
# Total Tweets:253
# Retweet Count:2
# Tweet Text: Some are stuck on #BTC FUD and others are making wise #DeFi moves. Which group do you belong to?
#
# #CryptoTwitter  https://t.co/05WxstjTFH👑 https://t.co/JgRATk9Ync
# Hashtags Used:['BTC', 'DeFi', 'CryptoTwitter']
# Tweet Scraped85:
# Username:cryptojohnsmith
# Description:Love CRYPTO💖
# Follow&create a Binance account
# Tip me if you like
# #BTC #ETH #ADA #SOL #XRP #BNB #DOGE #AVAX #TRX #MATIC #Binance #Python
# Refer & Earn on Binance
# Location:
#  Following Count:3237
# Follower Count:2922
# Total Tweets:134949
# Retweet Count:0
# Tweet Text: In Progress
# [Pos] Current Profit($T)
# #BTC[LONG ] +0.0
# #ETH   [LONG ] -2.5
# #ADA  [LONG ] -2.6
# #SOL   [LONG ] -2.4
# #XRP   [LONG ] +6.2
# #BNB[LONG ] +4.2
# #DOGE [LONG ] -0.4
# #AVAX [LONG ]+10.6
# #TRX [LONG ]+12.1
# #MATIC [LONG ] +1.5
#
# #Binance
# https://t.co/gC32Ueziqo https://t.co/BUyAMy4nHU
# Hashtags Used:['BTC', 'ETH', 'ADA', 'SOL', 'XRP', 'BNB', 'DOGE', 'AVAX', 'TRX', 'MATIC', 'Binance']
# Tweet Scraped86:
# Username:moscowtime_xyz
# Description:I'm a bot!
#
# Donate: https://t.co/xJlFhqcKeb · Made by @siim · BLOCKCLOCK is a registered trademark of @Coinkite
# Location:🇷🇺
#  Following Count:258
# Follower Count:219
# Total Tweets:6000
# Retweet Count:0
# Tweet Text: The current block height is 750176.
# For $1, you can buy 4,674 satoshis.
# The price of 1 #BTC is $21,396.
#
# Stats for the last hour:
#
# - Number of blocks mined: 10
# - Newly created coins: 62.5 BTC
# - Number of transactions confirmed: 19491 https://t.co/5YR7lAaG5V
# Hashtags Used:['BTC']
# Tweet Scraped87:
# Username:memo0265
# Description:Hadi bana bin vur bir say...
# Location: Türkiye
#  Following Count:103
# Follower Count:81
# Total Tweets:3071
# Retweet Count:24
# Tweet Text: ABD piyasaları çok iyi gidiyor ancak #Bitcoin ve #kripto piyasası geride kaldı.
#
# 2020 pandemi çöküşünden sonraki dönemde de halving haberlerine rağmen #BTC hisselerden çok çok daha sonra hareket etmişti.
#
# Kriptonun geride kalması normal
# Sabrın sonu selamet
# Hashtags Used:['Bitcoin', 'kripto']
# Tweet Scraped88:
# Username:CryptoBoy6666
# Description:i am a student who is interested in exploring new things.
# Location:
#  Following Count:1
# Follower Count:142
# Total Tweets:12884
# Retweet Count:0
# Tweet Text: Current #Polygon price Alert:
#
# #Matic $0.79312 USD
# #BTC 3.7106765228782636e-05
# #ETH 0.00046656862168362845
#
# Follow for recent Matic price updates
# #altcoin, #crypto, #cryptocurrency
# Hashtags Used:['Polygon', 'Matic', 'BTC', 'ETH', 'altcoin', 'crypto', 'cryptocurrency']
# Tweet Scraped89:
# Username:AnggunVesky
# Description:tetap semangat
# Location:Payakumbuh
#  Following Count:556
# Follower Count:39
# Total Tweets:940
# Retweet Count:0
# Tweet Text: @Calloftextama1 thank you for the opportunity given to us, hopefully this community will continue to progress in the future.
#
# @CryptoAlexx88
# @ekaningsih980
# @mr_dinda
#
# #CRYPTO #NFT #ETH #BTC #BNB #USDT
# Hashtags Used:['CRYPTO', 'NFT', 'ETH', 'BTC', 'BNB', 'USDT']
# Tweet Scraped90:
# Username:0xaiueo
# Description:giveaway hunter🧚🏻‍♀️ ||free tag|| #luwiproof 💜🦄 #VRpaid
# Location:
#  Following Count:4999
# Follower Count:206
# Total Tweets:37834
# Retweet Count:6002
# Tweet Text: 🎁 $100 CASH &amp; 5 WL GIVEAWAY 🎁
#
# 🏆 $100 CASH
# 🏆 5x WL
#
# 🎫
# 1⃣ RT + Like
# 2⃣ Follow me &amp; @ENZA_ETH
# 3⃣ Tag 3 friends
#
# 48Hrs📢
# #ETH #NFT #NFTs #Giveaway #SOL
# ...
# Tweet Scraped467:
# Username:Hitomisozu
# Description:暗号 , アニメ
# Location:
#  Following Count:84
# Follower Count:76
# Total Tweets:308
# Retweet Count:2
# Tweet Text: What is Kalima MainChain?
#
# https://t.co/PqvFvTtY5Y
#
# #kalimablockchain #datacollection #dataintegrity #immutabledata #datamonitization #bitcoin #crypto #cryptocurrency #NFT #NFTcommunity #nfts #ETH #BTC #Web3 https://t.co/UWwD8DGBae
# Hashtags Used:['kalimablockchain', 'datacollection', 'dataintegrity', 'immutabledata']
# Tweet Scraped468:
# Username:dexitPriceBot
# Description:This is a bot for deXit blockchain shows the price and data for $DXT each 5 minutes
# Location:deXit community
#  Following Count:2
# Follower Count:67
# Total Tweets:1216
# Retweet Count:0
# Tweet Text: The current data for #deXit
#
# price 0.0019 USD
# MarkcetCap 0.0 USD
# 24 hour volume 2216.61 USD
# 24 hour change -2.39 %
# Last updated at 2022-08-19 18:52:29.552930
#
# #deXit #deXitArmy #coingecko #coinmarketCap $DXT #crypto #BTC #BNB #ETH
# Hashtags Used:['deXit', 'deXit', 'deXitArmy', 'coingecko', 'coinmarketCap', 'crypto', 'BTC', 'BNB', 'ETH']
# Tweet Scraped469:
# Username:k1mseohee
# Description:(◞‸◟ㆀ) belum bigwin.
# Location:GMT +7
#  Following Count:1149
# Follower Count:42
# Total Tweets:2814
# Retweet Count:6005
# Tweet Text: 🎁 $100 CASH &amp; 5 WL GIVEAWAY 🎁
#
# 🏆 $100 CASH
# 🏆 5x WL
#
# 🎫
# 1⃣ RT + Like
# 2⃣ Follow me &amp; @ENZA_ETH
# 3⃣ Tag 3 friends
#
# 48Hrs📢
# #ETH #NFT #NFTs #Giveaway #SOL
# #Solana #BTC #Crypto #Ethereum https://t.co/NX9WnB9yD3
# Hashtags Used:['ETH']
# Tweet Scraped470:
# Username:Reyhan2007T
# Description:
# Location:
#  Following Count:3530
# Follower Count:140
# Total Tweets:15397
# Retweet Count:6005
# Tweet Text: 🎁 $100 CASH &amp; 5 WL GIVEAWAY 🎁
#
# 🏆 $100 CASH
# 🏆 5x WL
#
# 🎫
# 1⃣ RT + Like
# 2⃣ Follow me &amp; @ENZA_ETH
# 3⃣ Tag 3 friends
#
# 48Hrs📢
# #ETH #NFT #NFTs #Giveaway #SOL
# #Solana #BTC #Crypto #Ethereum https://t.co/NX9WnB9yD3
# Hashtags Used:['ETH']
# Tweet Scraped471:
# Username:ok222ok333
# Description:Single
# Location:
#  Following Count:32
# Follower Count:0
# Total Tweets:70
# Retweet Count:79
# Tweet Text: Colombia Moves To Explore #CBDC, Crypto Daily TV
# #cryptocurrency #bitcoin #crypto #blockchain #btc #forex #money #trading #btc #cryptocurrencies #cryptomarket #BTCUSD https://t.co/ZMLEAAeuTt
# Hashtags Used:['CBDC', 'cryptocurrency', 'bitcoin', 'crypto', 'blockchain', 'btc', 'forex', 'money']
# Tweet Scraped472:
# Username:NASIR_AAG
# Description:Digital marketer
# Location:Africa
#  Following Count:114
# Follower Count:21
# Total Tweets:235
# Retweet Count:4592
# Tweet Text: 🔥 Sending 2 x $250 in #BNB to 2 random people who:
#
# ✅ Like &amp; RT
# ✅ Follow @AltCryptoGems &amp; @Rovercrc
#
# Choosing the winners in 3 days with Twitterpicker!
#
# #BTC #Giveaway #ETH #Crypto
# Hashtags Used:['BNB']
# Tweet Scraped473:
# Username:BobNeedsTowin
# Description:Why are you looking at me? I know that I'm cute 😶‍🌫️
# Location:
#  Following Count:510
# Follower Count:10
# Total Tweets:1983
# Retweet Count:406
# Tweet Text: Are you Degen enough to be a Punter??🎰
# .
# .
# .
# .
# .
# @Stake @LeylaTwitch @RawDogg209 @Drake @opensea
#  #stake #EPL #MLB #The100 #UFC #premierleague #Drake #crypto #NFT #BTC #ETH #BNB #degenscryptoscanner #degen #Degenmint #DegenMints #degens #twitch #Crypto https://t.co/uEOvSFTTPB
# Hashtags Used:['stake', 'EPL', 'MLB']
# Tweet Scraped474:
# Username:JessP123456789
# Description:🐺🇨🇦⚜️crypto|politics|economy|BTC|ETH|Alts ➡️ SaitaPro https://t.co/WIQLsbCJ8v https://t.co/70e5AQvegh https://t.co/Q5NfUEWk0z 😁Saitama OG since july 30th🔳M87🤩
# Location:Québec, Canada
#  Following Count:4977
# Follower Count:2886
# Total Tweets:24683
# Retweet Count:0
# Tweet Text: 😃💥🚀🇨🇦⚜️🐺
# #Saitama ecosystem
# #SaitaPro wallet
# #SaitaSwap listings
# #WeAreSaitama #Crypto
# #SaitaRealty #Wolfcaster
# #SaitamaWolfPack‌‌ #FANGart
# #SaitamaTechnologyLLC $Saita
# #IXP #LuckyRoo #ETH #BTC
# #Kiba #Mandox #BCT #M87 https://t.co/Gu9vCxt6kE
# Hashtags Used:['Saitama', 'SaitaPro', 'SaitaSwap', 'WeAreSaitama', 'Crypto', 'SaitaRealty', 'Wolfcaster', 'SaitamaWolfPack\u200c\u200c', 'FANGart', 'SaitamaTechnologyLLC', 'IXP', 'LuckyRoo', 'ETH', 'BTC', 'Kiba', 'Mandox', 'BCT', 'M87']
# Tweet Scraped475:
# Username:Gmurtaza_GM
# Description:
# Location:Not on mars yet
#  Following Count:194
# Follower Count:56
# Total Tweets:1212
# Retweet Count:2
# Tweet Text: When $BTC breaks the 200 WMA as A Resistance, Everyone said, $BTC Back above 200 WMA. Now #BTC has broken 200 WMA as a Support. No one talks about it.
#
# 200 WMA Currently at $23,033
# Hashtags Used:['BTC']
# Tweet Scraped476:
# Username:Melody59515460
# Description:
# Location:
#  Following Count:186
# Follower Count:21
# Total Tweets:175
# Retweet Count:19
# Tweet Text: If #BTC indeed confirms a breakdown from the 200-week MA...
#
# Then it is possible that a relief bounce into the 200-week MA to flip it into new resistance could take place
#
# The 200-week MA represents the price point of ~$23200
#
# $BTC #Crypto #Bitcoin https://t.co/mZ7jYP9f1L
# Hashtags Used:['BTC']
# Tweet Scraped477:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:0
# Follower Count:93
# Total Tweets:28358
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1700.28 USD
# #Bitcoin 0.0795594442798927 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped478:
# Username:GrijalvaAngele
# Description:Miracles start to happen when you give as much energy to your dreams as you do to your fears.
# Location:Monaco
#  Following Count:91
# Follower Count:4
# Total Tweets:88
# Retweet Count:487
# Tweet Text: The sun rises once again on the #SeedNation☀️
#
# The whole market is red... but not the $SPR Token🔥
#
# With our liquidity manager, the price maintains a range between $0.95 and $1.10🤯
#
# Do you prefer volatile or stable projects?
#
# 💰100$ Giveaway💰
# RT + tag 3 friends
#
# #p2e #BSC #BTC https://t.co/NdywAxUVx8
# Hashtags Used:['SeedNation']
# Tweet Scraped479:
# Username:Pablockcripto
# Description:- Gestor de "Alcral Crypto Asset" en GPM
# - Trader de PA divergencias y Market Data
# - Canal YT y Twitch #pablonariotrader
# - Asesoría y formación en Fab-Invest.
# Location:
#  Following Count:500
# Follower Count:85
# Total Tweets:881
# Retweet Count:0
# Tweet Text: Cuando llevas 1 mes buscando el swing short y posteando memes de osos y el unico dia que no estas en la grafica porque es fiesta nacional, se da el short y te quedas fuera… #cryptocurrency #btc #bitcoin
# Hashtags Used:['cryptocurrency', 'btc', 'bitcoin']
# Tweet Scraped480:
# Username:UmbaRefer
# Description:Wanderlust. Lover. Music. Life.
# Location:CzechRepublic
#  Following Count:668
# Follower Count:86
# Total Tweets:429
# Retweet Count:15
# Tweet Text: Hello everyone, We are giving out $100 in #BITCOIN to 200 random participants.
#
# You can participate by Liking, Retweeting, Following Us and commenting your #BTC Address.
#
# Reward will be sent in 48hrs
#
# #Nfts  #SolanaNFT #BSC #cryptocurrency #Crypto #PiPayment #BB24 #Giveaway
# Hashtags Used:['BITCOIN']
# Tweet Scraped481:
# Username:MM_MoonMouse
# Description:https://t.co/W4Nhv2rGRQ - 1 Million fixed supply
#
# https://t.co/fNIZXwS68h - first web3.0 social network
# Location:
#  Following Count:70
# Follower Count:78
# Total Tweets:655
# Retweet Count:8
# Tweet Text: Why #MillionToken?
#
# ⭐️ 100%  #Web3 compatible.
# ⭐️ Stake &amp; yield farm $MM to earn more MM.
# ⭐️ Founder with over 1.3 Million YouTube subs.
# ⭐️ Thriving community &amp; growing #DAO.
# ⭐️ Available on 6+ #blockchains &amp; 2 CEX.
# ⭐️ 0.00% inflation rate.
#
# #cryptocurrency #mmg #btc https://t.co/2xmAfVWoYo
# Hashtags Used:['MillionToken', 'Web3']
# Tweet Scraped482:
# Username:CryptoTony539
# Description:🔺AVAX🔺🥷Self Declared Chad-Like Individual🥷
# Location:
#  Following Count:1131
# Follower Count:497
# Total Tweets:168
# Retweet Count:0
# Tweet Text: Shorting #btc nice start 😏 https://t.co/OBr0td9xWD
# Hashtags Used:['btc']
# Tweet Scraped483:
# Username:ok222ok333
# Description:Single
# Location:
#  Following Count:32
# Follower Count:0
# Total Tweets:70
# Retweet Count:133
# Tweet Text: @elonmusk while your dreaming and getting high !!! we just made the best coin in crypto history!!! wish you good luck, we are coming out with a hydrogen car!!! guess time to retire keep smoking 👑🚀💪🥳👸🏽🐶🎲🧸🧩
# #pmxx #btc #moneywithoutborders https://t.co/nGQV3WG2W6 🧩🧸🎲🐶🤸🏾‍♂️ https://t.co/FGGClTXlrD
# Hashtags Used:[]
# Tweet Scraped484:
# Username:Melody59515460
# Description:
# Location:
#  Following Count:186
# Follower Count:21
# Total Tweets:175
# Retweet Count:32
# Tweet Text: After successfully retest the 200-week MA on weak buy-side volume, #BTC has now broken down from this support
#
# Weekly Close below the 200-week MA will confirm the breakdown
#
# $BTC #Crypto #Bitcoin https://t.co/cfI70n9Ud5
# Hashtags Used:['BTC']
# Tweet Scraped485:
# Username:cryptoking9678
# Description:Crypto 🚀🚀🚀
# Location:
#  Following Count:1287
# Follower Count:39
# Total Tweets:1685
# Retweet Count:963
# Tweet Text: 🔥Decentralized VC Airdrop is live!🔥
#
# 📢Participate in our Airdrop and earn $10 worth of tokens for doing tasks.
#
# https://t.co/Z848A52wc9
#
# Airdrop rewards will be distributed on September 1 and 10,000 lucky random participants will be rewarded.
# #Airdrops #BTC #Ethereum #Giveaway https://t.co/8YkIrc5K2t
# Hashtags Used:[]
# Tweet Scraped486:
# Username:Lord_Defi22
# Description:#Defi lover, crypto hodler.
# Location:
#  Following Count:5
# Follower Count:58
# Total Tweets:17072
# Retweet Count:0
# Tweet Text: updated price for $EOS, $XLM, $MATIC:
#
# #EOS $1.309 USD
# #XLM 5.11e-06 #BTC
# #MATIC 0.0004662 #ETH
#
# I tweet updated prices, follow me to get recent updates.
#
# #cryptocurrency #crypto
# Hashtags Used:['EOS', 'XLM', 'BTC', 'MATIC', 'ETH', 'cryptocurrency', 'crypto']
# Tweet Scraped487:
# Username:Melody59515460
# Description:
# Location:
#  Following Count:186
# Follower Count:21
# Total Tweets:175
# Retweet Count:10
# Tweet Text: $FET experiences a picture-perfect rejection from the red resistance after that +30% move
#
# #FET has now revisited the green support for another retest
#
# At this stage, FET needs to Weekly Close inside the green area if FET is to try to rebound to red again
#
# #BTC #Crypto #Bitcoin https://t.co/ytTXpvN4qu https://t.co/pmwebaFRar
# Hashtags Used:['FET']
# Tweet Scraped488:
# Username:Nooldunki
# Description:Memurr
# Location:
#  Following Count:1008
# Follower Count:78
# Total Tweets:6754
# Retweet Count:9
# Tweet Text: #Bitcoin'in max 20.700'e kadar düşüp oradan tepki alması lazım.
#
# Sonrasında 26-28k bölgesini hedefler ama söylediğim gibi tepki alması şart..
#
# #btc
# Hashtags Used:['Bitcoin']
# Tweet Scraped489:
# Username:ok222ok333
# Description:Single
# Location:
#  Following Count:32
# Follower Count:0
# Total Tweets:70
# Retweet Count:815
# Tweet Text: The https://t.co/5i2i29uZn5 liquid indicater on our pmxx token
# https://t.co/ac6Rc4BleX
# Go read why ? Pmxx is one of the strongest 💪 coins world wide
# and all done in 2 weeks
# 🐶🌋🤸🏾‍♂️🧩🧸🎲💪🚀👑🌞🥂👸🏽🥳😍❤🦄
#
# #BTC #moneywithoutborders #MBMX #PeoplesMoney #metalbackedmoney #dude https://t.co/3kExphOZ4a
# Hashtags Used:[]
# Tweet Scraped490:
# Username:Melody59515460
# Description:
# Location:
#  Following Count:186
# Follower Count:21
# Total Tweets:175
# Retweet Count:23
# Tweet Text: New edition of the Rekt Capital Newsletter is out now 🔥
#
# "Macro Altcoin Market Analysis"
#
# This newsletter features charts and analysis on 7 Altcoins including $ETH, $MATIC, $NEAR, $REN, $THETA, $LINK, $DOT
#
# Sign up for $14 a month:
#
# https://t.co/S8FuwxOwfQ
#
# #BTC #Crypto #Bitcoin
# Hashtags Used:[]
# Tweet Scraped491:
# Username:helin_yollarda
# Description:
# Location:Dip
#  Following Count:820
# Follower Count:999
# Total Tweets:3219
# Retweet Count:21
# Tweet Text: 💥💫 #waves
# ♦️$waves simetrik üçgeni kirip re-test de tutunup hedefe giderken #btc çelme taktı. Fake out meydana geldi. Buradan ekleme yaptım..
# 📌yeniden üçgen içine giriyor.
# 💸 Hedef 1; 6.25
# 💸Hedef 2; 7.31
# ♦️Anlık 5.04
# 📌Destek;4.33
# 🛑yatırımım var
# Ytd https://t.co/VebEot5cGE https://t.co/87zlRpUmHB
# Hashtags Used:['waves', 'btc']
# Tweet Scraped492:
# Username:BitSwings
# Description:Free Bitcoin Trading Dashboard https://t.co/5EIWdd9JmH
#
# Join the Telegram free chat!
#
# https://t.co/ZOy5jU9SGR
# Location:
#  Following Count:197
# Follower Count:708
# Total Tweets:116186
# Retweet Count:0
# Tweet Text: [1D] #Bitcoin market is weakly trending down current momentum suggests the market is neutral. #stocks #btc #stockmarket visit: https://t.co/yuSljvM9Fq for more!
# Hashtags Used:['Bitcoin', 'stocks', 'btc', 'stockmarket']
# Tweet Scraped493:
# Username:yucelgr
# Description:I’m not a Democrat.
# I’m not a Republican.
# I’m a freedom maximalist.
#
# https://t.co/DMK8LnDHCp
#
#  #kripto
# Location:İzmir, Türkiye
#  Following Count:165
# Follower Count:9
# Total Tweets:100
# Retweet Count:0
# Tweet Text: Günlük kapanışa dikkat 🟢🟢
#
# #btc
# Hashtags Used:['btc']
# Tweet Scraped494:
# Username:Melody59515460
# Description:
# Location:
#  Following Count:186
# Follower Count:21
# Total Tweets:175
# Retweet Count:14
# Tweet Text: $FET has rallied 30% since the Altcoin Watchlist shared earlier this month in the Rekt Capital Newsletter
#
# #FET successfully retested green as support before launching to the red resistance
#
# Sign up for new Altcoins coming tomorrow:
#
# https://t.co/6D0cB8N56X
#
# #BTC #Crypto #Bitcoin https://t.co/N8aJ6a8w3M https://t.co/bXhFOTbO7y
# Hashtags Used:['FET']
# Tweet Scraped495:
# Username:mvp__shaq
# Description:updating
# Location:
#  Following Count:721
# Follower Count:346
# Total Tweets:4340
# Retweet Count:12
# Tweet Text: #Breaknews🔥🔥
# @Pito_Go is a Power house in the picoin utilities, You can travel all over the world using their logistics. Guess what 🥴🥴. It is 100% Picoin payment
# Who is excited like me🕺💃💃💃🕺🕺
# #PiCoin
# #Pipayments #piconverter #picoreteam #BTC #shibainu #EthereumMerge https://t.co/ObAY9PgqZN
# Hashtags Used:['Breaknews']
# Tweet Scraped496:
# Username:moniosaaja
# Description:Int.high R/R oil and gas stocks.
# #TXP #PTAL #MAHA_A #SOUC #AOI #VLE #SEI #AXL #EOG #GASX #SKRR Leveraging with commodities if bored. No advices here.
# Location:
#  Following Count:150
# Follower Count:334
# Total Tweets:934
# Retweet Count:0
# Tweet Text: @UnchartedFx #btc hodlers say you draw it wrong!
# Hashtags Used:['btc']
# Tweet Scraped497:
# Username:Melody59515460
# Description:
# Location:
#  Following Count:186
# Follower Count:21
# Total Tweets:175
# Retweet Count:36
# Tweet Text: #BTC is dipping right now as part of a potential technical retest of previous resistance
#
# $BTC #Crypto #Bitcoin https://t.co/quL4gaM2nG https://t.co/zrqzIbCvp2
# Hashtags Used:['BTC', 'Crypto', 'Bitcoin']
# Tweet Scraped498:
# Username:IluminatisCoin
# Description:The most reliable financial platform on the market with passive earnings for each transaction and direct payments to your wallet.
# Location:
#  Following Count:1
# Follower Count:2
# Total Tweets:7
# Retweet Count:0
# Tweet Text: You can receive profits by making investments 🪙💸
#
# Start investment 🙌👉 https://t.co/Y4aQJEh6kz
#
# Get profit now!
#
# © ILUMINATISCOIN
#
# #crypto #bitcoin #cryptocurrency #blockchain #btc #ethereum #money #forex #trading #entrepreneur #bitcoinmining https://t.co/LCuYIgjUFH
# Hashtags Used:['crypto', 'bitcoin', 'cryptocurrency', 'blockchain', 'btc', 'ethereum', 'money', 'forex', 'trading', 'entrepreneur', 'bitcoinmining']
# Tweet Scraped499:
# Username:ISS828EI
# Description:
# Location:
#  Following Count:273
# Follower Count:41
# Total Tweets:459
# Retweet Count:217
# Tweet Text: The main event this week is the US inflation data on Wednesday 10 August. Until that time, I do not recommend you to believe in any breakdowns and breakthroughs of any levels. The market is twitching on rumors and it will twitch for a couple more days. 1/2 #btc #crypto https://t.co/JF43oW0QeD
# Hashtags Used:[]
# Tweet Scraped500:
# Username:CryptoFarmerAy
# Description:An Economics graduate, a #crypto enthusiast with trading skill & competence in crypto price prediction based on TA. We either #win or we #learn. 🥰
# Location:
#  Following Count:379
# Follower Count:391
# Total Tweets:1495
# Retweet Count:0
# Tweet Text: @LadyofCrypto1 #NASDAQ is forming an inverse head &amp; shoulder pattern. A price reversal is taking place and this will lead to a dive in price of #Crypto assets.
# #BTC , #ETH and #Altcoins are already taking a bite. 🙄 https://t.co/YqvCcM0v3y
# Hashtags Used:['NASDAQ', 'Crypto', 'BTC', 'ETH', 'Altcoins']
# scraping has completed! :)

# %%
jsondata = pd.read_json('/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Homework/hw2-scraped_data.json')

jsondata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tweet Scraped    500 non-null    int64
#  1   Username         500 non-null    object
#  2   Description      500 non-null    object
#  3   Location         500 non-null    object
#  4   Following Count  500 non-null    int64
#  5   Follower Count   500 non-null    int64
#  6   Total Tweets     500 non-null    int64
#  7   Retweet Count    500 non-null    int64
#  8   Tweet Text       500 non-null    object
#  9   Hashtags Used    500 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 39.2+ KB

# %%
jsondata.head()
# Out:
#    Tweet Scraped         Username  \
# 0              1  ereyestercrypto
# 1              2   CorbettArnita5
# 2              3       Yormeyboss
# 3              4   TattooKingdom2
# 4              5     damounp11358
#
#                                          Description    Location  \
# 0  仮想通貨の価格を10分置きに通知するBOTです。BTC/JPY ETH/JPY XRP/JP...
# 1  Never perceive anything as being inevitable or...      Mexico
# 2
# 3
# 4  Photographer& photojournalist&nftartist&nftcre...  I don't no
#
#    Following Count  Follower Count  Total Tweets  Retweet Count  \
# 0                1             997        170617              0
# 1               94               1            91            485
# 2               30               3            18              2
# 3              321              60          3750              2
# 4              693             138          1686              0
#
#                                           Tweet Text  \
# 0  BTC/JPY = 2930617円 \nETH/JPY = 233895円 \nXRP/J...
# 1  The sun rises once again on the #SeedNation☀️\...
# 2  NEW GEM! 💎 @Saudishibtoken\n#SaudiShibaInu #Sa...
# 3                                   #BTC or #MATIC ?
# 4  To help refugee children in , Turkey\nI am sel...
#
#                                        Hashtags Used
# 0                 [ビットコイン, 仮想通貨, BTC, ETH, XRP, LTC]
# 1                                       [SeedNation]
# 2  [SaudiShibaInu, SaudiShiba, Bitcoin, cryptocur...
# 3                                       [BTC, MATIC]
# 4  [contemporaryart, nftnews, nftgiveaway, raredi...

# %%
jsondata.describe()
# Out:
#        Tweet Scraped  Following Count  Follower Count   Total Tweets  \
# count     500.000000       500.000000      500.000000     500.000000
# mean      250.500000       760.726000     3408.832000   18931.856000
# std       144.481833      1148.712868    40027.704377   46782.323072
# min         1.000000         0.000000        0.000000       1.000000
# 25%       125.750000        27.000000       29.000000     672.000000
# 50%       250.500000       234.500000      101.000000    3315.000000
# 75%       375.250000       931.250000      441.750000   17072.000000
# max       500.000000      5001.000000   879926.000000  486894.000000
#
#        Retweet Count
# count     500.000000
# mean      440.270000
# std      1303.629604
# min         0.000000
# 25%         0.000000
# 50%         4.000000
# 75%       132.250000
# max     10547.000000

# %%
jsondata_loc = jsondata.groupby('Location')

jsondata_loc
