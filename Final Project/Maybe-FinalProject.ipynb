# %% [markdown]
# ### Homework 2

# %%
# Import Needed Packages

import pandas as pd
import tweepy
import configparser
import json
import os

# %%
# Save actual key values to a separate '.ini' file for privacy reasons (don't want to directly share my keys with the world)

config = configparser.ConfigParser()
config.read('hw2-config.ini')

API_KEY = config['twitter']['API_KEY']
API_KEY_SECRET = config['twitter']['API_KEY_SECRET']
ACCESS_TOKEN = config['twitter']['ACCESS_TOKEN']
ACCESS_TOKEN_SECRET = config['twitter']['ACCESS_TOKEN_SECRET']

# %%
# Define function to print metadata information for tweets

def printtweetdata(n, ith_tweet, scrapped_data):
    
    d = {"Tweet Scraped":n, "Username": ith_tweet[0], "Description" :ith_tweet[1], "Location": ith_tweet[2], 
         "Following Count":ith_tweet[3], "Follower Count":ith_tweet[4],"Total Tweets":ith_tweet[5], "Retweet Count": ith_tweet[6],
         "Tweet Text": ith_tweet[7],"Hashtags Used":ith_tweet[8]}
         
         
    
    print(f"Tweet Scraped{n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f" Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text: {ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")
    
    scraped_data.append(d)
    
    try:
        if not os.path.isdir('/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Homework'):
            os.mkdir('/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Homework')
        with open(f'/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Homework/hw2-scraped_data-{words}.json', 'w') as outfile:
            json.dump(scraped_data, outfile, indent = 4)
    except:
        print ("An exception occurred")

# %%
# Authentication the account and credentials

auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth)

# %%
# Define function to scrape twitter for data based on 3 different prameters

def scrape(words, numtweet, scrapped_data):
    tweets = tweepy.Cursor(api.search_tweets, q = words, len = 'en',
                          tweet_mode = 'extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    
    i = 1
    
    # Extract various infomration through an iterative process
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
    
        
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
            
            
        ith_tweet = [username, description, location, following,
                   followers, totaltweets, retweetcount, text, hashtext]
        
        printtweetdata(i, ith_tweet, scraped_data)
        i = i+1

# %%
# Gathering of Data | 1 | Bitcoin Tweets

print('Enter hasthag to search for')
words = input()

print('Enter number of tweets to search for')
numtweet = int(input())

scraped_data = []
print('Fetching tweets...')

scrape(words, numtweet, scraped_data)
print('scraping has completed! :)')
# Out:
# Enter hasthag to search for
#  #ETH
# Enter number of tweets to search for
#  200
# Unexpected parameter: len
# Fetching tweets...
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Tweet Scraped1:
# Username:bhartiya_kishor
# Description:BLOCKCHAIN TECHNOLOGY
# Location:Gujarat, India
#  Following Count:144
# Follower Count:73
# Total Tweets:151
# Retweet Count:3
# Tweet Text: COUNTDOWN TO 2 DAYS! HERE WE GOOOOOO!
#
# Title: A Detour into the Virtual Nation - HyperNation
# Date: 22 August 2022
# Time: 10:00 EST
# Stream: Vimeo
#
# Registration:
# 👉 https://t.co/J5LtBOixCz 👈
# #hypernation #metaverse #blockchain #defi #crypto #btc #eth #dao #nft https://t.co/KhGR9IYHXL
# Hashtags Used:[]
# Tweet Scraped2:
# Username:akakshya12
# Description:crypto lover
# Location:Orissa, India
#  Following Count:1578
# Follower Count:59
# Total Tweets:3653
# Retweet Count:1272
# Tweet Text: 💸 $500 #Giveaway 💸
#
# We'll select 5 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrB7rr https://t.co/sobuxJaIqE
# Hashtags Used:['Giveaway']
# Tweet Scraped3:
# Username:Uwgtoixinhet
# Description:I studied every thing but never topped. But today the toppers of the best universities are my employees.
# Location:Las Vegas, NV, US
#  Following Count:751
# Follower Count:14
# Total Tweets:940
# Retweet Count:3271
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped4:
# Username:BrnTurkiye
# Description:BRN Metaverse Türkiye
#
# Golden Key of the #Metaverse  To purchase: https://t.co/stRWOwO1OD…
# Location:Metaverse
#  Following Count:5
# Follower Count:4630
# Total Tweets:123
# Retweet Count:0
# Tweet Text: Global Borsa listelenmesi için son 6 gün!
#
# https://t.co/xfljvmDPGW
#
# #BRN #Metaverse #Bitcoin #Crypto #eth #bnb #USDT
# Hashtags Used:['BRN', 'Metaverse', 'Bitcoin', 'Crypto', 'eth', 'bnb', 'USDT']
# Tweet Scraped5:
# Username:girum755
# Description:For I know the plans I have for you,” declares the LORD, “plans to prosper you and not to harm you, plans to give you hope & future 🙏🏾 Jeremiah 29:11
# Location:earth 🌎
#  Following Count:252
# Follower Count:1102
# Total Tweets:58016
# Retweet Count:29
# Tweet Text: Complete silence by @DrTedros, when 1000s of health facilities were destroyed by TPLF in #ETH - tells you 1 thing. He is still a TPLF hack exploiting the directorship position at @WHO to score wins for his terrorist orgn. #SackTheDG #UN #bbc https://t.co/lsoaKkb3mc
# Hashtags Used:['ETH']
# Tweet Scraped6:
# Username:dalewillard111
# Description:Follower of NFTs
# Location:In the Jungle
#  Following Count:1259
# Follower Count:219
# Total Tweets:3906
# Retweet Count:178
# Tweet Text: $12.000 in #ETH ( 3 WİNNERS )
#
#         RT • Follow • Like
# Hashtags Used:['ETH']
# Tweet Scraped7:
# Username:0xQueen1st
# Description:🌺Bismillah
# 🌺my old account @Missufee14 @justbeurrcityxx got suspended.
# please don't reroll me~
# 🌺Innalloha khoiru rooziqiin
# Location:Banyumas, Indonesia
#  Following Count:4482
# Follower Count:184
# Total Tweets:35654
# Retweet Count:8097
# Tweet Text: 🎁 $150 CASH &amp; WL GIVEAWAY !🎁
#
# 🏆 $150 CASH
#
# 🏆 5x Whitelist
#
# 1⃣ Follow @KOTJ_NFT
#
# 2⃣ Like &amp; RT
#
# 3⃣ Tag 3 Friends
#
# Ends in 48 hrs ⏳👀
#
# #NFTGiveaway #Giveaway #Airdrop #NFTdrop #SOL #SolanaNFT #ETH https://t.co/qE3nnaOQOz
# Hashtags Used:[]
# Tweet Scraped8:
# Username:YellowStones434
# Description:🔯
# Location:United States
#  Following Count:221
# Follower Count:559
# Total Tweets:358
# Retweet Count:452
# Tweet Text: 🐯Giveaway Announcement 🐯
#
# 🎁 We are giving 1 NFT @alienfrens
#
# To Win 🏆:
#
# 1⃣-FOLLOW @crazytigernft
# 2⃣-RT+ Like + RT pin Post
# 3⃣-Tag3people
#
#  Winner in 48 hours ⏱️
#
# #NFTGiveaway #NFTdrops #eth #nftarti̇st #Crypto #NFTCommunity https://t.co/yMM5enFTtn
# Hashtags Used:[]
# Tweet Scraped9:
# Username:RhhRaulPudd5
# Description:t’s so strange that autumn is so beautiful; yet everything is dying.
# Location:Mom’s basement
#  Following Count:627
# Follower Count:15
# Total Tweets:937
# Retweet Count:3271
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped10:
# Username:Jakline16471668
# Description:
# Location:
#  Following Count:430
# Follower Count:28
# Total Tweets:2172
# Retweet Count:197
# Tweet Text: Angels of anarchy 🔥
#
# Are you a rider ? 👀
#
# #NFTs #NFTGiveaway #nftart #NFTProject #NFTdrop #sneakpeak #eth #NFTCommunity https://t.co/NpSuxcXo79
# Hashtags Used:['NFTs', 'NFTGiveaway', 'nftart', 'NFTProject', 'NFTdrop', 'sneakpeak', 'eth', 'NFTCommunity']
# Tweet Scraped11:
# Username:SallyD1331
# Description:
# Location:
#  Following Count:123
# Follower Count:58
# Total Tweets:5149
# Retweet Count:8
# Tweet Text: @Dawson_Crikit @_NFTsPromoter @cybotz_nft Grab your #crikits before they🦗🚀⭐
# #crikit #crikitarmy #crikitnft #nftcommunity #freespeech #eth https://t.co/OGxpTeUBNg
# Hashtags Used:['crikits', 'crikit', 'crikitarmy', 'crikitnft', 'nftcommunity']
# Tweet Scraped12:
# Username:o9X0ilN
# Description:Just trying to learn more about NFT’s and Crypto. #FOMIE #MYPETHOOLIGAN #METAPRENEUR #ALIENFREN
# Location:
#  Following Count:1129
# Follower Count:26
# Total Tweets:1994
# Retweet Count:637
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @RoyalAlpha_X
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/eWV5Ezrjgn
# Hashtags Used:[]
# Tweet Scraped13:
# Username:nft_serena
# Description:#NFT #BTC #Sol #Avax #Shib
#
# Game & Anime.
# Location:
#  Following Count:3792
# Follower Count:148
# Total Tweets:26853
# Retweet Count:4818
# Tweet Text: 🎁 $100 CASH &amp; WL GIVEAWAY 🎁
#
# Prizes:
# 🏆 $100 CASH
# 🏆 6x WL
# 🎫
# 1️⃣ Follow @GroofStreet &amp; me
# 2️⃣ RT LIKE + TAG 3 FRENS
# 3️⃣ Have notifications on 🔔
#
# ⭐️Bonus Join DC 👇🏻
# https://t.co/Khnm9VHicj
#
# 48Hrs📢
# #GROOFSTREET #NFT #NFTproject #Solana #NFTs #ETH #NFTCommunity https://t.co/zPijUEHZrn
# Hashtags Used:[]
# Tweet Scraped14:
# Username:RAJANKU38217314
# Description:Waking up every day seems a bit excessive.
# Location:Houston, Texas
#  Following Count:149
# Follower Count:5
# Total Tweets:125
# Retweet Count:8097
# Tweet Text: 🎁 $150 CASH &amp; WL GIVEAWAY !🎁
#
# 🏆 $150 CASH
#
# 🏆 5x Whitelist
#
# 1⃣ Follow @KOTJ_NFT
#
# 2⃣ Like &amp; RT
#
# 3⃣ Tag 3 Friends
#
# Ends in 48 hrs ⏳👀
#
# #NFTGiveaway #Giveaway #Airdrop #NFTdrop #SOL #SolanaNFT #ETH https://t.co/qE3nnaOQOz
# Hashtags Used:[]
# Tweet Scraped15:
# Username:Allenrivercity
# Description:HVAC Owner/FamilyMan/NFT/Crypto/Creative@#SelfMadeFromTheBottomToTheTop#
# Location:Danville, VA
#  Following Count:1145
# Follower Count:993
# Total Tweets:3890
# Retweet Count:452
# Tweet Text: 🐯Giveaway Announcement 🐯
#
# 🎁 We are giving 1 NFT @alienfrens
#
# To Win 🏆:
#
# 1⃣-FOLLOW @crazytigernft
# 2⃣-RT+ Like + RT pin Post
# 3⃣-Tag3people
#
#  Winner in 48 hours ⏱️
#
# #NFTGiveaway #NFTdrops #eth #nftarti̇st #Crypto #NFTCommunity https://t.co/yMM5enFTtn
# Hashtags Used:[]
# Tweet Scraped16:
# Username:xll66864
# Description:我喜欢旅游
# Location:
#  Following Count:1203
# Follower Count:25
# Total Tweets:2091
# Retweet Count:637
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @RoyalAlpha_X
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/eWV5Ezrjgn
# Hashtags Used:[]
# Tweet Scraped17:
# Username:SallyD1331
# Description:
# Location:
#  Following Count:123
# Follower Count:58
# Total Tweets:5149
# Retweet Count:8
# Tweet Text: @Dawson_Crikit @SkurpySocial @Crikit_nft I can definitely say that the #crikits in my wallet sure do be multiplying, it must be that incoming #passiveincome ❤🦗❤
# @Crikit_nft #crikit #crikitnft #freespeech #eth #nft #fkcensorship #crikitarmy #nftcommunity
#
# https://t.co/9GAG2XeaaU https://t.co/6sN7RSAAQt
# Hashtags Used:['crikits']
# Tweet Scraped18:
# Username:GhossThea
# Description:Kripto'nun Dehası Ghoss Thea. Crypto Predictor/OnChain TeknikAnalist/Blockchain Genius |#Bitcoin | #ETH | #Metaverse | #kripto | #avax| #altcoin
# Location:
#  Following Count:18
# Follower Count:52557
# Total Tweets:202
# Retweet Count:0
# Tweet Text: Bu gönderimi Beğenip,Retweet yapan sıkı takipçilerim arasından 2 kişiye 1000’er ₺ göndereceğim 🎁🎁🎁
# Cumartesi gününe özel biraz para dağıtalım sıkı takipçilerime destek olsun ✌️
# ⏱Gece 01:45’de kazananları seçerim ve iban isterim
# BOL ŞANSLAR✅🎰
#
# #Binance #ETH #btc #Bitcoin
# Hashtags Used:['Binance', 'ETH', 'btc', 'Bitcoin']
# Tweet Scraped19:
# Username:TimbenGames
# Description:NFT Trader , Rollbot holder
# Location:
#  Following Count:327
# Follower Count:83
# Total Tweets:598
# Retweet Count:112
# Tweet Text: 30,000$ or 20 #ETH ?
# Hashtags Used:['ETH']
# Tweet Scraped20:
# Username:svachyous
# Description:treasure.
# Location:
#  Following Count:2538
# Follower Count:1935
# Total Tweets:25705
# Retweet Count:5609
# Tweet Text: 🎁 $400 CASH &amp; NFT GIVEAWAY ! 🎁
#
# Prize :
# 🏆 $400 CASH
# 🏆 5x NFT
#
# 1⃣Follow me &amp; @Ownic_Official
# 2⃣RT &amp; Like
# 3⃣Tag 3 friends
#
# 48h🕘
# #Solana #SOL #SolanaNFT #ETH
# #Giveaway #NFT $SOL #Crypto #NFTs https://t.co/S7watWs6ss
# Hashtags Used:[]
# Tweet Scraped21:
# Username:NelsonS59800262
# Description:
# Location:Porto, Portugal
#  Following Count:389
# Follower Count:167
# Total Tweets:4203
# Retweet Count:18
# Tweet Text: But wait…. There’s more!!! 🥳🙌🏼🔥
#
# LETS GOOOOOO!!!!!!!! 🥂👏👏👏👏
#
# #GroveToken #BSC #eth #Crypto #chasinghistory #altcoin #Bullish #SAFEMOONSWAP #BitMart https://t.co/iqxJg6ytwk
# Hashtags Used:['GroveToken', 'BSC', 'eth', 'Crypto', 'chasinghistory', 'altcoin']
# Tweet Scraped22:
# Username:0xbigwin127
# Description:mukha akong pera that's why I'm here. 🍀
# (@0x723f got suspended that's why this is a new account, not a multi nor a bot) #salamatite
# Location:ncity
#  Following Count:897
# Follower Count:12
# Total Tweets:2691
# Retweet Count:4819
# Tweet Text: 🎁 $100 CASH &amp; WL GIVEAWAY 🎁
#
# Prizes:
# 🏆 $100 CASH
# 🏆 6x WL
# 🎫
# 1️⃣ Follow @GroofStreet &amp; me
# 2️⃣ RT LIKE + TAG 3 FRENS
# 3️⃣ Have notifications on 🔔
#
# ⭐️Bonus Join DC 👇🏻
# https://t.co/Khnm9VHicj
#
# 48Hrs📢
# #GROOFSTREET #NFT #NFTproject #Solana #NFTs #ETH #NFTCommunity https://t.co/zPijUEHZrn
# Hashtags Used:[]
# Tweet Scraped23:
# Username:Oxekkabigwin
# Description:
# Location:Cikarang, Indonesia
#  Following Count:1164
# Follower Count:39
# Total Tweets:6276
# Retweet Count:682
# Tweet Text: The first #Crypto Project with #MoveToEarn Auto-staking &amp; Auto-compounding with $GMT &amp; $BNB Dividends
#
# Twitter- @RunEarner
#
# 👟Audit &amp; KYC Soon
# 👟Launching Soon
# 👟Website &amp; App Live
#
# #STEPN #NFT #ETH #Move2Earn #m2e #GMT #nft #BTC #BNB  #NFTshill #Altcoins $FITFI #PlayToEarn #P2E https://t.co/KVsRRQTo1J
# Hashtags Used:['Crypto', 'MoveToEarn']
# Tweet Scraped24:
# Username:JacobbSm1th
# Description:Crypto investor since childhood.
#
# $BTC $ETH
# Location:
#  Following Count:37
# Follower Count:117
# Total Tweets:606
# Retweet Count:0
# Tweet Text: Choose only two:
#
# 1 - $QNT
# 2 - $AZERO
# 3 - $DAG
# 4 - $ALBT
# 5 - $MNW
# 6 - $NOIA
# 7 - $TRAC
# 8 - $KDA
# 9 - $SAITO
# 10 - $LAND
#
# #bitcoin #EthereumMerge #ETH #BTC $ETH $BTC
# Hashtags Used:['bitcoin', 'EthereumMerge', 'ETH', 'BTC']
# Tweet Scraped25:
# Username:ahiedz9
# Description:
# Location:Garut, West Java
#  Following Count:380
# Follower Count:59
# Total Tweets:2227
# Retweet Count:103
# Tweet Text: For everyone rt like I  will send you $5000
# Drop your #ETH address https://t.co/8xhhfSJkb8
# Hashtags Used:['ETH']
# Tweet Scraped26:
# Username:LovewithGene
# Description:Engene 🧡 | 3rd yr college | A student of Lazy University | she/her | ISTP-T | #ENFuelUp #yudonote #DhKaldag| #GeneTYga | Manifesting a win a day ♥ |
# Location:Heeseung lang
#  Following Count:957
# Follower Count:110
# Total Tweets:4481
# Retweet Count:682
# Tweet Text: The first #Crypto Project with #MoveToEarn Auto-staking &amp; Auto-compounding with $GMT &amp; $BNB Dividends
#
# Twitter- @RunEarner
#
# 👟Audit &amp; KYC Soon
# 👟Launching Soon
# 👟Website &amp; App Live
#
# #STEPN #NFT #ETH #Move2Earn #m2e #GMT #nft #BTC #BNB  #NFTshill #Altcoins $FITFI #PlayToEarn #P2E https://t.co/KVsRRQTo1J
# Hashtags Used:['Crypto', 'MoveToEarn']
# Tweet Scraped27:
# Username:daukhuonkhonam
# Description:in the sky floated a single cloud
# and on the water a single isle
# Location:AZERBAIJAN
#  Following Count:405
# Follower Count:191
# Total Tweets:430
# Retweet Count:637
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @RoyalAlpha_X
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/eWV5Ezrjgn
# Hashtags Used:[]
# Tweet Scraped28:
# Username:Oxepabion
# Description:Semangat 🫰
#
# 3 akun ditangguhkan 😭 @DastereBolong @Mnuju_Kmenangan @MenangRek
# Location:
#  Following Count:2052
# Follower Count:33
# Total Tweets:11743
# Retweet Count:4819
# Tweet Text: 🎁 $100 CASH &amp; WL GIVEAWAY 🎁
#
# Prizes:
# 🏆 $100 CASH
# 🏆 6x WL
# 🎫
# 1️⃣ Follow @GroofStreet &amp; me
# 2️⃣ RT LIKE + TAG 3 FRENS
# 3️⃣ Have notifications on 🔔
#
# ⭐️Bonus Join DC 👇🏻
# https://t.co/Khnm9VHicj
#
# 48Hrs📢
# #GROOFSTREET #NFT #NFTproject #Solana #NFTs #ETH #NFTCommunity https://t.co/zPijUEHZrn
# Hashtags Used:[]
# Tweet Scraped29:
# Username:Enny098
# Description:Every tree 🌲 grows from its own roots... always be yourself...🤰🤰🤰
#
# #Zawjas
# Location:
#  Following Count:2757
# Follower Count:347
# Total Tweets:5628
# Retweet Count:97
# Tweet Text: First Airdrop to our Early Supporter!
# Rules To Enter:
# 1️⃣Must be follow
# 2️⃣Like and RT
# 3️⃣Tag 3 Friends
# 4️⃣Sumbit Details: https://t.co/g21wZbhaKS
#
# First 1.000 Valid Entry will get 500K $CANTOVI
#
# #Airdrop #Airdrops #Etherum #eth #Giveaway #canto #cryptocurrency #Crypto #bsc #binance https://t.co/QHanjpHBXW
# Hashtags Used:[]
# Tweet Scraped30:
# Username:sleeplesszy
# Description:feel free to unfollow this acc
# Location:
#  Following Count:306
# Follower Count:357
# Total Tweets:4900
# Retweet Count:31
# Tweet Text: 🌍 The Afrikans #NFT is an exclusive collection of 1111 unique art pieces, each representing the rich cultural and ethnic diversities of the African continent.
#
# A journey to revolutionize the robust #web3 ecosystem in the continent.
#
# ⛵️ https://t.co/RArl2dHK1M
#
# #NFTs #ETH #BTC https://t.co/8Zi9JMsR4z
# Hashtags Used:['NFT']
# Tweet Scraped31:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:0
# Follower Count:94
# Total Tweets:29579
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1632.24 USD
# #Bitcoin 0.07676878 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped32:
# Username:mutbaha7
# Description:maverick gui exi biu👩‍⚕️💮
# Location:Ankara, Türkiye
#  Following Count:686
# Follower Count:198
# Total Tweets:1067
# Retweet Count:1271
# Tweet Text: Weekend's here, and we are running a GIVEAWAY to make your weekend bright and awesome! ✨
#
# We can't wait to bring $SHROOM to the #Polygon and #ETH communities 🍄
#
# 🎉50 $MATIC to 5 winners🎉
#
# ♥️ &amp; RT
# Follow @wonderdotgame
# Tag 3 friends
#
# ⏰72 hours!⏰ https://t.co/jnabtMWOp8
# Hashtags Used:[]
# Tweet Scraped33:
# Username:ilteryigit2
# Description:
# Location:
#  Following Count:610
# Follower Count:210
# Total Tweets:15530
# Retweet Count:77
# Tweet Text: Hızlı Etkinlik Zamanı 🎁
#
# 2 Takipçimize 200 TRX 🍀
#
# 24:00’da Açıklanacak 🎁
#
# Şartlar :
#
# - Beni Takip Etmek
#
# - Bu Gönderiyi Beğenmek
#
# - Rt Yapmak
#
# #shiba #Doge #btc #eth #avax #ıcp #ceek
# Hashtags Used:[]
# Tweet Scraped34:
# Username:mc_picker27
# Description:cryptocurrency
# Location:Australia
#  Following Count:75
# Follower Count:16
# Total Tweets:101
# Retweet Count:5160
# Tweet Text: 🔥 Sending 2 x $250 in #BNB to 2 random people who:
#
# ✅ Like &amp; RT
# ✅ Follow @AltCryptoGems &amp; @Rovercrc
#
# Choosing the winners in 3 days with Twitterpicker!
#
# #BTC #Giveaway #ETH #Crypto
# Hashtags Used:['BNB']
# Tweet Scraped35:
# Username:AddressMyemail
# Description:
# Location:
#  Following Count:134
# Follower Count:63
# Total Tweets:794
# Retweet Count:90
# Tweet Text: JUST IN: Massive adoption. Don't miss out. Now is your chance to get in, grab more at this discount price &amp; #HODL for the huge pump.🤝💹
#
# #Bitgert #Brise #Bitgertcommunity #BRC20 #crypto #binance #Huobi #catecoin #shib #doge #btc #eth #sol #blockchain #web3 #Defi #NFTs #altcoin https://t.co/4c85g1e9vV
# Hashtags Used:['HODL']
# Tweet Scraped36:
# Username:yuleiviandrade
# Description:me encanta la aventura extrema., rumbear, disfrutar de la vida
# Location:venezuela
#  Following Count:1461
# Follower Count:132
# Total Tweets:4502
# Retweet Count:161
# Tweet Text: Drop your #ETH wallet address, I’m going to send 4 people some #Ethereum and 5 FREE #NFTs
#
# You must turn notifications &amp; RT | 24 hours⏲️
# Hashtags Used:['ETH', 'Ethereum', 'NFTs']
# Tweet Scraped37:
# Username:KingIvqR
# Description:Crypto Enthusiastic || ARTIST
#  || Ivarthahussla | NFT Collector | #BTC #SOL #ETH #NFTs
# Location:New York, USA
#  Following Count:3066
# Follower Count:829
# Total Tweets:5181
# Retweet Count:58
# Tweet Text: 💎Circle DAO 🤝 PROJECT KAITO 💎
#
# Giving away 2x Spots on here and 10x spots in @intocircledao Discord
#
# To enter:
# 1️⃣Follow @ProjectKaitoNFT @intocircledao
#  &amp; @___mo2000
# 2️⃣Like &amp; RT
# 3️⃣Tag 3 Friends!
#
# ⏰24 Hours
# #WL #ETH #Nftgiveaway #freemint https://t.co/wtSAEATlxv
# Hashtags Used:[]
# Tweet Scraped38:
# Username:JoyFamilyfc
# Description:#BTC  #BNB #SOL $XLM #CafeSwap #StellarFamily
# Traders Family
# success requires struggle and never gives up
# Location:Alseka
#  Following Count:1820
# Follower Count:79
# Total Tweets:1156
# Retweet Count:97
# Tweet Text: First Airdrop to our Early Supporter!
# Rules To Enter:
# 1️⃣Must be follow
# 2️⃣Like and RT
# 3️⃣Tag 3 Friends
# 4️⃣Sumbit Details: https://t.co/g21wZbhaKS
#
# First 1.000 Valid Entry will get 500K $CANTOVI
#
# #Airdrop #Airdrops #Etherum #eth #Giveaway #canto #cryptocurrency #Crypto #bsc #binance https://t.co/QHanjpHBXW
# Hashtags Used:[]
# Tweet Scraped39:
# Username:AlecEchav21
# Description:
# Location:
#  Following Count:492
# Follower Count:568
# Total Tweets:11939
# Retweet Count:18
# Tweet Text: But wait…. There’s more!!! 🥳🙌🏼🔥
#
# LETS GOOOOOO!!!!!!!! 🥂👏👏👏👏
#
# #GroveToken #BSC #eth #Crypto #chasinghistory #altcoin #Bullish #SAFEMOONSWAP #BitMart https://t.co/iqxJg6ytwk
# Hashtags Used:['GroveToken', 'BSC', 'eth', 'Crypto', 'chasinghistory', 'altcoin']
# Tweet Scraped40:
# Username:DglUmaJockey
# Description:The Visnudutas told Yamaraja that Lord Visnu wished him well and had ordered him to free the conditioned souls suffering in hell.
# Location:Metaverse
#  Following Count:592
# Follower Count:18
# Total Tweets:948
# Retweet Count:3272
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped41:
# Username:PythonBot_By_PM
# Description:I am Python Bot Created By @Prathamesh277.
#
# I retweet and like the tweets having these hashtags in them: #100DaysOfCode and #Python.
# Location:REMOTE
#  Following Count:1
# Follower Count:421
# Total Tweets:59065
# Retweet Count:2
# Tweet Text: Get your ticket for MGC1K private #NFT SALE!!!
#
# #NFTs #100DaysOfCode #ETH #MGC1K https://t.co/T5aYalA94p
# Hashtags Used:['NFT', 'NFTs', '100DaysOfCode', 'ETH', 'MGC1K']
# Tweet Scraped42:
# Username:0xsanyeongluck_
# Description:@luckyynabiix_ got sus #noizzy
# Location:sa puso mo
#  Following Count:3661
# Follower Count:50
# Total Tweets:11849
# Retweet Count:8097
# Tweet Text: 🎁 $150 CASH &amp; WL GIVEAWAY !🎁
#
# 🏆 $150 CASH
#
# 🏆 5x Whitelist
#
# 1⃣ Follow @KOTJ_NFT
#
# 2⃣ Like &amp; RT
#
# 3⃣ Tag 3 Friends
#
# Ends in 48 hrs ⏳👀
#
# #NFTGiveaway #Giveaway #Airdrop #NFTdrop #SOL #SolanaNFT #ETH https://t.co/qE3nnaOQOz
# Hashtags Used:[]
# Tweet Scraped43:
# Username:Tihmetabuffy
# Description:I’m flying because I gave everything up that weighed me down.
# Location:No i wont tell you
#  Following Count:2352
# Follower Count:377
# Total Tweets:15352
# Retweet Count:3272
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped44:
# Username:BrnTurkiye
# Description:BRN Metaverse Türkiye
#
# Golden Key of the #Metaverse  To purchase: https://t.co/stRWOwO1OD…
# Location:Metaverse
#  Following Count:5
# Follower Count:4630
# Total Tweets:123
# Retweet Count:7
# Tweet Text: Last 6 days for global exchange listing!
#
# https://t.co/Fe2EJGngi2
#
# #BRN #Metaverse #Bitcoin #Crypto #eth #bnb #USDT
# Hashtags Used:['BRN', 'Metaverse', 'Bitcoin', 'Crypto', 'eth', 'bnb', 'USDT']
# Tweet Scraped45:
# Username:Lord_Defi22
# Description:#Defi lover, crypto hodler.
# Location:
#  Following Count:5
# Follower Count:60
# Total Tweets:18163
# Retweet Count:0
# Tweet Text: updated price for $EOS, $ETH, $TRX:
#
# #EOS $1.287 USD
# #ETH 0.076683 #BTC
# #TRX 4.02e-05 #ETH
#
# I tweet updated prices, follow me to get recent updates.
#
# #cryptocurrency #crypto
# Hashtags Used:['EOS', 'ETH', 'BTC', 'TRX', 'ETH', 'cryptocurrency', 'crypto']
# Tweet Scraped46:
# Username:chrisnuneh
# Description:live ur life to the fullest #AshArmy
# Location:
#  Following Count:1223
# Follower Count:171
# Total Tweets:10805
# Retweet Count:37
# Tweet Text: Some people missed the whole pump of  #Bitcoin from $17,600 to $24,500 &amp; #ETH from $880 to $2,000 because they were bearish.
#
# Now when bitcoin came down to $21,000 they are coming out with tweets like “told you so“
#
# Like bro wtf! you missed 2x on ETH &amp; easy swing trade on #BTC
# Hashtags Used:['Bitcoin', 'ETH']
# Tweet Scraped47:
# Username:Oxluckybigw1n
# Description:#bismilah
# Location:dimana saja aku berada
#  Following Count:1906
# Follower Count:56
# Total Tweets:8232
# Retweet Count:4819
# Tweet Text: 🎁 $100 CASH &amp; WL GIVEAWAY 🎁
#
# Prizes:
# 🏆 $100 CASH
# 🏆 6x WL
# 🎫
# 1️⃣ Follow @GroofStreet &amp; me
# 2️⃣ RT LIKE + TAG 3 FRENS
# 3️⃣ Have notifications on 🔔
#
# ⭐️Bonus Join DC 👇🏻
# https://t.co/Khnm9VHicj
#
# 48Hrs📢
# #GROOFSTREET #NFT #NFTproject #Solana #NFTs #ETH #NFTCommunity https://t.co/zPijUEHZrn
# Hashtags Used:[]
# Tweet Scraped48:
# Username:TeamShakeri
# Description:CyberSecurity / Data analyst 🖥 Founder #LinuxZoneORG CTO https://t.co/okH6nr2YF8 sysadmin , RTs ≠ endorsements @linuxzoneorg
# Location:Toronto, Ontario
#  Following Count:128
# Follower Count:5080
# Total Tweets:348097
# Retweet Count:9
# Tweet Text: @Upgradde6913 @altcryptocom @Crikit_nft Grab your #crikits before they🦗🚀⭐
# #crikit #crikitarmy #crikitnft #nftcommunity #freespeech #eth https://t.co/lLDiCJOyli
# Hashtags Used:['crikits', 'crikit', 'crikitarmy', 'crikitnft', 'nftcommunity']
# Tweet Scraped49:
# Username:wpjyEMDlCn4ZlFp
# Description:
# Location:
#  Following Count:1904
# Follower Count:46
# Total Tweets:2776
# Retweet Count:259
# Tweet Text: Part 2 🍌🏝
# #NFT #NFTCollection #ETH https://t.co/eFBmbwgJhS
# Hashtags Used:['NFT', 'NFTCollection', 'ETH']
# Tweet Scraped50:
# Username:LEWBIGW1NS
# Description:hunter acc and kpop fan 😎
# Location:
#  Following Count:522
# Follower Count:46
# Total Tweets:1553
# Retweet Count:948
# Tweet Text: Providing Liquidity to $Earn YFO📈🤩
#
# 🥂 Start Earn now https://t.co/xGMErvRnDp
#
# 📈Find YFO on Uniswap : https://t.co/51Hvy5KP79…
#
# 💎Find YFO on Pancakeswap :
# https://t.co/8azM9TuF9V…
#
# #Ethereum #ETH #Bscgem #DeFi #NFTCommunity #NFT #farming #BSC https://t.co/0GtJmT8UYW
# Hashtags Used:[]
# Tweet Scraped51:
# Username:XRP_Promoter
# Description:XRP lover from a long time.
# #XRP #XRPprice
#
# DM for business inquiries/promo.
#
# #sponsored Join the People's Blockchain: https://t.co/xcF6DVNr1L
# Location:Blockchain
#  Following Count:14
# Follower Count:60
# Total Tweets:22153
# Retweet Count:0
# Tweet Text: Currency price update:
#
# $21265 #BTC
# $1632.24 #ETH
#
# #Cardano $0.453745 #ADA
# #ShibaInu $1.318e-05 #SHIB
# #BasicAttention $0.361376 #BAT
# #AxieInfinity $14.41 #AXS
# #Maker $840.71 #MKR
#
# $0.341609 USD #XRP
# €0.34035 EURO
# ¥46.77 JPY
#
# Join the People's Blockchain, link in bio.
# Hashtags Used:['BTC', 'ETH', 'Cardano', 'ADA', 'ShibaInu', 'SHIB', 'BasicAttention', 'BAT', 'AxieInfinity', 'AXS', 'Maker', 'MKR', 'XRP']
# Tweet Scraped52:
# Username:SWAGGYLIONSCLUB
# Description:5,555 SWAGGYLIONS redefining blockchain rewards. #SWAGGYLC: https://t.co/Q2TePw6IV4
# Location:Polygon Network
#  Following Count:15
# Follower Count:333
# Total Tweets:501
# Retweet Count:1
# Tweet Text: @SWAGGYLIONSCLUB; can't stop won't stop let's gooo!
#
# Official Discord:
# https://t.co/B6xOwBDWuy
#
# #SWAGGYLC #NFT #NFTCommunity #BTC  #ETH #SOL #BSC #BNB https://t.co/PIgwPZ8hdi
# Hashtags Used:['SWAGGYLC', 'NFT', 'NFTCommunity']
# Tweet Scraped53:
# Username:Carlitobigbags
# Description:Crypto/NFT investor 🚀🚀🚀 #LoadedLion LL#6088 CC#1418 #MadHareSociety #PsychoKitty #BalliesFam #WAGMI #BTFA #Terareum #Polygon #Eth #Bnb #CroFam #Bitcoin
# Location:
#  Following Count:1430
# Follower Count:917
# Total Tweets:4135
# Retweet Count:1
# Tweet Text: If this plays out I don’t mind waiting 10 years to make millions. Allllll I got is time baby. 💎🤲🏻 #Crypto #eth #Bitcoin https://t.co/3iKALwf8bA
# Hashtags Used:['Crypto', 'eth', 'Bitcoin']
# Tweet Scraped54:
# Username:blue_collarbtc
# Description:Firefighters explore economics, finance & the most important monetary technology of the 21st c. | Josh/Dan shared profile | Powered by @Coinkite & @hodlwithLedn
# Location:
#  Following Count:456
# Follower Count:5299
# Total Tweets:6306
# Retweet Count:0
# Tweet Text: @RyanSAdams @brian_armstrong @LefterisJP @LidoFinance @coinbase @krakenfx @stakedus @BitcoinSuisseAG What a relief. Close call. So glad #eth is protected by benevolent CEOs. https://t.co/ovU2s7f8bR
# Hashtags Used:['eth']
# Tweet Scraped55:
# Username:YellowStones434
# Description:🔯
# Location:United States
#  Following Count:221
# Follower Count:559
# Total Tweets:358
# Retweet Count:720
# Tweet Text: 🐯Giveaway Announcement 🐯
#
# 🎁 We are giving 1 NFT @LazyLionsNFT
#
# To Win 🏆:
#
# 1⃣-FOLLOW @crazytigernft
# 2⃣-RT+ Like + RT pin Post
# 3⃣-Tag3people
#
#  Winner in 48 hours ⏱️
#
# #NFTGiveaway #NFTdrops #ETH #nftart #crypto #NFTCommunity https://t.co/Wk6PS3Q83W
# Hashtags Used:[]
# Tweet Scraped56:
# Username:Bini0Bini00
# Description:nft holder and crypto investor $
# Location:
#  Following Count:75
# Follower Count:53
# Total Tweets:91
# Retweet Count:1769
# Tweet Text: 🍂 / / SEASONS RAFFLE \ \ 🌺
#
# August will be the start of a WILD ride, don't miss out. Seasons is coming to you very soon.
#
# 10x Seasons WL spots 🌞
#
# To enter: 🌺
#
# 🌿 Follow
# @SeasonsNFT_
#
# 🏷️ RT + Like
# ✨ Tag 3 friends
# ✅ Join the Discord
#
# #ETH #NFTs #FreeMints #SeasonsNFT https://t.co/KbKcTs4xxv
# Hashtags Used:[]
# Tweet Scraped57:
# Username:rajakha29525772
# Description:Go away!
# Location:Chicago, Illinois
#  Following Count:129
# Follower Count:0
# Total Tweets:121
# Retweet Count:8097
# Tweet Text: 🎁 $150 CASH &amp; WL GIVEAWAY !🎁
#
# 🏆 $150 CASH
#
# 🏆 5x Whitelist
#
# 1⃣ Follow @KOTJ_NFT
#
# 2⃣ Like &amp; RT
#
# 3⃣ Tag 3 Friends
#
# Ends in 48 hrs ⏳👀
#
# #NFTGiveaway #Giveaway #Airdrop #NFTdrop #SOL #SolanaNFT #ETH https://t.co/qE3nnaOQOz
# Hashtags Used:[]
# Tweet Scraped58:
# Username:cinetube8
# Description:NFT collections & artwork:
# MouseGangClub  👉 follow @MouseGangClub #MGC
# LADY Noir / Noir CAT  👉 https://t.co/drG6gosdgj
# #NFT #ETH #ladynoir
# Location:ethereum mainnet
#  Following Count:4566
# Follower Count:4720
# Total Tweets:10704
# Retweet Count:2
# Tweet Text: Get your ticket for MGC1K private #NFT SALE!!!
#
# #NFTs #100DaysOfCode #ETH #MGC1K https://t.co/T5aYalA94p
# Hashtags Used:['NFT', 'NFTs', '100DaysOfCode', 'ETH', 'MGC1K']
# Tweet Scraped59:
# Username:BiriBahtsiz
# Description:Insanlik
# Location:
#  Following Count:587
# Follower Count:187
# Total Tweets:15033
# Retweet Count:7
# Tweet Text: Last 6 days for global exchange listing!
#
# https://t.co/Fe2EJGngi2
#
# #BRN #Metaverse #Bitcoin #Crypto #eth #bnb #USDT
# Hashtags Used:['BRN', 'Metaverse', 'Bitcoin', 'Crypto', 'eth', 'bnb', 'USDT']
# Tweet Scraped60:
# Username:BrittanyMPotter
# Description:#SUPERFAMILY
# $BrittanyPotter32
# #TeamStacks
# #AsYouWish
# Location:
#  Following Count:4520
# Follower Count:318
# Total Tweets:9541
# Retweet Count:1273
# Tweet Text: 💸 $500 #Giveaway 💸
#
# We'll select 5 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrB7rr https://t.co/sobuxJaIqE
# Hashtags Used:['Giveaway']
# Tweet Scraped61:
# Username:HailMaryJoe1
# Description:Long shot NFL TD scorer props guy!
# New to crypto. Always learning. Always finding new ways to earn money. NOT FINANCIAL ADVICE! Play for fun play for profits!
# Location:The Right Side of the planet!
#  Following Count:533
# Follower Count:522
# Total Tweets:1221
# Retweet Count:103
# Tweet Text: For everyone rt like I  will send you $5000
# Drop your #ETH address https://t.co/8xhhfSJkb8
# Hashtags Used:['ETH']
# Tweet Scraped62:
# Username:EverSanyam
# Description:#EverRise $RISE #BSC #ETH #MATIC #AVAX #FTM #EverOwn #EverSwap #EverStake #EverMigrate #EverBridge #EverRevoke  #stakingNFTs Looking for tip in btc/eth/paytm.
# Location:EverRise City
#  Following Count:7
# Follower Count:313
# Total Tweets:30482
# Retweet Count:3
# Tweet Text: #EverRise $RISE #EverRiseV3 #EverRevoke #DeFi #Crypto #Cryptocurrency #ETH #EverRiseInu #NFTCommunity #EverMigrate #EverMigrate #Fantom #Avalanche #BNB https://t.co/rnldRLr7cG
# Hashtags Used:['EverRise', 'EverRiseV3', 'EverRevoke', 'DeFi', 'Crypto', 'Cryptocurrency', 'ETH', 'EverRiseInu', 'NFTCommunity', 'EverMigrate']
# Tweet Scraped63:
# Username:Lusia_samuraii
# Description:🌐https://t.co/ghharj2mHL🟣Crypto Investor |Content Creator|
# 🟣WE MARKET Your BLOCKCHAIN PROJECT
# $RBXS TWITTER SHILLER
# 🟣Follow @RBXSamurai
#  🟣#RBXSamura
# Location:
#  Following Count:148
# Follower Count:532
# Total Tweets:28193
# Retweet Count:5
# Tweet Text: With Dumbledao you buy and sell
# #Dumbledore @Dumbledao $DUMBLE
# Link tree:
# https://t.co/DvbdeeSHRr
# #Crypto #lunar #NFTcommunity #Nfts  #CryptoNews #BSCGems #BSCGem  #100xGems #Eth #BSC #trading #DeFi ... https://t.co/lCivGj3sht
# Hashtags Used:['Dumbledore', 'Crypto', 'lunar']
# Tweet Scraped64:
# Username:Ljnmyralinah
# Description:🏜
# Location:Mars
#  Following Count:608
# Follower Count:14
# Total Tweets:925
# Retweet Count:3273
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped65:
# Username:aaaaj3b_
# Description:congratulations @aaaaj3b_ *(^o^)/*
# Location:
#  Following Count:4306
# Follower Count:488
# Total Tweets:70532
# Retweet Count:823
# Tweet Text: We will giveaway 500$ to 5 winner in 7 days, you simply need to RT, Like + register at https://t.co/GPaVvXt7CY
#
# Post your username for proof 👇
#
# Good luck 🤞
#
# #BTC #ETH #Crypto #Cryptocurrency https://t.co/KJcLJyLoLi
# Hashtags Used:[]
# Tweet Scraped66:
# Username:ahiedz9
# Description:
# Location:Garut, West Java
#  Following Count:380
# Follower Count:59
# Total Tweets:2228
# Retweet Count:166
# Tweet Text: As promised I´m giving  $20,000  $ETH to the first 2000 people who follows and retweets!
#
# Drop your #ETH wallet address♥️♥️♥️ https://t.co/pMsrMmekXO
# Hashtags Used:['ETH']
# Tweet Scraped67:
# Username:0xwinAugust29
# Description:Tiga Putri Kecilku yg cantik dan lucu 😘
# Location:Jawa Barat, Indonesia
#  Following Count:4997
# Follower Count:562
# Total Tweets:45804
# Retweet Count:307
# Tweet Text: GIVEAWAY🎉🚀
#
# 0.4 #ETHEREUM (2 winners will be announced, 0.2 eth each)
#
# -Rt
# -Follow @thecoinswatch
#
# Ends in 24h
# 💰💰💰💰
#
# #ETH #ETHgiveaways #Crypto #CryptoGiveaway #Giveaway #GiveawayAlert  #BTC
# Hashtags Used:['ETHEREUM']
# Tweet Scraped68:
# Username:Nur64975086
# Description:#giveaway  #btc #ltc #coti
# #bnb
# me
# @TWPicker
# Location:Londra
#  Following Count:2176
# Follower Count:95
# Total Tweets:9896
# Retweet Count:287
# Tweet Text: 📣3 SAATLİK KISA ÇEKİLİŞ 📣
#
# 🎖150 TL🎖
#
# ⚔️ Şartlar ⚔️
#
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣@DopeDeerzNFT‘ nin sabit tweetine RT + Like at.🏆Bonus: İngilizce güzel yorum yapanlar 50 TL daha kazanacak!
#
# #btc #giveaway #eth #luna #binance #nfts #avax #elon #dolar #shib #ape #web3 #sol #bnb #faiz
# Hashtags Used:[]
# Tweet Scraped69:
# Username:ELPISTO98581182
# Description:
# Location:
#  Following Count:215
# Follower Count:1
# Total Tweets:287
# Retweet Count:1415
# Tweet Text: 🎁 GOLD LEGENDARY #30 BANANA BALLERS NFT + AUTOGRAPHED STEPH CURRY 🏀 JERSEY
#
# 1⃣ Follow @banana_ballers + @bananaballerceo + @StephenCurry30
# 2⃣ RT + Like
# 3⃣ Tag 3 friends
#
# ⏰ Ends on Mint Day 8.20.22 5pm EST
# #NFTCommunity #NFTGiveaway #ETH #StephenCurry #NBA #Basketball https://t.co/JkrbC4sAiJ
# Hashtags Used:[]
# Tweet Scraped70:
# Username:CalginRemzi
# Description:
# Location:
#  Following Count:199
# Follower Count:78
# Total Tweets:11500
# Retweet Count:7
# Tweet Text: Last 6 days for global exchange listing!
#
# https://t.co/Fe2EJGngi2
#
# #BRN #Metaverse #Bitcoin #Crypto #eth #bnb #USDT
# Hashtags Used:['BRN', 'Metaverse', 'Bitcoin', 'Crypto', 'eth', 'bnb', 'USDT']
# Tweet Scraped71:
# Username:SWAGGYLIONSCLUB
# Description:5,555 SWAGGYLIONS redefining blockchain rewards. #SWAGGYLC: https://t.co/Q2TePw6IV4
# Location:Polygon Network
#  Following Count:15
# Follower Count:333
# Total Tweets:501
# Retweet Count:2
# Tweet Text: @swaggylionsclub when's the next contest?
#
# Official Discord:
# https://t.co/B6xOwBDWuy
#
# #SWAGGYLC #NFT #NFTCommunity #BTC  #ETH #SOL #BSC #BNB https://t.co/S1zhw8DRw7
# Hashtags Used:['SWAGGYLC', 'NFT', 'NFTCommunity', 'BTC', 'ETH']
# Tweet Scraped72:
# Username:Tunabey05
# Description:
# Location:
#  Following Count:5
# Follower Count:6
# Total Tweets:458
# Retweet Count:7
# Tweet Text: Last 6 days for global exchange listing!
#
# https://t.co/Fe2EJGngi2
#
# #BRN #Metaverse #Bitcoin #Crypto #eth #bnb #USDT
# Hashtags Used:['BRN', 'Metaverse', 'Bitcoin', 'Crypto', 'eth', 'bnb', 'USDT']
# Tweet Scraped73:
# Username:Isynze1
# Description:#Crypto🔥 #NFT #nftpromoter on #tiktok👀 #solana #eth
# #opensea #web3 #nftalphacall
# Location:Paris, France
#  Following Count:97
# Follower Count:134
# Total Tweets:1572
# Retweet Count:0
# Tweet Text: @Axos_Universe LFG ! #Mint #Whitelist #eth #NFTCommunity https://t.co/pkXvFHRWK0
# Hashtags Used:['Mint', 'Whitelist', 'eth', 'NFTCommunity']
# Tweet Scraped74:
# Username:0xsanyeongluck_
# Description:@luckyynabiix_ got sus #noizzy
# Location:sa puso mo
#  Following Count:3661
# Follower Count:50
# Total Tweets:11849
# Retweet Count:4819
# Tweet Text: 🎁 $100 CASH &amp; WL GIVEAWAY 🎁
#
# Prizes:
# 🏆 $100 CASH
# 🏆 6x WL
# 🎫
# 1️⃣ Follow @GroofStreet &amp; me
# 2️⃣ RT LIKE + TAG 3 FRENS
# 3️⃣ Have notifications on 🔔
#
# ⭐️Bonus Join DC 👇🏻
# https://t.co/Khnm9VHicj
#
# 48Hrs📢
# #GROOFSTREET #NFT #NFTproject #Solana #NFTs #ETH #NFTCommunity https://t.co/zPijUEHZrn
# Hashtags Used:[]
# Tweet Scraped75:
# Username:Husoturk2
# Description:The name's Bean. Very bullish on shib!
# Location:Alabama, USA
#  Following Count:13
# Follower Count:0
# Total Tweets:196
# Retweet Count:0
# Tweet Text: Full thanks to @Tradeosiann as they have analysed this #bitcoin crash so my funds doesn't affected and I not faced any type of losses
# They are absolutely amazing in tips,advices and everything #Metaverse #BINANCE #BTC #ETH 🤭
# Hashtags Used:['bitcoin', 'Metaverse', 'BINANCE', 'BTC', 'ETH']
# Tweet Scraped76:
# Username:caithiasot_tuog
# Description:I was alone on a sunny shore
# by the forest’s pale blue lake
# Location:AUSTRALIA
#  Following Count:375
# Follower Count:18
# Total Tweets:403
# Retweet Count:3273
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped77:
# Username:nimeinteresa10
# Description:
# Location:
#  Following Count:46
# Follower Count:21
# Total Tweets:145
# Retweet Count:166
# Tweet Text: As promised I´m giving  $20,000  $ETH to the first 2000 people who follows and retweets!
#
# Drop your #ETH wallet address♥️♥️♥️ https://t.co/pMsrMmekXO
# Hashtags Used:['ETH']
# Tweet Scraped78:
# Username:fantom_insider
# Description:Insightful Analytics - Latest News - Golden Opportunities For Community Of Fantom Blockchain
#
# For Business: https://t.co/5epJFfPG8c
# Location:Moon
#  Following Count:301
# Follower Count:18107
# Total Tweets:847
# Retweet Count:10
# Tweet Text: Tokenomics and $SURV #Airdrop  numbers have been finalized.
#
# There will be airdrops on #AVAX #FTM and #ETH to all Surveyor #NFT holders.
#
# Airdrop size determined by rarity. These numbers will also be released this weekend.
#
# If you havent minted yet:
#
# https://t.co/WPx6kkymJ0 https://t.co/LbThgAZ7kK
# Hashtags Used:['Airdrop', 'AVAX', 'FTM', 'ETH']
# Tweet Scraped79:
# Username:XoqMerinoHs
# Description:Aspiring Influencer / NFT Art / Play to Earn games
# Location:Hong Kong
#  Following Count:598
# Follower Count:15
# Total Tweets:946
# Retweet Count:3273
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped80:
# Username:0x1st
# Description:💛 my old two accounts has been suspended 🙏
#
# #crypto #promoters  👍
# Location:
#  Following Count:797
# Follower Count:22
# Total Tweets:1855
# Retweet Count:5609
# Tweet Text: 🎁 $400 CASH &amp; NFT GIVEAWAY ! 🎁
#
# Prize :
# 🏆 $400 CASH
# 🏆 5x NFT
#
# 1⃣Follow me &amp; @Ownic_Official
# 2⃣RT &amp; Like
# 3⃣Tag 3 friends
#
# 48h🕘
# #Solana #SOL #SolanaNFT #ETH
# #Giveaway #NFT $SOL #Crypto #NFTs https://t.co/S7watWs6ss
# Hashtags Used:[]
# Tweet Scraped81:
# Username:LBrozdova
# Description:
# Location:
#  Following Count:158
# Follower Count:5
# Total Tweets:160
# Retweet Count:1493
# Tweet Text: 🎁 GIVEAWAY 🎁
#
# Prizes:
# 🏆 𝟮𝟱 𝘅 𝗪𝗟
# 🏆    𝟱 𝘅 𝗢𝗚
#
# To enter:
# 1️⃣ Follow @solcadia_nft
# 2️⃣ Like + Retweet
# 3️⃣ Tag 3 friends
#
# ⭐Join the Solcadia Discord for an 𝗲𝘅𝘁𝗿𝗮 𝗲𝗻𝘁𝗿𝘆!
#
# Ends in 48h ⏳
#
# #NFT #NFTGiveaway #NFTCommunity #ETH #Ethereum #Whitelist https://t.co/5oljNjjiyB
# Hashtags Used:[]
# Tweet Scraped82:
# Username:Ibeekay22
# Description:I'm into NFT's || #TopazTrooper
# Location:
#  Following Count:402
# Follower Count:20
# Total Tweets:757
# Retweet Count:126
# Tweet Text: !!!!!!! FLASH GIVEAWAY ALERT !!!!!!!
#
# 12  WL spots up for grabs
# 🦾 Like and RT
# 🦾 Follow @Mini_heroesNFT x @DopeBearsNFT_
# 🦾 Tag 3 heroes
#
# #NFTCommunity #NFTGiveaway #Freemint #NFTs #NFT #eth https://t.co/yjbJYzbmOo
# Hashtags Used:[]
# Tweet Scraped83:
# Username:dmf1357
# Description:
# Location:Minsk
#  Following Count:438
# Follower Count:57
# Total Tweets:1535
# Retweet Count:8097
# Tweet Text: 🎁 $150 CASH &amp; WL GIVEAWAY !🎁
#
# 🏆 $150 CASH
#
# 🏆 5x Whitelist
#
# 1⃣ Follow @KOTJ_NFT
#
# 2⃣ Like &amp; RT
#
# 3⃣ Tag 3 Friends
#
# Ends in 48 hrs ⏳👀
#
# #NFTGiveaway #Giveaway #Airdrop #NFTdrop #SOL #SolanaNFT #ETH https://t.co/qE3nnaOQOz
# Hashtags Used:[]
# Tweet Scraped84:
# Username:LivePriceCrypto
# Description:I Tweet the latest #Bitcoin & #Ethereum price and Daily/Weekly Technical Indicators Data every minute.
#
# Developed the 20/03/2022
# Location:
#  Following Count:4
# Follower Count:3236
# Total Tweets:211815
# Retweet Count:0
# Tweet Text: #Bitcoin Last Price $21243 #BTC 🚀
# Weekly Indicators:
# •Variation since Monday 00h00(UTC): -12.61%
# •MACD:
#  -MACD Line: -5179
#  -Signal Line: -5376
#
# #Ethereum Last Price $1630 #ETH
# •Variation: -15.79%
# •MACD:
#  -MACD Line: -346
#  -Signal Line: -406
#
# #Blockchain #Web3
# (5/6)
# 211642
# Hashtags Used:['Bitcoin', 'BTC', 'Ethereum', 'ETH', 'Blockchain', 'Web3']
# Tweet Scraped85:
# Username:Jetpshaliwe
# Description:“A King only bows down to his Queen”
# Location:Victoria, Australia
#  Following Count:972
# Follower Count:10
# Total Tweets:963
# Retweet Count:3273
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped86:
# Username:AmandaY12723119
# Description:
# Location:
#  Following Count:8
# Follower Count:0
# Total Tweets:6
# Retweet Count:198
# Tweet Text: Zoomex - Rejoignez la compétition de trading et avoir une chance de gagn... https://t.co/wYVkf6UTy9 via @YouTube @ZOOMEX_COM
# #referral #BTC #ETH #bonus #giveaways #USDT #USDC #USD #zoomex #French #Crypto
# Hashtags Used:[]
# Tweet Scraped87:
# Username:snluckyx
# Description:Giveaway joiner. New acc                                                          Was @gemwins1940
# #ayuminati
# Location:
#  Following Count:268
# Follower Count:18
# Total Tweets:772
# Retweet Count:30
# Tweet Text: 🌍 The Afrikans #NFT is an exclusive collection of 1111 unique art pieces, each representing the rich cultural and ethnic diversities of the African continent.
#
# A journey to revolutionize the robust #web3 ecosystem in the continent.
#
# ⛵️ https://t.co/RArl2dHK1M
#
# #NFTs #ETH #BTC https://t.co/8Zi9JMsR4z
# Hashtags Used:['NFT']
# Tweet Scraped88:
# Username:agzors
# Description:CryptoBatz | LongLost | 3lander | SpriteClub | Cryptoon Goonz
# Location:
#  Following Count:1974
# Follower Count:832
# Total Tweets:2315
# Retweet Count:5
# Tweet Text: I did it and now I'm in love👀👀 @3LandersNFT  where my 3Landers at 🥺🥺🥺
#
# #3L4L #NFTs #eth https://t.co/vX7Aeen8Xx
# Hashtags Used:['3L4L', 'NFTs', 'eth']
# Tweet Scraped89:
# Username:Sky71715260Sky
# Description:Manifesting bigwin kyutie🍀☘️
# Location:
#  Following Count:4054
# Follower Count:100
# Total Tweets:31644
# Retweet Count:5610
# Tweet Text: 🎁 $400 CASH &amp; NFT GIVEAWAY ! 🎁
#
# Prize :
# 🏆 $400 CASH
# 🏆 5x NFT
#
# 1⃣Follow me &amp; @Ownic_Official
# 2⃣RT &amp; Like
# 3⃣Tag 3 friends
#
# 48h🕘
# #Solana #SOL #SolanaNFT #ETH
# #Giveaway #NFT $SOL #Crypto #NFTs https://t.co/S7watWs6ss
# Hashtags Used:[]
# Tweet Scraped90:
# Username:HUY_HOAN888
# Description:
# Location:
#  Following Count:398
# Follower Count:264
# Total Tweets:31198
# Retweet Count:10
# Tweet Text: $ELON is best  
# #DogelonMars  #Dogelon #ELON
# #nft #eth  #elonmusk #cryptocom
# ...i https://t.co/zkKABbyJKL
# Hashtags Used:['DogelonMars', 'Dogelon', 'ELON', 'nft', 'eth', 'elonmusk', 'cryptocom']
# Tweet Scraped91:
# Username:acilkripto
# Description:Kriptolar ile ilgili her bilginin hiç bir  karşılık beklenmeden ve yatırım tavsiyesi verilmeden paylaşıldığı ortam
# Location:İstanbul, Türkiye
#  Following Count:29
# Follower Count:724
# Total Tweets:28081
# Retweet Count:0
# Tweet Text: Ethereum’da Merge’den Sonra Neler Gerçekleşecek? Merge Yükseltmesi ETH Fiyatını Nasıl Etkiler?
#
# #kripto #kriptopara #bitkoin #koin #coin #crypto #kriptohaber #bitcoin #btc #ethereum #etheryum #eth
#
# https://t.co/pLvrVLRHpo
# Hashtags Used:['kripto', 'kriptopara', 'bitkoin', 'koin', 'coin', 'crypto', 'kriptohaber', 'bitcoin', 'btc', 'ethereum', 'etheryum', 'eth']
# Tweet Scraped92:
# Username:SASjindraW1N
# Description:🤍GOD is GOOD all the time 👍 God gave me what I asked for🚪I knocked on His door and He opened it for me.Thanks God ️🕊️// Bigwin in August 2022 😇
# Location:
#  Following Count:4944
# Follower Count:168
# Total Tweets:49065
# Retweet Count:682
# Tweet Text: The first #Crypto Project with #MoveToEarn Auto-staking &amp; Auto-compounding with $GMT &amp; $BNB Dividends
#
# Twitter- @RunEarner
#
# 👟Audit &amp; KYC Soon
# 👟Launching Soon
# 👟Website &amp; App Live
#
# #STEPN #NFT #ETH #Move2Earn #m2e #GMT #nft #BTC #BNB  #NFTshill #Altcoins $FITFI #PlayToEarn #P2E https://t.co/KVsRRQTo1J
# Hashtags Used:['Crypto', 'MoveToEarn']
# Tweet Scraped93:
# Username:Bini0Bini00
# Description:nft holder and crypto investor $
# Location:
#  Following Count:75
# Follower Count:53
# Total Tweets:91
# Retweet Count:1205
# Tweet Text: MASSIVE ANNOUNCEMENT TOMORROW 📣
#
# Notifications on, you won't want to miss this. 🔔
#
# Any interactions will be considered for whitelist. ✅
#
# #ETH #NFTs #FreeMints #SeasonsNFT https://t.co/MDG07P1eBF
# Hashtags Used:[]
# Tweet Scraped94:
# Username:Arzu975248381
# Description:Evli mutlu çocuklu
# Location:
#  Following Count:2575
# Follower Count:216
# Total Tweets:13839
# Retweet Count:103
# Tweet Text: For everyone rt like I  will send you $5000
# Drop your #ETH address https://t.co/8xhhfSJkb8
# Hashtags Used:['ETH']
# Tweet Scraped95:
# Username:kth_wins2
# Description:#supREMIcy  #plushies • #WutTheFoxy  • #fambun  • #jennisis • #kirsfam • #PamilyaTalong • #NiceHwan  • #mochinesfam • #YnahAnak • #axelite • #sharkies
# Location:WINS CUTIE
#  Following Count:1255
# Follower Count:12
# Total Tweets:5065
# Retweet Count:48
# Tweet Text: 🖼️ Black Future Collection 🖼️
#
# A collaboration with Cadillac &amp; Nyla Hayes to create an exclusive 1/1 and limited edition Black Future Long Neckie #NFT Dropping on #OpenSea, a portion of the sales will benefit the Save the Music Foundation.
#
# ⛵️ https://t.co/pJyGnL3iVU
#
# #NFTs #ETH https://t.co/Xyd7dijYUI
# Hashtags Used:[]
# Tweet Scraped96:
# Username:RBizeri
# Description:🐎
# Location:
#  Following Count:342
# Follower Count:132
# Total Tweets:2631
# Retweet Count:77
# Tweet Text: Hızlı Etkinlik Zamanı 🎁
#
# 2 Takipçimize 200 TRX 🍀
#
# 24:00’da Açıklanacak 🎁
#
# Şartlar :
#
# - Beni Takip Etmek
#
# - Bu Gönderiyi Beğenmek
#
# - Rt Yapmak
#
# #shiba #Doge #btc #eth #avax #ıcp #ceek
# Hashtags Used:[]
# Tweet Scraped97:
# Username:Kaemikkinajj
# Description:Careless man's careful daughter
# Location:₿inance Angel
#  Following Count:622
# Follower Count:11
# Total Tweets:923
# Retweet Count:3273
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped98:
# Username:qtheMSGalBoss
# Description:NFT Collaboration manager of MSC
# Location:Netherlands
#  Following Count:748
# Follower Count:152
# Total Tweets:1142
# Retweet Count:3273
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped99:
# Username:Bitbookkeepers
# Description:U.S. Navy Veteran. Full-time #CryptoTax Accountant. MAcc, MBA Crypto Currency Trader. #Bitcoin #BTC #ETH #AMP #IOTX #DOT #LINK #WeAreTheWhales. #SOSUkraine
# Location:Miami, FL
#  Following Count:4995
# Follower Count:3179
# Total Tweets:20786
# Retweet Count:0
# Tweet Text: For those of us that know that the future of finance is #Crypto and are long term #Hodlers of #BTC and #ETH,price volatility is nothing more than an opportunity to shed degen dead weight before our face melting move to the stratosphere. Bye leveraged traders. Good riddance. #HODL https://t.co/OoQSVNlBTu
# Hashtags Used:['Crypto', 'Hodlers', 'BTC', 'ETH', 'HODL']
# Tweet Scraped100:
# Username:pd730131
# Description:Sleeping with
# @pacer_gg
# "
# 9
# Location:India
#  Following Count:219
# Follower Count:5
# Total Tweets:174
# Retweet Count:305
# Tweet Text: We just Crossed 1000 Followers !! And we want to celebrate it .
#  2 Lucky Followers will get 50 $OP each .
#
# 1- Follow @OpNService  Like +RT + tag 3 Friend
# 2- Comment Your OP address + Desired .op Domain
#
#  ~72 hrs
# #Giveaways  #ETH  #Ethereum  #Airdrop   #ENS
# #Optimism  #Binance https://t.co/zSpbxOdyJX
# Hashtags Used:[]
# Tweet Scraped101:
# Username:aguirrex14
# ...
# Tweet Text: The first #Crypto Project with #MoveToEarn Auto-staking &amp; Auto-compounding with $GMT &amp; $BNB Dividends
#
# Twitter- @RunEarner
#
# 👟Audit &amp; KYC Soon
# 👟Launching Soon
# 👟Website &amp; App Live
#
# #STEPN #NFT #ETH #Move2Earn #m2e #GMT #nft #BTC #BNB  #NFTshill #Altcoins $FITFI #PlayToEarn #P2E https://t.co/KVsRRQTo1J
# Hashtags Used:['Crypto', 'MoveToEarn']
# Tweet Scraped168:
# Username:cryptokaifx
# Description:This moment is your chance!
# Location:Kerala, India
#  Following Count:1649
# Follower Count:215
# Total Tweets:3101
# Retweet Count:1274
# Tweet Text: 💸 $500 #Giveaway 💸
#
# We'll select 5 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrB7rr https://t.co/sobuxJaIqE
# Hashtags Used:['Giveaway']
# Tweet Scraped169:
# Username:haetbitdy
# Description:Blessed!🍀
# Location:
#  Following Count:3297
# Follower Count:562
# Total Tweets:103043
# Retweet Count:4821
# Tweet Text: 🎁 $100 CASH &amp; WL GIVEAWAY 🎁
#
# Prizes:
# 🏆 $100 CASH
# 🏆 6x WL
# 🎫
# 1️⃣ Follow @GroofStreet &amp; me
# 2️⃣ RT LIKE + TAG 3 FRENS
# 3️⃣ Have notifications on 🔔
#
# ⭐️Bonus Join DC 👇🏻
# https://t.co/Khnm9VHicj
#
# 48Hrs📢
# #GROOFSTREET #NFT #NFTproject #Solana #NFTs #ETH #NFTCommunity https://t.co/zPijUEHZrn
# Hashtags Used:[]
# Tweet Scraped170:
# Username:0xsnanadongie
# Description:hunter GA acc | turn off my rt | my account @oxjaeminies @snanadongie suspend | #GalaxyTrue
# Location:
#  Following Count:686
# Follower Count:41
# Total Tweets:2621
# Retweet Count:32
# Tweet Text: 🌍 The Afrikans #NFT is an exclusive collection of 1111 unique art pieces, each representing the rich cultural and ethnic diversities of the African continent.
#
# A journey to revolutionize the robust #web3 ecosystem in the continent.
#
# ⛵️ https://t.co/RArl2dHK1M
#
# #NFTs #ETH #BTC https://t.co/8Zi9JMsR4z
# Hashtags Used:['NFT']
# Tweet Scraped171:
# Username:Cheemer4ever
# Description:Soy una persona amigable y divertida
# Location:
#  Following Count:45
# Follower Count:55
# Total Tweets:536
# Retweet Count:0
# Tweet Text: @cyber_bull_ @HAVOC_ERC Join us and have some fun guys, 6 days old and community is amazing and strong holders, dont miss it.
#
# TG: https://t.co/sxbpo6TLHE
#
# #harold #hidethepain #bsc #x100gem #smartchain #memecoin #btc #eth https://t.co/QZtXmtfQAp
# Hashtags Used:['harold', 'hidethepain', 'bsc', 'x100gem', 'smartchain', 'memecoin', 'btc', 'eth']
# Tweet Scraped172:
# Username:NormaDunbar8
# Description:加密小萌新 ，分享自己的一点小见解 #NFT #Web3 #DAO #Gamefi #元宇宙 #Defi
# Location:
#  Following Count:1154
# Follower Count:27
# Total Tweets:1970
# Retweet Count:637
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @RoyalAlpha_X
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/eWV5Ezrjgn
# Hashtags Used:[]
# Tweet Scraped173:
# Username:crypto_kingwins
# Description:BTC - BNB - CRYPTO-
# Location:Türkiye
#  Following Count:113
# Follower Count:37
# Total Tweets:71
# Retweet Count:5610
# Tweet Text: 🎁 $400 CASH &amp; NFT GIVEAWAY ! 🎁
#
# Prize :
# 🏆 $400 CASH
# 🏆 5x NFT
#
# 1⃣Follow me &amp; @Ownic_Official
# 2⃣RT &amp; Like
# 3⃣Tag 3 friends
#
# 48h🕘
# #Solana #SOL #SolanaNFT #ETH
# #Giveaway #NFT $SOL #Crypto #NFTs https://t.co/S7watWs6ss
# Hashtags Used:[]
# Tweet Scraped174:
# Username:Faocaygapdoi
# Description:always on the go
# Location:stratosphere
#  Following Count:604
# Follower Count:15
# Total Tweets:930
# Retweet Count:3274
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped175:
# Username:Nur64975086
# Description:#giveaway  #btc #ltc #coti
# #bnb
# me
# @TWPicker
# Location:Londra
#  Following Count:2176
# Follower Count:95
# Total Tweets:9897
# Retweet Count:65
# Tweet Text: Heya,we are starting collabs for all of projects to help them, and making together for create the biggest portfolio all of chains.Just DM for this.
# #Solana #eth #btc #bnb #avax #polygon #NFTs #NFTCommunity #NFTGiveaways #nftcollections #nftdrop #Tether
# Hashtags Used:[]
# Tweet Scraped176:
# Username:Abdulra32139237
# Description:Abdulrahim Abubakar
# Location:
#  Following Count:249
# Follower Count:31
# Total Tweets:138
# Retweet Count:30
# Tweet Text: [#CORE Daily Report(08.20)] 📈
#
# 1️⃣1 tCORE = 830 sUSDT(18↑)🚀
#     📌https://t.co/Hj7X1jKsYV
#
# 2️⃣APR: 419% = 1.1%/Day 💵😍
#     📌https://t.co/h24bQn4NCP
#
# 3️⃣Downloads: 53.6M(0.2↑) ⛏️
#     📌https://t.co/EIidrzV4Fr 🚀
#      ✅️Join now(android only)
#
# #CoreDAO #BTCs #BTC #ETH #Satoshi https://t.co/L9gaxRlnxD
# Hashtags Used:['CORE']
# Tweet Scraped177:
# Username:SuatKopal4
# Description:
# Location:
#  Following Count:154
# Follower Count:59
# Total Tweets:394
# Retweet Count:18
# Tweet Text: But wait…. There’s more!!! 🥳🙌🏼🔥
#
# LETS GOOOOOO!!!!!!!! 🥂👏👏👏👏
#
# #GroveToken #BSC #eth #Crypto #chasinghistory #altcoin #Bullish #SAFEMOONSWAP #BitMart https://t.co/iqxJg6ytwk
# Hashtags Used:['GroveToken', 'BSC', 'eth', 'Crypto', 'chasinghistory', 'altcoin']
# Tweet Scraped178:
# Username:BacTraciBras
# Description:Crypto evangelist | @KiwamiNFT
# Location:USA
#  Following Count:648
# Follower Count:16
# Total Tweets:932
# Retweet Count:3274
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped179:
# Username:SallyD1331
# Description:
# Location:
#  Following Count:123
# Follower Count:58
# Total Tweets:5151
# Retweet Count:9
# Tweet Text: @Upgradde6913 @altcryptocom @Crikit_nft Grab your #crikits before they🦗🚀⭐
# #crikit #crikitarmy #crikitnft #nftcommunity #freespeech #eth https://t.co/lLDiCJOyli
# Hashtags Used:['crikits', 'crikit', 'crikitarmy', 'crikitnft', 'nftcommunity']
# Tweet Scraped180:
# Username:NovitaJali
# Description:
# Location:
#  Following Count:4439
# Follower Count:159
# Total Tweets:61883
# Retweet Count:48
# Tweet Text: 🖼️ Black Future Collection 🖼️
#
# A collaboration with Cadillac &amp; Nyla Hayes to create an exclusive 1/1 and limited edition Black Future Long Neckie #NFT Dropping on #OpenSea, a portion of the sales will benefit the Save the Music Foundation.
#
# ⛵️ https://t.co/pJyGnL3iVU
#
# #NFTs #ETH https://t.co/Xyd7dijYUI
# Hashtags Used:[]
# Tweet Scraped181:
# Username:ManishKRaj2
# Description:Tathāstu • sleeping is a life hack | Good vibes only ✨ #blockchain #BNB #BTC #stufflistingsarmy #TechBharat
# Location:India 🇮🇳
#  Following Count:3492
# Follower Count:254
# Total Tweets:68814
# Retweet Count:1274
# Tweet Text: 💸 $500 #Giveaway 💸
#
# We'll select 5 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrB7rr https://t.co/sobuxJaIqE
# Hashtags Used:['Giveaway']
# Tweet Scraped182:
# Username:cryptoTRON2019
# Description:#Promoter/Investor📈/ #SOLANA/ TREND FOLLOW🔄/#NFT collector/#BTC/Never Trust Fiat/ #Metaverse #WEB3 #100XGEM🚀|🤝Wanted Partner| Advertising PromotionDM📩7/24
# Location:⬇️ÖN SATIŞ BORSASI HUOBİ💰
#  Following Count:5239
# Follower Count:9282
# Total Tweets:15427
# Retweet Count:0
# Tweet Text: Çok samimi söylüyorum etherium kendini bırakacak… #eth
# Hashtags Used:['eth']
# Tweet Scraped183:
# Username:levitransfi
# Description:
# Location:
#  Following Count:4373
# Follower Count:245
# Total Tweets:18065
# Retweet Count:126
# Tweet Text: !!!!!!! FLASH GIVEAWAY ALERT !!!!!!!
#
# 12  WL spots up for grabs
# 🦾 Like and RT
# 🦾 Follow @Mini_heroesNFT x @DopeBearsNFT_
# 🦾 Tag 3 heroes
#
# #NFTCommunity #NFTGiveaway #Freemint #NFTs #NFT #eth https://t.co/yjbJYzbmOo
# Hashtags Used:[]
# Tweet Scraped184:
# Username:0xbunaiyu
# Description:bismillahirrahmanirrahim, usaha tidak mengkhianati hasil
# Location:
#  Following Count:1890
# Follower Count:103
# Total Tweets:20916
# Retweet Count:4821
# Tweet Text: 🎁 $100 CASH &amp; WL GIVEAWAY 🎁
#
# Prizes:
# 🏆 $100 CASH
# 🏆 6x WL
# 🎫
# 1️⃣ Follow @GroofStreet &amp; me
# 2️⃣ RT LIKE + TAG 3 FRENS
# 3️⃣ Have notifications on 🔔
#
# ⭐️Bonus Join DC 👇🏻
# https://t.co/Khnm9VHicj
#
# 48Hrs📢
# #GROOFSTREET #NFT #NFTproject #Solana #NFTs #ETH #NFTCommunity https://t.co/zPijUEHZrn
# Hashtags Used:[]
# Tweet Scraped185:
# Username:KasmKurt82
# Description:..
# Location:.
#  Following Count:1693
# Follower Count:61
# Total Tweets:5736
# Retweet Count:50
# Tweet Text: 💰 2 KİŞİYE 100$ #Usdt💰
#  (Sponsorlu)
#
# 📌 Katılım;
# 1️⃣ @SpartaKripto ve @DozzeCrypto TAKİP et
# 2️⃣ Beğen+RT
# 3️⃣ TRC20/Usdt adresini yoruma bırak
#
# 24 Saat sonra sonlanacaktır.
#
# #btc #Eth #Pitbulltoken #Kriptoçekiliş #Airdrop #Giveaway #Ceek #Raca #çekiliş #Avax  #Airdrops #Trx  #SOL
# Hashtags Used:['Usdt']
# Tweet Scraped186:
# Username:ccryptoFinaNCee
# Description:i am Art collector , investor , from Switzerland ! investor in nft , in crypto ! ART maker ! #nftartist. https://t.co/1gSGvNoBhl
# Location:
#  Following Count:4862
# Follower Count:5205
# Total Tweets:95693
# Retweet Count:5
# Tweet Text: Ripple/XRP-FedNow-CBDC Delay Or Secret Liquidity Pools?,Ripple Private XRP Preallocation Contracts?
#
# https://t.co/uPn2uH9y3J
#
# #XRP #BTC  #ETH  #BCH #LTC #xrpthestandard #ripple #ripplenews #DigitalPerspectives #Crypto #GoldFi #Glint #Financial #Investing #procoinnews #RETWEET https://t.co/dBGRw29Fia
# Hashtags Used:[]
# Tweet Scraped187:
# Username:sdk3v_3
# Description:NFT Chaser
# Location:
#  Following Count:57
# Follower Count:53
# Total Tweets:71
# Retweet Count:1769
# Tweet Text: 🍂 / / SEASONS RAFFLE \ \ 🌺
#
# August will be the start of a WILD ride, don't miss out. Seasons is coming to you very soon.
#
# 10x Seasons WL spots 🌞
#
# To enter: 🌺
#
# 🌿 Follow
# @SeasonsNFT_
#
# 🏷️ RT + Like
# ✨ Tag 3 friends
# ✅ Join the Discord
#
# #ETH #NFTs #FreeMints #SeasonsNFT https://t.co/KbKcTs4xxv
# Hashtags Used:[]
# Tweet Scraped188:
# Username:Rainne94902952
# Description:
# Location:
#  Following Count:167
# Follower Count:45
# Total Tweets:234
# Retweet Count:32
# Tweet Text: 9月份大事件时间表
# 9月1日缩表950亿美金
# 9月2日20:30美联储公布8月份非农数据
# 9月12日芝商所(CME)计划推出 ETH期权，目前还在等待监管审查
# 9月13日20:30美联储公布8月份 CPI数据
# 9月15日左右ETH2.0合并
# 9月22日2:00美联储召开议息会议
# 10月1日缩表950亿美金
#
# #btc #ETH #crypto #美股
# Hashtags Used:[]
# Tweet Scraped189:
# Username:Vendetta4Life_
# Description:life is for the wicked ☯️
# Location:Planet Namek 🕉
#  Following Count:95
# Follower Count:2301
# Total Tweets:259
# Retweet Count:720
# Tweet Text: 🐯Giveaway Announcement 🐯
#
# 🎁 We are giving 1 NFT @LazyLionsNFT
#
# To Win 🏆:
#
# 1⃣-FOLLOW @crazytigernft
# 2⃣-RT+ Like + RT pin Post
# 3⃣-Tag3people
#
#  Winner in 48 hours ⏱️
#
# #NFTGiveaway #NFTdrops #ETH #nftart #crypto #NFTCommunity https://t.co/Wk6PS3Q83W
# Hashtags Used:[]
# Tweet Scraped190:
# Username:jambigwin17
# Description:Don't suspend me Twitter 😢😭
# Location:
#  Following Count:1350
# Follower Count:29
# Total Tweets:5602
# Retweet Count:48
# Tweet Text: 🖼️ Black Future Collection 🖼️
#
# A collaboration with Cadillac &amp; Nyla Hayes to create an exclusive 1/1 and limited edition Black Future Long Neckie #NFT Dropping on #OpenSea, a portion of the sales will benefit the Save the Music Foundation.
#
# ⛵️ https://t.co/pJyGnL3iVU
#
# #NFTs #ETH https://t.co/Xyd7dijYUI
# Hashtags Used:[]
# Tweet Scraped191:
# Username:Hai06332318
# Description:ok
# Location:
#  Following Count:324
# Follower Count:16
# Total Tweets:460
# Retweet Count:295
# Tweet Text: 🚀#Airdrop:100 winners share the prize pool valued 1,000U
#
# 🔥A Walkthrough of Primebox X #ETH 2.0 Carnival
# ⏰8/22,12:00UTC
# ☑️Follow @Huobi_Research,@Oceanland_io,@FellazXYZ
# ☑️RT+tag 3 friends
# ☑️Watch #Huobi live: https://t.co/LbmfHc7clN
#
# ⬇️Fill out form.
# https://t.co/FQKcA9S6lg https://t.co/8c1rMzlLap
# Hashtags Used:['Airdrop', 'ETH']
# Tweet Scraped192:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:0
# Follower Count:94
# Total Tweets:29579
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1629.65 USD
# #Bitcoin 0.07671811336476471 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped193:
# Username:darioigp
# Description:Digital creations. Surreal compositions.
# https://t.co/xlo7BNkIlC and https://t.co/BE2MVb2AHC
# Location:
#  Following Count:2207
# Follower Count:2977
# Total Tweets:26494
# Retweet Count:12
# Tweet Text: "The ones left"
# on @KnownOrigin_io
#
# An encounter that will only happen once...
#
# 3000x3000 / 300dpi.
#
# 1 of 1 • Now Available for offers
#
# https://t.co/9GmkcRi6ts
#
# Art by @darioigp
#
# #cryptoart #NFT #cryptoartist #ETH https://t.co/7TwHbKhl9v
# Hashtags Used:[]
# Tweet Scraped194:
# Username:MahmudJuwel13
# Description:I want to change my life
# Location:
#  Following Count:3569
# Follower Count:211
# Total Tweets:35166
# Retweet Count:8097
# Tweet Text: 🎁 $150 CASH &amp; WL GIVEAWAY !🎁
#
# 🏆 $150 CASH
#
# 🏆 5x Whitelist
#
# 1⃣ Follow @KOTJ_NFT
#
# 2⃣ Like &amp; RT
#
# 3⃣ Tag 3 Friends
#
# Ends in 48 hrs ⏳👀
#
# #NFTGiveaway #Giveaway #Airdrop #NFTdrop #SOL #SolanaNFT #ETH https://t.co/qE3nnaOQOz
# Hashtags Used:[]
# Tweet Scraped195:
# Username:Pegtiera_art
# Description:Wave heal art healing your heart
# Location:CA
#  Following Count:730
# Follower Count:20
# Total Tweets:961
# Retweet Count:3275
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped196:
# Username:Knightbigx
# Description:Wise men change their minds; fools never do
# Location:
#  Following Count:707
# Follower Count:16
# Total Tweets:894
# Retweet Count:28
# Tweet Text: SEASONS NFT x @PotHeadsHQ
#
# 🎁 Whitelist Giveaway 🎁
#
# 3X WL @SeasonsNFT_
#
# To enter:
# ✅ Follow @SeasonsNFT_ + @PotHeadsHQ + @moroccanbet
# ✅ Like &amp; RT
# ✅ Tag 3 friends
# #NFTGiveaway #FreeMint #NFT #ETH #NFTs
# 24hrs 🚨🚨🚨 https://t.co/Ek7QA0ybyt
# Hashtags Used:[]
# Tweet Scraped197:
# Username:quanmin97
# Description:#YY4L
# Location:
#  Following Count:1421
# Follower Count:144
# Total Tweets:5141
# Retweet Count:1
# Tweet Text: 10 Early Devotees will get rewarded. 👁
#
# 1️⃣ Follow @thedeceivereth
# 2️⃣ RT &amp; Like
# 3️⃣ Fill out the Google Form
#
# https://t.co/VjTRs8AooE
#
# #freemint #nft #FreeMint #NFTGiveaway #freemintNFT #FreeMintAlert #FreeMints #Giveaway #nftcomunity #NFTs  #ETHNFTs #FreeMint #freemintNFT #Eth
# Hashtags Used:[]
# Tweet Scraped198:
# Username:VkbJacoKyss
# Description:NFT Collector from the sunny island of Barbados 🇧🇧
# Location:US
#  Following Count:617
# Follower Count:4
# Total Tweets:956
# Retweet Count:3275
# Tweet Text: 🎉 Freemint Giveaways🎉
#
# We will be giving away:
# •🎟️3x Free Mint Spots for @usedtoiletswtf
#
# To enter:
# Follow @usedtoiletswtf&amp; @NFTscj
# RT &amp; Tag 3 friends
# Winners will be announced in 24 hours! Good luck!
#
# #ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL
# Hashtags Used:[]
# Tweet Scraped199:
# Username:loves_dogqwin
# Description:💛Maybe bigg #win 🌏
# Location:Antalya🇹🇷🇹🇷
#  Following Count:4842
# Follower Count:51
# Total Tweets:29528
# Retweet Count:4821
# Tweet Text: 🎁 $100 CASH &amp; WL GIVEAWAY 🎁
#
# Prizes:
# 🏆 $100 CASH
# 🏆 6x WL
# 🎫
# 1️⃣ Follow @GroofStreet &amp; me
# 2️⃣ RT LIKE + TAG 3 FRENS
# 3️⃣ Have notifications on 🔔
#
# ⭐️Bonus Join DC 👇🏻
# https://t.co/Khnm9VHicj
#
# 48Hrs📢
# #GROOFSTREET #NFT #NFTproject #Solana #NFTs #ETH #NFTCommunity https://t.co/zPijUEHZrn
# Hashtags Used:[]
# Tweet Scraped200:
# Username:Dokinhaaaaa
# Description:Pulante
# Location:
#  Following Count:626
# Follower Count:4
# Total Tweets:933
# Retweet Count:1274
# Tweet Text: 💸 $500 #Giveaway 💸
#
# We'll select 5 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrB7rr https://t.co/sobuxJaIqE
# Hashtags Used:['Giveaway']
# scraping has completed! :)

# %%
# Gathering of Data | 2 | Ethereum Tweets

print('Enter hasthag to search for')
words = input()

print('Enter number of tweets to search for')
numtweet = int(input())

scraped_data = []
print('Fetching tweets...')

scrape(words, numtweet, scraped_data)
print('scraping has completed! :)')

# %%
jsondata = pd.read_json(f'/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Homework/hw2-scraped_data-{words}.json')

jsondata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tweet Scraped    200 non-null    int64
#  1   Username         200 non-null    object
#  2   Description      200 non-null    object
#  3   Location         200 non-null    object
#  4   Following Count  200 non-null    int64
#  5   Follower Count   200 non-null    int64
#  6   Total Tweets     200 non-null    int64
#  7   Retweet Count    200 non-null    int64
#  8   Tweet Text       200 non-null    object
#  9   Hashtags Used    200 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 15.8+ KB

# %%
jsondata.head()
# Out:
#    Tweet Scraped         Username  \
# 0              1  bhartiya_kishor
# 1              2       akakshya12
# 2              3     Uwgtoixinhet
# 3              4       BrnTurkiye
# 4              5         girum755
#
#                                          Description           Location  \
# 0                              BLOCKCHAIN TECHNOLOGY     Gujarat, India
# 1                                       crypto lover      Orissa, India
# 2  I studied every thing but never topped. But to...  Las Vegas, NV, US
# 3  BRN Metaverse Türkiye\n\nGolden Key of the #Me...          Metaverse
# 4  For I know the plans I have for you,” declares...            earth 🌎
#
#    Following Count  Follower Count  Total Tweets  Retweet Count  \
# 0              144              73           151              3
# 1             1578              59          3653           1272
# 2              751              14           940           3271
# 3                5            4630           123              0
# 4              252            1102         58016             29
#
#                                           Tweet Text  \
# 0  COUNTDOWN TO 2 DAYS! HERE WE GOOOOOO!\n\nTitle...
# 1  💸 $500 #Giveaway 💸\n\nWe'll select 5 winners r...
# 2  🎉 Freemint Giveaways🎉\n\nWe will be giving awa...
# 3  Global Borsa listelenmesi için son 6 gün!\n\nh...
# 4  Complete silence by @DrTedros, when 1000s of h...
#
#                                        Hashtags Used
# 0                                                 []
# 1                                         [Giveaway]
# 2                                                 []
# 3  [BRN, Metaverse, Bitcoin, Crypto, eth, bnb, USDT]
# 4                                              [ETH]

# %%
jsondata_loc = jsondata.groupby('Location').groups
jsondata_loc

for loc in jsondata_loc:
    print(loc)
# Out:
#  promo@cryptoenez.com
# .
# AUSTRALIA
# AZERBAIJAN
# Alabama, USA
# Alseka
# Ankara, Türkiye
# Antalya🇹🇷🇹🇷
# Around The Globe
# Australia
# Banyumas, Indonesia
# Blockchain
# CA
# CN,HK,TH,SG
# Caloocan City, National Capita
# Canada
# Chicago, Illinois
# Chittagong, Bangladesh
# Cikarang, Indonesia
# Danville, VA
# Earth-199999
# EverRise City
# Fryslân
# Garut, West Java
# Gujarat, India
# Heeseung lang
# Hong Kong
# Houston, Texas
# In the Jungle
# India
# India 🇮🇳
# Jakarta Barat, DKI Jakarta
# Jawa Barat, Indonesia
# Kartosuro, Indonesia
# Kerala, India
# Ksar Draa
# Las Vegas, NV, US
# Londra
# Lubang, Mimaropa
# Mars
# Metaverse
# Miami, FL
# Minsk
# Mom’s basement
# Moon
# NFT
# Netherlands
# New York, USA
# No i wont tell you
# Orissa, India
# Paris, France
# Planet Namek 🕉
# Polygon Network
# Porto, Portugal
# REMOTE
# Republic of the Philippines
# SaitaPro
# Singapore
# Sugar Land, TX
# Tekirdağ
# The Metaverse
# The Right Side of the planet!
# Toronto, Ontario
# Türkiye
# US
# USA
# United States
# Victoria, Australia
# WINS CUTIE
# cape
# dimana saja aku berada
# earth 🌎
# ethereum mainnet
# ncity
# sa puso mo
# she / her , '03 🇵🇭
# stratosphere
# venezuela
# İstanbul, Türkiye
# भोपाल, भारत
# ₿inance Angel
# ⬇️ÖN SATIŞ BORSASI HUOBİ💰
# 🇵🇭

# %%
jsondata_text = jsondata.groupby('Tweet Text').groups
jsondata_text

lst = []

for txt in jsondata_text:
    lst.append(txt)
    

lst
# Out:
# ['!!!!!!! FLASH GIVEAWAY ALERT !!!!!!!\n\n12  WL spots up for grabs\n🦾 Like and RT \n🦾 Follow @Mini_heroesNFT x @DopeBearsNFT_ \n🦾 Tag 3 heroes \n\n#NFTCommunity #NFTGiveaway #Freemint #NFTs #NFT #eth https://t.co/yjbJYzbmOo',
#  '"The ones left"\non @KnownOrigin_io\n\nAn encounter that will only happen once...\n\n3000x3000 / 300dpi.\n\n1 of 1 • Now Available for offers\n\nhttps://t.co/9GmkcRi6ts\n\nArt by @darioigp\n\n#cryptoart #NFT #cryptoartist #ETH https://t.co/7TwHbKhl9v',
#  '#Bitcoin Last Price $21243 #BTC 🚀\nWeekly Indicators:\n•Variation since Monday 00h00(UTC): -12.61%\n•MACD:\n -MACD Line: -5179\n -Signal Line: -5376\n\n#Ethereum Last Price $1630 #ETH\n•Variation: -15.79%\n•MACD:\n -MACD Line: -346\n -Signal Line: -406\n\n#Blockchain #Web3\n(5/6)\n211642',
#  '#Ethereum price update: \n\n#ETH $1629.65 USD\n#Bitcoin 0.07671811336476471 #BTC\n\nFollow for recent ETH price updates\n#altcoin, #cryptocurrency, #crypto',
#  '#Ethereum price update: \n\n#ETH $1632.24 USD\n#Bitcoin 0.07676878 #BTC\n\nFollow for recent ETH price updates\n#altcoin, #cryptocurrency, #crypto',
#  '#EverRise $RISE #EverRiseV3 #EverRevoke #DeFi #Crypto #Cryptocurrency #ETH #EverRiseInu #NFTCommunity #EverMigrate #EverMigrate #Fantom #Avalanche #BNB https://t.co/rnldRLr7cG',
#  "#eth could see a pretty strong downside move over the next 14 trading days, wouldn't want to be in the buyers shoes if this works out as the charts suggest it will. https://t.co/4NeWgDG3Dp",
#  '$12.000 in #ETH ( 3 WİNNERS )\n\n        RT • Follow • Like',
#  '$ELON is best  \uea00\n#DogelonMars  #Dogelon #ELON\n#nft #eth  #elonmusk #cryptocom\n...i https://t.co/zkKABbyJKL',
#  '10 Early Devotees will get rewarded. 👁\n\n1️⃣ Follow @thedeceivereth\n2️⃣ RT &amp; Like \n3️⃣ Fill out the Google Form\n\nhttps://t.co/VjTRs8AooE\n\n#freemint #nft #FreeMint #NFTGiveaway #freemintNFT #FreeMintAlert #FreeMints #Giveaway #nftcomunity #NFTs  #ETHNFTs #FreeMint #freemintNFT #Eth',
#  '30,000$ or 20 #ETH ?',
#  '9月份大事件时间表\n9月1日缩表950亿美金\n9月2日20:30美联储公布8月份非农数据\n9月12日芝商所(CME)计划推出 ETH期权，目前还在等待监管审查\n9月13日20:30美联储公布8月份 CPI数据\n9月15日左右ETH2.0合并\n9月22日2:00美联储召开议息会议\n10月1日缩表950亿美金\n\n#btc #ETH #crypto #美股',
#  '@Axos_Universe LFG ! #Mint #Whitelist #eth #NFTCommunity https://t.co/pkXvFHRWK0',
#  '@Dawson_Crikit @SkurpySocial @Crikit_nft I can definitely say that the #crikits in my wallet sure do be multiplying, it must be that incoming #passiveincome ❤🦗❤\n@Crikit_nft #crikit #crikitnft #freespeech #eth #nft #fkcensorship #crikitarmy #nftcommunity \n\nhttps://t.co/9GAG2XeaaU https://t.co/6sN7RSAAQt',
#  '@Dawson_Crikit @_NFTsPromoter @cybotz_nft Grab your #crikits before they🦗🚀⭐\n#crikit #crikitarmy #crikitnft #nftcommunity #freespeech #eth https://t.co/OGxpTeUBNg',
#  '@RyanSAdams @brian_armstrong @LefterisJP @LidoFinance @coinbase @krakenfx @stakedus @BitcoinSuisseAG What a relief. Close call. So glad #eth is protected by benevolent CEOs. https://t.co/ovU2s7f8bR',
#  "@SWAGGYLIONSCLUB; can't stop won't stop let's gooo!\n\nOfficial Discord:\nhttps://t.co/B6xOwBDWuy\n\n#SWAGGYLC #NFT #NFTCommunity #BTC  #ETH #SOL #BSC #BNB https://t.co/PIgwPZ8hdi",
#  '@Upgradde6913 @altcryptocom @Crikit_nft Grab your #crikits before they🦗🚀⭐\n#crikit #crikitarmy #crikitnft #nftcommunity #freespeech #eth https://t.co/lLDiCJOyli',
#  '@Upgradde6913 @cryptogems555 @Crikit_nft Grab your #crikits before they🦗🚀⭐\n#crikit #crikitarmy #crikitnft #nftcommunity #freespeech #eth https://t.co/rsfTUJ9pL2',
#  '@Upgradde6913 @davidgokhshtein @Crikit_nft Grab your #crikits before they🦗🚀⭐\n#crikit #crikitarmy #crikitnft #nftcommunity #freespeech #eth https://t.co/oXSOoKYkjX',
#  '@cyber_bull_ @HAVOC_ERC Join us and have some fun guys, 6 days old and community is amazing and strong holders, dont miss it.\n\nTG: https://t.co/sxbpo6TLHE\n\n#harold #hidethepain #bsc #x100gem #smartchain #memecoin #btc #eth https://t.co/QZtXmtfQAp',
#  '@luffyinutoken @peter1xx4 #LFG #LuffyToken ‼️‼️🚀 CANT WAIT FOR THIS #AMA 🥳🥰✅ \n\n#LUFFY GOING TO $5 #BILLION MC‼️🤑🤑🤑🔥🔥\U0001fae0 #DYOR #100x #OP_FILMRED #TSUKA\n@HuobiGlobal @okx @kucoincom #ONEPIECE1056  #altcoins #NFT #P2E #ETH #BTC #Metaverse #anime #CryptoNews #ONEPIECE #Shib #spiral #VOLTARMY #VOLT https://t.co/Ddl4XYdO4D',
#  "@swaggylionsclub when's the next contest?\n\nOfficial Discord:\nhttps://t.co/B6xOwBDWuy\n\n#SWAGGYLC #NFT #NFTCommunity #BTC  #ETH #SOL #BSC #BNB https://t.co/S1zhw8DRw7",
#  'Angels of anarchy 🔥\n\nAre you a rider ? 👀\n\n#NFTs #NFTGiveaway #nftart #NFTProject #NFTdrop #sneakpeak #eth #NFTCommunity https://t.co/NpSuxcXo79',
#  'As promised I´m giving  $20,000  $ETH to the first 2000 people who follows and retweets! \n\nDrop your #ETH wallet address♥️♥️♥️ https://t.co/pMsrMmekXO',
#  'Bu gönderimi Beğenip,Retweet yapan sıkı takipçilerim arasından 2 kişiye 1000’er ₺ göndereceğim 🎁🎁🎁\nCumartesi gününe özel biraz para dağıtalım sıkı takipçilerime destek olsun ✌️\n⏱Gece 01:45’de kazananları seçerim ve iban isterim\nBOL ŞANSLAR✅🎰\n\n#Binance #ETH #btc #Bitcoin',
#  'But wait…. There’s more!!! 🥳🙌🏼🔥\n\nLETS GOOOOOO!!!!!!!! 🥂👏👏👏👏\n\n#GroveToken #BSC #eth #Crypto #chasinghistory #altcoin #Bullish #SAFEMOONSWAP #BitMart https://t.co/iqxJg6ytwk',
#  'COUNTDOWN TO 2 DAYS! HERE WE GOOOOOO!\n\nTitle: A Detour into the Virtual Nation - HyperNation\nDate: 22 August 2022\nTime: 10:00 EST\nStream: Vimeo\n\nRegistration: \n👉 https://t.co/J5LtBOixCz 👈\n#hypernation #metaverse #blockchain #defi #crypto #btc #eth #dao #nft https://t.co/KhGR9IYHXL',
#  'Choose only two:\n\n1 - $QNT\n2 - $AZERO\n3 - $DAG\n4 - $ALBT\n5 - $MNW\n6 - $NOIA\n7 - $TRAC\n8 - $KDA\n9 - $SAITO\n10 - $LAND\n\n#bitcoin #EthereumMerge #ETH #BTC $ETH $BTC',
#  'Complete silence by @DrTedros, when 1000s of health facilities were destroyed by TPLF in #ETH - tells you 1 thing. He is still a TPLF hack exploiting the directorship position at @WHO to score wins for his terrorist orgn. #SackTheDG #UN #bbc https://t.co/lsoaKkb3mc',
#  "Currency price update:\n\n$21265 #BTC\n$1632.24 #ETH\n\n#Cardano $0.453745 #ADA\n#ShibaInu $1.318e-05 #SHIB\n#BasicAttention $0.361376 #BAT\n#AxieInfinity $14.41 #AXS\n#Maker $840.71 #MKR\n\n$0.341609 USD #XRP\n€0.34035 EURO\n¥46.77 JPY\n\nJoin the People's Blockchain, link in bio.",
#  'Drop !\n\nBirdy Bob on OpenSea!\n https://t.co/jYG9ryuY1s @opensea \n\n#nft #eth #BobMarley https://t.co/TzoFZYOgQ1',
#  'Drop your #ETH wallet address, I’m going to send 4 people some #Ethereum and 5 FREE #NFTs\n\nYou must turn notifications &amp; RT | 24 hours⏲️',
#  'Ethereum’da Merge’den Sonra Neler Gerçekleşecek? Merge Yükseltmesi ETH Fiyatını Nasıl Etkiler? \n\n#kripto #kriptopara #bitkoin #koin #coin #crypto #kriptohaber #bitcoin #btc #ethereum #etheryum #eth   \n\nhttps://t.co/pLvrVLRHpo',
#  'FREE #NFT GIVEAWAY\nJUST FOLLOW RT LIKE\nDROP YOUR #ETH ADDRESS https://t.co/QY8wkcbWwd',
#  'First Airdrop to our Early Supporter!\nRules To Enter:\n1️⃣Must be follow \n2️⃣Like and RT\n3️⃣Tag 3 Friends\n4️⃣Sumbit Details: https://t.co/Yy9hROIQw0\n\nFirst 1.000 Valid Entry will get 500K $CANTOINU\n\n#Airdrop #Airdrops #Etherum #eth #Giveaway #binance #BSC #cryptocurrency #Crypto https://t.co/2fL4taROY0',
#  'First Airdrop to our Early Supporter!\nRules To Enter:\n1️⃣Must be follow \n2️⃣Like and RT\n3️⃣Tag 3 Friends\n4️⃣Sumbit Details: https://t.co/g21wZbhaKS\n\nFirst 1.000 Valid Entry will get 500K $CANTOVI\n\n#Airdrop #Airdrops #Etherum #eth #Giveaway #canto #cryptocurrency #Crypto #bsc #binance https://t.co/QHanjpHBXW',
#  'For everyone rt like I  will send you $5000\nDrop your #ETH address https://t.co/8xhhfSJkb8',
#  'For those of us that know that the future of finance is #Crypto and are long term #Hodlers of #BTC and #ETH,price volatility is nothing more than an opportunity to shed degen dead weight before our face melting move to the stratosphere. Bye leveraged traders. Good riddance. #HODL https://t.co/OoQSVNlBTu',
#  "Full thanks to @Tradeosiann as they have analysed this #bitcoin crash so my funds doesn't affected and I not faced any type of losses \nThey are absolutely amazing in tips,advices and everything #Metaverse #BINANCE #BTC #ETH 🤭",
#  'GIVEAWAY🎉🚀\n\n0.4 #ETHEREUM (2 winners will be announced, 0.2 eth each)\n\n-Rt\n-Follow @thecoinswatch\n\nEnds in 24h\n💰💰💰💰\n\n#ETH #ETHgiveaways #Crypto #CryptoGiveaway #Giveaway #GiveawayAlert  #BTC',
#  'Get your ticket for MGC1K private #NFT SALE!!!\n\n#NFTs #100DaysOfCode #ETH #MGC1K https://t.co/T5aYalA94p',
#  'Global Borsa listelenmesi için son 6 gün!\n\nhttps://t.co/xfljvmDPGW\n\n#BRN #Metaverse #Bitcoin #Crypto #eth #bnb #USDT',
#  'Gn/Gm #NFTCommunity 💙\n\nWith my pleasure to share with you my artwork ( Lipstick 💄)\n\nAvailable ⬇️ 0.06 #ETH \n\nWill be grateful for your support 😘✌️\n\nCheck out this item on OpenSea https://t.co/FlZ98yacSQ via @opensea \n\n#NFT #NFTs #nftcollector ❤️\u200d🔥💙 https://t.co/eEcurFy1dn',
#  'Heya,we are starting collabs for all of projects to help them, and making together for create the biggest portfolio all of chains.Just DM for this.\n#Solana #eth #btc #bnb #avax #polygon #NFTs #NFTCommunity #NFTGiveaways #nftcollections #nftdrop #Tether',
#  'Hızlı Etkinlik Zamanı 🎁\n\n2 Takipçimize 200 TRX 🍀\n\n24:00’da Açıklanacak 🎁\n\nŞartlar : \n\n- Beni Takip Etmek \n\n- Bu Gönderiyi Beğenmek \n\n- Rt Yapmak \n\n#shiba #Doge #btc #eth #avax #ıcp #ceek',
#  "I did it and now I'm in love👀👀 @3LandersNFT  where my 3Landers at 🥺🥺🥺\n\n#3L4L #NFTs #eth https://t.co/vX7Aeen8Xx",
#  'I would advise everybody to sell your #ETH and load up on $XRP',
#  'If the #ETH merge is completed as scheduled in September 2022, comment below what your preferred method of #payment will be: PayPal? Credit card? Or #crypto?',
#  'If this plays out I don’t mind waiting 10 years to make millions. Allllll I got is time baby. 💎🤲🏻 #Crypto #eth #Bitcoin https://t.co/3iKALwf8bA',
#  'Its all in the eyes \n\n#zilliqa #zil #zilfam #art #nft #nftart #btc #eth https://t.co/8KWiogpArK',
#  "JUST IN: Massive adoption. Don't miss out. Now is your chance to get in, grab more at this discount price &amp; #HODL for the huge pump.🤝💹\n\n#Bitgert #Brise #Bitgertcommunity #BRC20 #crypto #binance #Huobi #catecoin #shib #doge #btc #eth #sol #blockchain #web3 #Defi #NFTs #altcoin https://t.co/4c85g1e9vV",
#  'Last 6 days for global exchange listing!\n\nhttps://t.co/Fe2EJGngi2\n\n#BRN #Metaverse #Bitcoin #Crypto #eth #bnb #USDT',
#  "MASSIVE ANNOUNCEMENT TOMORROW 📣\n\nNotifications on, you won't want to miss this. 🔔\n\nAny interactions will be considered for whitelist. ✅\n\n#ETH #NFTs #FreeMints #SeasonsNFT https://t.co/MDG07P1eBF",
#  'More NFTs in the loyalty Store!\nJust added @TheFacelessMany &amp; @drifters_nft 🥳\nThis on top of @plataNetwork @elrondapes @cantinaroyal @cryptopittz \n@superrare_bears\n\nWork up the levels &amp; claim these great artworks \n\nEmail signup, fully licensed, $EGLD, #ETH, $BTC deposits https://t.co/rvzivMt0FL',
#  'Part 2 🍌🏝 \n#NFT #NFTCollection #ETH https://t.co/eFBmbwgJhS',
#  'Providing Liquidity to $Earn YFO📈🤩\n\n🥂 Start Earn now https://t.co/xGMErvRnDp\n\n📈Find YFO on Uniswap : https://t.co/51Hvy5KP79…\n\n💎Find YFO on Pancakeswap :\nhttps://t.co/8azM9TuF9V…\n\n#Ethereum #ETH #Bscgem #DeFi #NFTCommunity #NFT #farming #BSC https://t.co/0GtJmT8UYW',
#  'Ripple/XRP-FedNow-CBDC Delay Or Secret Liquidity Pools?,Ripple Private XRP Preallocation Contracts?\n\nhttps://t.co/uPn2uH9y3J\n\n#XRP #BTC  #ETH  #BCH #LTC #xrpthestandard #ripple #ripplenews #DigitalPerspectives #Crypto #GoldFi #Glint #Financial #Investing #procoinnews #RETWEET https://t.co/dBGRw29Fia',
#  'SEASONS NFT x @PotHeadsHQ\n\n🎁 Whitelist Giveaway 🎁\n\n3X WL @SeasonsNFT_\n\nTo enter:\n✅ Follow @SeasonsNFT_ + @PotHeadsHQ + @moroccanbet\n✅ Like &amp; RT\n✅ Tag 3 friends \n#NFTGiveaway #FreeMint #NFT #ETH #NFTs\n24hrs 🚨🚨🚨 https://t.co/Ek7QA0ybyt',
#  'Shill me one #gem that will do 100x in 2022 _________ 💎?\n\nMine: @Hodl \n\n#Emdarks #Gems #binance #BNB #ETH #1000xgem #moon #BSC #btc',
#  'Slow 2.4 | Normal 4 | Fast 10.2 | Instant 16.3 👈 current Ethereum gas prices in gwei. DM me a price and I will DM you as soon as gas drops below that price 👍 #Ethereum #GasPrice #ETHGasPrice #ETH\n\nHave you used the other bots in my family? @AVAXGas, @FTMGas',
#  'Some people missed the whole pump of  #Bitcoin from $17,600 to $24,500 &amp; #ETH from $880 to $2,000 because they were bearish. \n\nNow when bitcoin came down to $21,000 they are coming out with tweets like “told you so“ \n\nLike bro wtf! you missed 2x on ETH &amp; easy swing trade on #BTC',
#  'Sweating for crypto gains pique your interest? Help your physique while pumping up your portfolio 💼 #MotionToken #SaitaPro #Gym #uniswap #ETH #workout\n\nFollow:\n@Jon_Quinnell \n@NewtonMotion \n@token_motion https://t.co/0HdQ39eYhz',
#  'The first #Crypto Project with #MoveToEarn Auto-staking &amp; Auto-compounding with $GMT &amp; $BNB Dividends \n\nTwitter- @RunEarner\n\n👟Audit &amp; KYC Soon\n👟Launching Soon\n👟Website &amp; App Live\n\n#STEPN #NFT #ETH #Move2Earn #m2e #GMT #nft #BTC\xa0#BNB\xa0\xa0#NFTshill #Altcoins $FITFI #PlayToEarn #P2E https://t.co/KVsRRQTo1J',
#  'Tokenomics and $SURV #Airdrop  numbers have been finalized.\n\nThere will be airdrops on #AVAX #FTM and #ETH to all Surveyor #NFT holders.\n\nAirdrop size determined by rarity. These numbers will also be released this weekend.\n\nIf you havent minted yet: \n\nhttps://t.co/WPx6kkymJ0 https://t.co/LbThgAZ7kK',
#  'We just Crossed 1000 Followers !! And we want to celebrate it .\n 2 Lucky Followers will get 50 $OP each .\n\n1- Follow @OpNService  Like +RT + tag 3 Friend\n2- Comment Your OP address + Desired .op Domain \n\n ~72 hrs\n#Giveaways  #ETH  #Ethereum  #Airdrop   #ENS \n#Optimism  #Binance https://t.co/zSpbxOdyJX',
#  'We will giveaway 500$ to 5 winner in 7 days, you simply need to RT, Like + register at https://t.co/GPaVvXt7CY\n\nPost your username for proof 👇\n\nGood luck 🤞\n\n#BTC #ETH #Crypto #Cryptocurrency https://t.co/KJcLJyLoLi',
#  "Weekend's here, and we are running a GIVEAWAY to make your weekend bright and awesome! ✨\n\nWe can't wait to bring $SHROOM to the #Polygon and #ETH communities 🍄\n\n🎉50 $MATIC to 5 winners🎉\n\n♥️ &amp; RT \nFollow @wonderdotgame\nTag 3 friends\n\n⏰72 hours!⏰ https://t.co/jnabtMWOp8",
#  'With Dumbledao you buy and sell \n#Dumbledore @Dumbledao $DUMBLE\nLink tree: \nhttps://t.co/DvbdeeSHRr\n#Crypto #lunar #NFTcommunity #Nfts  #CryptoNews #BSCGems #BSCGem  #100xGems #Eth #BSC #trading #DeFi ... https://t.co/lCivGj3sht',
#  'Your network is your networth 🌐 #bnb #bsc #etc #eth #ethereum #crypto #memeverse',
#  'Zoomex - Rejoignez la compétition de trading et avoir une chance de gagn... https://t.co/wYVkf6UTy9 via @YouTube @ZOOMEX_COM \n#referral #BTC #ETH #bonus #giveaways #USDT #USDC #USD #zoomex #French #Crypto',
#  '[#CORE Daily Report(08.20)] 📈\n\n1️⃣1 tCORE = 830 sUSDT(18↑)🚀\n    📌https://t.co/Hj7X1jKsYV\n\n2️⃣APR: 419% = 1.1%/Day 💵😍\n    📌https://t.co/h24bQn4NCP\n\n3️⃣Downloads: 53.6M(0.2↑) ⛏️\n    📌https://t.co/EIidrzV4Fr 🚀\n     ✅️Join now(android only)\n\n#CoreDAO #BTCs #BTC #ETH #Satoshi https://t.co/L9gaxRlnxD',
#  'updated price for $EOS, $ETH, $TRX:\n\n#EOS $1.287 USD\n#ETH 0.076683 #BTC\n#TRX 4.02e-05 #ETH\n\nI tweet updated prices, follow me to get recent updates.\n\n#cryptocurrency #crypto',
#  'Çok samimi söylüyorum etherium kendini bırakacak… #eth',
#  '🌈  Bedans | FREE MINT  x Niner 🍭\n\n🎁 2 x Bedans FREE MINT giveaway\n\n1⃣Follow @Bedans_Official + @lijiuer1 \n2⃣RT +Like +Tag 3 friends\n\n⏲️24hrs\n#NFTCommunity #NFTGiveaway #ETH https://t.co/k1vVY17k3g',
#  '🌍 The Afrikans #NFT is an exclusive collection of 1111 unique art pieces, each representing the rich cultural and ethnic diversities of the African continent. \n\nA journey to revolutionize the robust #web3 ecosystem in the continent.\n\n⛵️ https://t.co/RArl2dHK1M\n\n#NFTs #ETH #BTC https://t.co/8Zi9JMsR4z',
#  "🍂 / / SEASONS RAFFLE \\ \\ 🌺\n\nAugust will be the start of a WILD ride, don't miss out. Seasons is coming to you very soon.\n\n10x Seasons WL spots 🌞\n\nTo enter: 🌺\n\n🌿 Follow\n@SeasonsNFT_\n \n🏷️ RT + Like\n✨ Tag 3 friends\n✅ Join the Discord\n\n#ETH #NFTs #FreeMints #SeasonsNFT https://t.co/KbKcTs4xxv",
#  '🎁 $100 CASH &amp; WL GIVEAWAY 🎁\n\nPrizes:\n🏆 $100 CASH\n🏆 6x WL\n🎫\n1️⃣ Follow @GroofStreet &amp; me\n2️⃣ RT LIKE + TAG 3 FRENS\n3️⃣ Have notifications on 🔔\n\n⭐️Bonus Join DC 👇🏻\nhttps://t.co/Khnm9VHicj\n\n48Hrs📢\n#GROOFSTREET #NFT #NFTproject #Solana #NFTs #ETH #NFTCommunity https://t.co/zPijUEHZrn',
#  '🎁 $150 CASH &amp; WL GIVEAWAY !🎁\n\n🏆 $150 CASH\n\n🏆 5x Whitelist\n\n1⃣ Follow @KOTJ_NFT\n\n2⃣ Like &amp; RT\n\n3⃣ Tag 3 Friends\n\nEnds in 48 hrs ⏳👀\n\n#NFTGiveaway #Giveaway #Airdrop #NFTdrop #SOL #SolanaNFT #ETH https://t.co/qE3nnaOQOz',
#  '🎁 $200 CASH GIVEAWAY 🎁\n\n🏆 $200 CASH\n\n🎫\n1⃣ RT + Like\n2⃣ Follow me &amp; @ENZA_ETH \n3⃣ Tag 3 friends\n\n48Hrs📢\n#ETH #NFT #NFTs #Giveaway #SOL\n#Solana #Matic #Crypto #Ethereum https://t.co/tPtBsIZK5k',
#  '🎁 $400 CASH &amp; NFT GIVEAWAY ! 🎁\n\nPrize :\n🏆 $400 CASH \n🏆 5x NFT\n\n1⃣Follow me &amp; @Ownic_Official \n2⃣RT &amp; Like\n3⃣Tag 3 friends\n\n48h🕘\n#Solana #SOL #SolanaNFT #ETH\n#Giveaway #NFT $SOL #Crypto #NFTs https://t.co/S7watWs6ss',
#  '🎁 GIVEAWAY 🎁\n\nPrizes:\n🏆 𝟮𝟱 𝘅 𝗪𝗟\n🏆    𝟱 𝘅 𝗢𝗚\n\nTo enter:\n1️⃣ Follow @solcadia_nft\n2️⃣ Like + Retweet\n3️⃣ Tag 3 friends\n\n⭐Join the Solcadia Discord for an 𝗲𝘅𝘁𝗿𝗮 𝗲𝗻𝘁𝗿𝘆!\n\nEnds in 48h ⏳\n\n#NFT #NFTGiveaway #NFTCommunity #ETH #Ethereum #Whitelist https://t.co/5oljNjjiyB',
#  '🎁 GIVEAWAY 🎁\n\n🏆 0.25 $SOL [ $10 ]\n🏆 10x WL Spots \n\nTo Enter\n1⃣  RT, Like &amp; Follow @GothicOkami \n2⃣  Their 📌 RT, like &amp; Comment\n\n⏱️ 24 Hours #ETH #NFTs #Giveaways #NFTCommunity https://t.co/tpD5SMf8kj',
#  '🎁 GOLD LEGENDARY #30 BANANA BALLERS NFT + AUTOGRAPHED STEPH CURRY 🏀 JERSEY \n\n1⃣ Follow @banana_ballers + @bananaballerceo + @StephenCurry30 \n2⃣ RT + Like\n3⃣ Tag 3 friends\n\n⏰ Ends on Mint Day 8.20.22 5pm EST\n#NFTCommunity #NFTGiveaway #ETH #StephenCurry #NBA #Basketball https://t.co/JkrbC4sAiJ',
#  '🎉 Freemint Giveaways🎉\n\nWe will be giving away:\n•🎟️3x Free Mint Spots for @usedtoiletswtf\n\nTo enter: \nFollow @usedtoiletswtf&amp; @NFTscj\nRT &amp; Tag 3 friends \nWinners will be announced in 24 hours! Good luck!\n\n#ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/9F2fNRLCzL',
#  '🎉 Freemint Giveaways🎉\n\nWe will be giving away:\n•🎟️3x Free Mint Spots for @usedtoiletswtf\n\nTo enter: \nFollow @usedtoiletswtf&amp; @RoyalAlpha_X\nRT &amp; Tag 3 friends \nWinners will be announced in 24 hours! Good luck!\n\n#ETH #NFTs #FreeMint #NFTCommunity #DYOR #NFTGiveaways #Web3 https://t.co/eWV5Ezrjgn',
#  '🎉The second stage of our #giveaway schedule is now live!\n\n🎁Prizes:\n\n5 x “Cool Creator” passes🎟\n5 x “Smart Collector” passes🎟\n\n💰Value: 1.65 #ETH ~ $2800\n\n✅Follow @8mint_Official \n✅Like, RT &amp; tag friends\n\n⏰10 winners in 48h\n\n#NFTGiveaway #FreeMint #NFT #WhitelistGiveaway https://t.co/u1f9VcDlBr',
#  '🎊 #Huobi PrimeBox x \n#ETH 2.0 Carnival Launched!\n\n🔥𝟏,𝟐𝟎𝟎 𝐄𝐓𝐇 𝐒𝐡𝐚𝐫𝐞𝐝, 𝐂𝐨𝐥𝐥𝐞𝐜𝐭 𝐂𝐚𝐫𝐝𝐬:\n🔹Trade\n🔹Refer \n🔹And More \n\n#EthereumMerge\n\n👇Get started\nhttps://t.co/OYrTVOW2qS https://t.co/VyXLjhIR5D',
#  '🐯Giveaway Announcement 🐯\n\n🎁 We are giving 1 NFT @LazyLionsNFT\n\nTo Win 🏆: \n\n1⃣-FOLLOW @crazytigernft\n2⃣-RT+ Like + RT pin Post\n3⃣-Tag3people \n\n Winner in 48 hours ⏱️\n\n#NFTGiveaway #NFTdrops #ETH #nftart #crypto #NFTCommunity https://t.co/Wk6PS3Q83W',
#  '🐯Giveaway Announcement 🐯\n\n🎁 We are giving 1 NFT @alienfrens\n\nTo Win 🏆: \n\n1⃣-FOLLOW @crazytigernft\n2⃣-RT+ Like + RT pin Post\n3⃣-Tag3people \n\n Winner in 48 hours ⏱️\n\n#NFTGiveaway #NFTdrops #eth #nftarti̇st #Crypto #NFTCommunity https://t.co/yMM5enFTtn',
#  '💎Circle DAO 🤝 PROJECT KAITO 💎\n\nGiving away 2x Spots on here and 10x spots in @intocircledao Discord\n \nTo enter:\n1️⃣Follow @ProjectKaitoNFT @intocircledao\n &amp; @___mo2000\n2️⃣Like &amp; RT\n3️⃣Tag 3 Friends!\n\n⏰24 Hours\n#WL #ETH #Nftgiveaway #freemint https://t.co/wtSAEATlxv',
#  '💥 The #1 Supporter of @Bitgertbrise🎖\n.\n➡ Hit "💙" &amp; "Retweet" you\'re a fan/supporter of #Bitgert &amp; @Brisecommunity\n\n#Brise #Bitgertcommunity #Crypto #Binance #btc #saitama #shib #babydoge #eth #sol #cryptocurrencies #blockchain #shibainu #loveylinu #catecoin https://t.co/SMyUvZdFcw',
#  '💰 2 KİŞİYE 100$ #Usdt💰\n (Sponsorlu)\n\n📌 Katılım;\n1️⃣ @SpartaKripto ve @DozzeCrypto TAKİP et\n2️⃣ Beğen+RT\n3️⃣ TRC20/Usdt adresini yoruma bırak \n\n24 Saat sonra sonlanacaktır.\n\n#btc #Eth #Pitbulltoken #Kriptoçekiliş #Airdrop #Giveaway #Ceek #Raca #çekiliş #Avax\xa0\xa0#Airdrops #Trx\xa0\xa0#SOL',
#  '💰🎁First 1000 People Retweet will receive 10 $ETH ($17,000  ) just follow, like, and retweets this &amp; 🔥\n\nDrop your #ETH   address\n\nsubscribe https://t.co/rbpcbn8X0X https://t.co/M00fb4kI0N',
#  "💸 $500 #Giveaway #Round 1💸\n\nWe'll select 5 winners randomly and award $100 $BUSD to each account! 🤑🤑\n\nRules: 👇\n\n1️⃣ Follow us &amp; @NanoMinionsnews \n 2️⃣ Tag 3 friends\n3️⃣ Like &amp; Retweet\n\nWinners will be picked in 72 hours\nGood luck 💚\n\n#ETH #DeFi #BSC #BTC\xa0\xa0\xa0\xa0 #BNB\xa0#BUSD #USDT",
#  "💸 $500 #Giveaway 💸\n\nWe'll select 5 winners randomly and award $100 to each account! 🤑🤑\n\nRules: 👇\n\n1️⃣ Tag 2 friends\n2️⃣ Must Like, Follow &amp; Retweet \n\nGood luck 💚\n\n#BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT\n\n🔗 https://t.co/iOPgBrB7rr https://t.co/sobuxJaIqE",
#  '💸🔥FCFS RAFFLE🔥💸 \n⏳24 hours⏳ \n🏆8 winners🏆\nMetablizzard\xa0 \n⛄️The first 200 will get\n🎁5 X\xa0 Metablizzard W/L spots \n💵3 X 5 USD in USDT\nRules:\n1.Follow @Metablizzardart\n2. Like &amp; RT raffle post\n3.Drop your #ETH adress in replay https://t.co/sz9JzqJJfb',
#  '📢 Interact to win 1 of 3 WL! \n⏰ 48h\n\nOur #NFTgame Power Plins is all about pancakes. Collect recipes &amp; ingredients, craft pancakes, fight and get special loot!\n\n🚀 Mint AND Game Launch: Sept 2022\n👉 Discord: https://t.co/lVx8fIyhRV\n\n#NFT #Arbitrum #Ethereum #ETH #NFTCommunity https://t.co/L6lzPKWYYC',
#  '📣3 SAATLİK KISA ÇEKİLİŞ 📣    \n\n🎖150 TL🎖\n\n⚔️ Şartlar ⚔️ \n\n1️⃣BEĞEN❤️-RT🔁\n2️⃣@DopeDeerzNFT‘ nin sabit tweetine RT + Like at.🏆Bonus: İngilizce güzel yorum yapanlar 50 TL daha kazanacak!\n\n#btc\xa0#giveaway #eth #luna #binance\xa0#nfts #avax\xa0#elon #dolar #shib #ape #web3 #sol #bnb #faiz',
#  '🔥 MASSIVE #Giveaway 🏆\n\n1× FREE MINT (NFT WORTH 160$)😱\n\n10× WL SPOTS 🔥\n\nTO WIN:⤵️\n✅ Follow @GasMonsterNFT &amp; @DSDAO5\n\n✅ Like,RT &amp; Turn on 🔔\n\n✅ Join discord. https://t.co/L4TNWKQGWi\n\n✅ Tag 3 Frens\n\n24H ⏰\n\n#NFTs #NFTGiveaways #NFTCommumity \n#ETH #Giveaways #Airdrop #nftart https://t.co/R41kQT9YU7',
#  '🔥 Sending 2 x $250 in #BNB to 2 random people who:\n\n✅ Like &amp; RT\n✅ Follow @AltCryptoGems &amp; @Rovercrc\n\nChoosing the winners in 3 days with Twitterpicker! \n\n#BTC #Giveaway #ETH #Crypto',
#  '🖼️ Black Future Collection 🖼️\n\nA collaboration with Cadillac &amp; Nyla Hayes to create an exclusive 1/1 and limited edition Black Future Long Neckie #NFT Dropping on #OpenSea, a portion of the sales will benefit the Save the Music Foundation.\n\n⛵️ https://t.co/pJyGnL3iVU\n\n#NFTs #ETH https://t.co/Xyd7dijYUI',
#  '🚀#Airdrop:100 winners share the prize pool valued 1,000U\n\n🔥A Walkthrough of Primebox X #ETH 2.0 Carnival\n⏰8/22,12:00UTC\n☑️Follow @Huobi_Research,@Oceanland_io,@FellazXYZ\n☑️RT+tag 3 friends\n☑️Watch #Huobi live: https://t.co/LbmfHc7clN\n\n⬇️Fill out form.\nhttps://t.co/FQKcA9S6lg https://t.co/8c1rMzlLap',
#  "🚨 Don't Miss Our Third Airdrop 🎁 Coming Very Soon⏳🔥🚀\n\n#Airdrops #AirdropCrypto\n#Contest #Giveaway #GiveawayAlert #CryptoGiveaway #NFTGiveaway #NFTCommunity #NFT\n#cryptocurrency #Crypto #CryptoNews #BSC #BSCGem #Fairlaunch #launchpad #BNB #Binance #ETH #Solana #CRO #Metamask https://t.co/ACnIQor2xE",
#  "🤖Circle DAO x The R3al Metaverse WL Giveaway 🤖\n\n💥We've decided to partner up with @r3almetaverse to offer 5x WL spots for their 34 episode parody series 💥\n\n1️⃣Like, RT\n2️⃣Follow @r3almetaverse &amp; @intocircledao \n3️⃣Tag 3 friends\n\n⏰24 Hours\n#WL #ETH #Nftgiveaway #metaverse https://t.co/D9yEkWBlVI"]

# %%
jsondata.describe()
# Out:
#        Tweet Scraped  Following Count  Follower Count   Total Tweets  \
# count     200.000000       200.000000      200.000000     200.000000
# mean      100.500000      1235.940000     4519.515000   14024.045000
# std        57.879185      1482.957712    47343.437444   34199.939678
# min         1.000000         0.000000        0.000000       6.000000
# 25%        50.750000       147.000000       28.000000     604.000000
# 50%       100.500000       595.000000       86.000000    2626.000000
# 75%       150.250000      1837.500000      329.250000   11849.000000
# max       200.000000      5239.000000   666931.000000  348097.000000
#
#        Retweet Count
# count     200.000000
# mean     1385.805000
# std      2231.981454
# min         0.000000
# 25%        16.500000
# 50%       161.000000
# 75%      1434.500000
# max     11623.000000
