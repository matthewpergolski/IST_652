# %% [markdown]
# # Final Project Code | IST 652

# %% [markdown]
# ## Package Install

# %%
# Download Packages if Needed
###########################################################################################################################

# %pip install tweepy
# %pip install ipywidgets

# %%
# Import Needed Packages
###########################################################################################################################

import pandas as pd
import numpy as np
import tweepy
import configparser
import json
import os
import re
import pandas as pd
import ipywidgets as widgets
from IPython.display import clear_output
from ipyfilechooser import FileChooser
from ipywidgets import interact
from pathlib import Path
from textblob import TextBlob, Word, Blobber
from textblob.classifiers import NaiveBayesClassifier
from textblob.taggers import NLTKTagger
#import matplotlib.pyplot as plt

# %% [markdown]
# ## Defining Functions

# %%
# Choose File Through Widget Experience | config.ini
###########################################################################################################################

# get home dir of user
home = str(Path.home()) 

# initialize a dict for the excel file; this removes the need to set global values
dict_file = {}

# change to simply `home` if you want users to navigate through diff dirs
#fc = FileChooser(f'{home}/excel')
fc = FileChooser(f'{home}/') 

# same here
#fc.sandbox_path = f'{home}/excel'
fc.sandbox_path = f'{home}/'

# limit file extensions to '.xls, .xlsb, .xlsm, .xlsx'
fc.filter_pattern = ['*.ini*']
fc.title = '<b>Select your file</b>'
display(fc)

# create empty dropdown for sheet names
dropdown = widgets.Dropdown(options=[''], value='', description='Sheets:', disabled=False)

# create output frame for the df
out = widgets.Output(layout=widgets.Layout(display='flex', flex_flow='column', align_items='flex-start', width='100%'))
# Out:
# FileChooser(path='/Users/pergolicious', filename='', title='<b>Select your file</b>', show_hidden=False, selec…

# %%
# Save actual key values to a separate '.ini' file for privacy reasons (don't want to directly share my keys with the world)
###########################################################################################################################

#configfile = '/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/FinalProject-Config.ini'

configfile = f'{fc.selected_path}/{fc.selected_filename}'
print(configfile)

config = configparser.ConfigParser()
config.read(f'{configfile}')

API_KEY = config['twitter']['API_KEY']
API_KEY_SECRET = config['twitter']['API_KEY_SECRET']
ACCESS_TOKEN = config['twitter']['ACCESS_TOKEN']
ACCESS_TOKEN_SECRET = config['twitter']['ACCESS_TOKEN_SECRET']
# Out:
# /Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/FinalProject-Config.ini

# %%
# Define function to print metadata information for tweets
###########################################################################################################################

directory = '/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project'

def printtweetdata(n, ith_tweet, scrapped_data):
    
    d = {"Tweet Scraped":n, "Username": ith_tweet[0], "Description" :ith_tweet[1], "Location": ith_tweet[2], 
         "Following Count":ith_tweet[3], "Follower Count":ith_tweet[4],"Total Tweets":ith_tweet[5], "Retweet Count": ith_tweet[6],
         "Tweet Text": ith_tweet[7],"Hashtags Used":ith_tweet[8]}
         
         
    
    print(f"Tweet Scraped{n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f" Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text: {ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")
    
    scraped_data.append(d)
    
    try:
        if not os.path.isdir(f'{directory}'):
            os.mkdir(f'{directory}')
        with open(f'{directory}/final-project-scraped_data-{words}.json', 'w') as outfile:
            json.dump(scraped_data, outfile, indent = 4)
    except:
        print ("An exception occurred")

# %%
# Authentication the account and credentials
###########################################################################################################################

auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth)

# %%
# Define function to scrape twitter for data based on 3 different prameters
###########################################################################################################################

def scrape(words, numtweet, scrapped_data):
    tweets = tweepy.Cursor(api.search_tweets, q = words, len = 'en',
                          tweet_mode = 'extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    
    i = 1
    
    # Extract various infomration through an iterative process
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
    
        
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
            
            
        ith_tweet = [username, description, location, following,
                   followers, totaltweets, retweetcount, text, hashtext]
        
        printtweetdata(i, ith_tweet, scraped_data)
        i = i+1

# %% [markdown]
# ## Gather and Format/Transform Data

# %%
# Gathering of Data | 1 | Bitcoin Tweets
###########################################################################################################################

print('Enter hasthag to search for')
words = input()

print('Enter number of tweets to search for')
numtweet = int(input())

scraped_data = []
print('Fetching tweets...')

scrape(words, numtweet, scraped_data)
print('scraping has completed! :)')
# Out:
# Enter hasthag to search for
#  #BTC
# Enter number of tweets to search for
#  500
# Unexpected parameter: len
# Fetching tweets...
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Tweet Scraped1:
# Username:0xbigwin_2901
# Description:Alhamdulillah for everything..#win #1000$ #pickme #pickaw #twitter ... inshallah too many wins in August🌟
# Location:
#  Following Count:2024
# Follower Count:50
# Total Tweets:9412
# Retweet Count:2609
# Tweet Text: 10$ GIVEAWAY | 4 HRS ☀️
#
# RT + Follow @DeGodsNFTS
#
# #NFTs #nft #NFTGiveaway #Giveaway #NFTCommunity #freemint #ethereum #btc #eth #crypto #cryptocurrency https://t.co/AhhBRE89Xp
# Hashtags Used:['NFTs', 'nft', 'NFTGiveaway', 'Giveaway', 'NFTCommunity', 'freemint', 'ethereum']
# Tweet Scraped2:
# Username:encryptedtermi1
# Description:Bitcoin´s terminator itsef: the only viable future for humanity. "If you don't believe me or don't get it, I don't have time to try to convince you, sorry." SN.
# Location:All the way ^
#  Following Count:73
# Follower Count:92
# Total Tweets:1707
# Retweet Count:0
# Tweet Text: @NevesPhilip @VitalikButerin You can get a miner a connect it to a pool and still earn #BTC. You haven´t refuted my arguments after saying that I'm incorrect. You limited yourself to parrot out what you've been sold.
# Hashtags Used:['BTC']
# Tweet Scraped3:
# Username:wodehous_gene
# Description:certified cat girl.
# Location:
#  Following Count:68
# Follower Count:14
# Total Tweets:7
# Retweet Count:1
# Tweet Text: Let  me introduce you to and access free Automation online for all your Complaint
#
# Inbox me I'm always available 24/7
# #HACKED #systemdown #unknownuser #accessdenied #coinbase
# #Bitcoin #BTC #BitcoinCash # BCH #Ripple #XRP #Monero #XMR #web3
# Hashtags Used:[]
# Tweet Scraped4:
# Username:leonsp3
# Description:The Certified online, Personal Health, Life & Mindfulness coach. Published Author .
# Entrepreneur and Internet Visionary
# Location:Pennsylvania, USA
#  Following Count:221
# Follower Count:101
# Total Tweets:258
# Retweet Count:265
# Tweet Text: HyperNation Dollar (HND) is a blockchain algorithmic stablecoin that is pegged to the U.S Dollar through the Proof of Consensus (POC).
# https://t.co/9UNxX0eVhg
#
# Follow @HyperNation8 &amp; @HyperNFTpro for more!
# #hypernation #metaverse #defi #dao #blockchain   #crypto #nft #eth #btc https://t.co/CXIIHr30cF
# Hashtags Used:[]
# Tweet Scraped5:
# Username:Valy200778
# Description:
# Location:
#  Following Count:184
# Follower Count:94
# Total Tweets:3501
# Retweet Count:9
# Tweet Text: #FEG TOKEN kodlamalar devam ederken yeni FEG token nasıl bir şey olacak merak edenler kimler? #SmartDeFi #BNB #EthereumMerge #BTC https://t.co/L8zrXmuVx6
# Hashtags Used:['FEG', 'SmartDeFi', 'BNB', 'EthereumMerge']
# Tweet Scraped6:
# Username:Vandad32050628
# Description:💰💲
# Location:
#  Following Count:29
# Follower Count:24
# Total Tweets:262
# Retweet Count:0
# Tweet Text: @cryptojack #eversafuv2 #BTC #BNB #BUSD #BSC  #rewards #transparent #gem #moon #passiveincome #positiverebase⚡🙏👌❄✔🔥💯❤🗯
# Hashtags Used:['eversafuv2', 'BTC', 'BNB', 'BUSD', 'BSC', 'rewards', 'transparent', 'gem', 'moon', 'passiveincome', 'positiverebase']
# Tweet Scraped7:
# Username:BitomicWhales
# Description:I tweet all #Bitcoin transactions over $25M #USD.
#
# https://t.co/JaklYlO2xd for more crypto alerts.
# Location:
#  Following Count:0
# Follower Count:181
# Total Tweets:35970
# Retweet Count:0
# Tweet Text: Someone just transfered 4756.66 #BTC ($94M USD)!
#
#             https://t.co/nFQRD2r7s6
# Hashtags Used:['BTC']
# Tweet Scraped8:
# Username:Winter2449
# Description:
# Location:
#  Following Count:272
# Follower Count:13
# Total Tweets:485
# Retweet Count:249
# Tweet Text: Bankman-Fried 说他的加密货币救助“结果喜忧参半”
# https://t.co/wOtiaAjaHY
# #FTX  #News #chinase #crypto #BTC #Ethereum
# Hashtags Used:['FTX', 'News', 'chinase', 'crypto', 'BTC', 'Ethereum']
# Tweet Scraped9:
# Username:leonsp3
# Description:The Certified online, Personal Health, Life & Mindfulness coach. Published Author .
# Entrepreneur and Internet Visionary
# Location:Pennsylvania, USA
#  Following Count:221
# Follower Count:101
# Total Tweets:258
# Retweet Count:93
# Tweet Text: 🎉Great News Citizens of HyperNation🎉
# Our HyperNation Token (HNT) value had increased 40% since its launching on 22nd August 2022🥳🥂
# https://t.co/30wvXfva25
#
# Follow @HyperNation8 &amp; @HyperNFTpro for more!
# #hypernation #metaverse #defi #dao #blockchain #hnt #crypto #nft #eth #btc https://t.co/WfSQ5LskUh
# Hashtags Used:[]
# Tweet Scraped10:
# Username:ozdenozen33
# Description:🌼🌼🌼
# Location:
#  Following Count:66
# Follower Count:73
# Total Tweets:1110
# Retweet Count:0
# Tweet Text: @Alyattes_ALYA @MEXC_Global #Alyattes #AlyaAıTrading #AlyaTOKEN #AlyaFINANCE #AlyaCARE #AlyaBot #Binance #BinanceBrokerAccount
# #BSCGEMS #BSC  #Mining #btc #Ethereum #BNB #DeFi  #Crypto #mining  #GEM @MEXC_Global #AlyattesSocialTeam 🧨
# Hashtags Used:['Alyattes', 'AlyaAıTrading', 'AlyaTOKEN', 'AlyaFINANCE', 'AlyaCARE', 'AlyaBot', 'Binance', 'BinanceBrokerAccount', 'BSCGEMS', 'BSC', 'Mining', 'btc', 'Ethereum', 'BNB', 'DeFi', 'Crypto', 'mining', 'GEM', 'AlyattesSocialTeam']
# Tweet Scraped11:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:1
# Follower Count:113
# Total Tweets:51686
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1562.08 USD
# #Bitcoin 0.07921081268565668 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped12:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338584
# Retweet Count:0
# Tweet Text: #STXUSDT Bull Alert!
#
# 5X Volume
# Price:      0.364
# 5-min %: 0.55%
# Volume:  $6,210
#
# #crypto #whale #btc #eth #STX $STX https://t.co/iUwznadiwh
# Hashtags Used:['STXUSDT', 'crypto', 'whale', 'btc', 'eth', 'STX']
# Tweet Scraped13:
# Username:brezilvinu
# Description:
# Location:
#  Following Count:188
# Follower Count:21
# Total Tweets:161
# Retweet Count:285
# Tweet Text: All you have to do to win is buy $VINU
#
# #bitcoin #btc #eth #crypto https://t.co/aMmWiqo1i6
# Hashtags Used:['bitcoin', 'btc', 'eth', 'crypto']
# Tweet Scraped14:
# Username:qunz620
# Description:对新事物充满好奇！勇于接收！
# Location:
#  Following Count:97
# Follower Count:24
# Total Tweets:330
# Retweet Count:36
# Tweet Text: Are you still worried about the deposit and withdrawal? Still struggling with how to cash in? Come to the #AirCash access platform! Direct wallet operation, fast, safe and worry-free!
# @Aircoinrea
# #AirCoinDAOLabs
# #AirCoin
# #AirCash #AirChain
# #BTC #BNB #solana #Binance #Coinbase https://t.co/v2FTKL5w7h
# Hashtags Used:['AirCash']
# Tweet Scraped15:
# Username:purigardengroup
# Description:#BSC #BNB #USDT #BUSD, Giveaway hoki 🏅🌟
# Location:indonesia
#  Following Count:1477
# Follower Count:177
# Total Tweets:39019
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped16:
# Username:gerradfletcher
# Description:Stay Focus, do not let them distract you #btc #MarketNewsWatch #tradingview
# Location:
#  Following Count:336
# Follower Count:5290
# Total Tweets:396
# Retweet Count:0
# Tweet Text: Investors frequently make things too difficult for themselves. Buffett's preferred value stocks frequently outperform the market, making success easier. Long-term profits are much easier to achieve with automated trading than with supposedly selling shorts. #marketnewswatch #BTC https://t.co/WVt570sXeR
# Hashtags Used:['marketnewswatch', 'BTC']
# Tweet Scraped17:
# Username:Abdulla40732281
# Description:Blog
# Location:
#  Following Count:83
# Follower Count:3
# Total Tweets:395
# Retweet Count:11
# Tweet Text: Head over to our Marketplace to list or buy Enders Gate NFT Trading Cards!⚔️
#
# Marketplace: https://t.co/xDn3JDdru9
# Website: https://t.co/V0zVL4wb5K
# Discord: https://t.co/kVryGFLE9a
# NFT Shop: https://t.co/Xfrgs6rZZD
#
# #EndersGate #HarmonyONE #BTC #ETH #P2E #TCG #marketplace https://t.co/tpdUDRt25W
# Hashtags Used:[]
# Tweet Scraped18:
# Username:abiwineveryday
# Description:Activated for Giveaway || suspended acc @syahrilabibii @sawabi_abi @abi_sawabi || i have 2 device (Realme android & dekstop acer ) karena kadang kerja nyambi rt
# Location:indonesia
#  Following Count:3141
# Follower Count:251
# Total Tweets:28263
# Retweet Count:1183
# Tweet Text: $50 - 12 HOURS 💵
#
# RT, like + follow @Crazy8Metasino (🔔) &amp; interact with their pinned 📌
#
# 🎰 CRAZY 8 METASINO 🎰
#
# #SOL/#DUST CASINO LAUNCH #GIVEAWAY!
#
# #NFT #NFTs #Crypto #Solana #ETH #NFTGiveaway #NFTGiveaways #NFTdrop #NFTcontest #Airdrop #crypto #NFTshill  #Web3 #P2E #BTC https://t.co/74m0dXI0Hj
# Hashtags Used:['SOL', 'DUST']
# Tweet Scraped19:
# Username:CryptoActu
# Description:Actualités et analyses dans le domaine des #cryptomonnaies, #Bitcoin, #Ethereum, #DeFi, #Blockchain 🚀
#
# https://t.co/N5zMPhSlmT ⚡️
# Location:France
#  Following Count:372
# Follower Count:17383
# Total Tweets:5484
# Retweet Count:0
# Tweet Text: #BlackRock choisit d'utiliser l'indice Bitcoin CF Benchmarks de #Kraken pour le suivi de prix dans sa fiducie #BTC à venir👇
# https://t.co/U0ls9iEomM
# Hashtags Used:['BlackRock', 'Kraken', 'BTC']
# Tweet Scraped20:
# Username:shinjastic23
# Description:Invest Wisely🤓, HODL 💎 = GODL🥇
# You Are a “KIP” If You Do Not Buy The “DIP”
# Location:
#  Following Count:2
# Follower Count:372
# Total Tweets:20372
# Retweet Count:131
# Tweet Text: #Bitcoin is moving in the same way like 2013/14 bear market.
#
# Three wave tops🔴🟡🟢are demonstrated in RSI Bollinger Bands associated with $BTC delayed 3 wave tops.
#
# Bull run is coming🚀
#
# RT and FOLLOW appreciated ￼
# #Bitcoin￼ #BTC￼ #Cryptos https://t.co/pUK1wvOYHS
# Hashtags Used:['Bitcoin']
# Tweet Scraped21:
# Username:RMindscapes
# Description:📽️ 📸 🎭 🎥📽️
# Film Director / wriiter / Stunt / fight choreographer/ action designer
# https://t.co/R2MKkTmQvu
# https://t.co/XANXJUbEgv
# Location:Florida, USA
#  Following Count:313
# Follower Count:47
# Total Tweets:65
# Retweet Count:0
# Tweet Text: Check out my item listing on OpenSea! https://t.co/4mcQvE7EG1 via @opensea #NFT #NFTs #NFTCommunity #NFTartist #NFTartwork #dark #goth #artwork #horror #scifi #hrgiger #monster #aliens #arte #ai #collectible #btc #crypto #digitalart #anunaki #tarot #zodiac #Creature
# Hashtags Used:['NFT', 'NFTs', 'NFTCommunity', 'NFTartist', 'NFTartwork', 'dark', 'goth', 'artwork', 'horror', 'scifi', 'hrgiger', 'monster', 'aliens', 'arte', 'ai', 'collectible', 'btc', 'crypto', 'digitalart', 'anunaki', 'tarot', 'zodiac', 'Creature']
# Tweet Scraped22:
# Username:BMA_blockchain
# Description:Blockchain Master Academy is an academy based on digital diversity training in financial markets and blockchain development.
# Location:
#  Following Count:0
# Follower Count:571
# Total Tweets:195
# Retweet Count:0
# Tweet Text: 05.09.2022 - Monday ✨Latest Crypto &amp; Financial Market Recap 📈
# -
# 2022 年 9 月 5 日 - 星期一✨最新的加密和金融市场回顾🥰
#
# 💁🏻‍♀️Watch it in the link below🔥
# https://t.co/XbIWrXMLYe
# .
# #blockchain #academy #crypto #eth #btc #nft https://t.co/KiHnkt8CAm
# Hashtags Used:['blockchain', 'academy', 'crypto', 'eth', 'btc', 'nft']
# Tweet Scraped23:
# Username:tmaeda09859926
# Description:$NXD
# Location:
#  Following Count:3319
# Follower Count:663
# Total Tweets:15473
# Retweet Count:72
# Tweet Text: 0.00023 #BNB to 1 Winner 🔥
#
# 1) Follow ✅
# 2) Like ❤️
# 3) Retweet 🔃
#
# #Crypto #BTC #LTC #Giveaways  #binancecode  #Bitcoin          #ETH #cryptoboxcode #BinancePay #cryptobox #BNB       #Binance https://t.co/SEY6NUIQWM
# Hashtags Used:['BNB', 'Crypto', 'BTC', 'LTC', 'Giveaways', 'binancecode', 'Bitcoin']
# Tweet Scraped24:
# Username:MnGfUPmJ8o
# Description:simple people. single, crypto enthusiast.    Now there is #BTC #ETH #LUNC #SHIB. Not taking risks. Like to socialize, read and learn, freedom
# Location:Los Angeles
#  Following Count:188
# Follower Count:25
# Total Tweets:76
# Retweet Count:0
# Tweet Text: Secret meeting of two crypto enthusiasts.🤣🤣🤣#BTC #ETH #SHIB #LUNC #LTC #DOGE #USDT #USDC #cryptocurrency #XRP #BNB #ADA #NFT #DeFi 🚀🚀🚀 https://t.co/LS1wFeXfKn
# Hashtags Used:['BTC', 'ETH', 'SHIB', 'LUNC', 'LTC', 'DOGE', 'USDT', 'USDC', 'cryptocurrency', 'XRP', 'BNB', 'ADA', 'NFT', 'DeFi']
# Tweet Scraped25:
# Username:bruindesimon
# Description:
# Location:
#  Following Count:2561
# Follower Count:713
# Total Tweets:56478
# Retweet Count:1
# Tweet Text: 📢Is ETH the new poster boy of crypto ?
#
# 📋 Curated post from Publish0x
# 💎 Read or write articles and get 💰 #crypto #referral #earn #btc
# https://t.co/6IcCSR7n1y
# Hashtags Used:['crypto', 'referral', 'earn', 'btc']
# Tweet Scraped26:
# Username:FalihTac
# Description:Mersin üniversitesi
# Galatasaray
# Turizm Rehberliği
# Fethiye
# Evergreen Travel
# Location:Fethiye, Türkiye
#  Following Count:233
# Follower Count:34
# Total Tweets:366
# Retweet Count:180
# Tweet Text: Rastgele beğenilerden 2 dostumdan İban isteyeceğim🤝🙋‍♂️
#
# #btc #bitcoin #LUNC #shiba #ETH
# Hashtags Used:['btc', 'bitcoin', 'LUNC', 'shiba', 'ETH']
# Tweet Scraped27:
# Username:1400stimulus
# Description:Tracking what a US $1400 stimulus check would be worth today if it was invested in various cryptocurrencies. Not financial advice. #bitcoin @crypto_stimulus
# Location:New Orleans, LA
#  Following Count:2
# Follower Count:694
# Total Tweets:9353
# Retweet Count:0
# Tweet Text: $BTC: $484.99 (34.64%)
# $ETH: $1,244.17 (88.87%)
# $ADA: $670.70 (47.91%)
# $BNB: $1,478.63 (105.62%)
# $DOGE: $1,592.66 (113.76%)
# $LINK: $355.56 (25.40%)
# $TRX: $1,771.56 (126.54%)
# $XRP: $1,048.33 (74.88%)
# $CAKE: $528.28 (37.73%)
#
# #btc #eth #ada #bnb #doge #cake
# Hashtags Used:['btc', 'eth', 'ada', 'bnb', 'doge', 'cake']
# Tweet Scraped28:
# Username:TheMintingM
# Description:Crypto | Quants | Research
# Location:
#  Following Count:69
# Follower Count:657
# Total Tweets:1775
# Retweet Count:0
# Tweet Text: Have you ever attended a Web 3.0 event or a meetup?
#
# #crypto #bitcoin #investment #trading #altcoins #blockchain #stockmarket #luna #terra #invest #trader #wealth #NFTs #stablecoins #stocks #btc #eth #bitcoins #binaryoptions #cryptopoll #poll
# Hashtags Used:['crypto', 'bitcoin', 'investment', 'trading', 'altcoins', 'blockchain', 'stockmarket', 'luna', 'terra', 'invest', 'trader', 'wealth', 'NFTs', 'stablecoins', 'stocks', 'btc', 'eth', 'bitcoins', 'binaryoptions', 'cryptopoll', 'poll']
# Tweet Scraped29:
# Username:mattu83
# Description:
# Location:
#  Following Count:337
# Follower Count:17
# Total Tweets:551
# Retweet Count:11430
# Tweet Text: 💸 $1,000 #Giveaway 💸
#
# We'll select 10 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrSIiZ https://t.co/DiRKGbV3cW
# Hashtags Used:['Giveaway']
# Tweet Scraped30:
# Username:stew_ilondanga
# Description:Stewart Milimu ilondanga = https://t.co/uS39Qb8kKt…
# Location:Nairobi
#  Following Count:39425
# Follower Count:58821
# Total Tweets:112091
# Retweet Count:0
# Tweet Text: While virtual reality will play a role in the metaverse, the metaverse will encompass a combination of a variety of different technologies. It also won’t replace the internet, but rather build on it. #gainwithstewartilondanga #AR #AI #MR #XR #NFTs #BTC #CRO #xrp #DeFi #FFTB #Web3
# Hashtags Used:['gainwithstewartilondanga', 'AR', 'AI', 'MR', 'XR', 'NFTs', 'BTC', 'CRO', 'xrp', 'DeFi', 'FFTB', 'Web3']
# Tweet Scraped31:
# Username:LuckyRiego08
# Description:shalallahu 'ala Muhammad
# shalallahu 'alaihi wa salam🏆
# Location:
#  Following Count:983
# Follower Count:52
# Total Tweets:13553
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped32:
# Username:ShanksHaki23
# Description:Terus berjuang $OCA
# Location:Bantimurung, Indonesia
#  Following Count:279
# Follower Count:12
# Total Tweets:456
# Retweet Count:781
# Tweet Text: 🔥🔥  𝐒 𝐎 𝐑 𝐓 𝐄 𝐎  🔥🔥
#
# 🚨 Quieres ganar 𝟮𝟱𝟬$ #USDTether #BTC
#
# Para participar
#
# - 🔄 al tweet
# - Sigue @CriiptoWolf @CriptoDrake
# - Sigue @TokoinGlobal @KeplerCapital
#
# Ganador en 48 horas
#
# *Más opciones de ganar si mencionas amigos y ♥️
#
# Suerte 🍀 https://t.co/RPo5JTJf3L
# Hashtags Used:['USDTether', 'BTC']
# Tweet Scraped33:
# Username:ThreeCycles
# Description:🤝ENS Broker: Buy/Sell/Negotiate ➡️🧪NFT Lab: Design/Mint/Sell ➡️💡 Crypto Lab: Consultancy Retweets not endorsements
# https://t.co/YS447MX9M3
# Location:The Metaverse
#  Following Count:1602
# Follower Count:904
# Total Tweets:7719
# Retweet Count:94
# Tweet Text: #BITCOIN IS READY FOR A 3-YEARS BULL MARKET.
#
# After a 1-year bear market, a 3-year bull market has always followed, since the birth of #BTC.
#
# There are 3 months and 28 days left before the closing of this annual candle. https://t.co/0ID5sfp7bE
# Hashtags Used:['BITCOIN']
# Tweet Scraped34:
# Username:Jsrod4
# Description:🚀🚀 Supporting fantastic projects like $CULT $JShare $JAMON $BRISE $STARL $XODEX $RVLT 🔥 put them on staking and get more tokens 😎
# Location:
#  Following Count:4923
# Follower Count:1085
# Total Tweets:15501
# Retweet Count:11
# Tweet Text: #ReadTheCultManifesto. Join the #revolution.
# ✊🏼✊🏾✊🏻✊✊🏿✊🏽
# $CULT and $RVLT.
#
# #wearecultdao #rvlt2earn #cult #BTC  #ETH #publicgood #DAO https://t.co/EDPUGHwKab
# Hashtags Used:['ReadTheCultManifesto', 'revolution', 'wearecultdao', 'rvlt2earn', 'cult', 'BTC', 'ETH']
# Tweet Scraped35:
# Username:ozdenozen33
# Description:🌼🌼🌼
# Location:
#  Following Count:66
# Follower Count:73
# Total Tweets:1110
# Retweet Count:0
# Tweet Text: @Alyattes_ALYA @MEXC_Global #Alyattes #AlyaAıTrading #AlyaTOKEN #AlyaFINANCE #AlyaCARE #AlyaBot #Binance #BinanceBrokerAccount
# #BSCGEMS #BSC  #Mining #btc #Ethereum #BNB #DeFi  #Crypto #mining  #GEM @MEXC_Global #AlyattesSocialTeam
# Hashtags Used:['Alyattes', 'AlyaAıTrading', 'AlyaTOKEN', 'AlyaFINANCE', 'AlyaCARE', 'AlyaBot', 'Binance', 'BinanceBrokerAccount', 'BSCGEMS', 'BSC', 'Mining', 'btc', 'Ethereum', 'BNB', 'DeFi', 'Crypto', 'mining', 'GEM', 'AlyattesSocialTeam']
# Tweet Scraped36:
# Username:FarzadTalebi13
# Description:
# Location:
#  Following Count:3
# Follower Count:0
# Total Tweets:51
# Retweet Count:3
# Tweet Text: 🧥👔 Outfits design concepts - LandRocker #Metaverse
#
# 🤠Build a unique avatar using a wide variety of accessories &amp; outfits
#
# #Accessories #avatar #customized #Glasses #p2e #playandearn #btc #clothes #fashiondesign #outfits #nft https://t.co/VdLZQHgwUz
# Hashtags Used:['Metaverse']
# Tweet Scraped37:
# Username:nyayi_maubigwin
# Description:bismillah selalu berdoa dan berusaha hasil Allah yang tentukan🌺🌷🌹
# 💚 #LegitNina #Ap8testi #jihantesti #sofialegit #Bravepaid #ShillCrewLegit
# Location:Kota Palembang, Sumatera Selat
#  Following Count:4974
# Follower Count:72
# Total Tweets:65549
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped38:
# Username:septemberwin_17
# Description:pengen bigwin tp ga bigwin terus
# Location:DKI Jakarta, Indonesia
#  Following Count:4919
# Follower Count:84
# Total Tweets:27572
# Retweet Count:1977
# Tweet Text: ⚡The greatest interest in #BTC and #ETH among U.S. states is shown in California
#
# 💭For reference, California is the headquarters of #Apple, #Alphabet and #Facebook🤔 https://t.co/WYR3NIUlsi
# Hashtags Used:['BTC', 'ETH']
# Tweet Scraped39:
# Username:AyacheShaddi
# Description:S+K+K
# Location:
#  Following Count:50
# Follower Count:29
# Total Tweets:13
# Retweet Count:0
# Tweet Text: Worried about this weekly bearflag #btc
# Hashtags Used:['btc']
# Tweet Scraped40:
# Username:coinok
# Description:Fast Crypto Exchange #BTC #Bitcoin #HODL
# Location:
#  Following Count:3283
# Follower Count:10487
# Total Tweets:487715
# Retweet Count:0
# Tweet Text: 1 BTC Price: Bitstamp 19715 USD #BTC #Bitcoin 2022-09-05 01:30 https://t.co/hYwn2yDkS1
# Hashtags Used:['BTC', 'Bitcoin']
# Tweet Scraped41:
# Username:Rashedu30542
# Description:Students
# Location:
#  Following Count:897
# Follower Count:17
# Total Tweets:2557
# Retweet Count:247
# Tweet Text: How Many Core Coin You have mine.
# Retweet and Like Guy's
# #Core #BTC #BTCs
# Hashtags Used:['Core', 'BTC', 'BTCs']
# Tweet Scraped42:
# Username:Lord_Defi22
# Description:#Defi lover, crypto hodler.
# Location:
#  Following Count:5
# Follower Count:107
# Total Tweets:37826
# Retweet Count:0
# Tweet Text: updated price for $QTUM, $ETH, $ETC:
#
# #QTUM $3.173 USD
# #ETH 0.079167 #BTC
# #ETC 0.02055 #ETH
#
# I tweet updated prices, follow me to get recent updates.
#
# #cryptocurrency #crypto
# Hashtags Used:['QTUM', 'ETH', 'BTC', 'ETC', 'ETH', 'cryptocurrency', 'crypto']
# Tweet Scraped43:
# Username:oxbigwin_jenny
# Description:
# Location:
#  Following Count:2563
# Follower Count:72
# Total Tweets:12632
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped44:
# Username:Oxypickawpickme
# Description:New Acc
# Location:
#  Following Count:1550
# Follower Count:41
# Total Tweets:4210
# Retweet Count:2609
# Tweet Text: 10$ GIVEAWAY | 4 HRS ☀️
#
# RT + Follow @DeGodsNFTS
#
# #NFTs #nft #NFTGiveaway #Giveaway #NFTCommunity #freemint #ethereum #btc #eth #crypto #cryptocurrency https://t.co/AhhBRE89Xp
# Hashtags Used:['NFTs', 'nft', 'NFTGiveaway', 'Giveaway', 'NFTCommunity', 'freemint', 'ethereum']
# Tweet Scraped45:
# Username:AndreaB25128396
# Description:nfts/ens/web3/poker 💕
# Location:Accra, Ghana
#  Following Count:0
# Follower Count:39
# Total Tweets:19
# Retweet Count:5
# Tweet Text: Currency price update:
#
# $21127 #BTC
# $1571.72 #ETH
#
# #Radix $0.059304 #XRD
# #Kava $1.8 #KAVA
# #Filecoin $6.25 #FIL
# #Decentraland $0.833382 #MANA
# #ElrondGold $52.45 #EGLD
#
# $0.340151 USD #XRP
# €0.338897 EURO
# ¥46.57 JPY
#
# Join the People's Blockchain, link in bio.
# Hashtags Used:['BTC', 'ETH', 'Radix', 'XRD', 'Kava', 'KAVA', 'Filecoin', 'FIL']
# Tweet Scraped46:
# Username:NecroKittie
# Description:#Mexc referral 1SdcL
# $Cel #CommunityFirst
# #CelShortSqueeze https://t.co/hhu5lon4D9
# #Bitcoin 💸
# #ETH 0xfe9c29eacafad4c36008f190a665f2510342d765
# Location:Texas, USA
#  Following Count:854
# Follower Count:383
# Total Tweets:1503
# Retweet Count:0
# Tweet Text: #CelShortSqueeze #CelsiusNetwork #Celsius #BTC #MOASS #GME #AMC #CommunityFirst #CELARMY #GMESQUEEZE #wallstreetbets #Crypto #trading #usd  #ETH #bitcoin #Tea #bet #altcoins #gambling #Luck #lottery #jackpot #win #winning #awardwinning #results $cel https://t.co/8OjycF0qrT
# Hashtags Used:['CelShortSqueeze', 'CelsiusNetwork', 'Celsius', 'BTC', 'MOASS', 'GME', 'AMC', 'CommunityFirst', 'CELARMY', 'GMESQUEEZE', 'wallstreetbets', 'Crypto', 'trading', 'usd', 'ETH', 'bitcoin', 'Tea', 'bet', 'altcoins', 'gambling', 'Luck', 'lottery', 'jackpot', 'win', 'winning', 'awardwinning', 'results']
# Tweet Scraped47:
# Username:M_artinKeown
# Description:I live in England, i like competitions, love football, watch the soaps (love Corrie) and generally here just to have a good time. #savethebees
# Location:United Kingdom
#  Following Count:2699
# Follower Count:2941
# Total Tweets:157982
# Retweet Count:6
# Tweet Text: ✨💰DAY 5//12 OF GIVEAWAY💰✨
#
# Win up to 10BN #KISHK and 100 #USDT or #USDC 💵💵💵
# ALL YOU HAVE TO DO IS:
#
# 👨‍👩‍👦TAG 3 FRIENDS
# 👀FOLLOW @TheChosenShib
# 👍LIKE &amp; RETWEET THIS POST
#
# Winner will be randomly selected Friday 9th of September.GoodLuck!
# #giveaway #giveaways #Crypto #BTC 🍀
# Hashtags Used:['KISHK', 'USDT', 'USDC']
# Tweet Scraped48:
# Username:0xbigwin18
# Description:bismillahirrahmanirrahim ✨
# matikan retweet yaa 👍
# Location:Indonesia
#  Following Count:4013
# Follower Count:95
# Total Tweets:15419
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped49:
# Username:LivePriceCrypto
# Description:I Tweet the latest #Bitcoin & #Ethereum price and Daily/Weekly Technical Indicators Data every minute.
#
# Developed the 20/03/2022
# Location:
#  Following Count:4
# Follower Count:3434
# Total Tweets:234074
# Retweet Count:0
# Tweet Text: #Bitcoin Last Price $19727 #BTC 🚀
# Daily Indicators:
# •Variation since 00h00(UTC): -1.38%
# •MACD:
#  -MACD Line: -771
#  -Signal Line: -721
#
# #Ethereum Last Price $1561 #ETH
# •Variation: -1.1%
# •MACD:
#  -MACD Line: -33
#  -Signal Line: -29
#
# #Blockchain #Web3
# (2/6)
# 233899
# Hashtags Used:['Bitcoin', 'BTC', 'Ethereum', 'ETH', 'Blockchain', 'Web3']
# Tweet Scraped50:
# Username:Sitiali33884557
# Description:Aku bukan bot/multi akun/scamer, beri kesempatan aku untuk menang,
# #Bigwin
# Location:Tanjung Morawa, Indonesia
#  Following Count:880
# Follower Count:159
# Total Tweets:3109
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped51:
# Username:WarPigs2DaMoon
# Description:Executive Chef with over 25 years in the food and Beverage industry. Hotel and Tourism is ready for Block Chain #Family #WarPigs #WPT 🐗 #Food #Crypto
# Location:Portland, OR
#  Following Count:4961
# Follower Count:826
# Total Tweets:10580
# Retweet Count:12
# Tweet Text: @WPT_Investing Syndicate will be no joke when it comes to enhancing the ecosystem. We have seen nothing yet! Please understand these advanced Tokenomics. Even @Token_Sniffer doesn’t understand the future 🧠🐗🧠$WPT #WARPT #StakingRewards #WontStopCantStop #btc #bnb #NFTutilities https://t.co/fks344nam1
# Hashtags Used:[]
# Tweet Scraped52:
# Username:TtwStockBot
# Description:https://t.co/vGCpFOJbTG
#
# 지인들과 있는 채팅방에 전달하는 메세지 보관용도의 트위터 봇일뿐임
#
# 타인, 제 3자와 소통을 위해 만들어진 봇이 아닙니다.
# Location:
#  Following Count:0
# Follower Count:100
# Total Tweets:37470
# Retweet Count:0
# Tweet Text: 네옴 다 가야지 한미가 단기과열이라 ㅋㅋㅋ LS전선도 네옴이드만 네옴 찌라시가 하도 많아서 ㅋㅋㅋㅋ
#  #thdtjsdn #주식 #NASDAQ #BTC
# Hashtags Used:['thdtjsdn', '주식', 'NASDAQ', 'BTC']
# Tweet Scraped53:
# Username:widya_mbul
# Description:#crypto
# #solana
# #holderNFT
# Location:Netherburn, Scotland
#  Following Count:703
# Follower Count:61
# Total Tweets:2531
# Retweet Count:178
# Tweet Text: 💸 $500 #Giveaway #Round 4💸
#
# We'll select 10 winners randomly and award $50 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Must Follow us &amp;
# @sCrypto0x
# (🔔)
# 2️⃣ Tag 3 friends
# 3️⃣ Like &amp; Retweet
#
# Winners will be picked in 48 hours
# Good luck 💚
#
# #ETH #NFTs  #ETH #BTC     #BNB  #BUSD  #USDT https://t.co/jbuszMYc0N
# Hashtags Used:['Giveaway', 'Round']
# Tweet Scraped54:
# Username:FarzadTalebi13
# Description:
# Location:
#  Following Count:3
# Follower Count:0
# Total Tweets:52
# Retweet Count:3
# Tweet Text: 🧥👔 LandRocker #Metaverse - Avatar concept design
#
# #avatar #customized #p2e #playandearn #btc #fashiondesign #nft #MetaverseNFT https://t.co/VpnP4jYZp2
# Hashtags Used:['Metaverse', 'avatar', 'customized', 'p2e', 'playandearn', 'btc', 'fashiondesign', 'nft']
# Tweet Scraped55:
# Username:razorhh4
# Description:
# Location:
#  Following Count:140
# Follower Count:8
# Total Tweets:131
# Retweet Count:249
# Tweet Text: Bankman-Fried 说他的加密货币救助“结果喜忧参半”
# https://t.co/wOtiaAjaHY
# #FTX  #News #chinase #crypto #BTC #Ethereum
# Hashtags Used:['FTX', 'News', 'chinase', 'crypto', 'BTC', 'Ethereum']
# Tweet Scraped56:
# Username:BTC_for_Freedom
# Description:Fix the money, fix the world🇳🇴
# Location:Norway
#  Following Count:493
# Follower Count:10601
# Total Tweets:2839
# Retweet Count:45
# Tweet Text: 16.8M #BTC
# —————— = 0.0021 BTC/person
#    8B people
# Hashtags Used:['BTC']
# Tweet Scraped57:
# Username:FarzadTalebi13
# Description:
# Location:
#  Following Count:3
# Follower Count:0
# Total Tweets:52
# Retweet Count:2
# Tweet Text: 🧥👔 Outfits design concepts - LandRocker #Metaverse
#
# 🤠Build a unique avatar using a wide variety of accessories &amp; outfits
#
# #Accessories #avatar #customized #Glasses #p2e #playandearn #btc #clothes #fashiondesign #outfits #nft https://t.co/TGYscJB8HL
# Hashtags Used:['Metaverse']
# Tweet Scraped58:
# Username:razorhh4
# Description:
# Location:
#  Following Count:140
# Follower Count:8
# Total Tweets:131
# Retweet Count:256
# Tweet Text: 这是对 Twitter 新的编辑推文功能的测试。 什么是编辑推文？
#  #News #chinese #crypto #BTC #ETH #Twitter
# https://t.co/8D3ihh4ZmJ
# Hashtags Used:['News', 'chinese', 'crypto', 'BTC', 'ETH', 'Twitter']
# Tweet Scraped59:
# Username:sahany967
# Description:Eski hesabım askıya alındı yeni hesabım bu
# Location:Denizli, Türkiye
#  Following Count:498
# Follower Count:135
# Total Tweets:16430
# Retweet Count:1
# Tweet Text: Gunaydın  Guzel  ınsanlar  hayırlı  bereketlı  kazanclı  bır  hafta  olması  dıleğıyle.❤️
# #btc #eth #zignaly #zigusdt
# Hashtags Used:['btc', 'eth', 'zignaly', 'zigusdt']
# Tweet Scraped60:
# Username:OxCitayamSlebew
# Description:Niat Dan Doa
# Location:Jakarta Barat, DKI Jakarta
#  Following Count:4534
# Follower Count:577
# Total Tweets:41504
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped61:
# Username:winterusufe
# Description:🔗VOUCH 6️⃣5️⃣🎹 #IwonHanabi #JaxLegit #HwannieProofs
# #VenusIsReal #bunniefied #izzywins #DobiProofs #christagifts #ravivouches #callistars #Jenus ✨🌟🍀🤑🤑
# Location:Republic of the Philippines
#  Following Count:2900
# Follower Count:136
# Total Tweets:19089
# Retweet Count:1977
# Tweet Text: ⚡The greatest interest in #BTC and #ETH among U.S. states is shown in California
#
# 💭For reference, California is the headquarters of #Apple, #Alphabet and #Facebook🤔 https://t.co/WYR3NIUlsi
# Hashtags Used:['BTC', 'ETH']
# Tweet Scraped62:
# Username:Sundayeverydaii
# Description:Jww:)
# Location:
#  Following Count:1370
# Follower Count:97
# Total Tweets:5958
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped63:
# Username:SparRoW90224966
# Description:Tell me, please, are all these practical jokes true or lies, or just a joke?
# Location:
#  Following Count:463
# Follower Count:59
# Total Tweets:790
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped64:
# Username:Binance_12
# Description:【取引する度に20%還元】 国内では取引できない仮想通貨なら バイナンス💡 招待コード入れて登録するだけ💰 取引手数料が20%オフに🉐 招待コードはこちら↓ FKZ6AXPG #仮想通貨 #Binance #BTC
# Location:
#  Following Count:1
# Follower Count:32
# Total Tweets:8526
# Retweet Count:0
# Tweet Text: 【取引する度に20%還元】
#
# 国内では取引できない仮想通貨なら
# バイナンス💡
#
# 招待コード入れて登録するだけ💰
# 取引手数料が20%オフに🉐
#
# 招待コードはこちら↓
# FKZ6AXPG
#
# #Binance
# #BTC
# #招待コード
# #20%
# 14:30
# Hashtags Used:['Binance', 'BTC', '招待コード']
# Tweet Scraped65:
# Username:BoxaOfficial
# Description:$BOXA A New Generation of Travel Experience |https://t.co/paRETh1S8o |https://t.co/2dQ4VkLOSW
# Location:
#  Following Count:110
# Follower Count:937
# Total Tweets:330
# Retweet Count:0
# Tweet Text: Good morning from Slovenia, #BOXA fam. #boxaestate #Crypto #eth #BTC https://t.co/cKQ1mIMNjP
# Hashtags Used:['BOXA', 'boxaestate', 'Crypto', 'eth', 'BTC']
# Tweet Scraped66:
# Username:ChouTzuyugunthe
# Description:🕯️𝑴𝒂𝒏𝒊𝒇𝒆𝒔𝒕𝒊𝒏𝒈 𝒘𝒊𝒏🕯️
# @JenusHQ #Jenus
# Location:
#  Following Count:3227
# Follower Count:144
# Total Tweets:18460
# Retweet Count:1977
# Tweet Text: ⚡The greatest interest in #BTC and #ETH among U.S. states is shown in California
#
# 💭For reference, California is the headquarters of #Apple, #Alphabet and #Facebook🤔 https://t.co/WYR3NIUlsi
# Hashtags Used:['BTC', 'ETH']
# Tweet Scraped67:
# Username:BalanceOt
# Description:WE DEVELOP RISK MANAGEMENT TOOLS. https://t.co/KRZG9J9af0
# Location:
#  Following Count:147
# Follower Count:688
# Total Tweets:26739
# Retweet Count:0
# Tweet Text: YOUR PRIVATE TRADING ASSISTANT 🚀
#
# #AI look at hourly charts $BTC #BTC
#
# As we look on the one-hour chart, one can observe as price pulled back from the temporary maximum at the...
#
# Just choose your coin and be an expert!
# #crypto #trading
#
# CHECK https://t.co/Gm1Mua8CwN https://t.co/dQFh068mM5
# Hashtags Used:['AI', 'BTC', 'crypto', 'trading']
# Tweet Scraped68:
# Username:poo_chain
# Description:https://t.co/zW14JwT2Su
# Location:
#  Following Count:957
# Follower Count:1275
# Total Tweets:669
# Retweet Count:1
# Tweet Text: 🇺🇸 US Congressman Brad Sherman says there’s too much money and power in #crypto to ban it. #BTC #BITCOIN #Blockchain
# Hashtags Used:['crypto', 'BTC', 'BITCOIN', 'Blockchain']
# Tweet Scraped69:
# Username:365investor
# Description:Swing/day trader. Sharing my opinions & charts, not financial advice.
# https://t.co/61bScJg8jV
# #bitcoin #ethereum #crypto
# Location:Australia
#  Following Count:3
# Follower Count:1377
# Total Tweets:2451
# Retweet Count:0
# Tweet Text: #BITCOIN SELL SIGNAL on the 15min timeframe!
# #btc #crypto #365investor #daytrade #swingtrade #NFA #DYOR
# Check my live stream for more information.
# Not Financial Advice! Trade responsibly.
# Hashtags Used:['BITCOIN', 'btc', 'crypto', '365investor', 'daytrade', 'swingtrade', 'NFA', 'DYOR']
# Tweet Scraped70:
# Username:0xAhmet9876
# Description:Be happy and healthy.
# Location:Türkiye
#  Following Count:301
# Follower Count:10
# Total Tweets:455
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped71:
# Username:crypt0status
# Description:You can follow the instant status of cryptocurrencies.
# Location:
#  Following Count:3
# Follower Count:46
# Total Tweets:3127
# Retweet Count:0
# Tweet Text: 1️⃣ #Bitcoin live: 19757.2440$ - Change: %-0.69 🔴
#
# 1️⃣ #Ethereum live: 1563.1141$ - Change: %-0.48 🔴
#
# Bonus as much as your investment (Coinbase) https://t.co/SbpSs4s0wh 🟢
#
# 🕑 08:30
#
# #btc #eth #coin #crypto #Etherium
# id: e39d09a786
# Hashtags Used:['Bitcoin', 'Ethereum', 'btc', 'eth', 'coin', 'crypto', 'Etherium']
# Tweet Scraped72:
# Username:bidmaster777
# Description:https://t.co/WHLVAnVHWK
# Location:
#  Following Count:1073
# Follower Count:230
# Total Tweets:104872
# Retweet Count:1
# Tweet Text: https://t.co/9azTezog2E register on #defichain and earn with me #cryptocurrency  #bitcoin #metaverse  #nft #polkadot #solana #ethereum #vechain #cardano $btc $eth $dfi $sol $ada $bnb $vet $doge #dfi #btc  #solana #binance #dogecoin (7:28)
# Hashtags Used:['defichain', 'cryptocurrency', 'bitcoin', 'metaverse', 'nft', 'polkadot']
# Tweet Scraped73:
# Username:byMPA
# Description:
# Location:
#  Following Count:1854
# Follower Count:267
# Total Tweets:2043
# Retweet Count:755
# Tweet Text: GELENEKSEL #USDT ÖDÜLLÜ ÇEKİLİŞİMİZ DEVAM EDİYOR! 📢📢📢
#
# Bu twiti beğenip RT eden takipçilerimden rastgele #TRC20 adresi isteyip #USDT göndereceğim.
# Sonuç saat 23.00’da…
#
# #Bitcoin   #BTC   #ETH
# Hashtags Used:['USDT', 'TRC20']
# Tweet Scraped74:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:1
# Follower Count:113
# Total Tweets:51686
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1563.02 USD
# #Bitcoin 0.07914129 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped75:
# Username:pramodyojit
# Description:ADS Coin My Love
# Location:
#  Following Count:571
# Follower Count:349
# Total Tweets:4887
# Retweet Count:13
# Tweet Text: Staked 300+ Cr #token already out of 1000 Cr Market Cap.
# Coming with 9 DIGITAL PLATFORMS, 5M+ COMMUNITY, ADSCOIN EXCHANGE &amp;  AS PER GOVT. GUIDELINES BY SEPTEMBER.
# "ADS GROUP OF COMPANIES "
# #BTC #bnb #kucoin
# @therahulads
# @adscoinofficial
# @Bscgemalerts
# @PMOIndia @RBI https://t.co/m2FfFWSpFY
# Hashtags Used:['token']
# Tweet Scraped76:
# Username:Minahpamungkas
# Description:my previous account @.pamungkas_minah @.Minpempeaz @.minah_pamungkas @.Minah_keyong @.Oxminah @.minapamungkas got suspended 🙏
# Location:banyumanik semarang
#  Following Count:4986
# Follower Count:253
# Total Tweets:109668
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped77:
# Username:hodler_investor
# Description:🇨🇿 #bitcoin maximalista a NFT geek žijící na Bali 🌴
#
# 💰 Můj projekt "₿itcoinová půjčka" v odkazu
#
# 💎🙌 = 🚀🌕
# Location:Bali, Indonesia
#  Following Count:230
# Follower Count:5125
# Total Tweets:2768
# Retweet Count:0
# Tweet Text: 📰#Bitcoin novinky:
#
# 💰Státní #BTC dluhopisy v Salvádoru🇸🇻 jsou stále odloženy (link 1⬇️)
#
# ⚡️Kapacita sítě #LightningNetwork  se za poslední rok zdvojnásobila na více než 4600 BTC (link 2⬇️)
#
# Bitcoin cena včera:🟩 +169$ / 0.85 %
#
# Přeji krásný den!
# Hashtags Used:['Bitcoin', 'BTC', 'LightningNetwork']
# Tweet Scraped78:
# Username:LeopoldMore3
# Description:... I know that I'll drown on my own
# Location:
#  Following Count:175
# Follower Count:42
# Total Tweets:11
# Retweet Count:1
# Tweet Text: #AirCash is a decentralized platform for the #exchange of Fiat currency and #cryptocurrency .It is on the #BSC ,#Avalanche , #Moonriver and #OasisNetwork
#
# @AirCoinreal #Aircoin $Air #AIR #AirCoinDAOLabs  #DeFi #Btc #cryptotrading #KuCoin #Huobi #Binance #OKEx #Gateio https://t.co/Szwyn8C2co
# Hashtags Used:['AirCash', 'exchange', 'cryptocurrency', 'BSC', 'Avalanche']
# Tweet Scraped79:
# Username:Binance__a1
# Description:BINANCE（バイナンス）の招待コード配布中（無断使用OKです）。 招待コードもしくは下記URLからの登録で取引手数料が【20%永久割引】になります。  ▼招待コード X61FCWIM  ▼招待URL https://t.co/Prf6jENyqW
# Location:
#  Following Count:1
# Follower Count:21
# Total Tweets:5366
# Retweet Count:0
# Tweet Text: バイナンスに登録する際こちらの招待IDか固定ツイートのURLから登録して頂くと取引額から手数料20%が永久に割引されます。
# 是非ご利用ください。
#
# ID:X61FCWIM
#
# 1814:30
#
# #Binance
# #BTC
# Hashtags Used:['Binance', 'BTC']
# Tweet Scraped80:
# Username:miss54430134
# Description:
# Location:
#  Following Count:22
# Follower Count:21
# Total Tweets:243
# Retweet Count:0
# Tweet Text: @cryptojack #eversafuv2 #BTC #BNB #BUSD #BSC  #rewards #transparent #gem #moon #passiveincome #positiverebase🔥❤💫
# Hashtags Used:['eversafuv2', 'BTC', 'BNB', 'BUSD', 'BSC', 'rewards', 'transparent', 'gem', 'moon', 'passiveincome', 'positiverebase']
# Tweet Scraped81:
# Username:HarryBe43608515
# Description:
# Location:
#  Following Count:93
# Follower Count:4
# Total Tweets:4
# Retweet Count:17
# Tweet Text: Bonus #Giveaway
# 💸 $100 💸 $USDT 💰💰
# To win:
# 👉 Follow, ❤ &amp; Retweet
#
# U must be a follower to win 🏆
# 48hrs ⏳⏳
#
# #Giveaways #NFTCommunity #BTC #ETH #Airdrops #Crypto #cryptocurrency #CryptoGiveaway #BSC #Solana https://t.co/xx0Q8Jqq6s
# Hashtags Used:['Giveaway', 'Giveaways']
# Tweet Scraped82:
# Username:Mehmetgun1234
# Description:
# Location:
#  Following Count:404
# Follower Count:12
# Total Tweets:2989
# Retweet Count:11
# Tweet Text: ÜCRETSİZ BASİT TEKNİK ANALİZ ÖĞREN...
#
# Piyasa da 3 çeşit trend türü vardır.
#
# -☆Yükselen trend
# -●Düşen/alçalan trend
# -◇Yatay trend (testere)
#
# #XU100 #btc    #eth #Binance    #BinanceSmartChain #mana https://t.co/k2so9L1oLf
# Hashtags Used:[]
# Tweet Scraped83:
# Username:UEEx_CN
# Description:#UEEx 華語頻道｜快速且方便的加密貨幣交易所，給您最優異的體驗｜https://t.co/ywI82OEQJH
# Location:
#  Following Count:5
# Follower Count:566
# Total Tweets:140
# Retweet Count:0
# Tweet Text: 交易伴手禮！
#
# 活動今天開始！！！有機會贏取現金獎勵
#
# 活動期限
# 2022年9月5日 00:00 - 2022年9月11日 23:59（UTC+8）
#
# 規則
#
# https://t.co/UE1xAgwlqN交易伴手禮-
#
# #btc #eth #交易所 #交易 #数字货币 #加密货币 #活动 #crypto #trading https://t.co/fx0N46sR5H
# Hashtags Used:['btc', 'eth', '交易所', '交易', '数字货币', '加密货币', '活动', 'crypto', 'trading']
# Tweet Scraped84:
# Username:0x_Pickawxyz
# Description:don't worry Uyah ⚡
# Location:Kota Bandung, Jawa Barat
#  Following Count:1728
# Follower Count:55
# Total Tweets:5630
# Retweet Count:2609
# Tweet Text: 10$ GIVEAWAY | 4 HRS ☀️
#
# RT + Follow @DeGodsNFTS
#
# #NFTs #nft #NFTGiveaway #Giveaway #NFTCommunity #freemint #ethereum #btc #eth #crypto #cryptocurrency https://t.co/AhhBRE89Xp
# Hashtags Used:['NFTs', 'nft', 'NFTGiveaway', 'Giveaway', 'NFTCommunity', 'freemint', 'ethereum']
# Tweet Scraped85:
# Username:ereyestercrypto
# Description:仮想通貨の価格を10分置きに通知するBOTです。BTC/JPY ETH/JPY XRP/JPY LTC/JPY
# @ereyester
# Location:
#  Following Count:1
# Follower Count:1013
# Total Tweets:173072
# Retweet Count:0
# Tweet Text: BTC/JPY = 2768844円
# ETH/JPY = 219569円
# XRP/JPY = 46.138円
# LTC/JPY = 8407.9円
# #ビットコイン #仮想通貨 #BTC #ETH #XRP #LTC
# Hashtags Used:['ビットコイン', '仮想通貨', 'BTC', 'ETH', 'XRP', 'LTC']
# Tweet Scraped86:
# Username:MVT_Crypto
# Description:قناة ( تحليلية - تعليمية ) تهتم بنشر المحتوى التعليمي للعملات الرقمية والتحليلات الفنية المتعلقة بها .
# التحليلات التي يتم نشرها مجرد رأي فني.
# #BTC
# Location:
#  Following Count:21
# Follower Count:203
# Total Tweets:261
# Retweet Count:0
# Tweet Text: $ONT
# #BTC #ETH #بيتكوين #العملات_الرقمية https://t.co/a4tTsuAWrm
# Hashtags Used:['BTC', 'ETH', 'بيتكوين', 'العملات_الرقمية']
# Tweet Scraped87:
# Username:adheemk56
# Description:You miss 100% of the shots you dont take
# Location:playing games
#  Following Count:340
# Follower Count:8
# Total Tweets:825
# Retweet Count:369
# Tweet Text: 💸🌟🪙$25 #BTC 🪙🌟💸
#
#            ➡️GIVEAWAY⬅️
#
#  ☑️Follow me
#  ☑️Like &amp; RT
#  ☑️Show love on my new video.
# (must leave proof)
#
# BACK TO BACK ALL IN SUGAR RUSH BONUS BUYS PAID HUGE! (So Lucky)
#
# https://t.co/XOxB5rJLRU
#
# ROLLING IN 24 HOURS https://t.co/sM0ezCtrTA
# Hashtags Used:['BTC']
# Tweet Scraped88:
# Username:misfewins
# Description:bismillah Big win $1000 pickme @pickaw ❤️🥰🥰🎉🎉🎉
# Location:DKI Jakarta, Indonesia
#  Following Count:4695
# Follower Count:188
# Total Tweets:32062
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped89:
# Username:bang_andar7
# Description:Fans @juventusfc ⚽🇮🇹 penggemar one piece ⚓
# Location:Gresik, Indonesia
#  Following Count:1931
# Follower Count:47
# Total Tweets:12618
# Retweet Count:120
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped90:
# Username:XRP98406862
# Description:XRP 🌝 FLR 🌞 SGB 🐦 Live on the road in a Winnebago trailer. Love kayak fishing and road cycling. Christian.
# Location:Billings, MT
#  Following Count:1624
# Follower Count:822
# Total Tweets:20119
# Retweet Count:91
# Tweet Text: 🚨 Red Alert for #XRP / #BTC pair &amp; BTC Dominance. We analysed XRP/BTC in June &amp; July, and currently, XRP flipped the first resistance in the month, proceeding to flip the 2nd Resistance soon.
#
# We all know then what happens next #XRPCommunity
#
# Cheers!
#
# https://t.co/OLyjsE8k1A
# Hashtags Used:['XRP', 'BTC']
# Tweet Scraped91:
# Username:whalesradar_com
# Description:https://t.co/oZVtGZzi5n
#
# Crypto Whale Radar and Scanner
#
# #Crypto #Bitcoin #Cryptocurrency #RastGele
#
# Whales Radar is brand of @FxCanli
# Location:İstanbul
#  Following Count:1
# Follower Count:1372
# Total Tweets:28330
# Retweet Count:0
# Tweet Text: #WANUSDT #WAN
# Signal #1
#
# Last Signal: N/A
# Before: 0.20020000
# After: 0.19740000 🔴(-1.40%)
# Volume Chng: 6,044 USDT (6.41%)
#
# Daily
# Price Chng: (-1.40%)🔴
# Volume: 21,088 USDT
#
# 🚀PRO ➡️ https://t.co/1EgdzYf2ot 🐳
#
# #Crypto #Bitcoin #BTC #ETH
# Hashtags Used:['WANUSDT', 'WAN', 'Crypto', 'Bitcoin', 'BTC', 'ETH']
# Tweet Scraped92:
# Username:FarzadTalebi13
# Description:
# Location:
#  Following Count:3
# Follower Count:0
# Total Tweets:52
# Retweet Count:2
# Tweet Text: 🏙️ LandRocker #Metaverse - Rover design
#
# 🔍 Use your Rover to mine planets for elements and valuable tokens including #NFTs, LMNT, LRT, #btc , and more
#
# ⬆ Upgrade your Rover to mine more efficiently
# #p2e #playandearn #crypto #BlockchainGames https://t.co/kNKNA9oNX3
# Hashtags Used:['Metaverse']
# Tweet Scraped93:
# Username:1000xhunterr
# Description:
# Location:
#  Following Count:28
# Follower Count:66
# Total Tweets:668
# Retweet Count:0
# Tweet Text: @kucoincom #xcn #btc will 100x in september
# Hashtags Used:['xcn', 'btc']
# Tweet Scraped94:
# Username:BTCtoCAD
# Description:#Bitcoin Is King 👑
# Bitcoin Price Converter for Canadian Dollar($CAD) and United States Dollar($USD), Bitcoin Blockchain Explorer with Wayback Machine and more.
# Location:Canada
#  Following Count:41
# Follower Count:371
# Total Tweets:33678
# Retweet Count:0
# Tweet Text: #Bitcoin price in US Dollar #BTC $usd #BTCUSD $XBT #xbtusd
# BTC Price Now : 19,720.28$ USD
# Avg Last Hour : 19,832.55$
# Avg 24 Hours : 19,815.05$
# 24h Change : -0.12%
# 24h Low : 19,619.02$
# 24h High : 20,011.72$
# More information here https://t.co/PWwAp4BXM0 https://t.co/WkEZb8WjqN
# Hashtags Used:['Bitcoin', 'BTC', 'BTCUSD', 'xbtusd']
# Tweet Scraped95:
# Username:Agent00Crypto
# Description:Crypto Intelligence Agent
# Location:Australia
#  Following Count:58
# Follower Count:551
# Total Tweets:40569
# Retweet Count:0
# Tweet Text: #btc #binance #cryptonews #hardfork #investor #alltimehigh #hotwallet #steemit https://t.co/w2iKzTkafm
# Hashtags Used:['btc', 'binance', 'cryptonews', 'hardfork', 'investor', 'alltimehigh', 'hotwallet', 'steemit']
# Tweet Scraped96:
# Username:JiangT1989
# Description:
# Location:Hunan
#  Following Count:851
# Follower Count:376
# Total Tweets:411
# Retweet Count:58
# Tweet Text: 9.5作业来了，有兴趣收藏操作：
# 1、Orbit Finance表单：https://t.co/cCXuhVk4Qk
# 2、Tally 教程：https://t.co/nadbw9imne
#
# 3、Jump教程：https://t.co/vuOAOqiHLd
#
# 4、AptinLabs教程：https://t.co/m3tZWlMFzh
# #Airdrop #ETH #BTC #testnet #NFTs #Giveaway #Crypto
# Hashtags Used:[]
# Tweet Scraped97:
# Username:JarazP
# Description:Everything comes to an end || All crypto twits are only my thoughts!!! Not a sugesttion, more like big guess!!
# Location:Poland
#  Following Count:29
# Follower Count:9
# Total Tweets:151
# Retweet Count:0
# Tweet Text: For Past 48h #btc managed only once to touch 20k line in market. New week start for now with fear and lost hope for #cryptocurrency . #ada #xrp #xlm #eth #chz #Avalanche https://t.co/r5DEfSgrmp
# Hashtags Used:['btc', 'cryptocurrency', 'ada', 'xrp', 'xlm', 'eth', 'chz', 'Avalanche']
# Tweet Scraped98:
# Username:zorowins_
# Description:→ not multi
# → joining account
# → 1 device only (multi devices 𝙗𝙚𝙛𝙤𝙧𝙚)
# Location:tg: @shintaro22 dc: shini#5847
#  Following Count:4180
# Follower Count:56
# Total Tweets:24056
# Retweet Count:1977
# Tweet Text: ⚡The greatest interest in #BTC and #ETH among U.S. states is shown in California
#
# ...
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338585
# Retweet Count:0
# Tweet Text: #SOLUSDT Bear Alert!
#
# 5X Volume
# Price:      31.6
# 5-min %: -0.91%
# Volume:  $779,272
#
# #crypto #whale #btc #eth #SOL $SOL https://t.co/iC0M0JeAvF
# Hashtags Used:['SOLUSDT', 'crypto', 'whale', 'btc', 'eth', 'SOL']
# Tweet Scraped470:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338585
# Retweet Count:0
# Tweet Text: #ROSEUSDT Bear Alert!
#
# 5X Volume
# Price:      0.06346
# 5-min %: -1.0%
# Volume:  $133,097
#
# #crypto #whale #btc #eth #ROSE $ROSE https://t.co/fyTvIQ5v2O
# Hashtags Used:['ROSEUSDT', 'crypto', 'whale', 'btc', 'eth', 'ROSE']
# Tweet Scraped471:
# Username:altscanner
# Description:Join Us On TG For More Advanced Analysis & Setups: https://t.co/vk8I8mOcSV
# Location:
#  Following Count:1
# Follower Count:245
# Total Tweets:9428
# Retweet Count:0
# Tweet Text: 🔽⏰ $CELR Is Cooling Down From 0.01777                                         #btc $BTC
# Hashtags Used:['btc']
# Tweet Scraped472:
# Username:altscanner
# Description:Join Us On TG For More Advanced Analysis & Setups: https://t.co/vk8I8mOcSV
# Location:
#  Following Count:1
# Follower Count:245
# Total Tweets:9428
# Retweet Count:0
# Tweet Text: $SOL is trying to move down, Dump It🔻📉                                      #btc $BTC
# Hashtags Used:['btc']
# Tweet Scraped473:
# Username:KuroHikari0123
# Description:My former accounts such as @BlackLight2310 has been s-worded. But I will not give up! Not a multi. Yoroshiku! 💗
# Location:
#  Following Count:2646
# Follower Count:42
# Total Tweets:17389
# Retweet Count:124
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped474:
# Username:0xstrlght
# Description:With God nothing is impossible.
#                            Bigwin soon, amen✨🍀 @JenusHQ
# Location:pickaw & twitpicker notice me
#  Following Count:4995
# Follower Count:528
# Total Tweets:66751
# Retweet Count:124
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped475:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338585
# Retweet Count:0
# Tweet Text: #GRTUSDT Bear Alert!
#
# 5X Volume
# Price:      0.1032
# 5-min %: -0.58%
# Volume:  $38,069
#
# #crypto #whale #btc #eth #GRT $GRT https://t.co/ksmFIdFTFY
# Hashtags Used:['GRTUSDT', 'crypto', 'whale', 'btc', 'eth', 'GRT']
# Tweet Scraped476:
# Username:0xwin25z
# Description:decided to join giveaways to help myself buy things that are needed in college journey.
# ~kindly turn off my retweets thanks!~
# Location:National Capital Region, Repub
#  Following Count:933
# Follower Count:82
# Total Tweets:1853
# Retweet Count:124
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped477:
# Username:TtwStockBot
# Description:https://t.co/vGCpFOJbTG
#
# 지인들과 있는 채팅방에 전달하는 메세지 보관용도의 트위터 봇일뿐임
#
# 타인, 제 3자와 소통을 위해 만들어진 봇이 아닙니다.
# Location:
#  Following Count:0
# Follower Count:100
# Total Tweets:37470
# Retweet Count:0
# Tweet Text: 설경진 저샛기도 종종 자주보이던디 ㅋㅋㅋ
#  #thdtjsdn #주식 #NASDAQ #BTC
# Hashtags Used:['thdtjsdn', '주식', 'NASDAQ', 'BTC']
# Tweet Scraped478:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338585
# Retweet Count:0
# Tweet Text: #ZILUSDT Bear Alert!
#
# 5X Volume
# Price:      0.03576
# 5-min %: -0.78%
# Volume:  $79,242
#
# #crypto #whale #btc #eth #ZIL $ZIL https://t.co/hOueuZ2AWJ
# Hashtags Used:['ZILUSDT', 'crypto', 'whale', 'btc', 'eth', 'ZIL']
# Tweet Scraped479:
# Username:At3ngG4de11__
# Description:@At3ng_G4d311 Susp Jgn diReroll #twitterpicker #pickaw #KobeAxeVouch #tigergang #crypton1te #Gemwinners #AP8testi #funsizedw1n #jennirous #taefairy#VRpaid
# Location:Lebak Bulus Jakarta Selatan
#  Following Count:2804
# Follower Count:77
# Total Tweets:13389
# Retweet Count:124
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped480:
# Username:MetaVars2140_en
# Description:
# Location:
#  Following Count:1139
# Follower Count:1650
# Total Tweets:17917
# Retweet Count:0
# Tweet Text: https://t.co/1kMnR2UGk1 #WEB3 #ART #AI #DIGITALART #DEGEN #DeFi #SHIBA #BLOCKCHAIN #METAVERSE #SOLANA #BNB #BTC #ETH #BITCOIN #CRYPTO #NFT
# Hashtags Used:['WEB3', 'ART', 'AI', 'DIGITALART', 'DEGEN', 'DeFi', 'SHIBA', 'BLOCKCHAIN', 'METAVERSE', 'SOLANA', 'BNB', 'BTC', 'ETH', 'BITCOIN', 'CRYPTO', 'NFT']
# Tweet Scraped481:
# Username:HaoHar
# Description:19. A newbie and will-to-learn person in Web3. Founder of #OctopusPunk. Please support me!
# Location:
#  Following Count:710
# Follower Count:192
# Total Tweets:624
# Retweet Count:1
# Tweet Text: Follow
# @TheKingsNFTco
#
# Like &amp; RT
# Tag 3 friends
# Win 5 WL spots
#
# #NFTs #NFTCommunity #NFTGiveaway #nftcollector #NFTcollections #nftart #pixelart #Solana #BTC  #FreeMintNFT #FreeMint https://t.co/ij3kyROVAo
# Hashtags Used:['NFTs', 'NFTCommunity', 'NFTGiveaway', 'nftcollector']
# Tweet Scraped482:
# Username:narvino404
# Description:#NKRI harga mati 🇮🇩🇮🇩 $BTC $ETH  $BNB $LEOS #jixenWin #tigergang #sofialegit #LEOSARMY #maximwins  #funsizedw1n #iwonmissy
# Location:
#  Following Count:4900
# Follower Count:275
# Total Tweets:73018
# Retweet Count:124
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped483:
# Username:x_fastlane_x
# Description:Part from — @ttoonft | @SteadyStackNFT \ @OpusLabsHQ \ @Everdome_io / @PlayElarium — Gonna be an amazing Journey 🔥
# Location:
#  Following Count:638
# Follower Count:209
# Total Tweets:1651
# Retweet Count:38
# Tweet Text: #BITCOIN Potential Bearish Path (Monthly)
#
# In case the previous ATH level doesn't hold, Market Structure gives us a potential roadmap.
#
# If #BTC finally breaks this level, which stop do you think it will reach in the worst case scenario? https://t.co/T8c62XTE6R
# Hashtags Used:['BITCOIN']
# Tweet Scraped484:
# Username:TheChosenShib
# Description:#WhereIsMyLambo #TheseBurgersDontFlipThemselves
# Location:
#  Following Count:532
# Follower Count:506
# Total Tweets:740
# Retweet Count:7
# Tweet Text: ✨💰DAY 5//12 OF GIVEAWAY💰✨
#
# Win up to 10BN #KISHK and 100 #USDT or #USDC 💵💵💵
# ALL YOU HAVE TO DO IS:
#
# 👨‍👩‍👦TAG 3 FRIENDS
# 👀FOLLOW @TheChosenShib
# 👍LIKE &amp; RETWEET THIS POST
#
# Winner will be randomly selected Friday 9th of September.GoodLuck!
# #giveaway #giveaways #Crypto #BTC 🍀
# Hashtags Used:['KISHK', 'USDT', 'USDC', 'giveaway', 'giveaways', 'Crypto', 'BTC']
# Tweet Scraped485:
# Username:ExchangeWhales
# Description:Stay up to date on the biggest cryptocurrency trades & liquidations on exchanges.
# #FTX #Binance #Kraken #ByBit #dYdX #Bitcoin #Ethereum #Btc #Eth $BTC $ETH
# Location:
#  Following Count:132
# Follower Count:4253
# Total Tweets:197089
# Retweet Count:0
# Tweet Text: 🔻 🔻 🔻 $1,166,398 BTCUSDT SHORTED @$19,720.00 on #Binance (5:23:48 UTC) #BTC #cryptocurrency
# Hashtags Used:['Binance', 'BTC', 'cryptocurrency']
# Tweet Scraped486:
# Username:rezekidtgdong
# Description:My previous account was suspended, please don't reroll me 😭 ♧ #Ap8testi #VRpaid @JenusHQ
# Location:Pasar Rebo, Indonesia
#  Following Count:1394
# Follower Count:121
# Total Tweets:5263
# Retweet Count:124
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped487:
# Username:timpack13
# Description:Jesus # 1, Creator of "Next Level Health" and CRYPTOnite Youtube channels! 📈 Crypto/NFT Trader, Fitness Influencer, 🎙Podcast, 📝 Blog
# Location:Tampa Bay, Florida
#  Following Count:390
# Follower Count:293
# Total Tweets:8533
# Retweet Count:46
# Tweet Text: 1/ This is the most important thread you will read in this bear market. #BTC #XAU #USD #EUR
#
# Are you prepared to preserve &amp; protect your wealth?
#
# This is critical in the next ~12 months.
#
# Ready? Let's dive in. 👇 https://t.co/vlWexOT4yT
# Hashtags Used:['BTC', 'XAU', 'USD', 'EUR']
# Tweet Scraped488:
# Username:Mavictori3
# Description:💋👣💣
# Location:Amsterdam
#  Following Count:1188
# Follower Count:85
# Total Tweets:2517
# Retweet Count:11430
# Tweet Text: 💸 $1,000 #Giveaway 💸
#
# We'll select 10 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrSIiZ https://t.co/DiRKGbV3cW
# Hashtags Used:['Giveaway']
# Tweet Scraped489:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338585
# Retweet Count:0
# Tweet Text: #STXUSDT Bear Alert!
#
# 20X Volume
# Price:      0.367
# 5-min %: 0.0%
# Volume:  $17,301
#
# #crypto #whale #btc #eth #STX $STX https://t.co/RSwCWFIXKU
# Hashtags Used:['STXUSDT', 'crypto', 'whale', 'btc', 'eth', 'STX']
# Tweet Scraped490:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338585
# Retweet Count:0
# Tweet Text: #API3USDT Bear Alert!
#
# 5X Volume
# Price:      1.716
# 5-min %: -0.52%
# Volume:  $22,857
#
# #crypto #whale #btc #eth #API3 $API3 https://t.co/9cnhncsx16
# Hashtags Used:['API3USDT', 'crypto', 'whale', 'btc', 'eth', 'API3']
# Tweet Scraped491:
# Username:0xmowkie1022xx
# Description:#VIP
# #TEUME
# #MYDAY
# #CARAT
# Location:
#  Following Count:496
# Follower Count:75
# Total Tweets:41960
# Retweet Count:124
# Tweet Text: 📢JUST IN: @RichQuack is the most trending on @DEXToolsApp TODAY🔥
#
# Congratulations #RichQuackArmy 📈
#
# #Crypto #CryptoNews #altcoin #BTC #BNB #RichQUACKMetaverse $QUACK #QUACKArmy #QUACK https://t.co/65IqkogRj3
# Hashtags Used:['RichQuackArmy', 'Crypto']
# Tweet Scraped492:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338585
# Retweet Count:0
# Tweet Text: #XRPDOWNUSDT Bull Alert!
#
# 5X Volume
# Price:      0.000944
# 5-min %: 0.11%
# Volume:  $3,130
#
# #crypto #whale #btc #eth #XRPDOWN $XRPDOWN https://t.co/RW3jDQkoor
# Hashtags Used:['XRPDOWNUSDT', 'crypto', 'whale', 'btc', 'eth', 'XRPDOWN']
# Tweet Scraped493:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338585
# Retweet Count:0
# Tweet Text: #KNCUSDT Bear Alert!
#
# 10X Volume
# Price:      1.665
# 5-min %: -0.18%
# Volume:  $64,150
#
# #crypto #whale #btc #eth #KNC $KNC https://t.co/P8L660Zz2A
# Hashtags Used:['KNCUSDT', 'crypto', 'whale', 'btc', 'eth', 'KNC']
# Tweet Scraped494:
# Username:LivePriceCrypto
# Description:I Tweet the latest #Bitcoin & #Ethereum price and Daily/Weekly Technical Indicators Data every minute.
#
# Developed the 20/03/2022
# Location:
#  Following Count:4
# Follower Count:3434
# Total Tweets:234074
# Retweet Count:0
# Tweet Text: #Bitcoin Last Price $19758 #BTC 🚀
# Daily Indicators:
# -RSI: 36.0
# -MA(20): 20777
# -MA(50): 22252
# -MA(200): 30727
# -Bollinger B. lower/upper: 18648/22906
#
# #Ethereum Last Price $1567 #ETH
# -RSI: 46.1
# -MA(20): 1602
# -MA(50): 1656
# -MA(200): 2118
# -BB: 1403/1802
#
# #Crypto #Live
# (1/6)
# 233892
# Hashtags Used:['Bitcoin', 'BTC', 'Ethereum', 'ETH', 'Crypto', 'Live']
# Tweet Scraped495:
# Username:CELCATOFFICIAL
# Description:What happens when you take away The Dream from 7.5 billion people?
#
# A revolution.
#
# #CELMEMES Maker. Futurist. Contrarian.
#
# *nothing tweeted is financial advice
# Location:anon.
#  Following Count:1161
# Follower Count:3073
# Total Tweets:38348
# Retweet Count:1
# Tweet Text: #CelShortSqueeze #CelsiusNetwork #Celsius #BTC #MOASS #GME #AMC #CommunityFirst #CELARMY #GMESQUEEZE #wallstreetbets #Crypto #trading #usd  #ETH #bitcoin #Tea #bet #altcoins #gambling #Luck #lottery #jackpot #win #winning #awardwinning #results $cel https://t.co/yfXWabVAYo
# Hashtags Used:['CelShortSqueeze', 'CelsiusNetwork', 'Celsius', 'BTC', 'MOASS', 'GME', 'AMC', 'CommunityFirst', 'CELARMY', 'GMESQUEEZE', 'wallstreetbets']
# Tweet Scraped496:
# Username:dexitPriceBot
# Description:This is a bot for deXit blockchain shows the price and data for $DXT each 5 minutes
# Location:deXit community
#  Following Count:2
# Follower Count:86
# Total Tweets:5873
# Retweet Count:0
# Tweet Text: The current data for #deXit
#
# price 0.0017 USD
# MarkcetCap 0.0 USD
# 24 hour volume 1224.88 USD
# 24 hour change -1.48 %
# Last updated at 2022-09-05 05:23:41.670747
#
# #deXit #deXitArmy #coingecko #coinmarketCap $DXT #crypto #BTC #BNB #ETH
# Hashtags Used:['deXit', 'deXit', 'deXitArmy', 'coingecko', 'coinmarketCap', 'crypto', 'BTC', 'BNB', 'ETH']
# Tweet Scraped497:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338585
# Retweet Count:0
# Tweet Text: #FORTHUSDT Bull Alert!
#
# 5X Volume
# Price:      4.79
# 5-min %: 0.63%
# Volume:  $9,664
#
# #crypto #whale #btc #eth #FORTH $FORTH https://t.co/KT9xk6wHR4
# Hashtags Used:['FORTHUSDT', 'crypto', 'whale', 'btc', 'eth', 'FORTH']
# Tweet Scraped498:
# Username:Lord_Defi22
# Description:#Defi lover, crypto hodler.
# Location:
#  Following Count:5
# Follower Count:107
# Total Tweets:37827
# Retweet Count:0
# Tweet Text: updated price for $QTUM, $BNB, $TRX:
#
# #QTUM $3.188 USD
# #BNB 0.014019 #BTC
# #TRX 4.027e-05 #ETH
#
# I tweet updated prices, follow me to get recent updates.
#
# #cryptocurrency #crypto
# Hashtags Used:['QTUM', 'BNB', 'BTC', 'TRX', 'ETH', 'cryptocurrency', 'crypto']
# Tweet Scraped499:
# Username:AdilQadirKhan
# Description:Aiming to buy altcoins at low and selling them at high, but currently buying at high and selling them at low || Engineer by profession
# Location:Kupwara, Jammu And Kashmir
#  Following Count:386
# Follower Count:167
# Total Tweets:871
# Retweet Count:0
# Tweet Text: @jasonpizzino #BTC charts doesn't look good https://t.co/jTTe7f7KYT
# Hashtags Used:['BTC']
# Tweet Scraped500:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15590
# Total Tweets:338585
# Retweet Count:0
# Tweet Text: #BNBDOWNUSDT Bull Alert!
#
# 5X Volume
# Price:      0.04462
# 5-min %: 0.59%
# Volume:  $5,081
#
# #crypto #whale #btc #eth #BNBDOWN $BNBDOWN https://t.co/TG7LbwhQQd
# Hashtags Used:['BNBDOWNUSDT', 'crypto', 'whale', 'btc', 'eth', 'BNBDOWN']
# scraping has completed! :)

# %%
# Choose File Through Widget Experience | /Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/final-project-scraped_data-#BTC.json
###########################################################################################################################

# get home dir of user
home = str(Path.home()) 

# initialize a dict for the excel file; this removes the need to set global values
dict_file = {}

# change to simply `home` if you want users to navigate through diff dirs
#fc = FileChooser(f'{home}/excel')
fc = FileChooser(f'{home}/') 

# same here
#fc.sandbox_path = f'{home}/excel'
fc.sandbox_path = f'{home}/'

# limit file extensions to '.xls, .xlsb, .xlsm, .xlsx'
fc.filter_pattern = ['*.json*']
fc.title = '<b>Select your file</b>'
display(fc)

# create empty dropdown for sheet names
dropdown = widgets.Dropdown(options=[''], value='', description='Sheets:', disabled=False)

# create output frame for the df
out = widgets.Output(layout=widgets.Layout(display='flex', flex_flow='column', align_items='flex-start', width='100%'))
# Out:
# FileChooser(path='/Users/pergolicious', filename='', title='<b>Select your file</b>', show_hidden=False, selec…

# %%
# Convert JSON Data to Data Frame
###########################################################################################################################

BTCjsondata = f'{fc.selected_path}/{fc.selected_filename}'
print(BTCjsondata)

BTCdf = pd.read_json(BTCjsondata)

BTCdf.reset_index(drop=True, inplace=True)

BTCdf.info()
# Out:
# /Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/final-project-scraped_data-#BTC.json
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tweet Scraped    500 non-null    int64
#  1   Username         500 non-null    object
#  2   Description      500 non-null    object
#  3   Location         500 non-null    object
#  4   Following Count  500 non-null    int64
#  5   Follower Count   500 non-null    int64
#  6   Total Tweets     500 non-null    int64
#  7   Retweet Count    500 non-null    int64
#  8   Tweet Text       500 non-null    object
#  9   Hashtags Used    500 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 39.2+ KB

# %%
# Gathering of Data | 2 | Ethereum Tweets
###########################################################################################################################

print('Enter hasthag to search for')
words = input()

print('Enter number of tweets to search for')
numtweet = int(input())

scraped_data = []
print('Fetching tweets...')

scrape(words, numtweet, scraped_data)
print('scraping has completed! :)')
# Out:
# Enter hasthag to search for
#  #ETH
# Enter number of tweets to search for
#  500
# Unexpected parameter: len
# Fetching tweets...
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# Input In [13], in <cell line: 13>()
#      10 scraped_data = []
#      11 print('Fetching tweets...')
# ---> 13 scrape(words, numtweet, scraped_data)
#      14 print('scraping has completed! :)')
#
# Input In [6], in scrape(words, numtweet, scrapped_data)
#       4 def scrape(words, numtweet, scrapped_data):
#       5     tweets = tweepy.Cursor(api.search_tweets, q = words, len = 'en',
#       6                           tweet_mode = 'extended').items(numtweet)
# ----> 7     list_tweets = [tweet for tweet in tweets]
#       9     i = 1
#      11     # Extract various infomration through an iterative process
#
# Input In [6], in <listcomp>(.0)
#       4 def scrape(words, numtweet, scrapped_data):
#       5     tweets = tweepy.Cursor(api.search_tweets, q = words, len = 'en',
#       6                           tweet_mode = 'extended').items(numtweet)
# ----> 7     list_tweets = [tweet for tweet in tweets]
#       9     i = 1
#      11     # Extract various infomration through an iterative process
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/tweepy/cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
#     284 if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285     # Reached end of current page, get the next page...
# --> 286     self.current_page = next(self.page_iterator)
#     287     while len(self.current_page) == 0:
#     288         self.current_page = next(self.page_iterator)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/tweepy/cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/tweepy/cursor.py:167, in IdIterator.next(self)
#     164     raise StopIteration
#     166 if self.index >= len(self.results) - 1:
# --> 167     data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     169     model = ModelParser().parse(
#     170         data, api = self.method.__self__,
#     171         payload_list=self.method.payload_list,
#     172         payload_type=self.method.payload_type
#     173     )
#     174     result = self.method.__self__.parser.parse(
#     175         data, api = self.method.__self__,
#     176         payload_list=self.method.payload_list,
#     177         payload_type=self.method.payload_type
#     178     )
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/tweepy/api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/tweepy/api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/tweepy/api.py:1303, in API.search_tweets(self, q, **kwargs)
#    1209 @pagination(mode='id')
#    1210 @payload('search_results')
#    1211 def search_tweets(self, q, **kwargs):
#    1212     """search_tweets(q, *, geocode, lang, locale, result_type, count, \
#    1213                      until, since_id, max_id, include_entities)
#    1214
#    (...)
#    1301     .. _Twitter's documentation on the standard search API: https://developer.twitter.com/en/docs/twitter-api/v1/tweets/search/overview
#    1302     """
# -> 1303     return self.request(
#    1304         'GET', 'search/tweets', endpoint_parameters=(
#    1305             'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#    1306             'until', 'since_id', 'max_id', 'include_entities'
#    1307         ), q=q, **kwargs
#    1308     )
#
# File ~/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/tweepy/api.py:263, in API.request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     261     raise NotFound(resp)
#     262 if resp.status_code == 429:
# --> 263     raise TooManyRequests(resp)
#     264 if resp.status_code >= 500:
#     265     raise TwitterServerError(resp)
#
# TooManyRequests: 429 Too Many Requests
# 88 - Rate limit exceeded

# %%
# Choose File Through Widget Experience | /Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/final-project-scraped_data-#ETH.json
###########################################################################################################################

# get home dir of user
home = str(Path.home()) 

# initialize a dict for the excel file; this removes the need to set global values
dict_file = {}

# change to simply `home` if you want users to navigate through diff dirs
#fc = FileChooser(f'{home}/excel')
fc = FileChooser(f'{home}/') 

# same here
#fc.sandbox_path = f'{home}/excel'
fc.sandbox_path = f'{home}/'

# limit file extensions to '.xls, .xlsb, .xlsm, .xlsx'
fc.filter_pattern = ['*.json*']
fc.title = '<b>Select your file</b>'
display(fc)

# create empty dropdown for sheet names
dropdown = widgets.Dropdown(options=[''], value='', description='Sheets:', disabled=False)

# create output frame for the df
out = widgets.Output(layout=widgets.Layout(display='flex', flex_flow='column', align_items='flex-start', width='100%'))
# Out:
# FileChooser(path='/Users/pergolicious', filename='', title='<b>Select your file</b>', show_hidden=False, selec…

# %%
# Convert JSON Data to Data Frame
###########################################################################################################################

ETHjsondata = f'{fc.selected_path}/{fc.selected_filename}'
print(ETHjsondata)

ETHdf = pd.read_json(ETHjsondata)

ETHdf.reset_index(drop=True, inplace=True)

ETHdf.info()
# Out:
# /Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/final-project-scraped_data-#ETH.json
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tweet Scraped    500 non-null    int64
#  1   Username         500 non-null    object
#  2   Description      500 non-null    object
#  3   Location         500 non-null    object
#  4   Following Count  500 non-null    int64
#  5   Follower Count   500 non-null    int64
#  6   Total Tweets     500 non-null    int64
#  7   Retweet Count    500 non-null    int64
#  8   Tweet Text       500 non-null    object
#  9   Hashtags Used    500 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 39.2+ KB

# %%
# Combine #BTC and #ETH Data Frames
###########################################################################################################################

df = pd.concat([BTCdf,ETHdf])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tweet Scraped    1000 non-null   int64
#  1   Username         1000 non-null   object
#  2   Description      1000 non-null   object
#  3   Location         1000 non-null   object
#  4   Following Count  1000 non-null   int64
#  5   Follower Count   1000 non-null   int64
#  6   Total Tweets     1000 non-null   int64
#  7   Retweet Count    1000 non-null   int64
#  8   Tweet Text       1000 non-null   object
#  9   Hashtags Used    1000 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 85.9+ KB

# %%
# Preview Data
###########################################################################################################################

df.head()
# Out:
#    Tweet Scraped         Username  \
# 0              1       Br0kenPort
# 1              2        Rutiana2_
# 2              3  crypto_cryer001
# 3              4     ThomasBoleto
# 4              5        MikeAven9
#
#                                          Description                Location  \
# 0                                      CryptoTrader!  ปทุมวัน, กรุงเทพมหานคร
# 1                         I am unapologetically me🤞🏻
# 2  Web3 Developer || Blockchain Developer || NFT ...               Metaverse
# 3  My name it's Thomas Boleto I'm full time trade...          United Kingdom
# 4               Joining some giveaways Enjoy Life 💖😍
#
#    Following Count  Follower Count  Total Tweets  Retweet Count  \
# 0               76              21           706             16
# 1              106             885           358              4
# 2               56               8            83            219
# 3               84              71           909             24
# 4             1894             219          8654            364
#
#                                           Tweet Text  \
# 0  JUST #WhalesClubs \n\n#LaborDay #Crypto Green ...
# 1  The latest and the best Gamify platform is @De...
# 2  First 2000 people to retweet gets free #ETH or...
# 3  5 Security Tips to Keep Your Crypto Safe [Easy...
# 4  💸🌟🪙$25 #BTC 🪙🌟💸\n\n           ➡️GIVEAWAY⬅️\n\n...
#
#                                        Hashtags Used
# 0  [WhalesClubs, LaborDay, Crypto, BTC, LUNC, shi...
# 1                                                 []
# 2  [ETH, BTC, NFTdrop, NFT, NFTs, NFTCommunity, N...
# 3                                                 []
# 4                                              [BTC]

# %% [markdown]
# ## Explore Data Questions

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### What are the Twitter Summary Statistics of the Sampled Users?

# %%
# Question 1 | What are the twitter summary statistics of the sampled users?
###########################################################################################################################

df.describe()
# Out:
#        Tweet Scraped  Following Count  Follower Count   Total Tweets  \
# count    1000.000000      1000.000000     1000.000000    1000.000000
# mean      250.500000       822.953000     4903.964000   88576.655000
# std       144.409501      1397.475594    13817.697431  136675.250559
# min         1.000000         0.000000        0.000000       2.000000
# 25%       125.750000         1.000000       64.000000     864.000000
# 50%       250.500000       142.000000      201.500000    8595.500000
# 75%       375.250000       965.000000     4253.000000  127763.000000
# max       500.000000     11878.000000   266932.000000  551501.000000
#
#        Retweet Count
# count    1000.000000
# mean      528.258000
# std      1696.610673
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%       135.250000
# max     11621.000000

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### Who is the Most Followed Account from the Tweet Sample?

# %%
# Question 2 | Who is the most followed sampled account?
###########################################################################################################################

sorteddf = df.sort_values(by = ['Follower Count'], ascending = False)

MostFollowed_Username = sorteddf['Username'].iloc[0]
MostFollowed_FollowerCount = sorteddf['Follower Count'].iloc[0]

print(f'Most Followed Account | Username: {MostFollowed_Username}, Follower Count: {MostFollowed_FollowerCount}')
# Out:
# Most Followed Account | Username: RichQuack, Follower Count: 266932

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### Which Locations are the Users Tweeting From?

# %%
# Question 3 | Which locations are the users tweeting from (via Twitter)?
###########################################################################################################################

df_loc = df.groupby('Location').groups
df_loc_lst = []

for loc in df_loc:
    print(loc)
    df_loc_lst.append(loc)
    
len(df_loc_lst)
# Out:
# #GenSquad #GenFam
# #aircoinDAOlabs   # aircoin
# $SUZUME
# 1 Bank
# 100k Club ENS - ENS degen
# 17
# A chart
# Abu Dhabi
# Always DYOR !!!
# Amazonas (AM)
# Amsterdam
# Argentina
# Asian
# Atlantis
# Australia
# Ayeyarwaddy, Myanmar
# B-2100
# Bandung, Jawa Barat
# Banten, Indonesia
# Belo Horizonte, Brasil
# Blockchain
# Bogor Barat, Indonesia
# Brasil
# Brooklyn, NY
# Build. Explore. Earn
# California, USA
# Cardano Blockchain
# Champhai, India
# Chicago, IL + Metaverse
# Cilandak, Indonesia
# Cimahi Selatan, Indonesia
# City of London, London
# Cosmos
# Costa Rica
# Crypto Metaverse
# Delhi India
# Delhi, India
# Denizli, Türkiye
# Dhaka, Bangladesh
# Dojo
# Dubai
# EE UU
# ENS Showroom
# Earth
# El Salvador
# Essex
# Ethereum
# Find us here 👉🏼
# Florida, USA
# Gcash - 09287503658 #Pickaw
# Germany
# Gidan-Madi, Nigeria
# Global
# Happy days happy place
# Hawaii
# Here
# Hunter Acc🇲🇨
# Hyderabad, India
# I'm lucky
# INDONESIA
# Ilorin, Nigeria
# Imo State , Nigeria
# In the land downunder
# India
# Indonesia
# Indonesia 🇮🇩
# Indonesia 🇮🇩🇮🇩🇮🇩
# Iraq
# Italy
# Italy Nord-est
# Japan
# Jawa Barat, Indonesia
# Jepang
# Kalimantan Selatan, Indonesia
# Kalimantan Timur, Indonesia
# Kingdom of Saudi Arabia
# KowloonBay
# KowloonCity
# KowloonReservoir
# Kupwara, Jammu And Kashmir
# Kurdistan
# LA
# Labuan, Malaysia
# Lebak Bulus Jakarta Selatan
# Lion-devant-Dun, France
# London
# London, England
# Los Angeles, CA
# Los Angeles, California
# MOON
# Makassar, Indonesia
# Makati City
# Malaysia
# Mars
# Mempool
# Metaverse
# Mferverse
# Montréal, Québec
# Moon
# Myanmar
# National Capital Region, Repub
# Nebraska, USA
# Netherlands
# New Delhi, India
# Online Community
# Outerspace
# Pakistan
# Palm Bay, FL
# Paris, France
# Pasar Rebo, Indonesia
# PatSinLeng
# Pekan Baru, Riau
# Philippines
# Plainfield, IL
# Port Harcourt, Nigeria
# Portland, OR
# Puerto Cabello, Venezuela
# Republic of the Philippines
# Rocket
# Roma, Lazio
# Samsun, Türkiye
# San Francisco, CA
# Seattle, WA
# Sematang Borang, Indonesia
# Seoul, Republic of Korea
# SheungShui
# SheungWan
# Sleman, Indonesia
# Slovenija
# Sol 3
# Solana Blockchain🍻
# Somewhere in the Metaverse
# Spain
# Star
# Sydney, New South Wales
# São Paulo
# TR
# TaiHang
# TaiShuiHang
# Taiwan
# Tampa Bay, Florida
# Tate’sCairn
# Texas, USA
# Thailand
# The Garden
# ToKwaWan
# Toronto, Ontario
# Tuvaluan
# Türkiye
# UAE
# UK
# UK
# US
# USA
# Uk
# Ukraine
# United Kingdom
# United States
# United States of America
# Up there
# Utah
# Valencia, Comunidad Valenciana
# Virginia
# Virginia, USA
# WEB3
# Washington
# West Virginia
# World
# Worldwide
# Wyoming
# Yogyakarta
# Yozgat, Türkiye
# Zaragoza, España
# Zwickau, Deutschland
# anon.
# bagdad
# crypto-alerts.eth
# deXit community
# dijalan
# france lang
# global NFT , mom , Korea, app,
# japan
# moon 🌕
# my mind
# opensea.io
# peshawer university
# pickaw & twitpicker notice me
# qalbu
# sana situ sini mana
# server
# she/her
# star boundary
# villaverde alto madrid
# Ötüken
# İletişim için DM📩
# İstanbul
# İstanbul
# İstanbul, Türkiye
# Одесса
# جدة, المملكة العربية السعودية
# नई दिल्ली इंडिया
# ปทุมวัน, กรุงเทพมหานคร
# 仮想通貨を始めるならバイナンスがオススメ！↓↓
# 日本 大阪
# 湖北, 中华人民共和国
# 대한민국대전
# 🇮🇩
# 🇵🇭🇰🇷
# 209

# %% [markdown]
# ### Question 4

# %% [markdown]
# #### What Percentage of the Sampled Tweets Contain the Terms 'Giveaway', 'Contest', or 'Prize'?

# %%
# Question 4 | What Percentage of the Sampled Tweets Contain the Terms 'Giveaway', 'Contest', or 'Prize'?
###########################################################################################################################

df_text = df.groupby('Tweet Text').groups
df_text

lst = []

for txt in df_text:
    lst.append(txt)
    


searchterms = ['giveaway','contest','prize']
#pd.value_counts(np.array(lst))
giveawaycount = round((sum(len(re.findall(r'(giveaway) | (contest) | (prize)', x.lower())) for x in lst)/(len(lst)))*100)

print(f'"{searchterms}" was mentioned in {giveawaycount}% of the tweets captured in the sample.')
# Out:
# "['giveaway', 'contest', 'prize']" was mentioned in 17% of the tweets captured in the sample.

# %% [markdown]
# ### Question 5

# %% [markdown]
# #### What is the average Polarity and Subjectivity of the Tweet Sample?

# %%
# Question 5 | What is the average Polarity and Subjectivity of the Tweet Sample?
###########################################################################################################################

pol = lambda tweet: TextBlob(tweet).sentiment.polarity
sub = lambda tweet: TextBlob(tweet). sentiment.subjectivity

df['Polarity'] = df['Tweet Text'].apply(pol)
df['Subjectivity'] = df['Tweet Text'].apply(sub)

PolMean = np.mean(df['Polarity'])
print(f'Average Polarity Score: {PolMean}')
print('----------------------------------')
SubMean = np.mean(df['Subjectivity'])
print(f'Average Subjectivity Score: {SubMean}')
# Out:
# Average Polarity Score: 0.06521544246031746
# ----------------------------------
# Average Subjectivity Score: 0.29789763744588743
