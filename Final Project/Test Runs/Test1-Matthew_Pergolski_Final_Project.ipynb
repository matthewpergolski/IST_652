# %% [markdown]
# # Final Project Code | IST 652

# %% [markdown]
# ## Package Install

# %%
# Download Packages if Needed
###########################################################################################################################

# %pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /Users/pergolicious/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (4.10.1)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/pergolicious/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tweepy) (2.28.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /Users/pergolicious/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /Users/pergolicious/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from tweepy) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pergolicious/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/pergolicious/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/pergolicious/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pergolicious/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import Needed Packages
###########################################################################################################################

import pandas as pd
import numpy as np
import tweepy
import configparser
import json
import os
import re
import pandas as pd
import ipywidgets as widgets
from IPython.display import clear_output
from ipyfilechooser import FileChooser
from ipywidgets import interact
from pathlib import Path
from textblob import TextBlob, Word, Blobber
from textblob.classifiers import NaiveBayesClassifier
from textblob.taggers import NLTKTagger
#import matplotlib.pyplot as plt

# %% [markdown]
# ## Defining Functions

# %%
# Choose File Through Widget Experience | config.ini
###########################################################################################################################

# get home dir of user
home = str(Path.home()) 

# initialize a dict for the excel file; this removes the need to set global values
dict_file = {}

# change to simply `home` if you want users to navigate through diff dirs
#fc = FileChooser(f'{home}/excel')
fc = FileChooser(f'{home}/') 

# same here
#fc.sandbox_path = f'{home}/excel'
fc.sandbox_path = f'{home}/'

# limit file extensions to '.xls, .xlsb, .xlsm, .xlsx'
fc.filter_pattern = ['*.ini*']
fc.title = '<b>Select your file</b>'
display(fc)

# create empty dropdown for sheet names
dropdown = widgets.Dropdown(options=[''], value='', description='Sheets:', disabled=False)

# create output frame for the df
out = widgets.Output(layout=widgets.Layout(display='flex', flex_flow='column', align_items='flex-start', width='100%'))
# Out:
# FileChooser(path='/Users/pergolicious', filename='', title='<b>Select your file</b>', show_hidden=False, selec…

# %%
# Save actual key values to a separate '.ini' file for privacy reasons (don't want to directly share my keys with the world)
###########################################################################################################################

#configfile = '/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/FinalProject-Config.ini'

configfile = f'{fc.selected_path}/{fc.selected_filename}'
print(configfile)

config = configparser.ConfigParser()
config.read(f'{configfile}')

API_KEY = config['twitter']['API_KEY']
API_KEY_SECRET = config['twitter']['API_KEY_SECRET']
ACCESS_TOKEN = config['twitter']['ACCESS_TOKEN']
ACCESS_TOKEN_SECRET = config['twitter']['ACCESS_TOKEN_SECRET']
# Out:
# /Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/FinalProject-Config.ini

# %%
# Define function to print metadata information for tweets
###########################################################################################################################

directory = '/Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project'

def printtweetdata(n, ith_tweet, scrapped_data):
    
    d = {"Tweet Scraped":n, "Username": ith_tweet[0], "Description" :ith_tweet[1], "Location": ith_tweet[2], 
         "Following Count":ith_tweet[3], "Follower Count":ith_tweet[4],"Total Tweets":ith_tweet[5], "Retweet Count": ith_tweet[6],
         "Tweet Text": ith_tweet[7],"Hashtags Used":ith_tweet[8]}
         
         
    
    print(f"Tweet Scraped{n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f" Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text: {ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")
    
    scraped_data.append(d)
    
    try:
        if not os.path.isdir(f'{directory}'):
            os.mkdir(f'{directory}')
        with open(f'{directory}/final-project-scraped_data-{words}.json', 'w') as outfile:
            json.dump(scraped_data, outfile, indent = 4)
    except:
        print ("An exception occurred")

# %%
# Authentication the account and credentials
###########################################################################################################################

auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth)

# %%
# Define function to scrape twitter for data based on 3 different prameters
###########################################################################################################################

def scrape(words, numtweet, scrapped_data):
    tweets = tweepy.Cursor(api.search_tweets, q = words, len = 'en',
                          tweet_mode = 'extended').items(numtweet)
    list_tweets = [tweet for tweet in tweets]
    
    i = 1
    
    # Extract various infomration through an iterative process
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
    
        
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
            
            
        ith_tweet = [username, description, location, following,
                   followers, totaltweets, retweetcount, text, hashtext]
        
        printtweetdata(i, ith_tweet, scraped_data)
        i = i+1

# %% [markdown]
# ## Gather and Format/Transform Data

# %%
# Gathering of Data | 1 | Bitcoin Tweets
###########################################################################################################################

print('Enter hasthag to search for')
words = input()

print('Enter number of tweets to search for')
numtweet = int(input())

scraped_data = []
print('Fetching tweets...')

scrape(words, numtweet, scraped_data)
print('scraping has completed! :)')
# Out:
# Enter hasthag to search for
#  #BTC
# Enter number of tweets to search for
#  500
# Unexpected parameter: len
# Fetching tweets...
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Tweet Scraped1:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:1
# Follower Count:113
# Total Tweets:51013
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1568.18 USD
# #Bitcoin 0.07906763338610626 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped2:
# Username:cryptonian_god
# Description:
# Location:CHICAGO
#  Following Count:2239
# Follower Count:1168
# Total Tweets:3946
# Retweet Count:93
# Tweet Text: @cz_binance @Crypto__Diva #BTC , #ETH, #BNB &amp; #VOLT sounds like a more reasonable list what do you think? 🤔
#
# 3 blue chips + 1 volted small cap ⚡️
# Hashtags Used:['BTC', 'ETH', 'BNB', 'VOLT']
# Tweet Scraped3:
# Username:ValerieAcheson2
# Description:Crypto Alerted Our Tweets are not Financial Advise Be Carefull
# Location:Mulanay, Calabarzon
#  Following Count:97
# Follower Count:10
# Total Tweets:13
# Retweet Count:2
# Tweet Text: updated price for $EOS, $ETH, $ETC:
#
# #EOS $1.518 USD
# #ETH 0.078341 #BTC
# #ETC 0.02088 #ETH
#
# I tweet updated prices, follow me to get recent updates.
#
# #cryptocurrency #crypto
# Hashtags Used:['EOS', 'ETH', 'BTC', 'ETC', 'ETH']
# Tweet Scraped4:
# Username:DailyCrypto_t
# Description:Latest Cryptocurrency News
# Location:
#  Following Count:1204
# Follower Count:4208
# Total Tweets:16682
# Retweet Count:0
# Tweet Text: Bitcoin Mining Can Revolutionize Energy Industry &amp; Its Use, Says Arcane Research
# #Bitcoin #Ethereum #BTC #ETH #Crypto #CryptoNews
#
# https://t.co/WNu4aVzgEf https://t.co/enJnc9AayQ
# Hashtags Used:['Bitcoin', 'Ethereum', 'BTC', 'ETH', 'Crypto', 'CryptoNews']
# Tweet Scraped5:
# Username:Bharats14669137
# Description:#BSCMathematics
# #BSTC
# बस छोटी सी ख्वाहिश है हमारी,
# कि,
# माँ बाप की कोई ख्वाहिश अधूरी ना रहे..!!
# ❤️🖤
# Location:Sujangarh
#  Following Count:439
# Follower Count:196
# Total Tweets:3994
# Retweet Count:0
# Tweet Text: @dpradhanbjp @dpradhanbjp
#  जी देश भर के 1.3 करोड़ #DELED/#BSTC/#ETT/#JBT/#BTC डिप्लोमा धारी बेरोजगार प्राथमिक शिक्षकों के परिवारों को सुप्रीम कोर्ट से SLP (C) No. - 003222/2022 और Diary No. - 9845 वापिस लेकर न्याय प्रदान करें ।
# 🙏🙏🙏🙏🙏
# @EduMinOfIndia
#  @ncteDelhi
#  @PMOIndia
#  @Annapurna4BJP https://t.co/oiE7AboUYJ
# Hashtags Used:['DELED', 'BSTC', 'ETT', 'JBT', 'BTC']
# Tweet Scraped6:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15566
# Total Tweets:337317
# Retweet Count:0
# Tweet Text: #KSMUSDT Bull Alert!
#
# 30X Volume
# Price:      51.2
# 5-min %: 0.79%
# Volume:  $198,075
#
# #crypto #whale #btc #eth #KSM $KSM https://t.co/4d0U7ytBNZ
# Hashtags Used:['KSMUSDT', 'crypto', 'whale', 'btc', 'eth', 'KSM']
# Tweet Scraped7:
# Username:belinayguner04
# Description:
# Location:
#  Following Count:7
# Follower Count:4
# Total Tweets:271
# Retweet Count:26
# Tweet Text: Yarın Abd borsaları tatil olduğundan dolayı hacimsiz bir market bekliyorum, kâr almayı unutmayalım. Yoldan toplamıyoruz neticede☺️
#
# Herkese iyi akşamlar🙋‍♂️
# #btc #bitcoin
# Hashtags Used:[]
# Tweet Scraped8:
# Username:Burak16190259
# Description:
# Location:
#  Following Count:4
# Follower Count:4
# Total Tweets:80
# Retweet Count:614
# Tweet Text: GELENEKSEL #USDT ÖDÜLLÜ ÇEKİLİŞİMİZ DEVAM EDİYOR! 📢📢📢
#
# Bu twiti beğenip RT eden takipçilerimden rastgele #TRC20 adresi isteyip #USDT göndereceğim.
# Sonuç saat 23.00’da…
#
# #Bitcoin   #BTC   #ETH
# Hashtags Used:['USDT', 'TRC20']
# Tweet Scraped9:
# Username:MehmetH638025
# Description:
# Location:
#  Following Count:2097
# Follower Count:92
# Total Tweets:8975
# Retweet Count:13
# Tweet Text: Sıkıcı bir hafta sonu geride kalmak üzere. Umarım hafta içi volitaritenin olduğu canlı bir piyasa olur.
#
# Peki sizce yükseliş gelecek mi?
#
# Yükselir diyen beğensin ❤️
# Düşüş bekleyen ise RT 🔃
#
# Bakalım sizler ne düşünüyorsunuz..
#
# #BTC #Bitcoin #ETH #Ethereum
# #MANA #Meta #Metaverse
# Hashtags Used:[]
# Tweet Scraped10:
# Username:youhodl_bitcoin
# Description:Don’t wake up to find your #Bitcoin has been stolen by a hacker. Use youHODL, voted the safest self-custody #BitcoinWallet to store your #BTC by Bitcoin News.
# Location:
#  Following Count:119
# Follower Count:5263
# Total Tweets:6697
# Retweet Count:0
# Tweet Text: These are the 5 most profitable #Bitcoin  mining pools as at 04/09/2022:
#
# 1. @b1pool
# 2. @antpoolofficial
# 3. @genesismining
# 4. @viabtc
# 5. @f2pool_official
#
# #BTC
# #BitcoinWallet
# #BitcoinMining
# Hashtags Used:['Bitcoin', 'BTC', 'BitcoinWallet', 'BitcoinMining']
# Tweet Scraped11:
# Username:CrezyRexFlock
# Description:The little T-rax with unique character. 1/1 PFP non generate. Discord : https://t.co/gzbEUHtP9s
# Location:
#  Following Count:312
# Follower Count:304
# Total Tweets:510
# Retweet Count:2
# Tweet Text: Hello #STX  fams, join our discord for more info about @chicconft
# Only on @trygamma
# - Sales
# - Mint
# - Auction
# and more
#
# Link : https://t.co/oQetXOrtAn
#
# #STX  #BTCUSDT  #BTC #gammaio #STXFAM
# Hashtags Used:['STX']
# Tweet Scraped12:
# Username:hotcokalet
# Description:
# Location:
#  Following Count:3179
# Follower Count:106
# Total Tweets:8296
# Retweet Count:29
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped13:
# Username:CebomertDal
# Description:
# Location:
#  Following Count:304
# Follower Count:71
# Total Tweets:3649
# Retweet Count:557
# Tweet Text: 🎁 ÇEKİLİŞ 🎁
#
# 🏆1 KİŞİYE 10$ (180 TL) 💸  HEDİYE 🎗
#
# Yapmanız gerekenler 👇
#
# 1⃣ @CryptoDolars   TAKİP EDİN 🎗
#
# Bu twite RT, FAV❤ ATIN
#
# SÜRE: 12H
#
# #btc    #bitcoin    #NFTGiveaway #ETH #shiba #Solana #sol #nfts
# Hashtags Used:[]
# Tweet Scraped14:
# Username:Emimma2
# Description:💎 Crypto Lover
# 💎 $RBXS Twitter Shiller
# 💎 We shill your Blockchain Projects!
# 💎 Follow @RBXSamurai #RBXSamurai
# Location:
#  Following Count:319
# Follower Count:1265
# Total Tweets:52242
# Retweet Count:0
# Tweet Text: Automate your marketing with RBXS!
#
# https://t.co/CkAoDEym7V
#
# #RBXS #RBXSamurai #Rbx  #crypto #staking #NFT #cryptocurrency  #DeFi #Binance #ETH #Bitcoin #BSC #BTC #1000xgem  #RBXStoken #Crypto https://t.co/YyCtYFJchM
# Hashtags Used:['RBXS', 'RBXSamurai', 'Rbx', 'crypto', 'staking', 'NFT', 'cryptocurrency', 'DeFi', 'Binance', 'ETH', 'Bitcoin', 'BSC', 'BTC', '1000xgem', 'RBXStoken', 'Crypto']
# Tweet Scraped15:
# Username:zahranussarat10
# Description:dollar is dollar.....💰💰💰💰💰💸💵💸💵⚖️💵
# Location:Bogor, Jawa Barat
#  Following Count:3932
# Follower Count:234
# Total Tweets:13037
# Retweet Count:120
# Tweet Text: 💸 $500 #Giveaway #Round 4💸
#
# We'll select 10 winners randomly and award $50 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Must Follow us &amp;
# @sCrypto0x
# (🔔)
# 2️⃣ Tag 3 friends
# 3️⃣ Like &amp; Retweet
#
# Winners will be picked in 48 hours
# Good luck 💚
#
# #ETH #NFTs  #ETH #BTC     #BNB  #BUSD  #USDT https://t.co/jbuszMYc0N
# Hashtags Used:['Giveaway', 'Round']
# Tweet Scraped16:
# Username:matteo_guido
# Description:
# Location:Ferrara, Emilia Romagna
#  Following Count:247
# Follower Count:37
# Total Tweets:8
# Retweet Count:0
# Tweet Text: This zesty faucet from @_bitcoiner is making me tweet this to claim my free Lightning sats. ⚡
#
# @boltcoiner unlock me 0afa9f4c-6204-466a-971e-c8d3488bd95b
#
# #Bitcoin #BTC #LN #LightningNetwork #boltcoiner
# https://t.co/zXA1KF4zKj
# Hashtags Used:['Bitcoin', 'BTC', 'LN', 'LightningNetwork', 'boltcoiner']
# Tweet Scraped17:
# Username:EliRuth13
# Description:💨❤Ali A.S Ki Baadshahi Hai❤
# Location:
#  Following Count:156
# Follower Count:35
# Total Tweets:19
# Retweet Count:4
# Tweet Text: #CELRUSDT Bear Alert!
#
# 10X Volume
# Price:      0.01787
# 5-min %: -0.78%
# Volume:  $29,987
#
# #crypto #whale #btc #eth #CELR $CELR https://t.co/AabEepFhrU
# Hashtags Used:['CELRUSDT', 'crypto', 'whale', 'btc', 'eth']
# Tweet Scraped18:
# Username:devimzn
# Description:ADS exchange
# Location:
#  Following Count:485
# Follower Count:127
# Total Tweets:306
# Retweet Count:0
# Tweet Text: #ADSCOIN is the Future of #Crypto World.  We are Coming By SEPTEMBER,  With 5M+ DEDICATED TEAM, 9 DIGITALPLATFORMS, As Per GOVT. GUIDELINES. Our Own #ADSCOINEXCHANGE Listed with TOP 20 COINS
# #btc #ETH # BNB #ADA @therahulads @CryptooIndia https://t.co/0ix3w2mwMF https://t.co/aNYOarqjgh
# Hashtags Used:['ADSCOIN', 'Crypto', 'ADSCOINEXCHANGE', 'btc', 'ETH', 'ADA']
# Tweet Scraped19:
# Username:Anaristlerdenm1
# Description:$Pi Network $ WSBT   $DKS
#
# MEXCGLOBAL
# Location:
#  Following Count:482
# Follower Count:104
# Total Tweets:4462
# Retweet Count:615
# Tweet Text: GELENEKSEL #USDT ÖDÜLLÜ ÇEKİLİŞİMİZ DEVAM EDİYOR! 📢📢📢
#
# Bu twiti beğenip RT eden takipçilerimden rastgele #TRC20 adresi isteyip #USDT göndereceğim.
# Sonuç saat 23.00’da…
#
# #Bitcoin   #BTC   #ETH
# Hashtags Used:['USDT', 'TRC20']
# Tweet Scraped20:
# Username:gulch_capital
# Description:Preparing normies for defi and beyond. #meta before it was cool. Magic Internet Money will eat the world. Get in Kyle, we gettin' rich!
# Location:
#  Following Count:91
# Follower Count:3342
# Total Tweets:428
# Retweet Count:0
# Tweet Text: @cjasonmaier Integrate @cryptocom merchant payments or #BTC pay server using Umbrel.
# Hashtags Used:['BTC']
# Tweet Scraped21:
# Username:ZekOnlemec
# Description:Too Late For Love
# Location:İzmir
#  Following Count:421
# Follower Count:54
# Total Tweets:600
# Retweet Count:615
# Tweet Text: GELENEKSEL #USDT ÖDÜLLÜ ÇEKİLİŞİMİZ DEVAM EDİYOR! 📢📢📢
#
# Bu twiti beğenip RT eden takipçilerimden rastgele #TRC20 adresi isteyip #USDT göndereceğim.
# Sonuç saat 23.00’da…
#
# #Bitcoin   #BTC   #ETH
# Hashtags Used:['USDT', 'TRC20']
# Tweet Scraped22:
# Username:sergen_un
# Description:
# Location:
#  Following Count:203
# Follower Count:12
# Total Tweets:408
# Retweet Count:30
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped23:
# Username:Awesowewnner4
# Description:No pain , no gain! 🥲💙💫
# 5-2-0
# Location:Türkiye
#  Following Count:1872
# Follower Count:469
# Total Tweets:18071
# Retweet Count:758
# Tweet Text: GELENEKSEL #USDT ÖDÜLLÜ ÇEKİLİŞİMİZ DEVAM EDİYOR! 📢📢📢
#
# Bu twiti beğenip RT eden takipçilerimden rastgele #TRC20 adresi isteyip #USDT göndereceğim.
# Sonuç saat 23.00’da…
#
# #Bitcoin #BTC #ETH
# Hashtags Used:['USDT', 'TRC20']
# Tweet Scraped24:
# Username:david029290
# Description:hello world
# Location:
#  Following Count:163
# Follower Count:9
# Total Tweets:75
# Retweet Count:0
# Tweet Text: #BTCUSDT #btc
# 횡보하길래 자면서 매도 걸어놨더니 딱 그자리까지옴
# 자다 일어나서 9월4일 마무리
# 역시 10배해야... https://t.co/AyYhxHeZG6
# Hashtags Used:['BTCUSDT', 'btc']
# Tweet Scraped25:
# Username:shark_tech_
# Description:مهندس معماري ، محلل فني
# كل ما يطرح في الحساب هو بغرض التحليل الفني للأسواق المالية وليس توصية للبيع أو الشراء
# اوصيك بالإدارة المالية وإدارة المخاطر
# Location:
#  Following Count:247
# Follower Count:51
# Total Tweets:404
# Retweet Count:0
# Tweet Text: الان موسم العملات الالتس وليس البيتكوين
# #btc
# #Altseason https://t.co/labYEw1vbC
# Hashtags Used:['btc', 'Altseason']
# Tweet Scraped26:
# Username:nacho7suarez
# Description:@CCrewNFT  💎 Cryptocurrencies, ICOs & NFTs 💎
# Location:Barcelona, España
#  Following Count:681
# Follower Count:109
# Total Tweets:1815
# Retweet Count:84
# Tweet Text: #Bitcoin is moving in the same way like 2013/14 bear market.
#
# Three wave tops🔴🟡🟢are demonstrated in RSI Bollinger Bands associated with $BTC delayed 3 wave tops.
#
# Bull run is coming🚀
#
# RT and FOLLOW appreciated ￼
# #Bitcoin￼ #BTC￼ #Cryptos https://t.co/pUK1wvOYHS
# Hashtags Used:['Bitcoin']
# Tweet Scraped27:
# Username:Jhon83100725
# Description:
# Location:
#  Following Count:25
# Follower Count:4
# Total Tweets:291
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped28:
# Username:pelinaykar3
# Description:pelin
# Location:
#  Following Count:581
# Follower Count:39
# Total Tweets:1802
# Retweet Count:30
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped29:
# Username:0xIndia
# Description:🇮🇳🕌 नमस्ते 🕌🇮🇳 कृपा से हर किसी को जीवन में सुख, शांति और समृद्धि प्राप्त नया भारत #IndiaWantsCrypto #Bitcoin #ETH #BNB #Tether #WazirX #CoinDCX #Zebpay
# Location:नई दिल्ली इंडिया
#  Following Count:19
# Follower Count:158
# Total Tweets:64279
# Retweet Count:0
# Tweet Text: 🇮🇳 इंडिया बिटकॉइन(BTC) रेडिंग मूल्य 🇮🇳
# ✅WazirX   :1,638,730 INR
# ✅CoinDCX:1,703,401 INR
# ✅Zebpay   :1,679,138 INR
# #India #BTC #Bitcoin #बिटकॉइन #BTCINR
# https://t.co/z6i3YylKYM
# Hashtags Used:['India', 'BTC', 'Bitcoin', 'बिटकॉइन', 'BTCINR']
# Tweet Scraped30:
# Username:bay23murat
# Description:Finans
# Location:
#  Following Count:291
# Follower Count:15
# Total Tweets:1012
# Retweet Count:18
# Tweet Text: Rusya’nın, Avrupa’nın gazını kesmesi piyasa açısından ne anlama geliyor?
#
# Haftalık Piyasa Analizi..
#
# Link: https://t.co/27HlE81giX
#
# #usdtry #bist #bist100 #DolarTL #Bitcoin #resesyon #faiz #enflasyon #altın #dolar #Brent #petrol #btc #Ekonomi #politika #borsa #doğalgaz https://t.co/CcjehymQbd
# Hashtags Used:[]
# Tweet Scraped31:
# Username:ES_SPY_SPX
# Description:#ES #SPY #SPX #Stocks Disclaimer: For entertainment purpose ONLY NO Trades! No Discord, Telegram, DMs, Algos etc.
# Location:South Banana Stand
#  Following Count:20
# Follower Count:31
# Total Tweets:278
# Retweet Count:0
# Tweet Text: $AAPL - Weekly
#
# AAPL event next week
# So, may be a push
# but
# for now
# look like more lows coming ..
#
# #AAPL #META #AMZN #GOOG
# #TSLA #NFLX #DIS
# #SPY #SPX #ES_F
# $SPY $SPX $ES_F
# #BTC #ETH #NVDA #AMC https://t.co/h8zfaMzAxu
# Hashtags Used:['AAPL', 'META', 'AMZN', 'GOOG', 'TSLA', 'NFLX', 'DIS', 'SPY', 'SPX', 'ES_F', 'BTC', 'ETH', 'NVDA', 'AMC']
# Tweet Scraped32:
# Username:daveweisberger1
# Description:CEO of CoinRoutes, Market Structure Geek, Chaotic Good Magician (JK, but who reads these), Digital Assets for freedom #bitcoin #ethereum #defi #crypto
# Location:Miami
#  Following Count:260
# Follower Count:6344
# Total Tweets:4095
# Retweet Count:0
# Tweet Text: Well said
#
# The hypocrisy of the global elite has been supercharged by widening wealth inequality, driven, in large part, by sustained monetary debasement.
#
# Those in control of the worlds money have their own rules, so it’s time for something to replace it:
#
# #btc https://t.co/tA00EsimAy
# Hashtags Used:['btc']
# Tweet Scraped33:
# Username:CRYPTOBOYMOON
# Description:Bitcoin🚀 Cryptocurrency💵 blockchain📱 is the future
# Location:Islamabad, Pakistan
#  Following Count:351
# Follower Count:3705
# Total Tweets:226592
# Retweet Count:4
# Tweet Text: ICYMI: The @Nasdaq and Digitra are teaming up to launch a new exchange for institutions to trade #Bitcoin!
#
# #BTC
# https://t.co/kUfmTZg1u7
# Hashtags Used:['Bitcoin', 'BTC']
# Tweet Scraped34:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15566
# Total Tweets:337317
# Retweet Count:0
# Tweet Text: #ANKRUSDT Bull Alert!
#
# 5X Volume
# Price:      0.03499
# 5-min %: 0.14%
# Volume:  $50,974
#
# #crypto #whale #btc #eth #ANKR $ANKR https://t.co/Is6NfjDlZD
# Hashtags Used:['ANKRUSDT', 'crypto', 'whale', 'btc', 'eth', 'ANKR']
# Tweet Scraped35:
# Username:Tidackapapa
# Description:win please
# Location:DKI Jakarta, Indonesia
#  Following Count:2953
# Follower Count:161
# Total Tweets:14848
# Retweet Count:19
# Tweet Text: $100 || 5679.25 PHP || 1489230.00 IDR #BTC
#
# 🔱Rt &amp; Follow
#
# Ends 24hrs
# Hashtags Used:['BTC']
# Tweet Scraped36:
# Username:Daniel18713221
# Description:
# Location:
#  Following Count:217
# Follower Count:200
# Total Tweets:1259
# Retweet Count:79
# Tweet Text: Bringing Back The Meme Culture
# @cz_binance #bsc #bnb #meme #BTC #Binance @1goonrich @ZachBoychuk #babyczarmy @GollumsGems @OfficialTravlad @tqsully @SolidProof_io @Overdose_AI https://t.co/Hf83r16aoH
# Hashtags Used:['bsc', 'bnb', 'meme', 'BTC', 'Binance', 'babyczarmy']
# Tweet Scraped37:
# Username:oguzhann907
# Description:
# Location:
#  Following Count:205
# Follower Count:28
# Total Tweets:702
# Retweet Count:132
# Tweet Text: 🎁ÇEKİLİŞ🎁
#
# 🏆1 KİŞİYE 20$ (360 TL)💸  HEDİYE🎗
#
# Yapmanız gerekenler👇
#
# 1⃣ @uzmankriptoo sabit twitine RT, FAV❤
#
# Ve youtube videosuna like,YORUM Yapın👇
#
# https://t.co/pEf9sAmlpp
#
# Bu twite RT, FAV❤ATIN
#
# SÜRE:48H
#
# #btc    #bitcoin    #NFTGiveaway #ETH #shiba #Solana #sol
# Hashtags Used:[]
# Tweet Scraped38:
# Username:LivePriceCrypto
# Description:I Tweet the latest #Bitcoin & #Ethereum price and Daily/Weekly Technical Indicators Data every minute.
#
# Developed the 20/03/2022
# Location:
#  Following Count:4
# Follower Count:3432
# Total Tweets:233396
# Retweet Count:0
# Tweet Text: #Bitcoin Last Price $19830 #BTC 🚀
# Daily Indicators:
# •Pivot Fibonacci:
#  -Support 1: 19422
#  -S2: 18080
#  -S3: 15907
#  -Middle: 21594
#  -Resistance 1: 23767
#
# #Ethereum Last Price $1568 #ETH
# •Pivot:
#  -S1: 1437
#  -S2: 1293
#  -S3: 1061
#  -M: 1670
#  -R1: 1902
#
# #Crypto #DeFi
# (3/6)
# 233222
# Hashtags Used:['Bitcoin', 'BTC', 'Ethereum', 'ETH', 'Crypto', 'DeFi']
# Tweet Scraped39:
# Username:BuyHiSellLow420
# Description:
# Location:Washington, DC
#  Following Count:94
# Follower Count:20
# Total Tweets:1324
# Retweet Count:1
# Tweet Text: #btc wen 10k (and I’m not talking about the Cambridge 10k) 😂😂😂😂
# Hashtags Used:['btc']
# Tweet Scraped40:
# Username:NagjiJograna1
# Description:
# Location:
#  Following Count:0
# Follower Count:0
# Total Tweets:276
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped41:
# Username:btc_status
# Description:Tweet data that will help you consider #BTC price movements.
# BTC の値動きの考察に役立つ情報をツイートします。
# Location:Japan
#  Following Count:2
# Follower Count:46112
# Total Tweets:433902
# Retweet Count:0
# Tweet Text: #BTC Derivs Sheet (Tweet every 15 min.)
# CME Delayed (10 min)
# GS Delayed (15 min) and OI = SHARES OUT https://t.co/UgdcsrFgnG
# Hashtags Used:['BTC']
# Tweet Scraped42:
# Username:Charlessss0511
# Description:Bio.
# Location:
#  Following Count:12
# Follower Count:0
# Total Tweets:250
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped43:
# Username:Kurademegha1
# Description:
# Location:
#  Following Count:1
# Follower Count:0
# Total Tweets:298
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped44:
# Username:SureshK35959257
# Description:
# Location:
#  Following Count:15
# Follower Count:0
# Total Tweets:291
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped45:
# Username:W3N_LVPV5
# Description:V1R35 1N NVM3R15
# #Saitama 4life ♥️ Wolfpack defender🤘🐺 / empath / satanic buddhist
# .
# Crypto / graphix / art / music 🎸 #SaitaRealty #luckyroo #solidblock #m87
# Location:The Chromatic Ribbon
#  Following Count:1267
# Follower Count:1071
# Total Tweets:9933
# Retweet Count:4
# Tweet Text: I Believe 💯% #Saitama is going to reach $1 🚀
#
# Like 👍🏻.  .   Follow 👍🏻.  .   Retweet👍🏻
#
# #100x #1000xgem #altcoins #Crypto #CryptoNews
# @WeAreSaitama
#  #SaitaPro #BTC #BITCOIN #news
# Hashtags Used:['Saitama', '100x', '1000xgem', 'altcoins', 'Crypto']
# Tweet Scraped46:
# Username:MukeshC67474085
# Description:Vpo karanpura bhadra hanumangardh
# Location:
#  Following Count:9
# Follower Count:2
# Total Tweets:288
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped47:
# Username:samyar73741
# Description:♡feg♡
# Location:
#  Following Count:243
# Follower Count:71
# Total Tweets:3904
# Retweet Count:262
# Tweet Text: “high community credibility that has passed the test of time”
#
# We couldn’t agree more @PancakeSwap ❤️
#
# Click on BUY FEG on PCS on https://t.co/q0nGfPA3Q1
#
# Or to swap ETH click BUY FEG on UNI
#
# #FEG #PCS #Crypto #BSC #ETH #cryptocurrency #BTC #community #DeFi #blockchain https://t.co/1L2WnJJ7CE
# Hashtags Used:[]
# Tweet Scraped48:
# Username:rio7819
# Description:rio
# Location:
#  Following Count:623
# Follower Count:37
# Total Tweets:1846
# Retweet Count:30
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped49:
# Username:2cQoQdjLHWzZYTy
# Description:
# Location:
#  Following Count:0
# Follower Count:1
# Total Tweets:259
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped50:
# Username:PITCOnYc
# Description:FSU‘19.Everything Astro (Astronomy-ology, Physics,Trading,Geometry)More Life, Money, Music, Boxing, Sexy People in that Order. 💡💕|🖤💡
# Location:New York, USA
#  Following Count:345
# Follower Count:287
# Total Tweets:2551
# Retweet Count:0
# Tweet Text: The scary thing about #BTC is from a Purely Technical perspective, it could fall to exactly $0.01 and still be within the rules to bounce higher, or retain Its Bullish Sentiment. Thinking forward, that’s the scariest phuckin’ roller coaster 🎢 ride anyone could take. 😬 😟
# Hashtags Used:['BTC']
# Tweet Scraped51:
# Username:PrinceAbdulman
# Description:Need bby time
# Location:
#  Following Count:1
# Follower Count:0
# Total Tweets:265
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped52:
# Username:CandiaJonwell
# Description:
# Location:
#  Following Count:8
# Follower Count:1
# Total Tweets:268
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped53:
# Username:Viratsi10861233
# Description:
# Location:
#  Following Count:0
# Follower Count:0
# Total Tweets:257
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped54:
# Username:Smartgenerati10
# Description:
# Location:
#  Following Count:0
# Follower Count:0
# Total Tweets:215
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped55:
# Username:ricahmaesayat1
# Description:
# Location:
#  Following Count:33
# Follower Count:2
# Total Tweets:258
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped56:
# Username:WOLFTASI_
# Description:في ضواحي الكريبتو #btc ..معلم..صديق الجميع ..
# Location:دولة الكويت
#  Following Count:595
# Follower Count:112
# Total Tweets:2985
# Retweet Count:1
# Tweet Text: كنت اتوقع هذه العينات محصورة في #تاسي
# فقط … لكن تفاجأت اعداد مأهولة في سوق الكريبتو لا تعد ولا تحصى  … 🤡🤡🤡🤡
#
# #btc #لا_تبيع_بخسارة https://t.co/xBZgtLd31E
# Hashtags Used:['تاسي', 'btc']
# Tweet Scraped57:
# Username:YogeshJ13731133
# Description:Jay mata di
# Location:
#  Following Count:19
# Follower Count:5
# Total Tweets:295
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped58:
# Username:Mccharl41242197
# Description:
# Location:
#  Following Count:15
# Follower Count:0
# Total Tweets:279
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped59:
# Username:TebatsoWeb
# Description:m out going and smart
# Location:
#  Following Count:44
# Follower Count:0
# Total Tweets:266
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped60:
# Username:Lucena14400624
# Description:
# Location:
#  Following Count:0
# Follower Count:0
# Total Tweets:250
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped61:
# Username:tanishakhatun11
# Description:queen
# Location:
#  Following Count:0
# Follower Count:0
# Total Tweets:269
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped62:
# Username:Rajakum04457034
# Description:Maut Ka naam to Yun Hi badnaam asali dard sala jindagi deti hai
# Location:
#  Following Count:63
# Follower Count:1
# Total Tweets:321
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped63:
# Username:AbdulRe66819733
# Description:IN A WORLD FULL OF SWAG
# BE A MAN WITH CLASS.
# Location:
#  Following Count:12
# Follower Count:0
# Total Tweets:246
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped64:
# Username:NiteshR57057221
# Description:
# Location:
#  Following Count:4
# Follower Count:0
# Total Tweets:248
# Retweet Count:20
# Tweet Text: Those who manage Metaverse projects are the people who shape the future! So who are they?
# #BabyChitaToken #chitaverse #Metaverse #MetaverseNFT #MetaverseNews #Crypto #CryptoNews #btc #Ethereum #cryptocurrencies #future #news https://t.co/QRVbHCoXLn
# Hashtags Used:['BabyChitaToken', 'chitaverse']
# Tweet Scraped65:
# Username:ClankApp
# Description:Biggest blockchains transactions in real time. Api available: https://t.co/4vwvqel9cV 🐳 Made in France ❤️ Powered by @blockchair. Check out @Trengible.
# Location:Moon
#  Following Count:5
# Follower Count:14415
# Total Tweets:517071
# Retweet Count:0
# Tweet Text: 💵4,756 #BTC (94,312,450 USD) move from unknown wallet to unknown wallet
#
# Date : 2022-09-04 18:05:07 (GMT 0)
# Blockchain : #BITCOIN
# Symbol : #BTC
#
# Detail: https://t.co/LzNtKusqft
# Hashtags Used:['BTC', 'BITCOIN', 'BTC']
# Tweet Scraped66:
# Username:Ni1ckoO
# Description:
# Location:
#  Following Count:19
# Follower Count:3
# Total Tweets:17
# Retweet Count:3
# Tweet Text: ❤️Bonjour les amis !!!
#
# 🔥Crypto-émission du jour : Analyse LONG TERME des cryptos des abonnés : BNB, ADA, XRP, SOL, DODGE, DOT, MATIC, SHIB, TRX, AVAX 🔥
#
# 🎥Lien de la vidéo : https://t.co/mXu82X1vH3
#
# 💎N'hésitez pas à RETWEET pour partager un maximum !❤️
#
# #BTC #Bitcoin #Crypto https://t.co/9t8R0LitnE
# Hashtags Used:[]
# Tweet Scraped67:
# Username:hamdy107020
# Description:#thunderlegit
# Location:
#  Following Count:2466
# Follower Count:91
# Total Tweets:17948
# Retweet Count:1571
# Tweet Text: 10$ GIVEAWAY | 4 HRS ☀️
#
# RT + Follow @DeGodsNFTS
#
# #NFTs #nft #NFTGiveaway #Giveaway #NFTCommunity #freemint #ethereum #btc #eth #crypto #cryptocurrency https://t.co/AhhBRE89Xp
# Hashtags Used:['NFTs', 'nft', 'NFTGiveaway', 'Giveaway', 'NFTCommunity', 'freemint', 'ethereum']
# Tweet Scraped68:
# Username:KFilipins
# Description:investing in #crypto
# living the best life
# #hodl #gamefi #defi
# Location:
#  Following Count:798
# Follower Count:162
# Total Tweets:494
# Retweet Count:1
# Tweet Text: @cryptojack well I'd follow the main rule: do not put all of your eggs in the one basket
# so I'd buy both #BTC and #ADA
# Hashtags Used:['BTC', 'ADA']
# Tweet Scraped69:
# Username:bombosyer2
# Description:bosyer
# Location:
#  Following Count:915
# Follower Count:62
# Total Tweets:2989
# Retweet Count:30
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped70:
# Username:AliRizaBey71
# Description:İş, Güç ve hayat koşuşturmacası
# Location:
#  Following Count:1189
# Follower Count:70
# Total Tweets:4291
# Retweet Count:222
# Tweet Text: 📣2 SAATLİK KISA ÇEKİLİŞ 📣
#
# 🎖250 TL🎖
#
# ⚔️Şartlar⚔️
#
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣@ZigguratDao‘ nun sabit tweetine RT + Like at.🏆Bonus: Şartları yerine getirenler 100 TL daha kazanacak.
#
# #btc #giveaway #eth #luna #binance #nfts #avax #elon #dolar #shib #ape #Metaverse #web3 #bnb #sol
# Hashtags Used:[]
# Tweet Scraped71:
# Username:Muhammedamlolu7
# Description:
# Location:
#  Following Count:2
# Follower Count:3
# Total Tweets:6
# Retweet Count:615
# Tweet Text: GELENEKSEL #USDT ÖDÜLLÜ ÇEKİLİŞİMİZ DEVAM EDİYOR! 📢📢📢
#
# Bu twiti beğenip RT eden takipçilerimden rastgele #TRC20 adresi isteyip #USDT göndereceğim.
# Sonuç saat 23.00’da…
#
# #Bitcoin   #BTC   #ETH
# Hashtags Used:['USDT', 'TRC20']
# Tweet Scraped72:
# Username:adnancilingir66
# Description:
# Location:
#  Following Count:35
# Follower Count:1
# Total Tweets:34
# Retweet Count:109
# Tweet Text: #kripto piyasasında büyük bir yer edinen, piyasanın en ekolojik projesi olan  $VINU ‘yu  @gate_io Listelenmesinden sonra başka bir T1 borsa listelenmesi bekliyor 😉
#
# https://t.co/lI270V6PCu
#
# @VitaInuCoin @ElemontCapital
#
# #VINU #altcoin #BTC #BNB #Ethereum #Gateio https://t.co/O9tYszUjZ1
# Hashtags Used:['kripto']
# Tweet Scraped73:
# Username:0couple7
# Description:Follow me✨
# Location:
#  Following Count:171
# Follower Count:38665
# Total Tweets:314
# Retweet Count:105
# Tweet Text: 🎁 ÇEKİLİŞ 🎁
#
# 🏆 5 KİŞİYE 200₺ TOPLAMDA (1000₺) HEDİYE 🎁
#
# YAPMANIZ GEREKENLER⬇️
#
# SON 3 TWİTE RT,FAV❤️ ATIN
#
# BU TWİTE RT FAV.
#
# 2 ARKADAŞINIZI ETİKETLEYİN
#
# BENİ TAKİP ETMEYİ UNUTMAYIN🙂
#
# CUMARTESİ GÜNÜ AÇIKLANACAK.🎊🎊🎊🎊
#
# #BTC #Bitcoin #Solana #NFT #shiba #ETHUSD #Binance
# Hashtags Used:[]
# Tweet Scraped74:
# Username:Salmaz6600
# Description:a man who wants to meet you💪💪💌💌💌
# Location:
#  Following Count:94
# Follower Count:209
# Total Tweets:18133
# Retweet Count:30
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped75:
# Username:behreminbu
# Description:Sаnmа аcıtmаz dünyа seni o kаfeste
# Location:
#  Following Count:50687
# Follower Count:88343
# Total Tweets:5158
# Retweet Count:105
# Tweet Text: 🎁 ÇEKİLİŞ 🎁
#
# 🏆 5 KİŞİYE 200₺ TOPLAMDA (1000₺) HEDİYE 🎁
#
# YAPMANIZ GEREKENLER⬇️
#
# SON 3 TWİTE RT,FAV❤️ ATIN
#
# BU TWİTE RT FAV.
#
# 2 ARKADAŞINIZI ETİKETLEYİN
#
# BENİ TAKİP ETMEYİ UNUTMAYIN🙂
#
# CUMARTESİ GÜNÜ AÇIKLANACAK.🎊🎊🎊🎊
#
# #BTC #Bitcoin #Solana #NFT #shiba #ETHUSD #Binance
# Hashtags Used:[]
# Tweet Scraped76:
# Username:ClankApp
# Description:Biggest blockchains transactions in real time. Api available: https://t.co/4vwvqel9cV 🐳 Made in France ❤️ Powered by @blockchair. Check out @Trengible.
# Location:Moon
#  Following Count:5
# Follower Count:14415
# Total Tweets:517071
# Retweet Count:0
# Tweet Text: 💵3,989 #BTC (79,105,480 USD) move from unknown wallet to unknown wallet
#
# Date : 2022-09-04 18:05:07 (GMT 0)
# Blockchain : #BITCOIN
# Symbol : #BTC
#
# Detail: https://t.co/NVW3Apwsau
# Hashtags Used:['BTC', 'BITCOIN', 'BTC']
# Tweet Scraped77:
# Username:sanzdela79
# Description:Nfts cardano
# Location:
#  Following Count:305
# Follower Count:225
# Total Tweets:18704
# Retweet Count:35
# Tweet Text: 💥BRUTAL💥👏
#
# Nigeria y #Binance  están en conversaciones para crear una zona económica digital que apoyará la adopción de la tecnología #blockchain 🥳🔥🇳🇬
#
# #Crypto #BNB #BTC https://t.co/QNdOaFfKZy
# Hashtags Used:['Binance']
# Tweet Scraped78:
# Username:_Glen72
# Description:Politics ⛔️ PORN=Unfollow, DM ⛔️
# Location:
#  Following Count:44763
# Follower Count:54099
# Total Tweets:64424
# Retweet Count:105
# Tweet Text: 🎁 ÇEKİLİŞ 🎁
#
# 🏆 5 KİŞİYE 200₺ TOPLAMDA (1000₺) HEDİYE 🎁
#
# YAPMANIZ GEREKENLER⬇️
#
# SON 3 TWİTE RT,FAV❤️ ATIN
#
# BU TWİTE RT FAV.
#
# 2 ARKADAŞINIZI ETİKETLEYİN
#
# BENİ TAKİP ETMEYİ UNUTMAYIN🙂
#
# CUMARTESİ GÜNÜ AÇIKLANACAK.🎊🎊🎊🎊
#
# #BTC #Bitcoin #Solana #NFT #shiba #ETHUSD #Binance
# Hashtags Used:[]
# Tweet Scraped79:
# Username:ClankApp
# Description:Biggest blockchains transactions in real time. Api available: https://t.co/4vwvqel9cV 🐳 Made in France ❤️ Powered by @blockchair. Check out @Trengible.
# Location:Moon
#  Following Count:5
# Follower Count:14415
# Total Tweets:517071
# Retweet Count:0
# Tweet Text: 💵4,460 #BTC (88,430,070 USD) move from unknown wallet to unknown wallet
#
# Date : 2022-09-04 18:05:07 (GMT 0)
# Blockchain : #BITCOIN
# Symbol : #BTC
#
# Detail: https://t.co/Kcg2GzqnLj
# Hashtags Used:['BTC', 'BITCOIN', 'BTC']
# Tweet Scraped80:
# Username:youHODL_escrow
# Description:We offer a free service to buyers who wish to protect their Bitcoin purchase against fraud. Email suppor@youhodl.us to find out more.
# Location:
#  Following Count:15
# Follower Count:18
# Total Tweets:1109
# Retweet Count:0
# Tweet Text: Authentic 30cm Rose Tyrien/Iris (Two Tone) Epsom #Birkin handbag from 2016, on behalf of a client. On offer for only 0.15 #Bitcoin, SUBSTANTIALLY below market value.
#
# Available safely through us via Escrow.
#
# #BTC
# #Hermes https://t.co/A0I7K5y2ex
# Hashtags Used:['Birkin', 'Bitcoin', 'BTC', 'Hermes']
# Tweet Scraped81:
# Username:cryptoalerted
# Description:Crypto Alerted Our Tweets are not Financial Advise Be Carefull
# Location:USA
#  Following Count:107
# Follower Count:771
# Total Tweets:35996
# Retweet Count:0
# Tweet Text: Goons of Balatroon (GOB) went up 14.9 percent in the last 1 minutes on https://t.co/rgEAV9gIXu. #GOB  #crypto #bitcoin #cryptocurrency #btc #ethereum #blockchain #eth #trading #altcoin #binance #cryptonews
# Hashtags Used:['GOB', 'crypto', 'bitcoin', 'cryptocurrency', 'btc', 'ethereum', 'blockchain', 'eth', 'trading', 'altcoin', 'binance', 'cryptonews']
# Tweet Scraped82:
# Username:denver5441
# Description:demver
# Location:
#  Following Count:591
# Follower Count:44
# Total Tweets:1825
# Retweet Count:30
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped83:
# Username:2021mora3
# Description:
# Location:
#  Following Count:616
# Follower Count:71
# Total Tweets:1133
# Retweet Count:10927
# Tweet Text: 💸 $1,000 #Giveaway 💸
#
# We'll select 10 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrSIiZ https://t.co/DiRKGbV3cW
# Hashtags Used:['Giveaway']
# Tweet Scraped84:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:1
# Follower Count:113
# Total Tweets:51013
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1568.9 USD
# #Bitcoin 0.07898021 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped85:
# Username:Awesowewnner4
# Description:No pain , no gain! 🥲💙💫
# 5-2-0
# Location:Türkiye
#  Following Count:1872
# Follower Count:469
# Total Tweets:18071
# Retweet Count:615
# Tweet Text: GELENEKSEL #USDT ÖDÜLLÜ ÇEKİLİŞİMİZ DEVAM EDİYOR! 📢📢📢
#
# Bu twiti beğenip RT eden takipçilerimden rastgele #TRC20 adresi isteyip #USDT göndereceğim.
# Sonuç saat 23.00’da…
#
# #Bitcoin   #BTC   #ETH
# Hashtags Used:['USDT', 'TRC20']
# Tweet Scraped86:
# Username:berlin2990
# Description:berlin
# Location:
#  Following Count:587
# Follower Count:38
# Total Tweets:1805
# Retweet Count:30
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped87:
# Username:Banglal69729157
# Description:bad jet
# Location:
#  Following Count:759
# Follower Count:62
# Total Tweets:1020
# Retweet Count:453
# Tweet Text: Why you should buy $MANC?
#  - Reputable Audit ( InterFi )
#  - 10 Global CEXs Listing
#  - CMC Verified Top #500
#  - Game company that has millions of downloads from stores @manc_games
#
#  #Crypto #MEXC #BitMart #BTC #ETH #CEX https://t.co/6jMtxtTUAR
# Hashtags Used:[]
# Tweet Scraped88:
# Username:BurkOzer54
# Description:@Burk_Ozer54 👈
# Location:Serdivan, Sakarya
#  Following Count:7023
# Follower Count:9879
# Total Tweets:20339
# Retweet Count:105
# Tweet Text: 🎁 ÇEKİLİŞ 🎁
#
# 🏆 5 KİŞİYE 200₺ TOPLAMDA (1000₺) HEDİYE 🎁
#
# YAPMANIZ GEREKENLER⬇️
#
# SON 3 TWİTE RT,FAV❤️ ATIN
#
# BU TWİTE RT FAV.
#
# 2 ARKADAŞINIZI ETİKETLEYİN
#
# BENİ TAKİP ETMEYİ UNUTMAYIN🙂
#
# CUMARTESİ GÜNÜ AÇIKLANACAK.🎊🎊🎊🎊
#
# #BTC #Bitcoin #Solana #NFT #shiba #ETHUSD #Binance
# Hashtags Used:[]
# Tweet Scraped89:
# Username:lowelo2006
# Description:
# Location:
#  Following Count:229
# Follower Count:54
# Total Tweets:342
# Retweet Count:21
# Tweet Text: PreSend is developing an anti-phishing &amp; anti-scammer functionality that stops bad actors from taking possession of your wallet or changing the destination address of your funds fractions of a second before you send them on 3rd party websites! #BNB #AVAX #NFT #ETH #FTM #BTC
# Hashtags Used:[]
# Tweet Scraped90:
# Username:Red_Iibertus
# Description:#BTC = FREEDOM
#
# The future is #Bitcoin⚡🔥🔥🔥🔥
# Location:Canada
#  Following Count:1037
# Follower Count:450
# Total Tweets:4754
# Retweet Count:0
# Tweet Text: Still waiting for Binance to return funds that scammers use their exchange to launder #BTC through. https://t.co/aFZHL5VGl0
# Hashtags Used:['BTC']
# Tweet Scraped91:
# Username:CryptoHouse2022
# Description:
# Location:
#  Following Count:397
# Follower Count:88
# Total Tweets:6
# Retweet Count:0
# Tweet Text: 753$ in $ETH |  ⏰ 6h
#
# Retweet, Follow and Like 👍
# #Crypto #BTC  #LTC #Giveaways  #binancecode  #Bitcoin #ETH #cryptoboxcode #BinancePay #cryptobox #BNB  #Binance
# Hashtags Used:['Crypto', 'BTC', 'LTC', 'Giveaways', 'binancecode', 'Bitcoin', 'ETH', 'cryptoboxcode', 'BinancePay', 'cryptobox', 'BNB', 'Binance']
# Tweet Scraped92:
# Username:Lord_Defi22
# Description:#Defi lover, crypto hodler.
# Location:
#  Following Count:5
# Follower Count:106
# Total Tweets:37230
# Retweet Count:0
# Tweet Text: updated price for $EOS, $AVAX, $SOL:
#
# #EOS $1.491 USD
# #AVAX 0.000957 #BTC
# #SOL 0.02024 #ETH
#
# I tweet updated prices, follow me to get recent updates.
#
# #cryptocurrency #crypto
# Hashtags Used:['EOS', 'AVAX', 'BTC', 'SOL', 'ETH', 'cryptocurrency', 'crypto']
# Tweet Scraped93:
# Username:Musty7887
# Description:Takip eden arkadaşları bende takip ediyorum. Ayrıca çekiliş ve airdroplara katılım sağlıyorum. Takipte kalın #Queenteam #IwonHanabi
# Location:Türkiye
#  Following Count:5000
# Follower Count:263
# Total Tweets:23799
# Retweet Count:30
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped94:
# Username:boygillerden
# Description:520🌺
# 714.777 🍀
#
# #AVAX #TRX #SOLANA
# Location:
#  Following Count:1167
# Follower Count:61
# Total Tweets:5081
# Retweet Count:351
# Tweet Text: Prize:   0.3 $SOL ( 9$) ✔️🎁
#
# 1 winner 🏆
#
# To Enter:
# 1️⃣ Follow @CryptoDolars
#
# 2️⃣ Like &amp; RT
#
# 3️⃣ Tag 2 Friends
#
# ⏰24hrs
#
# #SolanaSummer  #web3 #Metaverse #Crypto #Binance     #eth #btc    #avax    #USDT #Tether     #NFTGiveaway  #NFTs #NFTCommunity  #sol  #Giveaway
# Hashtags Used:[]
# Tweet Scraped95:
# Username:ecemalasafak
# Description:
# Location:Adana, Türkiye
#  Following Count:4404
# Follower Count:240
# Total Tweets:20756
# Retweet Count:30
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped96:
# Username:SuzartAriane
# Description:Use my referral link https://t.co/rdi2tUgy2E to sign up for https://t.co/NppXAI5QRm and we both get $50 USD :)
# Location:ferraz
#  Following Count:643
# Follower Count:44
# Total Tweets:1227
# Retweet Count:10927
# Tweet Text: 💸 $1,000 #Giveaway 💸
#
# We'll select 10 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrSIiZ https://t.co/DiRKGbV3cW
# Hashtags Used:['Giveaway']
# Tweet Scraped97:
# Username:Bizzatkendisi1
# Description:
# Location:Türkiye
#  Following Count:627
# Follower Count:69
# Total Tweets:5348
# Retweet Count:615
# Tweet Text: GELENEKSEL #USDT ÖDÜLLÜ ÇEKİLİŞİMİZ DEVAM EDİYOR! 📢📢📢
#
# Bu twiti beğenip RT eden takipçilerimden rastgele #TRC20 adresi isteyip #USDT göndereceğim.
# Sonuç saat 23.00’da…
#
# #Bitcoin   #BTC   #ETH
# Hashtags Used:['USDT', 'TRC20']
# Tweet Scraped98:
# Username:buseaydnn34
# Description:Taklit etme aslını yaşa @galatasaraySK
# Location:İstanbul, Türkiye
#  Following Count:24105
# Follower Count:28097
# Total Tweets:900
# Retweet Count:105
# Tweet Text: 🎁 ÇEKİLİŞ 🎁
#
# 🏆 5 KİŞİYE 200₺ TOPLAMDA (1000₺) HEDİYE 🎁
#
# YAPMANIZ GEREKENLER⬇️
#
# SON 3 TWİTE RT,FAV❤️ ATIN
#
# BU TWİTE RT FAV.
#
# 2 ARKADAŞINIZI ETİKETLEYİN
#
# BENİ TAKİP ETMEYİ UNUTMAYIN🙂
#
# CUMARTESİ GÜNÜ AÇIKLANACAK.🎊🎊🎊🎊
#
# #BTC #Bitcoin #Solana #NFT #shiba #ETHUSD #Binance
# Hashtags Used:[]
# Tweet Scraped99:
# Username:KFilipins
# Description:investing in #crypto
# living the best life
# #hodl #gamefi #defi
# Location:
#  Following Count:798
# Follower Count:162
# Total Tweets:494
# Retweet Count:1
# Tweet Text: @BitcoinMagazine #BTC is too goof for this world, lots of people ain't ready for it yet, unfortunately
# Hashtags Used:['BTC']
# Tweet Scraped100:
# Username:feverman52
# Description:...
# Location:
#  Following Count:542
# Follower Count:75
# Total Tweets:9450
# Retweet Count:30
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped101:
# Username:delinindelisii0
# Description:..
# Location:Ankara, Türkiye
#  Following Count:20088
# Follower Count:25815
# Total Tweets:57622
# Retweet Count:105
# Tweet Text: 🎁 ÇEKİLİŞ 🎁
#
# 🏆 5 KİŞİYE 200₺ TOPLAMDA (1000₺) HEDİYE 🎁
#
# YAPMANIZ GEREKENLER⬇️
#
# SON 3 TWİTE RT,FAV❤️ ATIN
#
# BU TWİTE RT FAV.
#
# 2 ARKADAŞINIZI ETİKETLEYİN
#
# BENİ TAKİP ETMEYİ UNUTMAYIN🙂
#
# CUMARTESİ GÜNÜ AÇIKLANACAK.🎊🎊🎊🎊
#
# #BTC #Bitcoin #Solana #NFT #shiba #ETHUSD #Binance
# Hashtags Used:[]
# Tweet Scraped102:
# Username:atigra06
# Description:
# Location:
#  Following Count:99
# ...
# Tweet Scraped470:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:1
# Follower Count:113
# Total Tweets:51013
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1569.68 USD
# #Bitcoin 0.07901545 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped471:
# Username:yuugiriawano
# Description:仮想通貨やNFT値上がり率ランキング等をつぶやくBotです。
# ホームページもどうぞご覧ください。
# 様々な金融商品の売買シグナルが無料で見られます。
#
# Please visit my website.
# The real-time NFT ranking is here.
# Location:
#  Following Count:0
# Follower Count:935
# Total Tweets:46913
# Retweet Count:0
# Tweet Text: 仮想通貨値下がり率ランキング
#
# 2022-09-05 03:00:00
#
# 1位 $RND  -60.0
# 2位 $SOS  -58.0
# 3位 $FSW  -49.0
# 4位 $NU  -49.0
# 5位 $GEIST  -38.0
# 6位 $ACH1  -37.0
# 7位 $LIVE  -37.0
# 8位 $GMEE  -28.0
# 9位 $EFI  -24.0
# 10位 $GODZ  -22.0
# (%)
#
# #Bitcoin #BTC #BTCUSD #BTCJPY #Crypto #FX https://t.co/C0pxI8WoFw
# Hashtags Used:['Bitcoin', 'BTC', 'BTCUSD', 'BTCJPY', 'Crypto', 'FX']
# Tweet Scraped472:
# Username:iDaz1122
# Description:$BTFA is the way! Do not take any of my Tweets as financial advice, do your own research when investing.
# Location:
#  Following Count:94
# Follower Count:59
# Total Tweets:3578
# Retweet Count:7
# Tweet Text: 🍌#100xgem 💎
#   #BTFA &amp; #BANDEX
#      merger incoming
# -2nd #NFT launch, creator
# @fabricesapolsky
# (marvel artist)
#  #metaverse #inswaywetrust
#  #Volt #btc #Crypto #NFT #P2EGame
# #Bananachips #Lunc #SHIB @jfosteronfire
# @ViPinball4k @BananaTFA            https://t.co/wKYnzWwH7J https://t.co/OGFqniLpw8
# Hashtags Used:['100xgem', 'BTFA', 'BANDEX', 'NFT', 'metaverse']
# Tweet Scraped473:
# Username:BitcoinBTC_pl
# Description:🟠Tylko #Bitcoin $BTC 🥇#BTC #kryptowaluty 🤖 #HODL 🚀🌖 #tylkobitcoin ₿🧡 #BitcoinBTC ₿🟠 #kupbitcoin ₿🚀 #analizatechniczna #krypto
# Location:Polska
#  Following Count:362
# Follower Count:335
# Total Tweets:830
# Retweet Count:0
# Tweet Text: 🟠Cena #Bitcoin⚡️wynosi 19866.66$💵 #kryptowaluty #BTC $BTC #HODL 🚀🌖19866.66
# Hashtags Used:['Bitcoin', 'kryptowaluty', 'BTC', 'HODL']
# Tweet Scraped474:
# Username:Maxi__1981
# Description:🚀 Cryptonaut from 🇦🇹 and $TTM whale 🐳. Everything IMO! DYOR! $NEP $TTM  @tothemoon_net @N3_FTW_NETWORK #NFT #Metaverse #GameFi
#
# https://t.co/F5S6hsZrtL
# Location:Österreich
#  Following Count:4468
# Follower Count:5377
# Total Tweets:19563
# Retweet Count:2
# Tweet Text: 🚀🔥 FUSIONS NEWS 🔥🚀
#
# ➡️ ARENA 64 REGISTRATION OPENS IN 1 HOUR! ⚔️🏟️
#
# ➡️ TOURNAMENT #9! 😱🔥
#
# REGISTER HERE: ➡️ https://t.co/hUJmg9CGMc
#
# ➡️ @tothemoon_net ❤️
#
# ➡️ @N3_FTW_NETWORK ❤️
#
# #Metaverse #NFT #GAS $GAS #BlockchainGaming #GameFi #NFTCommunity #Airdrop #BTC #ETH $NEO #NEO https://t.co/BdhNz6kCKv
# Hashtags Used:[]
# Tweet Scraped475:
# Username:KriptoHavadis_
# Description:Paylaşımlar Yatırım Tavsiyesi Değildir!
# Youtube Kanalımız: https://t.co/VPNTWrDuuS
# Telegram: https://t.co/4vFyjYVkY0
# Haberler için: https://t.co/A5EayYDbK3
# Location:
#  Following Count:16
# Follower Count:27
# Total Tweets:1501
# Retweet Count:0
# Tweet Text: İşte Bitcoin’in En Büyük Kayıp ve Çıkarları Gördüğü Zamanlar! Bitcoin’in belirli bir kapanış saatinin olmaması, yatırımcıları kendisine çeken bir özelliktir. #kriptopara #bitcoin #btc
#
# https://t.co/NFgPz4Csog https://t.co/xWu2Bd5KA9
# Hashtags Used:['kriptopara', 'bitcoin', 'btc']
# Tweet Scraped476:
# Username:moscowtime_xyz
# Description:I'm a bot!
#
# Donate: https://t.co/xJlFhqcKeb · Made by @siim · BLOCKCLOCK is a registered trademark of @Coinkite
# Location:🇷🇺
#  Following Count:257
# Follower Count:242
# Total Tweets:6405
# Retweet Count:0
# Tweet Text: The current block height is 752612.
# The price of 1 #BTC is $19,866.
# Moscow time is 50:34.
#
# Stats for the last hour:
#
# - Number of blocks mined: 4
# - Newly created coins: 25 BTC
# - Number of transactions confirmed: 6946 https://t.co/EB3kw7e1ge
# Hashtags Used:['BTC']
# Tweet Scraped477:
# Username:ereyestercrypto
# Description:仮想通貨の価格を10分置きに通知するBOTです。BTC/JPY ETH/JPY XRP/JPY LTC/JPY
# @ereyester
# Location:
#  Following Count:1
# Follower Count:1013
# Total Tweets:173001
# Retweet Count:0
# Tweet Text: BTC/JPY = 2782354円
# ETH/JPY = 219619円
# XRP/JPY = 46.508円
# LTC/JPY = 8347.1円
# #ビットコイン #仮想通貨 #BTC #ETH #XRP #LTC
# Hashtags Used:['ビットコイン', '仮想通貨', 'BTC', 'ETH', 'XRP', 'LTC']
# Tweet Scraped478:
# Username:tfscrypto
# Description:Cryptocurency tree map. Updated multiple times a day
# 🤖 Last update: September, 4 2022 18:00 UTC
# Location:Blockchain
#  Following Count:33
# Follower Count:39
# Total Tweets:1375
# Retweet Count:0
# Tweet Text: 🚀 TOP 10 CRYPTO MAP 🚀
# #BTC #BitCoin $BTC
# September, 4 2022 18:00 UTC https://t.co/oeJnSWPrqP
# Hashtags Used:['BTC', 'BitCoin']
# Tweet Scraped479:
# Username:mccarthy_blithe
# Description:::»»::»»+&
# Location:Angola
#  Following Count:21
# Follower Count:1
# Total Tweets:4
# Retweet Count:0
# Tweet Text: #CELRUSDT Bear Alert!5X VolumePrice:      0.01795-min %: -0.61%Volume:  $16,182 #crypto #whale #btc #eth #CELR…
# Hashtags Used:['CELRUSDT', 'crypto', 'whale', 'btc', 'eth', 'CELR']
# Tweet Scraped480:
# Username:by_nukorea
# Description:AIを用いて仮想通貨の相場の予想をするbotです。(BTC：1時間ごと)
#
# 中の人　https://t.co/M3Mpf7lZlw
# リンク提供元：@amazonJP様　、@RakutenJP様
#
# このツイートは個人の趣味であり、ツイート内容による運用結果について一切責任を負いません。
# Location:
#  Following Count:1
# Follower Count:2566
# Total Tweets:57570
# Retweet Count:0
# Tweet Text: 現在のビットコインの価格は2782807.0円です。AIにより1時間後の価格は下がると予想されました。なお、前回の予想は当たり、現在の予測の正答率は52%です。 #ビットコイン #BTC #AI
# Hashtags Used:['ビットコイン', 'BTC', 'AI']
# Tweet Scraped481:
# Username:christy79056576
# Description:
# Location:
#  Following Count:0
# Follower Count:0
# Total Tweets:50
# Retweet Count:38
# Tweet Text: Right now trendline is acting as support if it breaks Below then 17K will be the buy zone.
# If it continues then strong resistance is at 28K, between 21.5k and 28K minor resistance can create selling pressure.
#
# #Bitcoin #BTC  #cryptocurrency https://t.co/nG4MYqskXu
# Hashtags Used:[]
# Tweet Scraped482:
# Username:pujanggacitty1x
# Description:pendiam, humoris
# Location:Sumbawa
#  Following Count:1765
# Follower Count:33
# Total Tweets:5486
# Retweet Count:1573
# Tweet Text: 10$ GIVEAWAY | 4 HRS ☀️
#
# RT + Follow @DeGodsNFTS
#
# #NFTs #nft #NFTGiveaway #Giveaway #NFTCommunity #freemint #ethereum #btc #eth #crypto #cryptocurrency https://t.co/AhhBRE89Xp
# Hashtags Used:['NFTs', 'nft', 'NFTGiveaway', 'Giveaway', 'NFTCommunity', 'freemint', 'ethereum']
# Tweet Scraped483:
# Username:Maxi__1981
# Description:🚀 Cryptonaut from 🇦🇹 and $TTM whale 🐳. Everything IMO! DYOR! $NEP $TTM  @tothemoon_net @N3_FTW_NETWORK #NFT #Metaverse #GameFi
#
# https://t.co/F5S6hsZrtL
# Location:Österreich
#  Following Count:4468
# Follower Count:5377
# Total Tweets:19563
# Retweet Count:2
# Tweet Text: 🚀🔥 FUSIONS NEWS 🔥🚀
#
# ➡️ ARENA 64 REGISTRATION OPENS IN 1 HOUR! ⚔️🏟️
#
# ➡️ TOURNAMENT #9! 😱🔥
#
# REGISTER HERE: ➡️ https://t.co/hUJmg9CGMc
#
# ➡️ @tothemoon_net ❤️
#
# ➡️ @N3_FTW_NETWORK ❤️
#
# #Metaverse #NFT #GAS $GAS #BlockchainGaming #GameFi #NFTCommunity #Airdrop #BTC #ETH $NEO #NEO https://t.co/BdhNz6kCKv
# Hashtags Used:['Metaverse', 'NFT', 'GAS', 'BlockchainGaming', 'GameFi', 'NFTCommunity', 'Airdrop', 'BTC', 'ETH', 'NEO']
# Tweet Scraped484:
# Username:JeanDoobs
# Description:Mi Homme Mi Robot et Re Mi Ours derrière. De tout, de rien, mais j'aime çà!
# #fintech #bitcoins #formule1 #bordeaux #kaamelott
# Location:Gironde, Aquitaine
#  Following Count:162
# Follower Count:2166
# Total Tweets:565012
# Retweet Count:1
# Tweet Text: Récupération disponible !!!
# #crypto #blockchain #forex #btc #ethereum  #trading #bitcoinmining #investment #business #forextrader #bitcoinnews #bitcoins #entrepreneur #invest #trader
#  #binaryoptions #bitcointrading #eth #cryptocurrencies #cryptotrading #forextrading #binance
# Hashtags Used:['crypto', 'blockchain', 'forex', 'btc', 'ethereum', 'trading', 'bitcoinmining', 'investment', 'business']
# Tweet Scraped485:
# Username:LV4RK1VE
# Description:#BTS, rdg acc, joining acc.
# alipin ng mga papel
# allergic sa pusit
# Location:run, yeah you gotta run, (+63)
#  Following Count:1052
# Follower Count:26
# Total Tweets:3290
# Retweet Count:1573
# Tweet Text: 10$ GIVEAWAY | 4 HRS ☀️
#
# RT + Follow @DeGodsNFTS
#
# #NFTs #nft #NFTGiveaway #Giveaway #NFTCommunity #freemint #ethereum #btc #eth #crypto #cryptocurrency https://t.co/AhhBRE89Xp
# Hashtags Used:['NFTs', 'nft', 'NFTGiveaway', 'Giveaway', 'NFTCommunity', 'freemint', 'ethereum']
# Tweet Scraped486:
# Username:JeanDoobs
# Description:Mi Homme Mi Robot et Re Mi Ours derrière. De tout, de rien, mais j'aime çà!
# #fintech #bitcoins #formule1 #bordeaux #kaamelott
# Location:Gironde, Aquitaine
#  Following Count:162
# Follower Count:2166
# Total Tweets:565012
# Retweet Count:1
# Tweet Text: Récupération disponible !!!
# #crypto #blockchain #forex #btc #ethereum #money #trading #bitcoinmining #investment #business #forextrader #bitcoinnews #bitcoins #entrepreneur #invest #trader #binaryoptions #bitcointrading #eth #cryptocurrencies #cryptotrading #forextrading #binance
# Hashtags Used:['crypto', 'blockchain', 'forex', 'btc', 'ethereum', 'money', 'trading', 'bitcoinmining', 'investment', 'business']
# Tweet Scraped487:
# Username:MoneyBotBR
# Description:Cotação das principais moedas do mercado
# Location:Atualizado a cada 1 hora
#  Following Count:0
# Follower Count:95
# Total Tweets:8148
# Retweet Count:0
# Tweet Text: 🕐 15:00
#
# Dólar Comercial (#USD):
# R$5,17 | -1,37%
#
# Euro (#EUR):
# R$5,14 | -1,26%
#
# Libra Esterlina (#GBP):
# R$5,95 | -1,69%
#
# Bitcoin (#BTC):
# R$103.000,00 | 0,12%
#
# Peso Argentino (#ARS):
# R$0,04 | -1,2%
#
# Yuan Chinês (#CNY):
# R$0,75 | -1,23%
# Hashtags Used:['USD', 'EUR', 'GBP', 'BTC', 'ARS', 'CNY']
# Tweet Scraped488:
# Username:Bnymn17371246
# Description:#Trabzonspor
# Location:
#  Following Count:366
# Follower Count:119
# Total Tweets:252
# Retweet Count:82
# Tweet Text: 🎁ÇEKİLİŞ🎁
#
# 🏆2 KİŞİYE 30$ TOPLAMDA 60$ (1080 TL) 💸 HEDİYE🎗
#
# 1⃣yotube kanalına ABONE OLUN👇
#
# https://t.co/NWZsfrJZBj
#
# Ve youtube videosuna LİKE❤ YORUM Yapın👇
#
# https://t.co/QA7fMy5aF6
#
# Bu twite RT, FAV❤ATIN
#
# SÜRE:48H
# #btc    #bitcoin    #NFTGiveaway #ETH #shiba #Sol
# Hashtags Used:[]
# Tweet Scraped489:
# Username:Hiboklkn
# Description:ŞÜKÜR 🙏
# Location:Bursa, Türkiye
#  Following Count:378
# Follower Count:52
# Total Tweets:2981
# Retweet Count:109
# Tweet Text: #kripto piyasasında büyük bir yer edinen, piyasanın en ekolojik projesi olan  $VINU ‘yu  @gate_io Listelenmesinden sonra başka bir T1 borsa listelenmesi bekliyor 😉
#
# https://t.co/lI270V6PCu
#
# @VitaInuCoin @ElemontCapital
#
# #VINU #altcoin #BTC #BNB #Ethereum #Gateio https://t.co/O9tYszUjZ1
# Hashtags Used:['kripto']
# Tweet Scraped490:
# Username:cRe5520
# Description:The channel breakout trading strategy bot for BitMEX, FTX, Bybit and Binance Futures.
# This account continuously tweets about how the system is working.
# Location:AWS eu-west-1a Ireland Region
#  Following Count:16
# Follower Count:250
# Total Tweets:41719
# Retweet Count:0
# Tweet Text: strategy: 5010HL1h atr20d: 917.73
#
# 04 Sep 2022 18:00:01 UTC
# 🔄 'None' 03:00:01 JST
# --- 20370.0  long_entry_trigger
#  &gt;  19826.0  last_price $BTC/USD
# --- 19584.0  short_entry_trigger
#
# #BTC/USD perpetual contract on #BitMEX
# Hashtags Used:['BTC', 'BitMEX']
# Tweet Scraped491:
# Username:topcryptostats
# Description:Stats every hour of the top 10 crypto currencies
# Location:Blockchain
#  Following Count:0
# Follower Count:4559
# Total Tweets:423033
# Retweet Count:0
# Tweet Text: Bitcoin - BTC
# Price: $19,854.69
# Change in 1h: -0.20016329%
# Market cap: $380,043,916,857.75
# Ranking: 1
# #Bitcoin #BTC
# Hashtags Used:['Bitcoin', 'BTC']
# Tweet Scraped492:
# Username:KitcoCrypto
# Description:Kitco’s coverage on #cryptocurrencies is unique as to how the emerging #crypto space is interacting, impacting and influencing commodities markets and investors
# Location:
#  Following Count:20
# Follower Count:1515
# Total Tweets:26308
# Retweet Count:0
# Tweet Text: https://t.co/dIubJoO1df 14:00 EDT $USD
#
# #BTC ⬇ $19.84K (-0.28%)
# #LTC ⬆ $59.47 (0.32%)
# #BNB ⬆ $279.05 (0.05%)
# #TRX ⬆ $0.0634 (0.28%)
# #XLM ⬆ $0.1054 (0.19%)
# #ETH ⬆ $1569.77 (0.13%)
# #XRP ⬆ $0.3314 (0.03%)
# #BCH ⬆ $117.34 (0.14%)
#
# #kitco #crypto https://t.co/gnwNM0QRMa
# Hashtags Used:['BTC', 'LTC', 'BNB', 'TRX', 'XLM', 'ETH', 'XRP', 'BCH', 'kitco', 'crypto']
# Tweet Scraped493:
# Username:whalesradar_com
# Description:https://t.co/oZVtGZzi5n
#
# Crypto Whale Radar and Scanner
#
# #Crypto #Bitcoin #Cryptocurrency #RastGele
#
# Whales Radar is brand of @FxCanli
# Location:İstanbul
#  Following Count:1
# Follower Count:1360
# Total Tweets:28225
# Retweet Count:0
# Tweet Text: #CAKEUSDT #CAKE
# Signal #3
#
# Last Signal: 199 mins ago
# Before: 4.06500000
# After: 4.06300000 🔴(-0.05%)
# Volume Chng: 359,696 USDT (10.42%)
#
# Daily
# Price Chng: (0.94%)🟢
# Volume: 3,446,469 USDT
#
# 🚀PRO ➡️ https://t.co/1EgdzYf2ot 🐳
#
# #Crypto #Bitcoin #BTC #ETH
# Hashtags Used:['CAKEUSDT', 'CAKE', 'Crypto', 'Bitcoin', 'BTC', 'ETH']
# Tweet Scraped494:
# Username:bitcoinbotGER
# Description:Jede Stunde wird über BTC Kurs informiert
# Location:
#  Following Count:0
# Follower Count:139
# Total Tweets:5450
# Retweet Count:0
# Tweet Text: Der $BTC Preis liegt aktuell bei $19,839.37.
# 🔴 Im Vergleich zum letzten Tweet, ist der Preis um $52.46 (0.26%) gesunken.
# 🟢 In den letzten 24 Stunden ist der Preis um $23.4 (0.12%) gestiegen.
#
# #Bitcoin #BTC https://t.co/oTF8Qx67ke
# Hashtags Used:['Bitcoin', 'BTC']
# Tweet Scraped495:
# Username:NowBitcoinPrice
# Description:#Bitcoin price updates every 30 minutes #BTC #money.
# #Follow us now!
# Liked this account? You can send BTC tips here: 1EreDjZs57CamY9dyXUHrQ4Q1ucDYNvfAE
# Location:Bitcoin
#  Following Count:1539
# Follower Count:3976
# Total Tweets:78044
# Retweet Count:0
# Tweet Text: Sep 04, 2022 17:59:00 UTC | 19,840.40$ | 19,327.40€ | 16,578.50£ | #Bitcoin #BTC $BTC #crypto #financial #news https://t.co/9OhgvNEINb
# Hashtags Used:['Bitcoin', 'BTC', 'crypto', 'financial', 'news']
# Tweet Scraped496:
# Username:BTCHourlyPrice
# Description:✨ Follow for $BTC Price Updates! 💸
# 📢 Every Hour, on the Hour! 📢
# #Bitcoin #BTC #Crypto
# * data source: https://t.co/PN1WctcBme *
# Location:
#  Following Count:1
# Follower Count:397
# Total Tweets:15860
# Retweet Count:0
# Tweet Text: 1 $BTC = $19,839.10 $USD
# 🟢 +0.11% chg/24h
#
# #Bitcoin #BTC #Crypto #Cryptocurrency
# Hashtags Used:['Bitcoin', 'BTC', 'Crypto', 'Cryptocurrency']
# Tweet Scraped497:
# Username:JemmyTrade
# Description:جيمي تريدJemmyTrade هي خدمه متكامله الهدف منها هو نشر ثقافه الاستثمار و التداول وتقديم افضل الفرص المتاحه في العالم لنساعد متابعينا  ف تحقيق الأرباح بأبسط الطر
# Location:
#  Following Count:65
# Follower Count:1035
# Total Tweets:339
# Retweet Count:1
# Tweet Text: 🔵معلومة: تضم قائمة أغنى 100 عنوان #Bitcoin  ما مجموعه ٢،٩٧٨،٧١٧ $BTC   بقيمة 59.1 مليار دولار
# #JemmyTrade
# #BTC
# #CryptoNews
# Hashtags Used:['Bitcoin', 'JemmyTrade', 'BTC', 'CryptoNews']
# Tweet Scraped498:
# Username:slash_trader
# Description:Ежедневные Эйрдропы #Airdrops I #Bounty I Розыгрыши криптовалют I #NFT, #ICO, #IDO, #IEO, #IGO l Бонусхантинг
# Location:
#  Following Count:34
# Follower Count:155
# Total Tweets:1355
# Retweet Count:0
# Tweet Text: Entangle #Testnet
#
# Оценка: 7/10⭐️
# Награда: Whitelist
# Ссылка: https://t.co/vHOLQNOsXW
# Указываем ETH адрес
#
# #Giveaways #NFTGiveaways #Giveaway #Airdrops #Bitcoin #cryptocurrency #BTC #NFTCommunity #BNB #Ethereum #BSCGems #BSC #Binance https://t.co/rx58xk6uDh
# Hashtags Used:['Testnet', 'Giveaways', 'NFTGiveaways', 'Giveaway', 'Airdrops', 'Bitcoin', 'cryptocurrency', 'BTC', 'NFTCommunity', 'BNB', 'Ethereum', 'BSCGems', 'BSC', 'Binance']
# Tweet Scraped499:
# Username:btc
# Description:The #BTCTimes delivers quality reporting of the #Bitcoin news you care about, covers stories that others don't, and addresses bad takes in mainstream media.
# Location:Worldwide
#  Following Count:159
# Follower Count:116959
# Total Tweets:3281
# Retweet Count:3
# Tweet Text: ICYMI: El Salvador’s #Bitcoin Beach and the surrounding area will receive an upgrade!
#
# #BTC
# https://t.co/oHCkx3ax3Z
# Hashtags Used:['Bitcoin', 'BTC']
# Tweet Scraped500:
# Username:picvsco
# Description:
# Location:Tanıtım için DM
#  Following Count:21
# Follower Count:224852
# Total Tweets:14540
# Retweet Count:106
# Tweet Text: 🎁 ÇEKİLİŞ 🎁
#
# 🏆 5 KİŞİYE 200₺ TOPLAMDA (1000₺) HEDİYE 🎁
#
# YAPMANIZ GEREKENLER⬇️
#
# SON 3 TWİTE RT,FAV❤️ ATIN
#
# BU TWİTE RT FAV.
#
# 2 ARKADAŞINIZI ETİKETLEYİN
#
# BENİ TAKİP ETMEYİ UNUTMAYIN🙂
#
# CUMARTESİ GÜNÜ AÇIKLANACAK.🎊🎊🎊🎊
#
# #BTC #Bitcoin #Solana #NFT #shiba #ETHUSD #Binance
# Hashtags Used:[]
# scraping has completed! :)

# %%
# Choose File Through Widget Experience | /Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/final-project-scraped_data-#BTC.json
###########################################################################################################################

# get home dir of user
home = str(Path.home()) 

# initialize a dict for the excel file; this removes the need to set global values
dict_file = {}

# change to simply `home` if you want users to navigate through diff dirs
#fc = FileChooser(f'{home}/excel')
fc = FileChooser(f'{home}/') 

# same here
#fc.sandbox_path = f'{home}/excel'
fc.sandbox_path = f'{home}/'

# limit file extensions to '.xls, .xlsb, .xlsm, .xlsx'
fc.filter_pattern = ['*.json*']
fc.title = '<b>Select your file</b>'
display(fc)

# create empty dropdown for sheet names
dropdown = widgets.Dropdown(options=[''], value='', description='Sheets:', disabled=False)

# create output frame for the df
out = widgets.Output(layout=widgets.Layout(display='flex', flex_flow='column', align_items='flex-start', width='100%'))
# Out:
# FileChooser(path='/Users/pergolicious', filename='', title='<b>Select your file</b>', show_hidden=False, selec…

# %%
# Convert JSON Data to Data Frame
###########################################################################################################################

BTCjsondata = f'{fc.selected_path}/{fc.selected_filename}'
print(BTCjsondata)

BTCdf = pd.read_json(BTCjsondata)

BTCdf.reset_index(drop=True, inplace=True)

BTCdf.info()
# Out:
# /Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/final-project-scraped_data-#BTC.json
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tweet Scraped    500 non-null    int64
#  1   Username         500 non-null    object
#  2   Description      500 non-null    object
#  3   Location         500 non-null    object
#  4   Following Count  500 non-null    int64
#  5   Follower Count   500 non-null    int64
#  6   Total Tweets     500 non-null    int64
#  7   Retweet Count    500 non-null    int64
#  8   Tweet Text       500 non-null    object
#  9   Hashtags Used    500 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 39.2+ KB

# %%
# Gathering of Data | 2 | Ethereum Tweets
###########################################################################################################################

print('Enter hasthag to search for')
words = input()

print('Enter number of tweets to search for')
numtweet = int(input())

scraped_data = []
print('Fetching tweets...')

scrape(words, numtweet, scraped_data)
print('scraping has completed! :)')
# Out:
# Enter hasthag to search for
#  #ETH
# Enter number of tweets to search for
#  500
# Unexpected parameter: len
# Fetching tweets...
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Unexpected parameter: len
# Tweet Scraped1:
# Username:Camillaherlet
# Description:
# Location:
#  Following Count:420
# Follower Count:14
# Total Tweets:692
# Retweet Count:10929
# Tweet Text: 💸 $1,000 #Giveaway 💸
#
# We'll select 10 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrSIiZ https://t.co/DiRKGbV3cW
# Hashtags Used:['Giveaway']
# Tweet Scraped2:
# Username:0JMONEY1
# Description:let trend the digital currency
# Location:
#  Following Count:112
# Follower Count:28
# Total Tweets:811
# Retweet Count:0
# Tweet Text: @binance $PRGD on the Polygon Network
#
# @Prosperity_Gold
# https://t.co/IcwROt1BAv
#
# @NFTMotorsCo
# https://t.co/mx0mwtpI1V
#
# https://t.co/Jjj6GCJNJP
#
# #Crypto #polygon #matic #nft #cryptocurrency #btc  #eth #bsc #bnb #altcoins #CryptoNews #NFTs #100x #1000x #Binance https://t.co/IjFHc0C7IF
# Hashtags Used:['Crypto', 'polygon', 'matic', 'nft', 'cryptocurrency', 'btc', 'eth', 'bsc', 'bnb', 'altcoins', 'CryptoNews', 'NFTs', '100x', '1000x', 'Binance']
# Tweet Scraped3:
# Username:kingcrypto1337
# Description:#NFTCommunity #HBAR
# Location:
#  Following Count:1612
# Follower Count:1343
# Total Tweets:9619
# Retweet Count:0
# Tweet Text: @ZuseMarket @happy_hash_frog @Duggie14940281 @DrPerezNFT @dave123william1 @DochartaighLeon @MT107068073421 @hbar1000 @HbarRich @HBARRise @not_at_work @HederaViking
# @Sasan_Hedera
# @hederadev @Jajamoney4
# @SPINFX69 @JoeHighTimesNFT  @Appex_preditor
# #Hedera #HBAR #btc #SOL #ETH #AVAX #crypto #NFT  #NFTGiveaway
# Hashtags Used:['Hedera', 'HBAR', 'btc', 'SOL', 'ETH', 'AVAX', 'crypto', 'NFT', 'NFTGiveaway']
# Tweet Scraped4:
# Username:utkusrk
# Description:#jasonfam
# Hesaplar kapanmasın lütfen!
# Location:Eskişehir, Türkiye
#  Following Count:593
# Follower Count:117
# Total Tweets:6345
# Retweet Count:38
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped5:
# Username:gvardeborn
# Description:NFTs changed my whole life❤️. Earned over $200k💸+ from flipping NFTs. Now I'm helping projects grow.
# Location:Cyprus
#  Following Count:121
# Follower Count:6
# Total Tweets:203
# Retweet Count:77
# Tweet Text: Free #NFT giveaway 👑 24 hours ⏰
#
# Drop your $ETH &amp; #Solana address ⬇️
#
# 🌀 Like + Follow me + Retweet 🌀
#
# #NFTGiveaway #NFTCommunity #NFTdrop #Giveaways #NFTs #NFTGiveaways #ETH #EthereumNFTs #ETHNFTs https://t.co/Sf4kRvZyZW
# Hashtags Used:['NFT', 'Solana', 'NFTGiveaway']
# Tweet Scraped6:
# Username:HapaKid_eth
# Description:The nicest a$$hole you’ll ever meet 😂 Executive Team @MutantApeWife   https://t.co/oIvPSsMnUV    Marketing @JunglebayAC https://t.co/1Acsjorwh4
# Location:Hawai`i
#  Following Count:1336
# Follower Count:1015
# Total Tweets:3361
# Retweet Count:18
# Tweet Text: 🎉Want to win a BAPC V2 NFT, Cash backs/free mints and WL Spots? 🎉
#
# -Follow @BoredApePixelCl @TimepieceApes2  @Mutantapewife
# -Like and Retweet
# -Tag 3 friend
# -Set a reminder for this space
# https://t.co/plkHEikknE
#
# #NFTGiveaways #NFts #NFTCommunity #ETH
# Hashtags Used:[]
# Tweet Scraped7:
# Username:Edaheof
# Description:Tek iyilik bilgi  Tek kötülük  cehalettir .                              sokrates___
# Location:
#  Following Count:356
# Follower Count:87
# Total Tweets:5413
# Retweet Count:224
# Tweet Text: 📣2 SAATLİK KISA ÇEKİLİŞ 📣
#
# 🎖250 TL🎖
#
# ⚔️Şartlar⚔️
#
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣@ZigguratDao‘ nun sabit tweetine RT + Like at.🏆Bonus: Şartları yerine getirenler 100 TL daha kazanacak.
#
# #btc #giveaway #eth #luna #binance #nfts #avax #elon #dolar #shib #ape #Metaverse #web3 #bnb #sol
# Hashtags Used:[]
# Tweet Scraped8:
# Username:Hinah777
# Description:Law student 🔴University of London🇦🇺
# #crptoarmy. #intradaytrading#stockexchange👀
# You can't make good deal with bad people.
# Location:
#  Following Count:54
# Follower Count:77
# Total Tweets:7221
# Retweet Count:96
# Tweet Text: @cz_binance @Crypto__Diva #BTC , #ETH, #BNB &amp; #VOLT sounds like a more reasonable list what do you think? 🤔
#
# 3 blue chips + 1 volted small cap ⚡️
# Hashtags Used:['BTC', 'ETH', 'BNB', 'VOLT']
# Tweet Scraped9:
# Username:CcMyfeelings
# Description:I'm just some guy loving honesty, humility, honor
# and above all: the beautiful castle Dracula! Follow the evidence! Wherever it leads!
# Location:
#  Following Count:101
# Follower Count:162
# Total Tweets:3446
# Retweet Count:0
# Tweet Text: If you do not have an analyzing brain, #Ethereum and anything #Eth like sounds just great.
#
# But looking under the hood shows us the horrors beyond human comprehension. On all levels.
#
# Buy ONLY #Bitcoin https://t.co/wNGuKOaTgX
# Hashtags Used:['Ethereum', 'Eth', 'Bitcoin']
# Tweet Scraped10:
# Username:oxFairtale4
# Description:Bir kez kaybettim sonrakileri umursamadım. 🕊️🍀
# Location:England, United Kingdom
#  Following Count:345
# Follower Count:71
# Total Tweets:3161
# Retweet Count:38
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped11:
# Username:Waffles_C
# Description:Crypto enthusiast
# Location:40 Bartlett Street, GC61 C50
#  Following Count:1904
# Follower Count:236
# Total Tweets:1370
# Retweet Count:7
# Tweet Text: Plump Penguins have arrived on Cardano 🐧
#
# Inspired by @pudgypenguins, our penguins are ready to spread cool vibes across Cardano 💙
#
# You are early, any interaction with this tweet will be considered for an OG 🔔
#
# #Cardano #CNFT #CNFTCommunity #ETH #Ethereum #EthereumNFTs #NFT https://t.co/8QQ5x8uSnt
# Hashtags Used:[]
# Tweet Scraped12:
# Username:dilekavax5
# Description:Stockbroker - Designer👾 - Techno lover
# Location:İstanbul, Türkiye
#  Following Count:632
# Follower Count:1251
# Total Tweets:923
# Retweet Count:70
# Tweet Text: ✨GIVEAWAY✨
#
# 🏅5x Crafters City WL
#
# 🎯Follow:@craftersonline and @dilekavax5
#
# 🎯RT/FAV this tweet
#
# 🎯Tag 2 friends
#
# #NFTdrop #ETH #GiveawayAlert #Solana #NFTCommunity #NFTGiveaways #Giveaway #Avalanche https://t.co/UwWuNsOY5q
# Hashtags Used:['NFTdrop']
# Tweet Scraped13:
# Username:gvardeborn
# Description:NFTs changed my whole life❤️. Earned over $200k💸+ from flipping NFTs. Now I'm helping projects grow.
# Location:Cyprus
#  Following Count:121
# Follower Count:6
# Total Tweets:203
# Retweet Count:15
# Tweet Text: 🍀🍀 #NFTGiveaways 🍀🍀
#
# Follow me,like, retweet
#
# 🚨 Ends 500 retweet
#
# Drop #eth adress
#
# #NFTCommunity #NFTGiveaways #nftgirl #NFTCommunity #nftcollector #nftarti̇sts https://t.co/yL0nMc6Zds
# Hashtags Used:['NFTGiveaways', 'eth', 'NFTCommunity', 'NFTGiveaways', 'nftgirl']
# Tweet Scraped14:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:1
# Follower Count:113
# Total Tweets:51014
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1568.29 USD
# #Bitcoin 0.07910002032615664 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped15:
# Username:NickRoot02
# Description:
# Location:
#  Following Count:196
# Follower Count:123
# Total Tweets:12081
# Retweet Count:96
# Tweet Text: @cz_binance @Crypto__Diva #BTC , #ETH, #BNB &amp; #VOLT sounds like a more reasonable list what do you think? 🤔
#
# 3 blue chips + 1 volted small cap ⚡️
# Hashtags Used:['BTC', 'ETH', 'BNB', 'VOLT']
# Tweet Scraped16:
# Username:busraslvrc
# Description:
# Location:
#  Following Count:4909
# Follower Count:577
# Total Tweets:48548
# Retweet Count:38
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped17:
# Username:samyar73741
# Description:♡feg♡
# Location:
#  Following Count:243
# Follower Count:71
# Total Tweets:3915
# Retweet Count:30
# Tweet Text: #in_FEG_we_trust 🦍❤️💪
#
# =====================
# #feg $feg #Crypto
# #BTC #BNB #ETH #NFTs
# =====================
# @FEGtoken @lifeisdefi @RTRcrypto @dewbo1 @GingerMammoth1 @Ste_Cha_FEG @FEGchris https://t.co/luh2SCktCi
# Hashtags Used:['in_FEG_we_trust', 'feg', 'Crypto', 'BTC', 'BNB', 'ETH', 'NFTs']
# Tweet Scraped18:
# Username:Lordmooner
# Description:
# Location:Lagos, Nigeria
#  Following Count:17
# Follower Count:12
# Total Tweets:703
# Retweet Count:1
# Tweet Text: Can’t stop talking about $NA @ItsNotArt_eth to everybody I know ☎️☎️☎️this project is going to succeed remember my words #NFTs #ETH #Cryptos #x1000GEM #utilities #NFT #nftart #x1000Gems #Metaverse #merge https://t.co/zaxJKJQ5fy
# Hashtags Used:[]
# Tweet Scraped19:
# Username:ZClubNFT
# Description:Z Club NFT Pass is a private group of 150 NFT: passes & access to an exclusive club of Whales. With proven track record by @Mrandersonnfter
# Location:
#  Following Count:0
# Follower Count:4874
# Total Tweets:49
# Retweet Count:0
# Tweet Text: First 2000 people to retweet gets free #ETH or #BTC    (yes, for real) 👀
#
# #NFTdrop #NFT #NFTs #NFTCommunity #NFTart #NFTCollection https://t.co/GeMMi2gnsy
# Hashtags Used:['ETH', 'BTC', 'NFTdrop', 'NFT', 'NFTs', 'NFTCommunity', 'NFTart', 'NFTCollection']
# Tweet Scraped20:
# Username:Cryptob11946400
# Description:Jpegs || Web 3 enthusiast || alpha on every retweet || NFA
# Location:
#  Following Count:868
# Follower Count:750
# Total Tweets:3396
# Retweet Count:62
# Tweet Text: 💥#Giveaway 💥
#  50 $USDT to 1 random person ‼️
#
# 🔹Follow @avaxworld &amp; @machine_promo
# 🔹Rt &amp; Like &amp; Tag some friends
#
# ⏳72 Hours. Good Luck!🍀
# #ETH #BTC #NFTs #NFT #NFTCommunity #cryptocurrency #BNB
# Hashtags Used:['Giveaway']
# Tweet Scraped21:
# Username:beyza_crypto
# Description:#BITCOIN ANALİZLERİMİ SİZLER İÇİN PAYLAŞIYORUM. TAKİP EDİN. RETWEET YAPIN DAHA FAZLA KİŞİYE ULAŞALIM. KİMSE ZARAR ETMESİN.
# Location:
#  Following Count:30
# Follower Count:17
# Total Tweets:77
# Retweet Count:0
# Tweet Text: HANGİSİNİ TUTUYORSUN?
#
# #BNB
# #ETH 🔷
# #KASTA 💎
# #BTC
# $MATIC 🌀
# #SHIB 🐶
# #DOGE 🐕
# #VOLT⚡️
# #LUFFY 🧡
# #NFTBOOKS📘
# #KIBA🐱
# #XTZ
# #QUACK🐥
# #MATIC🥏
# #SAND ⌛️
# #SOL 👽
# $LUNC 🌔
# #DROVERINU 💙
# #PLUGPRO🤘🏿
# Hashtags Used:['BNB', 'ETH', 'KASTA', 'BTC', 'SHIB', 'DOGE', 'VOLT', 'LUFFY', 'NFTBOOKS', 'KIBA', 'XTZ', 'QUACK', 'MATIC', 'SAND', 'SOL', 'DROVERINU', 'PLUGPRO']
# Tweet Scraped22:
# Username:blockchain_land
# Description:https://t.co/bAbQp67fZR 🤖
# #BTC #ETH
# @talentrepublic_
# https://t.co/DWjk2LYi1B
# 📟 https://t.co/BlYhdVAW4O
# 📧 Jose.rodriguez@talent-network.org
# Location:
#  Following Count:1600
# Follower Count:2863
# Total Tweets:14561
# Retweet Count:3
# Tweet Text: Steve Wozniak se une a Blockchain Land Nuevo León 2022 - Mira la noticia completa: https://t.co/42F4Bdxt6d
#
# Síguenos para no perderte las mejores noticias
# #Bitcoin #criptomonedas #cripto #altcoins #btc #ETH #noticrip #Blockchain https://t.co/feKB3k1HqY
# Hashtags Used:[]
# Tweet Scraped23:
# Username:samyar73741
# Description:♡feg♡
# Location:
#  Following Count:243
# Follower Count:71
# Total Tweets:3915
# Retweet Count:14
# Tweet Text: We are ready for Youtube. @FEGtoken will be joining me LIVE from the BLUE Sofa! Time &amp; Date still in the works! #FEG #ETH #BTC - we here and ready to make the world a better place! Find us on Youtube!
#
# https://t.co/Ply7cNT0Km https://t.co/jwPkjVQEs0
# Hashtags Used:['FEG']
# Tweet Scraped24:
# Username:dutacro1
# Description:Lescro
# Location:Los Angeles, CA
#  Following Count:1131
# Follower Count:264
# Total Tweets:3199
# Retweet Count:339
# Tweet Text: 🎉ETH GIVEAWAY🎉
#
# Prizes:
# 🏆0,1 ETH to 1 lucky winner
#
# 1️⃣ Like and Retweet
# 2️⃣ Follow @DegenMintPassn @MagntNFT
# @TattooedEGGs @AVAX_SOLNFT
# 3️⃣ Tag 3 Friends
#
# ⏰48h GL🍀
#
# #ETH #Ethereum #giveaway #NFT #NFTS  #NFTGiveaway #NFTCommunity #Crypto #NFTProject  #Whitelist
# Hashtags Used:[]
# Tweet Scraped25:
# Username:AbsCaream
# Description:Success is a journey and not a destination. Taking over the world with opportunities
# Location:
#  Following Count:641
# Follower Count:89
# Total Tweets:2598
# Retweet Count:0
# Tweet Text: @lords_of_cro
# @NazariPennie
# This project called @cookiesaleio has just been confirmed to be backed by a very strong community and Co-founder
#
# #BSC #ETH #BNB #COOKIETOKEN #Cookiesale https://t.co/hZIwH1nflj
# Hashtags Used:['BSC', 'ETH', 'BNB', 'COOKIETOKEN', 'Cookiesale']
# Tweet Scraped26:
# Username:Colrow26C
# Description:Beatles Bowie Weller Costello Smiths Roxy Music Manchester United and the North Wests Northern Soul specialists @beatinrhythm
# Location:Manchester
#  Following Count:765
# Follower Count:573
# Total Tweets:13420
# Retweet Count:7
# Tweet Text: #ETH https://t.co/mecdYdRUoO
# Hashtags Used:['ETH']
# Tweet Scraped27:
# Username:OUTTA_FOCUS
# Description:Tall, Dark, and Handsome.  Political Science guy. A Fitness enthusiast, political whacko, and counterculture Demi-God.  A 6'3 lame #CRYPTO nerd. 🧠 4 Self.
# Location:BROOKLYN NY 2 wherever I roam.
#  Following Count:2833
# Follower Count:14898
# Total Tweets:55249
# Retweet Count:0
# Tweet Text: 🤔 about it, #TheMerge of #Ethereum could be as early as this Friday.  #EthereumMerge #ETH 🦇🔊🐼
#
# 🤯🤯🤯🤯🤯
# Hashtags Used:['TheMerge', 'Ethereum', 'EthereumMerge', 'ETH']
# Tweet Scraped28:
# Username:kmatsuda_77
# Description:#RunBlox #Sleepagotchi friend
# Location:
#  Following Count:202
# Follower Count:37
# Total Tweets:378
# Retweet Count:153
# Tweet Text: 🏧S O P H O N x ATM Giveaway🏧
#
# #ETH chain free mint NFT
#
# 🎁FREE MINT X 5 SPOT
#
# 1️⃣ Follow
# @TheForeverWar, @Bounty_ATM
# 2️⃣ Tag 3 Friends
# 3️⃣ Like &amp; RT
# 4️⃣ Submit form : https://t.co/1V6VMaAGbN
#
# ⏰~9/9
#
# #sophon #NFTs #NFTGiveaway #airdrop #airdrpatm https://t.co/M402MTeY45
# Hashtags Used:['ETH']
# Tweet Scraped29:
# Username:SimpsonsBeer
# Description:#crypto
# Location:
#  Following Count:2216
# Follower Count:88
# Total Tweets:8460
# Retweet Count:38
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped30:
# Username:JustinKerwood
# Description:
# Location:
#  Following Count:70
# Follower Count:23
# Total Tweets:581
# Retweet Count:42
# Tweet Text: Have you noticed that the #XRPCommunity doesn’t spread FUD or need to bad mouth other coins / Tokens?! Most #BTC and #ETH maxis do this daily because they fear $XRP and you only spread fake news or try to damage others when you are scared / worried! We know what we hold! #XRPARMY
# Hashtags Used:['XRPCommunity', 'BTC', 'ETH']
# Tweet Scraped31:
# Username:spumezeyno
# Description:🍀🍀🍀
# Gerçeği, insanların ölçüsü ile değil; insanları gerçeğin ölçüsü ile tanı.
# Location:
#  Following Count:1023
# Follower Count:98
# Total Tweets:6031
# Retweet Count:133
# Tweet Text: 🎁ÇEKİLİŞ🎁
#
# 🏆1 KİŞİYE 20$ (360 TL)💸  HEDİYE🎗
#
# Yapmanız gerekenler👇
#
# 1⃣ @uzmankriptoo sabit twitine RT, FAV❤
#
# Ve youtube videosuna like,YORUM Yapın👇
#
# https://t.co/pEf9sAmlpp
#
# Bu twite RT, FAV❤ATIN
#
# SÜRE:48H
#
# #btc    #bitcoin    #NFTGiveaway #ETH #shiba #Solana #sol
# Hashtags Used:[]
# Tweet Scraped32:
# Username:cred_alert
# Description:#DeFi Liquidation and credit monitoring powered by @cred_protocol.
# Location:Ethereum
#  Following Count:1
# Follower Count:39
# Total Tweets:4707
# Retweet Count:0
# Tweet Text: ⚠️ LIQUIDATION APPROACHING ⚠️
#
# $92,045 position at risk on #aave
#
# Wallet: 0x032c3192242aa00f681c2e76f141cb106b875574
#
# Health factor: 1.03
#
# View transactions 👇
# https://t.co/Lx53L9t2uV
#
# #credprotocol #defi #liquidation #eth
# Hashtags Used:['aave', 'credprotocol', 'defi', 'liquidation', 'eth']
# Tweet Scraped33:
# Username:0xOmni_
# Description:⭕️@Inn3r_Circle⭕️ FEW💫PG🦖SW🐺GAS🥃 MIRATASHI⚡️OpSin 🖤DSPC🍕EZU 🪷MORTIVERSE 👻YYG☯️3VOLV3️⃣MONSTERLAND💀NAYUTA🏙️CF⚔️ Vandal 🌆Jikan🐵 Discord: omni#888
# Location:
#  Following Count:3299
# Follower Count:1522
# Total Tweets:10957
# Retweet Count:138
# Tweet Text: ✨ WL GIVEAWAY  ✨
#
# 🌏 TheUndrWrld ✖️ Shojira 😈
#
# To celebrate:
#
# Win🏆3 x WL for Shojira 😈!
#
# To Win:
# 1⃣Follow @TheUndrWrldNFT @ncwvanq @shojira @undrwrldgifts🔔
# 2⃣❤️+♻️
# 3⃣Tag friends
#
# ⏰24 hours🍀Good luck🍀
#
# #WLGiveaway #NFTCommunity  #Whitelist #NFT  #ETH #NFTs #web3 #freemint https://t.co/tJusxI5Gxx
# Hashtags Used:[]
# Tweet Scraped34:
# Username:Mustafaoglu
# Description:Erik
# Location:
#  Following Count:785
# Follower Count:175
# Total Tweets:1997
# Retweet Count:38
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped35:
# Username:Jexlent_Ro
# Description:
# Location:United States
#  Following Count:733
# Follower Count:141
# Total Tweets:1500
# Retweet Count:339
# Tweet Text: 🎉ETH GIVEAWAY🎉
#
# Prizes:
# 🏆0,1 ETH to 1 lucky winner
#
# 1️⃣ Like and Retweet
# 2️⃣ Follow @DegenMintPassn @MagntNFT
# @TattooedEGGs @AVAX_SOLNFT
# 3️⃣ Tag 3 Friends
#
# ⏰48h GL🍀
#
# #ETH #Ethereum #giveaway #NFT #NFTS  #NFTGiveaway #NFTCommunity #Crypto #NFTProject  #Whitelist
# Hashtags Used:[]
# Tweet Scraped36:
# Username:_MetaModelsNFT
# Description:NFT that promotes women inclusivity in the Web3 and Blockchain industry.✨AscensionProtocol✨ co-founder @thecynthiatran 💕https://t.co/PGja07W6bu
# Location:
#  Following Count:570
# Follower Count:9754
# Total Tweets:139
# Retweet Count:16
# Tweet Text: Everyone go listen to the recap from our spaces tonight! About 500 attended and it was amazing. Nothing more important than your mental health 💜 Give it a listen and a share, you never knows whose life you are going to change/save! #MentalHealth #NFTCommunity #ETH #WomeninWeb3 https://t.co/4dm37zbxnA
# Hashtags Used:[]
# Tweet Scraped37:
# Username:OwlsActivated
# Description:#AP8testi #VRpaid
# Location:
#  Following Count:1213
# Follower Count:45
# Total Tweets:4189
# Retweet Count:3393
# #NFTGiveaways  #NFT #NFTCommunity #NFTs #Giveaway #ETH #SOL https://t.co/YE0hokeB7rEgiKQ18
# Hashtags Used:[]
# Tweet Scraped38:
# Username:DankFroglet
# Description:Pepe is life.
#
# Coder and Bitcoin enthusiast.
# Location:
#  Following Count:367
# Follower Count:384
# Total Tweets:232
# Retweet Count:24
# Tweet Text: Over 10% minted in only a few days!
#
# Who will you pull?
#
# Mint : https://t.co/94AfMJeo6N or https://t.co/rlzO8A2BbR
#
# Contract: https://t.co/cSkeMud3t6
#
# Reveal after all 420 are minted!
#
# #MintingNow #smolfrenz #eth https://t.co/57j2k0Chf1
# Hashtags Used:[]
# Tweet Scraped39:
# Username:cnftcheka
# Description:#Cardano #CNFT #LFG 🚀🚀🚀
# Location:
#  Following Count:1719
# Follower Count:174
# Total Tweets:8593
# Retweet Count:97
# Tweet Text: 🎉 RAISON D'ETRE GIVEAWAY🚀
#
# 🏆 1 x RAISON GENESIS 🔥🔥
#
# 1️⃣ - ❤️ &amp; RT
# 2️⃣ - Follow @Cains1999 &amp; @MrWen28
# 3️⃣ - Tag 3 friends
#
# ⏳72 H⏳
#  #CNFTGIVEAWAY #CNFTCommunity #CNFTProject #CNFT #NFT #NFTs #ada #cardano #sol #eth #CNFTGiveaways #NFTGiveaway #NFTCommunity https://t.co/mV4varrcCc
# Hashtags Used:[]
# Tweet Scraped40:
# Username:zeyneppturk2000
# Description:metaverse
# Location:Ankara, Türkiye
#  Following Count:797
# Follower Count:77
# Total Tweets:3294
# Retweet Count:38
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped41:
# Username:Ayli_samurai1
# Description:🌐https://t.co/brE4vFdNDj
#
# 💎Crypto Investor |Content Creator|
# 💎WE MARKET Your BLOCKCHAIN PROJECT
# $RBXS TWITTER SHILLER
# 💎Follow @RBXSamurai
#  💎#RBXSamur
# Location:
#  Following Count:232
# Follower Count:491
# Total Tweets:38268
# Retweet Count:10
# Tweet Text: MAGICAL MUTTS IS A COLLECTION OF 2,777 NFTS minting on the ETH blockchain.
# ⬇️⬇️
# #DUMBLE
#  #Dumbledao
# 🧊
#   @DumbleDAO
# 🧊
#  #Crypto #RBXSTOKEN #RBXS #RBXSamurai #BSC #eth https://t.co/9LQWlIx5l1
# Hashtags Used:['DUMBLE', 'Dumbledao']
# Tweet Scraped42:
# Username:luckyluanriego_
# Description:#INJANGiya
# Location:
#  Following Count:4626
# Follower Count:559
# Total Tweets:45524
# Retweet Count:1574
# Tweet Text: 10$ GIVEAWAY | 4 HRS ☀️
#
# RT + Follow @DeGodsNFTS
#
# #NFTs #nft #NFTGiveaway #Giveaway #NFTCommunity #freemint #ethereum #btc #eth #crypto #cryptocurrency https://t.co/AhhBRE89Xp
# Hashtags Used:['NFTs', 'nft', 'NFTGiveaway', 'Giveaway', 'NFTCommunity', 'freemint', 'ethereum']
# Tweet Scraped43:
# Username:SimpsonsBeer
# Description:#crypto
# Location:
#  Following Count:2216
# Follower Count:88
# Total Tweets:8460
# Retweet Count:135
# Tweet Text: 1 kişiden İBAN/TRC20 isteyeceğim. 🍀
#
# Bu gönderiyi beğenmeniz ve beni takip etmeniz yeterli.
#
# #BTC #ETH
# Hashtags Used:['BTC', 'ETH']
# Tweet Scraped44:
# Username:Daniel22064722
# Description:#HZM Coin The first #cryptocurrency in the Arab world HZM Coin will redraw the financial picture in the Arab world🐪🔝#Bitcoin #Etherum #metaverse #NFT #Web3
# Location:
#  Following Count:131
# Follower Count:52
# Total Tweets:148
# Retweet Count:0
# Tweet Text: #hzmcoin
# #Buy_HZM_COIN #Crypto
# #cryptotrading #Metaverse  #Bitcoin  #future #ETH  #100xgem @malarab1 https://t.co/qMmy6SlNiL
# Hashtags Used:['hzmcoin', 'Buy_HZM_COIN', 'Crypto', 'cryptotrading', 'Metaverse', 'Bitcoin', 'future', 'ETH', '100xgem']
# Tweet Scraped45:
# Username:Jerrry_samurai
# Description:💎Crypto Lover💎
# 💎$RBXS Twitter Shiller💎
# 💎We market your blockchain projects💎
# 💎Follow @RBXSamurai #RBXSamurai💎
# Location:
#  Following Count:678
# Follower Count:648
# Total Tweets:12023
# Retweet Count:0
# Tweet Text: Your decision today will determine what situation will be like in the next few years.
#
# #RBXS
# #DumbleDAO
# #DumbledDAO
# @DumbleDAO
#
# https://t.co/SVv6tVlAAJ
#
# #lunar #NFTcommunity #Nfts  #CryptoNews #BSCGems #BSCGem  #100xGems #Eth #BSC #trading https://t.co/oVN2kT3mvS
# Hashtags Used:['RBXS', 'DumbleDAO', 'DumbledDAO', 'lunar', 'NFTcommunity', 'Nfts', 'CryptoNews', 'BSCGems', 'BSCGem', '100xGems', 'Eth', 'BSC', 'trading']
# Tweet Scraped46:
# Username:AyatAyatalsaed7
# Description:Learn to fight alone
# Location:جدة, المملكة العربية السعودية
#  Following Count:287
# Follower Count:25
# Total Tweets:90
# Retweet Count:165
# Tweet Text: 🎁Hey, 50 $ETH will sent to your Wallet to 1000 Participants 🎁
#
# A person who retweets, follows me and retweets will receive 50 #ETH ( $80,000 ) (yes, for real)
#
# +retweet pinned
# Drop your wallet address https://t.co/HkfEvwluxU
# Hashtags Used:[]
# Tweet Scraped47:
# Username:Allen01230
# Description:NFT COLLECTOR & HOLDER. BIg Brain Trees🥦of @fellablooms.one of the founder of @dauliartnft .Advisor of @handymetagirls
# $Near my grassroots ❤️😍
# Location:Nigeria
#  Following Count:780
# Follower Count:171
# Total Tweets:468
# Retweet Count:643
# Tweet Text: 🔥 Sending 2 x $250 in #BNB    to 2 random people who:
#
# ✅ Like &amp; RT
# ✅ Follow me - @cryptoamazo @altcryptomars
#
# Choosing the winners in 2 days with Twitterpicker!
#
# #BTC    #Giveaway #ETH #Crypto
# Hashtags Used:['BNB']
# Tweet Scraped48:
# Username:SquWave
# Description:"Don’t promise when you are happy, don’t reply when you are angry, and don’t decide when you are sad." | Heraclitus
#
# $FLSH 🥩
# Location:Türkiye
#  Following Count:70
# Follower Count:31
# Total Tweets:415
# Retweet Count:38
# Tweet Text: 🎁5 Kişiye Toplam 1000 TL Çekilişi🎁
#
# ⚡️Şartlar⚡️
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣ Takip et: @macrofriends @Gem_Ustasi
#
#  ⌛48H
#
# #btc #binance #eth #sol #avax  #ship #doge #elon #busd #dolar #ava #giveaway #NFTs #NFTCommunity #NFTdrop #imx #ape #NFTGiveaway #usdt #bnb #dego #nmr #dust #faiz #srm https://t.co/uoXqPYHMni
# Hashtags Used:['btc']
# Tweet Scraped49:
# Username:femikadiri_
# Description:Not the regular femi //@fullstopnft
# Location:Unilag
#  Following Count:952
# Follower Count:404
# Total Tweets:3963
# Retweet Count:44
# Tweet Text: 🎁GIVEAWAY🎁
#
# 🏷3 WL OF @CoziesOfficial
# 🏷3WL OF @davrosnfts
# 🏷3 WL OF @CryptopopC
# 🏷3 WL OF @TheSplitVerse
#
# 🔑TO ENTER
# 1️⃣FOLLOW ALL AND ON NOTIF🚦🛎
# 2️⃣❤️ &amp; RT THIS TWEET
# 3️⃣TAG 3 FRENS
# #FREEMINT #ETH #GiveawayNFT
# ⏰WINNERS IN FEW HRS https://t.co/sgLt0DDJJX
# Hashtags Used:[]
# Tweet Scraped50:
# Username:L_l_0_N
# Description:DAILY GIVEAWAYS 📌 | @OasisProtocol Ambassador🏖️🌹| @alienfrens holder🖖🏽💚 | PROMO 📥 |
# Location:Matrix
#  Following Count:3756
# Follower Count:4039
# Total Tweets:10823
# Retweet Count:1
# Tweet Text: 🎉 @PeaceEagleNFT FREE MINT GIVEAWAY 🎉
#
# x5 FREE MINTS SPOTS 🦅
#
# 1⃣ Follow @L_l_0_N &amp; @PeaceEagleNFT 💯
# 2⃣ Like and RT ❤️🔁
# 3⃣ Tag 3 friends! 🫂
#
# ⌛Winner announce in 24h⌛
#
# #NFTdrops #NFTGiveaways #NFTs
# #ETH #NFTCommunity #NFTGiveaway
# #ETHNFTs #Giveaway #FREE #freeNFT #Ethereum https://t.co/PrRrsvZxyn
# Hashtags Used:[]
# Tweet Scraped51:
# Username:PenguinsCNFT
# Description:A teaser account for the official plump penguins coming to cardano
# Location:
#  Following Count:794
# Follower Count:637
# Total Tweets:89
# Retweet Count:7
# Tweet Text: Plump Penguins have arrived on Cardano 🐧
#
# Inspired by @pudgypenguins, our penguins are ready to spread cool vibes across Cardano 💙
#
# You are early, any interaction with this tweet will be considered for an OG 🔔
#
# #Cardano #CNFT #CNFTCommunity #ETH #Ethereum #EthereumNFTs #NFT https://t.co/8QQ5x8uSnt
# Hashtags Used:[]
# Tweet Scraped52:
# Username:AliAli44809797
# Description:Bitcoin #etherıum #astarnetwor @MusesNFT #xrp
# Location:
#  Following Count:77
# Follower Count:80
# Total Tweets:12122
# Retweet Count:5
# Tweet Text: #Btc saat 00:00 itibari ile işleme ara verse, pazartesi sabah saat 09:00'da tekrar işleme başlasa da, insanlar 1 gün bari rahat uyusa
#
# Değil mi?
# #Bitcoin #Eth #altcoin #Crypto
# Hashtags Used:['Btc']
# Tweet Scraped53:
# Username:BrendaL85283334
# Description:
# Location:
#  Following Count:7
# Follower Count:0
# Total Tweets:266
# Retweet Count:1471
# Tweet Text: We currently have more than 1 million #ETH. If #Ethereum hard fork succeeds, we will donate some  forked #ETHW to #ETHW community and developers to build #ethereum ecosystem. https://t.co/ee4kGSuVoK
# Hashtags Used:['ETH', 'Ethereum', 'ETHW', 'ETHW']
# Tweet Scraped54:
# Username:elobwana
# Description:
# Location:
#  Following Count:3075
# Follower Count:1781
# Total Tweets:3362
# Retweet Count:0
# Tweet Text: Top Five Metaverse Coin To Trade in September 2022
#
# https://t.co/ykk5Tfkq23
#
# #crypto #blockchain #dAPPs #smartcontracts #bitcoin #ETH #BNB #Stablecoins #DeFi #XRP #XDC #XLM #ADA #DAO #investing #staking #mining #ALGO #SHIB #NFTs #Metaverse
# Hashtags Used:['crypto', 'blockchain', 'dAPPs', 'smartcontracts', 'bitcoin', 'ETH', 'BNB', 'Stablecoins', 'DeFi', 'XRP', 'XDC', 'XLM', 'ADA', 'DAO', 'investing', 'staking', 'mining', 'ALGO', 'SHIB', 'NFTs', 'Metaverse']
# Tweet Scraped55:
# Username:L_l_0_N
# Description:DAILY GIVEAWAYS 📌 | @OasisProtocol Ambassador🏖️🌹| @alienfrens holder🖖🏽💚 | PROMO 📥 |
# Location:Matrix
#  Following Count:3756
# Follower Count:4039
# Total Tweets:10823
# Retweet Count:1
# Tweet Text: 🎉 @PeaceEagleNFT FREE MINT GIVEAWAY 🎉
#
# x5 FREE MINTS SPOTS 🦅
#
# 1⃣ Follow @L_l_0_N &amp; @PeaceEagleNFT 💯
# 2⃣ Like and RT ❤️🔁
# 3⃣ Tag 3 friends! 🫂
#
# ⌛Winner announce in 24h⌛
#
# #NFTdrops #NFTGiveaways #NFTs
# #ETH #NFTCommunity #NFTGiveaway
# #ETHNFTs #Giveaway #FREE #freeNFT #Ethereum https://t.co/PrRrsvZxyn
# Hashtags Used:['NFTdrops', 'NFTGiveaways', 'NFTs', 'ETH', 'NFTCommunity', 'NFTGiveaway', 'ETHNFTs', 'Giveaway', 'FREE', 'freeNFT', 'Ethereum']
# Tweet Scraped56:
# Username:Lord_Defi22
# Description:#Defi lover, crypto hodler.
# Location:
#  Following Count:5
# Follower Count:106
# Total Tweets:37231
# Retweet Count:0
# Tweet Text: updated price for $EOS, $AVAX, $SOL:
#
# #EOS $1.491 USD
# #AVAX 0.0009569 #BTC
# #SOL 0.02024 #ETH
#
# I tweet updated prices, follow me to get recent updates.
#
# #cryptocurrency #crypto
# Hashtags Used:['EOS', 'AVAX', 'BTC', 'SOL', 'ETH', 'cryptocurrency', 'crypto']
# Tweet Scraped57:
# Username:Septemberw1n09
# Description:#bull_bnb  #LuxyLaunch
# #ganti hp ssnya jadi beda
# Location:
#  Following Count:3105
# Follower Count:77
# Total Tweets:25342
# Retweet Count:349
# Tweet Text: 🚨Mutant Neighbors Alert🚨
# ❤️LIKE &amp; RT
# FOLLOW: @MutantNeighbors
# SHARE THIS VID AND PICK YOUR SIDE IN THIS P2E UPCOMING GAME. GET IN EARLY AND JOIN THE DISCORD-https://t.co/GcAzM2yzgP #ETH #NFT #P2E #LFG #Etherum #NFTCommunity https://t.co/J7NlVjtZGY
# Hashtags Used:[]
# Tweet Scraped58:
# Username:Ayli_samurai1
# Description:🌐https://t.co/brE4vFdNDj
#
# 💎Crypto Investor |Content Creator|
# 💎WE MARKET Your BLOCKCHAIN PROJECT
# $RBXS TWITTER SHILLER
# 💎Follow @RBXSamurai
#  💎#RBXSamur
# Location:
#  Following Count:232
# Follower Count:491
# Total Tweets:38268
# Retweet Count:23
# Tweet Text: First of its kind NFT collection!
#
# #Dumbledao #Dumble $DUMBLE
#
#  https://t.co/QCTrqC3fk0
#  https://t.co/AyyNNehYI2
#
# $RBXS #Crypto #lunar #Nfts #RBXS #RBXSamurai #BSCGem #100xGems #Eth #BSC  #DeFi https://t.co/DulQleER1h
# Hashtags Used:['Dumbledao', 'Dumble']
# Tweet Scraped59:
# Username:letecho_com
# Description:投資者向けニュース配信サービス
# 情報の価値を拡大し続ける。
# もっとも正確な情報を、もっとも楽しい形で投資者へ届ける。様々なSNS機能で情報収集がより楽しくなる。投資者向けのプラットフォームである。上場企業のIR、決算、適時開示、掲示板・仮想通貨の市場状況を速報。
# Location:Japan
#  Following Count:14
# Follower Count:116
# Total Tweets:130536
# Retweet Count:0
# Tweet Text: #eth #Ethereum [2022/09/05 03:06:38]
# 値段：219,966¥
# 時価総額：26,493,869,945,680¥
# 高値(24h)：220,590¥
# 安値(24h)：216,283¥
# 値段変動率(1h)：-0.03％
# See more: https://t.co/bdLQn9gxiU
# #cyptocurrency #仮想通貨 #ビットコイン
# Hashtags Used:['eth', 'Ethereum', 'cyptocurrency', '仮想通貨', 'ビットコイン']
# Tweet Scraped60:
# Username:LivePriceCrypto
# Description:I Tweet the latest #Bitcoin & #Ethereum price and Daily/Weekly Technical Indicators Data every minute.
#
# Developed the 20/03/2022
# Location:
#  Following Count:4
# Follower Count:3432
# Total Tweets:233397
# Retweet Count:0
# Tweet Text: #Bitcoin Last Price $19833 #BTC 🚀
# Weekly Indicators:
# -RSI: 32.0
# -MA(20): 25819
# -MA(50): 38942
# -MA(200): 23167
# -Bollinger B. lower/upper: 13517/38122
#
# #Ethereum Last Price $1568 #ETH
# -RSI: 41.8
# -MA(20): 1747
# -MA(50): 2775
# -MA(200): 1264
# -BB: 713/2781
#
# #Crypto #Live
# (4/6)
# 233223
# Hashtags Used:['Bitcoin', 'BTC', 'Ethereum', 'ETH', 'Crypto', 'Live']
# Tweet Scraped61:
# Username:genelpatron01
# Description:Yatırımcı, Coin uzmanı, Coinleri çizgilerine uyduran Trader 💪💪
# https://t.co/dPVHd2syeg
#  telegram kanalım: https://t.co/N6tA72aYck
# Location:
#  Following Count:56
# Follower Count:51755
# Total Tweets:10085
# Retweet Count:132
# Tweet Text: 💥💫 Patron'dan hediye 💥💥
#
# 2 kişiye çekiliş ile #TL hediye edeceğim
#
# ✅Şart
#
# 💸Bu twet dahil son 10 twete #RT #Fav yap ve beni takip et😎
#
# (Kontrol ediyorum)
#
# 📌Sonuç: Yarın 23.00
#
# #bitcoin          #eth #metaverse #dxgm #chz  #cekilis #ada #luna #lunc
# Hashtags Used:['TL', 'RT', 'Fav']
# Tweet Scraped62:
# Username:jwlilac
# Description:@guuuuitaeee suspended. Don't reroll me, thanks.
# Location:Bigwin
#  Following Count:1707
# Follower Count:203
# Total Tweets:29955
# Retweet Count:121
# Tweet Text: @MergeApes NFT is your only chance to mint a piece of #crypto history #Merge #PoAP - Proof of Attendance Protocol: We are the first #NFT Collection to mint on a Green #Eth Network and the first to Give 42.0% to public goods funding through @Gitcoin Grants!
#
# #Gitcoin #publicgoods https://t.co/gdLV6QEx2f
# Hashtags Used:['crypto', 'Merge', 'PoAP']
# Tweet Scraped63:
# Username:frCryptoLab
# Description:
# Location:Voltiland
#  Following Count:22
# Follower Count:1
# Total Tweets:105
# Retweet Count:0
# Tweet Text: @cz_binance @Crypto__Diva #BTC #ETH #BNB and #VOLT https://t.co/YMugh0Esm1
# Hashtags Used:['BTC', 'ETH', 'BNB', 'VOLT']
# Tweet Scraped64:
# Username:novelli_capucci
# Description:
# Location:
#  Following Count:56
# Follower Count:2006
# Total Tweets:313
# Retweet Count:1471
# Tweet Text: We currently have more than 1 million #ETH. If #Ethereum hard fork succeeds, we will donate some  forked #ETHW to #ETHW community and developers to build #ethereum ecosystem. https://t.co/ee4kGSuVoK
# Hashtags Used:['ETH', 'Ethereum', 'ETHW', 'ETHW']
# Tweet Scraped65:
# Username:MurrayGill20
# Description:Just a good ol boy...God Bless!  🇺🇲👍
# Location:
#  Following Count:211
# Follower Count:76
# Total Tweets:22
# Retweet Count:3
# Tweet Text: #Dogechain built  to the #dogecoin community!
#
# I can't see🐻‍❄️market because🐕 #Dogechain is on 🔥 and 🐳🐳 are filling their bags with $DC. DC is next $SHIB no doubt.
#
# #Bitcoin       #ETH  $Doge  #NFTs #DeFi #BNB    #BUSD $BUSD $USDT #GameFi #P2E #P2EGame $lunc #LUNAtics https://t.co/sW9q9JDlYU
# Hashtags Used:['Dogechain', 'dogecoin', 'Dogechain']
# Tweet Scraped66:
# Username:graeme_stirling
# Description:
# Location:Edinburgh, UK
#  Following Count:2478
# Follower Count:1700
# Total Tweets:228666
# Retweet Count:366
# Tweet Text: 💰 Dubai is the goal. TatePunks will take us there. 💰
#
# Join our #Giveaway  to win 1.5 #ETH :
# ➡️ Follow us
# ➡️ Tag 3 friends
# ➡️ Like and RT this tweet
#
# #NFTs #NFTGiveaway #NFTCommunity #nftart #cryptocurrency #NFTGiveaways #opensea #OpenSeaNFT #PolygonNFT https://t.co/POW5d90S0f
# Hashtags Used:['Giveaway', 'ETH']
# Tweet Scraped67:
# Username:SakaSanki
# Description:•| Digital Artist|• $SKL #SKALIENS  #DEXGAME $dxgm $BNB $afen *Meine Tweets sind keine Finanzberatung!*
# Location:
#  Following Count:334
# Follower Count:382
# Total Tweets:4699
# Retweet Count:0
# Tweet Text: When I look at the market ...#Crypto #Bitcoin #ETH #altcoins #NFTCommunity #NFTGiveaways #cryptotrading #Ethereum #EthereumMerge #Coinbase #Binance #bnb #skaliens $skl #BTC https://t.co/n7xKRwzdno
# Hashtags Used:['Crypto', 'Bitcoin', 'ETH', 'altcoins', 'NFTCommunity', 'NFTGiveaways', 'cryptotrading', 'Ethereum', 'EthereumMerge', 'Coinbase', 'Binance', 'bnb', 'skaliens', 'BTC']
# Tweet Scraped68:
# Username:abdullahgulal
# Description:
# Location:
#  Following Count:97
# Follower Count:8
# Total Tweets:2360
# Retweet Count:0
# Tweet Text: @YamacVinu @cz_binance Hello there As an investor, I primarily care about nature-friendly projects. I know you care too. I suggest you review the Vita Inu. * Nature friendly (energy usage per transfer) * No transfer fee * Transfer rate &lt;1second * Smart contract support
#  #BNB #VINU #ETH  #BTC
# Hashtags Used:['BNB', 'VINU', 'ETH', 'BTC']
# Tweet Scraped69:
# Username:Akunterpickaw
# Description:bigwin come true $100 $200 $300 $400 $500 sampai $1000 $2000
# Location:Caratland
#  Following Count:3978
# Follower Count:78
# Total Tweets:19336
# Retweet Count:1574
# Tweet Text: 10$ GIVEAWAY | 4 HRS ☀️
#
# RT + Follow @DeGodsNFTS
#
# #NFTs #nft #NFTGiveaway #Giveaway #NFTCommunity #freemint #ethereum #btc #eth #crypto #cryptocurrency https://t.co/AhhBRE89Xp
# Hashtags Used:['NFTs', 'nft', 'NFTGiveaway', 'Giveaway', 'NFTCommunity', 'freemint', 'ethereum']
# Tweet Scraped70:
# Username:cafunk
# Description:SBL Team @sneakybirdlabs. 3D Animation EP @FuryofTheFurNFT
# “Jobs fill your pocket, but adventures fill your soul.” – Jaime Lyn Beatty
# Location:Menlo Park, CA
#  Following Count:4419
# Follower Count:2261
# Total Tweets:10665
# Retweet Count:2
# Tweet Text: 🚨BEWARE!!🚨
#
# @FuryofTheFurNFT has so much #nftutility, and there is so much more coming!
#
# It is extremely hard not to fall in love with the #NFTCommunity here, and the #nftart is just incredible.
#
# Proceed with caution.. 😎🤘🏼💥
#
# #FOTF4LIFE #NoTedLeftBehind #NFTs #ETH https://t.co/a4SrF2pBQe
# Hashtags Used:['nftutility']
# Tweet Scraped71:
# Username:jaeyunslaylaa
# Description:manifestingbig wins🍀🍀🍀 || 2 accs sus😭😭
# Location:Republic of the Philippines
#  Following Count:3185
# Follower Count:161
# Total Tweets:10443
# Retweet Count:1574
# Tweet Text: 10$ GIVEAWAY | 4 HRS ☀️
#
# RT + Follow @DeGodsNFTS
#
# #NFTs #nft #NFTGiveaway #Giveaway #NFTCommunity #freemint #ethereum #btc #eth #crypto #cryptocurrency https://t.co/AhhBRE89Xp
# Hashtags Used:['NFTs', 'nft', 'NFTGiveaway', 'Giveaway', 'NFTCommunity', 'freemint', 'ethereum']
# Tweet Scraped72:
# Username:sadiyaaax01
# Description:Asthetic   #btc #eth #pickaw #picknava
# Location:India
#  Following Count:956
# Follower Count:43
# Total Tweets:4836
# Retweet Count:10929
# Tweet Text: 💸 $1,000 #Giveaway 💸
#
# We'll select 10 winners randomly and award $100 to each account! 🤑🤑
#
# Rules: 👇
#
# 1️⃣ Tag 2 friends
# 2️⃣ Must Like, Follow &amp; Retweet
#
# Good luck 💚
#
# #BTC #Crypto #Contest #Casino #prize #Competition #ETH #NFT
#
# 🔗 https://t.co/iOPgBrSIiZ https://t.co/DiRKGbV3cW
# Hashtags Used:['Giveaway']
# Tweet Scraped73:
# Username:ritchiesacra
# Description:A sentient being with a camera. Mrs Sacramento's eldest.
#
# Distant relative of the acclaimed photographer Harvey Jones (although he might deny it!)
# Location:UK
#  Following Count:4070
# Follower Count:4252
# Total Tweets:46264
# Retweet Count:3
# Tweet Text: 3 pieces from my ongoing series: 7 days | 7 poems | 7 artworks based on these poems
#
# Days 1, 2, 3 completed (Pablo Neruda, Dante Alighieri, Sylvia Plath)
#
# 4th artwork tonight at 9pm CET
#
# #NFTCommunity #NFTs #digitalart #foundation #poetry #ETH @foundation https://t.co/PsEOyh68Dc
# Hashtags Used:[]
# Tweet Scraped74:
# Username:Emimma2
# Description:💎 Crypto Lover
# 💎 $RBXS Twitter Shiller
# 💎 We shill your Blockchain Projects!
# 💎 Follow @RBXSamurai #RBXSamurai
# Location:
#  Following Count:319
# Follower Count:1265
# Total Tweets:52244
# Retweet Count:1
# Tweet Text: Automate your marketing with RBXS!
#
# https://t.co/CkAoDEym7V
#
# #RBXS #RBXSamurai #Rbx  #crypto #staking #NFT #cryptocurrency  #DeFi #Binance #ETH #Bitcoin #BSC #BTC #1000xgem  #RBXStoken #Crypto https://t.co/YyCtYFJchM
# Hashtags Used:['RBXS', 'RBXSamurai', 'Rbx', 'crypto', 'staking', 'NFT', 'cryptocurrency']
# Tweet Scraped75:
# Username:ninebellNp
# Description:Estudiante de economía, Amante de las cripto y de los NFT....🫦🐾🐾🐾👣
# Location:
#  Following Count:1028
# Follower Count:1003
# Total Tweets:24227
# Retweet Count:32
# Tweet Text: 🎉FREE #NFT GIVEAWAY🎉
#
# To win:
# 1️⃣Follow @ATSIZCIRUH
# 2️⃣ Like &amp; Retweet
# 3️⃣ Drop your #ETH wallet
#
# #nftCommunity #nftcollector #nftartist #nftart #NFTProject #NFTGiveaway #NFTs #NFTdrop #FreeNFT #NFTAirdrop #NFTshill https://t.co/Z6MtJvMarQ
# Hashtags Used:['NFT', 'ETH', 'nftCommunity']
# Tweet Scraped76:
# Username:manishd11757290
# Description:
# Location:
#  Following Count:3
# Follower Count:1
# Total Tweets:265
# Retweet Count:1471
# Tweet Text: We currently have more than 1 million #ETH. If #Ethereum hard fork succeeds, we will donate some  forked #ETHW to #ETHW community and developers to build #ethereum ecosystem. https://t.co/ee4kGSuVoK
# Hashtags Used:['ETH', 'Ethereum', 'ETHW', 'ETHW']
# Tweet Scraped77:
# Username:Tawatchaikhunt3
# Description:
# Location:
#  Following Count:1
# Follower Count:0
# Total Tweets:277
# Retweet Count:1471
# Tweet Text: We currently have more than 1 million #ETH. If #Ethereum hard fork succeeds, we will donate some  forked #ETHW to #ETHW community and developers to build #ethereum ecosystem. https://t.co/ee4kGSuVoK
# Hashtags Used:['ETH', 'Ethereum', 'ETHW', 'ETHW']
# Tweet Scraped78:
# Username:ApeBotENS
# Description:Collection of  tweets about web3 domains.
#
# Retweets #ENSdomain #ENSdomains #NFTdomain #NFTdomains #web3domain #web3domains
#
# Created by
# @domain_monkey
# Location:Metaverse
#  Following Count:1
# Follower Count:933
# Total Tweets:61259
# Retweet Count:1
# Tweet Text: Love to see @10kClubOfficial back over 2E 👀
#
# Numbers are &amp; always have been a universal language &amp; will provide a vital role in future #blockchain identity. 🟪⛓️
#
# s/o @ensvision for streamlining adoption.
#
# #eth $eth #Ethereum #10kclub #ensdomains https://t.co/x9dz0qe7wW
# Hashtags Used:[]
# Tweet Scraped79:
# Username:RafaqatKhatana1
# Description:
# Location:
#  Following Count:4
# Follower Count:0
# Total Tweets:274
# Retweet Count:1471
# Tweet Text: We currently have more than 1 million #ETH. If #Ethereum hard fork succeeds, we will donate some  forked #ETHW to #ETHW community and developers to build #ethereum ecosystem. https://t.co/ee4kGSuVoK
# Hashtags Used:['ETH', 'Ethereum', 'ETHW', 'ETHW']
# Tweet Scraped80:
# Username:oluyinka_t
# Description:A lover of God
# Location:
#  Following Count:4994
# Follower Count:261
# Total Tweets:15560
# Retweet Count:138
# Tweet Text: 🚨FREE #NFT GIVEAWAY 🚨
#
# Worth 0.2 #ETH ($307)
#
# ➡️ Follow Me 🔔
# ➡️ Retweet &amp; ❤️
#
# 24H ⏳
#
# #NFTGiveaway #NFTCommunity https://t.co/Y8SMyHK7hI
# Hashtags Used:['NFT', 'ETH', 'NFTGiveaway', 'NFTCommunity']
# Tweet Scraped81:
# Username:ArsianJr
# Description:
# Location:
#  Following Count:554
# Follower Count:119
# Total Tweets:2530
# Retweet Count:305
# Tweet Text: #ETH or #SOL Winner, 240min 🍀
#
# RT + Follow me (🔔) 🤝
# Hashtags Used:['ETH', 'SOL']
# Tweet Scraped82:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15566
# Total Tweets:337318
# Retweet Count:0
# Tweet Text: #ILVUSDT Bull Alert!
#
# 5X Volume
# Price:      75.8
# 5-min %: 0.53%
# Volume:  $14,617
#
# #crypto #whale #btc #eth #ILV $ILV https://t.co/dwqmX7mF63
# Hashtags Used:['ILVUSDT', 'crypto', 'whale', 'btc', 'eth', 'ILV']
# Tweet Scraped83:
# Username:siopisss61
# Description:
# Location:
#  Following Count:688
# Follower Count:213
# Total Tweets:5439
# Retweet Count:224
# Tweet Text: 📣2 SAATLİK KISA ÇEKİLİŞ 📣
#
# 🎖250 TL🎖
#
# ⚔️Şartlar⚔️
#
# 1️⃣BEĞEN❤️-RT🔁
# 2️⃣@ZigguratDao‘ nun sabit tweetine RT + Like at.🏆Bonus: Şartları yerine getirenler 100 TL daha kazanacak.
#
# #btc #giveaway #eth #luna #binance #nfts #avax #elon #dolar #shib #ape #Metaverse #web3 #bnb #sol
# Hashtags Used:[]
# Tweet Scraped84:
# Username:xdithephladkul1
# Description:
# Location:
#  Following Count:23
# Follower Count:6
# Total Tweets:275
# Retweet Count:1471
# Tweet Text: We currently have more than 1 million #ETH. If #Ethereum hard fork succeeds, we will donate some  forked #ETHW to #ETHW community and developers to build #ethereum ecosystem. https://t.co/ee4kGSuVoK
# Hashtags Used:['ETH', 'Ethereum', 'ETHW', 'ETHW']
# Tweet Scraped85:
# Username:CitilUnal
# Description:FENERBAHÇE 💛💙
# Location:Osmangazi, Bursa-Tokat
#  Following Count:2154
# Follower Count:223
# Total Tweets:8933
# Retweet Count:615
# Tweet Text: GELENEKSEL #USDT ÖDÜLLÜ ÇEKİLİŞİMİZ DEVAM EDİYOR! 📢📢📢
#
# Bu twiti beğenip RT eden takipçilerimden rastgele #TRC20 adresi isteyip #USDT göndereceğim.
# Sonuç saat 23.00’da…
#
# #Bitcoin   #BTC   #ETH
# Hashtags Used:['USDT', 'TRC20']
# Tweet Scraped86:
# Username:jamalur_rashid
# Description:
# Location:
#  Following Count:37
# Follower Count:2
# Total Tweets:275
# Retweet Count:1471
# Tweet Text: We currently have more than 1 million #ETH. If #Ethereum hard fork succeeds, we will donate some  forked #ETHW to #ETHW community and developers to build #ethereum ecosystem. https://t.co/ee4kGSuVoK
# Hashtags Used:['ETH', 'Ethereum', 'ETHW', 'ETHW']
# Tweet Scraped87:
# Username:gosh_rudakov
# Description:A guy who likes to read both pjo and harry potter!Trade link - https://t.co/WoTuG5yZvS…
# Location:sneaker head
#  Following Count:430
# Follower Count:25
# Total Tweets:1096
# Retweet Count:893
# Tweet Text: 🎁#NFTGiveaway🎁
#
# Prizes:
# 🏆0.5 $Sol (20$) 💵
#
# To win :
# 1️⃣ Follow @Nftskullsociety
# 2⃣ ♥️&amp; RT &amp; 2 tag friend
# 3⃣  İnteract with their 📌 tweet
#
# 48hrs ⏰
#
# #NFTCommunity #ETH #SOL #NFTGiveaways #nftart #Solana #SolanaGiveaways #SolanaNFT #NFT https://t.co/X4LYybZuJn
# Hashtags Used:['NFTGiveaway']
# Tweet Scraped88:
# Username:BatraLov
# Description:
# Location:
#  Following Count:112
# Follower Count:57
# Total Tweets:6674
# Retweet Count:13
# Tweet Text: On this first day of #cheemsinu buyback, a total of 20 #BNB    which accounts for $5,517.05, 6.5 #ETH which accounts for $10,081.76 and 250 #Avax    which accounts for $4701.25 which gives us a combined amount of $20,300.06 have been used to #buyback today so far.
# Hashtags Used:['cheemsinu', 'BNB', 'ETH']
# Tweet Scraped89:
# Username:oluyinka_t
# Description:A lover of God
# Location:
#  Following Count:4994
# Follower Count:261
# Total Tweets:15560
# Retweet Count:158
# Tweet Text: 🚨FREE #NFT GIVEAWAY 🚨
#
# Worth 0.25 #ETH ($387)
#
# ➡️ Follow Me 🔔
# ➡️ Retweet &amp; ❤️
#
# 24H ⏳
#
# #NFTGiveaway #NFTCommunity https://t.co/F2m52yjBzZ
# Hashtags Used:['NFT', 'ETH', 'NFTGiveaway', 'NFTCommunity']
# Tweet Scraped90:
# Username:IIID3NT
# Description:THE IDΞNT COLLECTIVE ⚫️⚫️⚫️ #NFT collection by @nonfunjible launching mid-September 2022 with #infosec theme featuring ethical #hacking and password cracking
# Location:
#  Following Count:1216
# Follower Count:204
# Total Tweets:266
# Retweet Count:1
# Tweet Text: What’s the buzz?
#
# New series: Monsters of Fashion
#
# https://t.co/FA9LWb5gdX
#
# #NFTCollection #ETH #nftart #nftcollector #cryptocurrency #NFTCommunity #Ethereum #NFTdrop #NFTs #crypto #NFT https://t.co/ZKSprQHVdv
# Hashtags Used:['NFTCollection', 'ETH', 'nftart', 'nftcollector']
# Tweet Scraped91:
# Username:Ma86789353Malik
# Description:
# Location:उत्तर प्रदेश, भारत
#  Following Count:145
# Follower Count:42
# Total Tweets:253
# Retweet Count:1471
# Tweet Text: We currently have more than 1 million #ETH. If #Ethereum hard fork succeeds, we will donate some  forked #ETHW to #ETHW community and developers to build #ethereum ecosystem. https://t.co/ee4kGSuVoK
# Hashtags Used:['ETH', 'Ethereum', 'ETHW', 'ETHW']
# Tweet Scraped92:
# Username:0xEthereumYoda
# Description:UP or DOWN...
# .
# .
# .
# .
# Price matters NOT.
# Location:
#  Following Count:1
# Follower Count:113
# Total Tweets:51014
# Retweet Count:0
# Tweet Text: #Ethereum price update:
#
# #ETH $1568.18 USD
# #Bitcoin 0.07906763338610626 #BTC
#
# Follow for recent ETH price updates
# #altcoin, #cryptocurrency, #crypto
# Hashtags Used:['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# Tweet Scraped93:
# Username:Iron_Pino
# Description:..^.^.. Master of Coin ..^.^..
# Location:Nederland
#  Following Count:369
# Follower Count:309
# Total Tweets:3638
# Retweet Count:305
# Tweet Text: #ETH or #SOL Winner, 240min 🍀
#
# RT + Follow me (🔔) 🤝
# Hashtags Used:['ETH', 'SOL']
# Tweet Scraped94:
# Username:ayoub_cherke
# Description:
# Location:
#  Following Count:434
# Follower Count:22
# Total Tweets:440
# Retweet Count:397
# Tweet Text: 2x @utilityapeNFT
# 4x @chubbypengs
# 5x @AbstractRealm_
# 5x @cyba_space
#
# To win👇🏻👇🏻
#
# 👉🏾Follow Me 👉🏾@Starbioola and all aforementioned 👆🏽👆🏽 accounts
# 👉🏾Like, RT Tweet and tag 3 friends
#
# Winners in 48 hours  🫡
#  #NFTGiveaways #ETH #SolanaGiveaway https://t.co/nLwNhcyF8d
# Hashtags Used:[]
# Tweet Scraped95:
# Username:cryptonian_god
# Description:
# Location:CHICAGO
#  Following Count:2239
# Follower Count:1168
# Total Tweets:3946
# Retweet Count:96
# Tweet Text: @cz_binance @Crypto__Diva #BTC , #ETH, #BNB &amp; #VOLT sounds like a more reasonable list what do you think? 🤔
#
# 3 blue chips + 1 volted small cap ⚡️
# Hashtags Used:['BTC', 'ETH', 'BNB', 'VOLT']
# Tweet Scraped96:
# Username:Siraphatsornmon
# Description:
# Location:
#  Following Count:3
# Follower Count:0
# Total Tweets:254
# Retweet Count:1471
# Tweet Text: We currently have more than 1 million #ETH. If #Ethereum hard fork succeeds, we will donate some  forked #ETHW to #ETHW community and developers to build #ethereum ecosystem. https://t.co/ee4kGSuVoK
# Hashtags Used:['ETH', 'Ethereum', 'ETHW', 'ETHW']
# Tweet Scraped97:
# Username:Dwoz788
# Description:looking for some perfect things ⚜️⚜️
# BACA #4326
# Location:naple
#  Following Count:333
# Follower Count:79
# Total Tweets:275
# Retweet Count:339
# Tweet Text: 🎉ETH GIVEAWAY🎉
#
# Prizes:
# 🏆0,1 ETH to 1 lucky winner
#
# 1️⃣ Like and Retweet
# 2️⃣ Follow @DegenMintPassn @MagntNFT
# @TattooedEGGs @AVAX_SOLNFT
# 3️⃣ Tag 3 Friends
#
# ⏰48h GL🍀
#
# ...
#
# 2⃣ LIKE + RT
#
# 3⃣TAG 3FRENS
#
# 24⏰
#
# #Giveaway #WLGiveaways #FreeMint #FreeMintNFT
# #ETH #NFT #NFTCommunitys #BITCOIN https://t.co/M5Ong1VmVf
# Hashtags Used:[]
# Tweet Scraped470:
# Username:T3LAPIYA
# Description:━ 18 • #6️⃣5️⃣🎹 | one piece is real ୨୧
# Location:bai jing ting's ♡
#  Following Count:1902
# Follower Count:107
# Total Tweets:9736
# Retweet Count:690
# Tweet Text: $50 - 12 HOURS 💵
#
# RT, like + follow @Crazy8Metasino (🔔) &amp; interact with their pinned 📌
#
# 🎰 CRAZY 8 METASINO 🎰
#
# #SOL/#DUST CASINO LAUNCH #GIVEAWAY!
#
# #NFT #NFTs #Crypto #Solana #ETH #NFTGiveaway #NFTGiveaways #NFTdrop #NFTcontest #Airdrop #crypto #NFTshill  #Web3 #P2E #BTC https://t.co/74m0dXI0Hj
# Hashtags Used:['SOL', 'DUST']
# Tweet Scraped471:
# Username:goodslayerr
# Description:I JUST WANNA PLAY IN FAIR GAMES. #NFTs #SOL #ETH #BNB #BTC
# Location:Blockchain
#  Following Count:2968
# Follower Count:351
# Total Tweets:13675
# Retweet Count:351
# Tweet Text: Prize:   0.3 $SOL ( 9$) ✔️🎁
#
# 1 winner 🏆
#
# To Enter:
# 1️⃣ Follow @CryptoDolars
#
# 2️⃣ Like &amp; RT
#
# 3️⃣ Tag 2 Friends
#
# ⏰24hrs
#
# #SolanaSummer  #web3 #Metaverse #Crypto #Binance     #eth #btc    #avax    #USDT #Tether     #NFTGiveaway  #NFTs #NFTCommunity  #sol  #Giveaway
# Hashtags Used:[]
# Tweet Scraped472:
# Username:Rebeka_Btc
# Description:#bitcoin  ❤ 🇸🇻
# Location:El Salvador
#  Following Count:1178
# Follower Count:480
# Total Tweets:322
# Retweet Count:5
# Tweet Text: Buy and sell #bitcoin #usdt and #eth instantly using Paxful with over 300 payment methods.
#
# Register and get 5$ btc⭐ https://t.co/sptyM4W4yB
#
# #Paxful #payonner #wise #neteller #advcash #webmoney #skrill #astropay #payeer #airtm #gifts #amazon #cards #paypal #free https://t.co/A6Vh5A0HjE
# Hashtags Used:['bitcoin', 'usdt', 'eth']
# Tweet Scraped473:
# Username:0xskylerskye22
# Description:🇵🇭🇵🇭🇵🇭🇵🇭
# #giveaway
#
# 📩DM for promotion | Marketing Admin of
# @KlocNFT | DM for #NFTPromotion #GenSquad
#
# Stake: skylerskye1122
# Location:Philippines
#  Following Count:2461
# Follower Count:286
# Total Tweets:13784
# Retweet Count:158
# Tweet Text: 🚨FREE #NFT GIVEAWAY 🚨
#
# Worth 0.25 #ETH ($387)
#
# ➡️ Follow Me 🔔
# ➡️ Retweet &amp; ❤️
#
# 24H ⏳
#
# #NFTGiveaway #NFTCommunity https://t.co/F2m52yjBzZ
# Hashtags Used:['NFT', 'ETH', 'NFTGiveaway', 'NFTCommunity']
# Tweet Scraped474:
# Username:parabukucu_
# Description:feel free to tag me.
# never lose hope.
# Location:
#  Following Count:4313
# Follower Count:178
# Total Tweets:22597
# Retweet Count:111
# Tweet Text: Paylaştığım son 5 gönderiye etkileşim veren takipçilerim arasından 1 kişiden iban isteyeceğim. 🔔
#
# #Bitcoin #btc #Ethereum #eth
# Hashtags Used:['Bitcoin', 'btc', 'Ethereum']
# Tweet Scraped475:
# Username:MikLO_11
# Description:#Koa #Cro #hbar #xrp #ADA #xlm #koacombat 💪💪💪#polygon #matic #eth #NFT #tectonic #cronos #tonic #grovetoken #cronoschain 💥💥💥 #Crypto ⚡#Bitcoin 📈#BTC
# Location:Moon
#  Following Count:2130
# Follower Count:267
# Total Tweets:3967
# Retweet Count:0
# Tweet Text: @Crypto__emily 🚨💎@KoaCombat💎🚨@CryptoGuyBCH 🚨@BarbaraInu1 @TattoodYoda1 #KOACOMBAT🚨#KOA 🚨#altcoins #altcoin  #cro  #crypto #eth #DeFi #cryptocurrency #Gems
# #BNB  #Cro  #1000xgem #xrp #ADA #xlm #koacombat 💪💪#polygon #eth #cronos  #cronoschain #500xgem ⚡#Bitcoin
#  https://t.co/P6KWhOGxXF
# Hashtags Used:['KOACOMBAT', 'KOA', 'altcoins', 'altcoin', 'cro', 'crypto', 'eth', 'DeFi', 'cryptocurrency', 'Gems', 'BNB', 'Cro', '1000xgem', 'xrp', 'ADA', 'xlm', 'koacombat', 'polygon', 'eth', 'cronos', 'cronoschain', '500xgem', 'Bitcoin']
# Tweet Scraped476:
# Username:DilipKu31900417
# Description:
# Location:
#  Following Count:226
# Follower Count:109
# Total Tweets:498
# Retweet Count:13
# Tweet Text: Well The ADS Coin is going to rule the millions/billions of hearts by the Septmber only. World community is looking eagerly for ADS Coin, to be proud part of 5M+ Community &amp; 9DIGITAL PATFORMS within the norms of Govt of India. . #BTC #BNB #WRX #ETH #PMOIndia #RBI https://t.co/bC4Q37GRAI
# Hashtags Used:[]
# Tweet Scraped477:
# Username:MandyYiu2
# Description:$HBAR Lover
# Hedera NFT Enthusiast
# https://t.co/UVgGAaKykc…
# https://t.co/7plQgZAM3G
# Location:
#  Following Count:767
# Follower Count:264
# Total Tweets:1894
# Retweet Count:116
# Tweet Text: GIVEAWAY ALERT! 💰
# Giving away 1000 $META &amp; 1000 $COSMIC cause we are feeling so good tonight! 🥰
#
# -Follow @c0smicimmigrant &amp; @METAVISIONx
# - Join Discord, link in bio
# - Like and RT this post
# - Tag friends
#
# #HBAR #HBARNFT #HederaNFT #Hedera #Hbarbarian #nft #eth #NFTGiveaways https://t.co/qZ1pK3XvKA
# Hashtags Used:[]
# Tweet Scraped478:
# Username:airdrophayri
# Description:
# Location:
#  Following Count:289
# Follower Count:55
# Total Tweets:2477
# Retweet Count:83
# Tweet Text: 🎁ÇEKİLİŞ🎁
#
# 🏆2 KİŞİYE 30$ TOPLAMDA 60$ (1080 TL) 💸 HEDİYE🎗
#
# 1⃣yotube kanalına ABONE OLUN👇
#
# https://t.co/NWZsfrJZBj
#
# Ve youtube videosuna LİKE❤ YORUM Yapın👇
#
# https://t.co/QA7fMy5aF6
#
# Bu twite RT, FAV❤ATIN
#
# SÜRE:48H
# #btc    #bitcoin    #NFTGiveaway #ETH #shiba #Sol
# Hashtags Used:[]
# Tweet Scraped479:
# Username:KyleNowak20
# Description:#Cheese
# Location:McFarland, WI
#  Following Count:1305
# Follower Count:1000
# Total Tweets:2363
# Retweet Count:32
# Tweet Text: Im feeling generous tonight @fatratmafia community been lit gained a lot of new friends I wanna give back to the community giving away a #FatRatMafia and 2 @boogerzwtf !!! Both dope and ones a low key gem check it out ! LIKE ! RT !TAG 3 DEGENS !!! #NFT #NFTGiveaways #eth #NFTs https://t.co/ed9KfXh3uD
# Hashtags Used:[]
# Tweet Scraped480:
# Username:Sebasti68029035
# Description:💗Lines Geek/\| NFT Enthusiast
# Location:
#  Following Count:0
# Follower Count:47
# Total Tweets:21
# Retweet Count:0
# Tweet Text: #CELRUSDT Bull Alert!5X VolumePrice:      0.017735-min %: 0.056%Volume:  $18,660 #crypto #whale #btc #eth #CELR…
# Hashtags Used:['CELRUSDT', 'crypto', 'whale', 'btc', 'eth', 'CELR']
# Tweet Scraped481:
# Username:Danni_Twit
# Description:18+ | Dev @TwitterDev | Manager @Blazemist_ | @Minecraft Realms Contributor @Mojang | Verified @NameMC_com | Admin @GatorCraftNtwrk |
#
# My Vouches: #DanniLegit
# Location:Denmark
#  Following Count:1935
# Follower Count:362
# Total Tweets:6754
# Retweet Count:158
# Tweet Text: 🚨FREE #NFT GIVEAWAY 🚨
#
# Worth 0.25 #ETH ($387)
#
# ➡️ Follow Me 🔔
# ➡️ Retweet &amp; ❤️
#
# 24H ⏳
#
# #NFTGiveaway #NFTCommunity https://t.co/F2m52yjBzZ
# Hashtags Used:['NFT', 'ETH', 'NFTGiveaway', 'NFTCommunity']
# Tweet Scraped482:
# Username:RUDIBLACKER
# Description:
# Location:
#  Following Count:132
# Follower Count:13
# Total Tweets:544
# Retweet Count:108
# Tweet Text: 🎁Hey, 50 $ETH will sent to your Wallet to 1000 Participants 🎁
#
# A person who retweets, follows me and retweets will receive 50 #ETH ( $80,000 ) (yes, for real)
#
# +retweet pinned
# Drop your wallet address https://t.co/juOVIpP2OV
# Hashtags Used:[]
# Tweet Scraped483:
# Username:OUEDRAO83666879
# Description:STUDENT
# Location:BURKINA FASO
#  Following Count:73
# Follower Count:10
# Total Tweets:72
# Retweet Count:96
# Tweet Text: Stay tuned with Us. as We are preparing launch the Main Net.
# #Core #btc #eth #crypto #coreDAO #DeFi #NTF #Tether #Cryptocurrency https://t.co/l0xhRKiamY
# Hashtags Used:['Core', 'btc', 'eth', 'crypto', 'coreDAO', 'DeFi', 'NTF', 'Tether']
# Tweet Scraped484:
# Username:abnormal_crypto
# Description:Get alerted on abnormal volume moves in the crypto market. Move ahead of other traders when crypto whales make big moves. Data from Binance.
# Location:
#  Following Count:0
# Follower Count:15566
# Total Tweets:337318
# Retweet Count:0
# Tweet Text: #SRMUSDT Bull Alert!
#
# 5X Volume
# Price:      0.826
# 5-min %: 0.24%
# Volume:  $34,089
#
# #crypto #whale #btc #eth #SRM $SRM https://t.co/RzaYtKZbSR
# Hashtags Used:['SRMUSDT', 'crypto', 'whale', 'btc', 'eth', 'SRM']
# Tweet Scraped485:
# Username:MikLO_11
# Description:#Koa #Cro #hbar #xrp #ADA #xlm #koacombat 💪💪💪#polygon #matic #eth #NFT #tectonic #cronos #tonic #grovetoken #cronoschain 💥💥💥 #Crypto ⚡#Bitcoin 📈#BTC
# Location:Moon
#  Following Count:2130
# Follower Count:267
# Total Tweets:3967
# Retweet Count:0
# Tweet Text: @prudensfx 🚨💎@KoaCombat💎🚨@CryptoGuyBCH 🚨@BarbaraInu1 @TattoodYoda1 #KOACOMBAT🚨#KOA 🚨#altcoins #altcoin  #cro  #crypto #eth #DeFi #cryptocurrency #Gems
# #BNB  #Cro  #1000xgem #xrp #ADA #xlm #koacombat 💪💪#polygon #eth #cronos  #cronoschain #500xgem ⚡#Bitcoin
#  https://t.co/P6KWhOGxXF
# Hashtags Used:['KOACOMBAT', 'KOA', 'altcoins', 'altcoin', 'cro', 'crypto', 'eth', 'DeFi', 'cryptocurrency', 'Gems', 'BNB', 'Cro', '1000xgem', 'xrp', 'ADA', 'xlm', 'koacombat', 'polygon', 'eth', 'cronos', 'cronoschain', '500xgem', 'Bitcoin']
# Tweet Scraped486:
# Username:XavierHounnou
# Description:je suis un homme simple timide et unpeu bavard, j'aime la musique le sport et les jeux vidéos
# Location:République du Bénin
#  Following Count:738
# Follower Count:150
# Total Tweets:12607
# Retweet Count:11
# Tweet Text: 8️⃣/🔟 #Giveaways #WHEX
#
# 280B | 10 #Followers | 1 #Day
#
# ➡️ RT &amp; Follow Me
#
# #BTC #BNB #CRO #TRX #AVAX #BUSD #USDD #USDTether #ETH #Airdrop #Solana #Crypto #Airdrops #CryptoNews #cryptocurrency #Cryptoreview #cryptocurrencies
#
# @rocketbotpro GW 280,000,000,000.00 WHEX 10 1D @0xMerry https://t.co/jhhrAsv5TF
# Hashtags Used:['Giveaways', 'WHEX', 'Followers', 'Day', 'BTC', 'BNB', 'CRO', 'TRX', 'AVAX', 'BUSD', 'USDD', 'USDTether']
# Tweet Scraped487:
# Username:Papatyaabla
# Description:İnstagram :📸 PapatyaAblaniz
# 🦂 Scorpion ☕🍫
# Location:Türkiye
#  Following Count:8884
# Follower Count:8492
# Total Tweets:16695
# Retweet Count:158
# Tweet Text: 🚨FREE #NFT GIVEAWAY 🚨
#
# Worth 0.25 #ETH ($387)
#
# ➡️ Follow Me 🔔
# ➡️ Retweet &amp; ❤️
#
# 24H ⏳
#
# #NFTGiveaway #NFTCommunity https://t.co/F2m52yjBzZ
# Hashtags Used:['NFT', 'ETH', 'NFTGiveaway', 'NFTCommunity']
# Tweet Scraped488:
# Username:Lord_Defi22
# Description:#Defi lover, crypto hodler.
# Location:
#  Following Count:5
# Follower Count:106
# Total Tweets:37231
# Retweet Count:0
# Tweet Text: updated price for $ADA, $BNB, $ETC:
#
# #ADA $0.5038 USD
# #BNB 0.014068 #BTC
# #ETC 0.02056 #ETH
#
# I tweet updated prices, follow me to get recent updates.
#
# #cryptocurrency #crypto
# Hashtags Used:['ADA', 'BNB', 'BTC', 'ETC', 'ETH', 'cryptocurrency', 'crypto']
# Tweet Scraped489:
# Username:0xchitalovelyy
# Description:#WAYV #NCT my old acc was suspended😭
# Location:
#  Following Count:3372
# Follower Count:62
# Total Tweets:11021
# Retweet Count:3393
# #NFTGiveaways  #NFT #NFTCommunity #NFTs #Giveaway #ETH #SOL https://t.co/YE0hokeB7rEgiKQ18
# Hashtags Used:[]
# Tweet Scraped490:
# Username:Salihktem2
# Description:Crypto will take over fiat #SaitaRealty #Saitama 🐺🏠🔥🐺🔥🏠
# Location:Sverige
#  Following Count:125
# Follower Count:1157
# Total Tweets:32869
# Retweet Count:0
# Tweet Text: @Mullallymusic #Defi
# #saitama 🐺
# #Bitcoin
# #Etherium
# #eth
# #cryptos
# #NFTs
# #crypto 🔐
# #CryptoNews 📰🗞
# #Saitapro 🐺✅🔥
# #cryprocurrency📈
# #SaitaRealty  🐺🏠
# Hashtags Used:['Defi', 'saitama', 'Bitcoin', 'Etherium', 'eth', 'cryptos', 'NFTs', 'crypto', 'CryptoNews', 'Saitapro', 'cryprocurrency', 'SaitaRealty']
# Tweet Scraped491:
# Username:MikLO_11
# Description:#Koa #Cro #hbar #xrp #ADA #xlm #koacombat 💪💪💪#polygon #matic #eth #NFT #tectonic #cronos #tonic #grovetoken #cronoschain 💥💥💥 #Crypto ⚡#Bitcoin 📈#BTC
# Location:Moon
#  Following Count:2130
# Follower Count:267
# Total Tweets:3967
# Retweet Count:0
# Tweet Text: @WhalesMetaverse 🚨💎@KoaCombat💎🚨@CryptoGuyBCH 🚨@BarbaraInu1 @TattoodYoda1 #KOACOMBAT🚨#KOA 🚨#altcoins #altcoin  #cro  #crypto #eth #DeFi #cryptocurrency #Gems
# #BNB  #Cro  #1000xgem #xrp #ADA #xlm #koacombat 💪💪#polygon #eth #cronos  #cronoschain #500xgem ⚡#Bitcoin
#  https://t.co/P6KWhOGxXF
# Hashtags Used:['KOACOMBAT', 'KOA', 'altcoins', 'altcoin', 'cro', 'crypto', 'eth', 'DeFi', 'cryptocurrency', 'Gems', 'BNB', 'Cro', '1000xgem', 'xrp', 'ADA', 'xlm', 'koacombat', 'polygon', 'eth', 'cronos', 'cronoschain', '500xgem', 'Bitcoin']
# Tweet Scraped492:
# Username:BABAYAGAtqrz
# Description:
# Location:
#  Following Count:110
# Follower Count:57
# Total Tweets:595
# Retweet Count:330
# Tweet Text: $12000 in #ETH ( 4 WİNNERS )
#
#         RT • Follow • Like
# Hashtags Used:['ETH']
# Tweet Scraped493:
# Username:dark_dracool
# Description:Feel Like a Pro My Bro
# #dracoolegit
# #Helpdracool
# Location:Giveaway won: 24
#  Following Count:2409
# Follower Count:1284
# Total Tweets:7949
# Retweet Count:138
# Tweet Text: 🚨FREE #NFT GIVEAWAY 🚨
#
# Worth 0.2 #ETH ($307)
#
# ➡️ Follow Me 🔔
# ➡️ Retweet &amp; ❤️
#
# 24H ⏳
#
# #NFTGiveaway #NFTCommunity https://t.co/Y8SMyHK7hI
# Hashtags Used:['NFT', 'ETH', 'NFTGiveaway', 'NFTCommunity']
# Tweet Scraped494:
# Username:EnginAktepe6
# Description:Engin
# Location:İzmir, Türkiye
#  Following Count:924
# Follower Count:89
# Total Tweets:296
# Retweet Count:290
# Tweet Text: 🎁 ÇEKİLİŞ 🎁
#
# 🏆1 KİŞİYE 10$ (180 TL) 💸  HEDİYE 🎗
#
# Yapmanız gerekenler 👇
#
# 1⃣ @TraderEda TAKİP EDİN 🎗
#
# Bu twite RT, FAV❤ ATIN
#
# SÜRE: 12H
#
# #btc #bitcoin #NFTGiveaway #ETH #shiba #Solana #sol #nfts
# Hashtags Used:[]
# Tweet Scraped495:
# Username:DerekTMcKinney
# Description:Developer of things. Love tech. Maybe check out https://t.co/3SPykPkLI1. Creator of the Told Podcast. https://t.co/jxzNnOaPFT
# Location:Here and Now
#  Following Count:691
# Follower Count:10423
# Total Tweets:310749
# Retweet Count:0
# Tweet Text: 🤓🤔👍 #knownews ##blockchain ##cryptocurrency #bitcoin #eth XRP: Whether or not you should consider buying at this  https://t.co/JvZwWLJhRo
# Hashtags Used:['knownews', 'blockchain', 'cryptocurrency', 'bitcoin', 'eth']
# Tweet Scraped496:
# Username:YukisPyramids
# Description:Artist/Creator/My 1st collection, 1/1 Lucid Pyramid NFTs, digitaly designed art pieces, each with its own feeling which you determine as it's yours to own.
# Location:Visual Alchemist 👁
#  Following Count:431
# Follower Count:423
# Total Tweets:483
# Retweet Count:1
# Tweet Text: @NFTKingForever Lucid Pyramid
# Animated Reboots 👀
# Will be live on #opensea tomorrow
# All with unlockable content ✨️
#
# #NFTs #nftart #nftcollectors #digitalart #cryptoart #ETH #NFTdrop https://t.co/dfvIGBGPTa
# Hashtags Used:['opensea', 'NFTs', 'nftart', 'nftcollectors', 'digitalart', 'cryptoart', 'ETH', 'NFTdrop']
# Tweet Scraped497:
# Username:Silanizwq0
# Description:
# Location:
#  Following Count:1
# Follower Count:9
# Total Tweets:3101
# Retweet Count:20
# Tweet Text: Büyük bir hediye gelecek aranızdan bir takipçime kripto paralara gönül vermiş bildirimleri açık kimler var?
#
# #btc #eth #kriptopara
# Hashtags Used:['btc', 'eth']
# Tweet Scraped498:
# Username:MissFortuna11
# Description:Akun yang ke suspen @missfortuna1801, sedih harus mulai dari awal lagi.
# please follback ya.🙏🙏🙏
# Location:
#  Following Count:1208
# Follower Count:45
# Total Tweets:4301
# Retweet Count:8609
# Tweet Text: 🙌To Merge! To airdrop!
# 📖Did you mint "Proof of Stake" by @VitalikButerin ?
#
# 💰0.3 #ETH Airdrop to 3 Lucky guys who:
# 📌Follow @bib_exchange
# 📌RT and tag 3 friends.
# 📌Post a pic of ETH holding.
# ⏰Ended in Sept 5, 2022
# #Airdrops #Giveaways https://t.co/JX9sU14tls
# Hashtags Used:['ETH']
# Tweet Scraped499:
# Username:MikLO_11
# Description:#Koa #Cro #hbar #xrp #ADA #xlm #koacombat 💪💪💪#polygon #matic #eth #NFT #tectonic #cronos #tonic #grovetoken #cronoschain 💥💥💥 #Crypto ⚡#Bitcoin 📈#BTC
# Location:Moon
#  Following Count:2130
# Follower Count:267
# Total Tweets:3967
# Retweet Count:0
# Tweet Text: @cyber_bull_ 🚨💎@KoaCombat💎🚨@CryptoGuyBCH 🚨@BarbaraInu1 @TattoodYoda1 #KOACOMBAT🚨#KOA 🚨#altcoins #altcoin  #cro  #crypto #eth #DeFi #cryptocurrency #Gems
# #BNB  #Cro  #1000xgem #xrp #ADA #xlm #koacombat 💪💪#polygon #eth #cronos  #cronoschain #500xgem ⚡#Bitcoin
#  https://t.co/P6KWhOGxXF
# Hashtags Used:['KOACOMBAT', 'KOA', 'altcoins', 'altcoin', 'cro', 'crypto', 'eth', 'DeFi', 'cryptocurrency', 'Gems', 'BNB', 'Cro', '1000xgem', 'xrp', 'ADA', 'xlm', 'koacombat', 'polygon', 'eth', 'cronos', 'cronoschain', '500xgem', 'Bitcoin']
# Tweet Scraped500:
# Username:coaster89
# Description:Psychedelic Abstraction Artist 👽
# Art Collector 🎨
# BTC / NFT Enthusiast 🟧⛓
#
# @CyberKongz OG 🦍
# @DrCool_OG_Kong 🌈
#
# 4D / 5D #ens //
#
# Opinions are my own. NFA.
# Location:
#  Following Count:2566
# Follower Count:1726
# Total Tweets:2719
# Retweet Count:1
# Tweet Text: Love to see @10kClubOfficial back over 2E 👀
#
# Numbers are &amp; always have been a universal language &amp; will provide a vital role in future #blockchain identity. 🟪⛓️
#
# s/o @ensvision for streamlining adoption.
#
# #eth $eth #Ethereum #10kclub #ensdomains https://t.co/x9dz0qe7wW
# Hashtags Used:['blockchain', 'eth', 'Ethereum', '10kclub', 'ensdomains']
# scraping has completed! :)

# %%
# Choose File Through Widget Experience | /Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/final-project-scraped_data-#ETH.json
###########################################################################################################################

# get home dir of user
home = str(Path.home()) 

# initialize a dict for the excel file; this removes the need to set global values
dict_file = {}

# change to simply `home` if you want users to navigate through diff dirs
#fc = FileChooser(f'{home}/excel')
fc = FileChooser(f'{home}/') 

# same here
#fc.sandbox_path = f'{home}/excel'
fc.sandbox_path = f'{home}/'

# limit file extensions to '.xls, .xlsb, .xlsm, .xlsx'
fc.filter_pattern = ['*.json*']
fc.title = '<b>Select your file</b>'
display(fc)

# create empty dropdown for sheet names
dropdown = widgets.Dropdown(options=[''], value='', description='Sheets:', disabled=False)

# create output frame for the df
out = widgets.Output(layout=widgets.Layout(display='flex', flex_flow='column', align_items='flex-start', width='100%'))
# Out:
# FileChooser(path='/Users/pergolicious', filename='', title='<b>Select your file</b>', show_hidden=False, selec…

# %%
# Convert JSON Data to Data Frame
###########################################################################################################################

ETHjsondata = f'{fc.selected_path}/{fc.selected_filename}'
print(ETHjsondata)

ETHdf = pd.read_json(ETHjsondata)

ETHdf.reset_index(drop=True, inplace=True)

ETHdf.info()
# Out:
# /Users/pergolicious/Library/CloudStorage/OneDrive-SyracuseUniversity/Syracuse University/Courses/IST 652/Final Project/final-project-scraped_data-#ETH.json
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tweet Scraped    500 non-null    int64
#  1   Username         500 non-null    object
#  2   Description      500 non-null    object
#  3   Location         500 non-null    object
#  4   Following Count  500 non-null    int64
#  5   Follower Count   500 non-null    int64
#  6   Total Tweets     500 non-null    int64
#  7   Retweet Count    500 non-null    int64
#  8   Tweet Text       500 non-null    object
#  9   Hashtags Used    500 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 39.2+ KB

# %%
# Combine #BTC and #ETH Data Frames
###########################################################################################################################

df = pd.concat([BTCdf,ETHdf])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tweet Scraped    1000 non-null   int64
#  1   Username         1000 non-null   object
#  2   Description      1000 non-null   object
#  3   Location         1000 non-null   object
#  4   Following Count  1000 non-null   int64
#  5   Follower Count   1000 non-null   int64
#  6   Total Tweets     1000 non-null   int64
#  7   Retweet Count    1000 non-null   int64
#  8   Tweet Text       1000 non-null   object
#  9   Hashtags Used    1000 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 85.9+ KB

# %%
# Preview Data
###########################################################################################################################

df.head()
# Out:
#    Tweet Scraped         Username  \
# 0              1   0xEthereumYoda
# 1              2   cryptonian_god
# 2              3  ValerieAcheson2
# 3              4    DailyCrypto_t
# 4              5  Bharats14669137
#
#                                          Description             Location  \
# 0      UP or DOWN...\n.\n.\n.\n.\nPrice matters NOT.
# 1                                                                 CHICAGO
# 2  Crypto Alerted Our Tweets are not Financial Ad...  Mulanay, Calabarzon
# 3                         Latest Cryptocurrency News
# 4  #BSCMathematics\n#BSTC\nबस छोटी सी ख्वाहिश है ...            Sujangarh
#
#    Following Count  Follower Count  Total Tweets  Retweet Count  \
# 0                1             113         51013              0
# 1             2239            1168          3946             93
# 2               97              10            13              2
# 3             1204            4208         16682              0
# 4              439             196          3994              0
#
#                                           Tweet Text  \
# 0  #Ethereum price update: \n\n#ETH $1568.18 USD\...
# 1  @cz_binance @Crypto__Diva #BTC , #ETH, #BNB &a...
# 2  updated price for $EOS, $ETH, $ETC:\n\n#EOS $1...
# 3  Bitcoin Mining Can Revolutionize Energy Indust...
# 4  @dpradhanbjp @dpradhanbjp\n जी देश भर के 1.3 क...
#
#                                        Hashtags Used
# 0  [Ethereum, ETH, Bitcoin, BTC, altcoin, cryptoc...
# 1                              [BTC, ETH, BNB, VOLT]
# 2                          [EOS, ETH, BTC, ETC, ETH]
# 3  [Bitcoin, Ethereum, BTC, ETH, Crypto, CryptoNews]
# 4                       [DELED, BSTC, ETT, JBT, BTC]

# %% [markdown]
# ## Explore Data Questions

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### What are the Twitter Summary Statistics of the Sampled Users?

# %%
# Question 1 | What are the twitter summary statistics of the sampled users?
###########################################################################################################################

df.describe()
# Out:
#        Tweet Scraped  Following Count  Follower Count  Total Tweets  \
# count    1000.000000      1000.000000     1000.000000  1.000000e+03
# mean      250.500000      1486.602000     3202.503000  2.962066e+04
# std       144.409501      6585.345691    17618.447824  1.122321e+05
# min         1.000000         0.000000        0.000000  3.000000e+00
# 25%       125.750000        70.000000       45.000000  6.000000e+02
# 50%       250.500000       335.000000      127.500000  3.967000e+03
# 75%       375.250000      1246.250000      496.000000  1.807100e+04
# max       500.000000    156639.000000   224852.000000  2.630360e+06
#
#        Retweet Count
# count     1000.00000
# mean       455.14700
# std       1578.24673
# min          0.00000
# 25%          0.00000
# 50%         25.50000
# 75%        133.00000
# max      10930.00000

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### Who is the Most Followed Account from the Tweet Sample?

# %%
# Question 2 | Who is the most followed sampled account?
###########################################################################################################################

sorteddf = df.sort_values(by = ['Follower Count'], ascending = False)

MostFollowed_Username = sorteddf['Username'].iloc[0]
MostFollowed_FollowerCount = sorteddf['Follower Count'].iloc[0]

print(f'Most Followed Account | Username: {MostFollowed_Username}, Follower Count: {MostFollowed_FollowerCount}')
# Out:
# Most Followed Account | Username: picvsco, Follower Count: 224852

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### Which Locations are the Users Tweeting From?

# %%
# Question 3 | Which locations are the users tweeting from (via Twitter)?
###########################################################################################################################

df_loc = df.groupby('Location').groups
df_loc_lst = []

for loc in df_loc:
    print(loc)
    df_loc_lst.append(loc)
    
len(df_loc_lst)
# Out:
#  yatırım tavsiyesi değildir!
# #bylabil for proof
# 'ham, Oxfordshire
# 11:11 ᛋ
# 17
# 22
# 37
# 3753 Cruithne (orbital)
# 40 Bartlett Street, GC61 C50
# AWS eu-west-1a Ireland Region
# Adana, Türkiye
# America
# Amersfoort, Nederland
# Angola
# Ankara, Türkiye
# Antalya, Türkiye
# Anywhere peaceful
# Artist & Collector
# Atualizado a cada 1 hora
# Australia
# Aydın, Türkiye
# BROOKLYN NY 2 wherever I roam.
# BURKINA FASO
# Baguio City, Cordillera Admin
# Baltimore, MD
# Bangladesh
# Barcelona, España
# Barquisimeto-Venezuela
# Bhubaneshwar, India
# Bigwin
# Bitcoin
# BlockChain
# Blockchain
# Bogor, Jawa Barat
# Boulder, Colorado
# Bronx, NY
# Bulgaria
# Bursa, Türkiye
# CHICAGO
# Calgary, Alberta
# Canada
# Caratland
# Caratland🎠 • Exoplanet🪐
# Cardano Blockchain
# Chottogram.
# Ciledug, Indonesia
# CityDAO
# Colombo
# Columbus, OH
# Cuba
# Cyprus
# DKI Jakarta, Indonesia
# Delhi
# Delhi, India
# Denizli, Türkiye
# Denmark
# Deutschland
# Dhaka, Bangladesh
# Didsbury, Manchester
# Diyarbakır
# Diyarbakır, Türkiye
# Dm me for Business Inquiries
# Dubai, United Arab Emirates
# East, England
# Edinburgh, UK
# El Salvador
# England, United Kingdom
# Envigado, Colombia
# Eskişehir, Türkiye
# Ethereum
# Ferrara, Emilia Romagna
# France
# Gaziantep, Türkiye
# Gironde, Aquitaine
# Giveaway won: 24
# Global
# Hawai`i
# Hawaii, USA
# Here and Now
# Ho Chi Minh, Vietnam
# Honolulu, HI
# Houston, TX
# In the Blockchain
# India
# Iraq
# Islamabad, Pakistan
# Japan
# Jawa Tengah, Indonesia
# KMJ ♡
# Kampala - Uganda
# Kendari, Indonesia
# Kolomna, Russia
# Kota Medan, Sumatera Utara
# Kuwait
# Kuwait
# Lagos, Nigeria
# London, England
# Long Beach, CA
# Los Angeles, CA
# MOon
# Maclaren’s Pub
# Malaysia
# Manchester
# Manchester, England
# Mars
# Marseille, France
# Matrix
# McFarland, WI
# Menlo Park, CA
# Mersin, Türkiye
# MetaIsland
# Metaverse
# Metaverse
# Miami
# Mino
# Monagas - Venezuela
# Moon
# Mulanay, Calabarzon
# Multiverse
# Nakuru, Kenya
# Nederland
# New York, NY
# New York, USA
# Newcastle, New South Wales
# Nigeria
# Orlando, FL
# Osmangazi, Bursa-Tokat
# Ottawa, Ontario
# Paris
# Philippines
# Polska
# Polygon
# Poznan
# Republic of the Philippines
# Riau, Indonesia
# Rio de Janeiro, Brazil
# Riyadh
# Round Rock, TX
# Ruda Śląska, Polska
# République du Bénin
# SHEEBAVERSE
# Sacramento, CA
# Sakarya, Türkiye
# Samsun, Türkiye
# San Francisco, CA
# Santiago, Chile
# Serdivan, Sakarya
# Silver Spring, MD
# Singapore
# South Africa🇿🇦Secunda
# South Banana Stand
# Southlake, TX
# State of Iowa
# Submit Your NFT Collection
# Sujangarh
# Sumbawa
# Sverige
# Sydney
# Tanıtım için DM
# Texas, USA
# The Chromatic Ribbon
# The Future
# The Hague, The Netherlands
# Tokyo
# Trabzon, Türkiye
# Trabzon\Akcaabat
# TradingView
# Turkey
# TÜRKİYE
# Türkiye
# UK
# US
# USA
# Unilag
# United States
# Venezuela
# Visual Alchemist 👁
# Volt Island, Meta
# Voltiland
# Wan
# Warrington, England
# Washington
# Washington, DC
# Web 3
# Worldwide
# Yalova, Türkiye
# You send a link  i block you.
# Zombie Hideout
# bai jing ting's ♡
# china
# deXit community
# ferraz
# florida
# help me, I'm broke
# https://www.illuvium.io/
# izmir
# kwangya
# localhost
# love
# metaverse
# more wins to come 🌼
# naple
# run, yeah you gotta run, (+63)
# server
# sneaker head
# somerset, England
# turuglobal.com
# valencia
# Österreich
# Özgür Cheff
# İstanbul
# İstanbul, Türkiye
# İzmir
# İzmir, Türkiye
# Беларусь
# المملكة العربية السعودية
# جدة, المملكة العربية السعودية
# دولة الكويت
# उत्तर प्रदेश, भारत
# नई दिल्ली इंडिया
# ₿itcoin
# ◻️🔗◻️🔗◻️🔗◻️🔗◻️🔗◻️🔗◻️🔗◻️
# 東京都
# 대한민국 종로구
# 🇬🇧
# 🇮🇩
# 🇮🇩 s/her, 22
# 🇷🇺
# 🌎
# 230

# %% [markdown]
# ### Question 4

# %% [markdown]
# #### What Percentage of the Sampled Tweets Contain the Terms 'Giveaway', 'Contest', or 'Prize'?

# %%
# Question 4 | What Percentage of the Sampled Tweets Contain the Terms 'Giveaway', 'Contest', or 'Prize'?
###########################################################################################################################

df_text = df.groupby('Tweet Text').groups
df_text

lst = []

for txt in df_text:
    lst.append(txt)
    


searchterms = ['giveaway','contest','prize']
#pd.value_counts(np.array(lst))
giveawaycount = round((sum(len(re.findall(r'(giveaway) | (contest) | (prize)', x.lower())) for x in lst)/(len(lst)))*100)

print(f'"{searchterms}" was mentioned in {giveawaycount}% of the tweets captured in the sample.')
# Out:
# "['giveaway', 'contest', 'prize']" was mentioned in 20% of the tweets captured in the sample.

# %% [markdown]
# ### Question 5

# %% [markdown]
# #### What is the average Polarity and Subjectivity of the Tweet Sample?

# %%
# Question 5 | What is the average Polarity and Subjectivity of the Tweet Sample?
###########################################################################################################################

pol = lambda tweet: TextBlob(tweet).sentiment.polarity
sub = lambda tweet: TextBlob(tweet). sentiment.subjectivity

df['Polarity'] = df['Tweet Text'].apply(pol)
df['Subjectivity'] = df['Tweet Text'].apply(sub)

PolMean = np.mean(df['Polarity'])
print(f'Average Polarity Score: {PolMean}')
print('----------------------------------')
SubMean = np.mean(df['Subjectivity'])
print(f'Average Subjectivity Score: {SubMean}')
# Out:
# Average Polarity Score: 0.0833704375225469
# ----------------------------------
# Average Subjectivity Score: 0.21137566322566323
